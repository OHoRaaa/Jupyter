# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
# 다나와 사이트에서 원하는 조건의 상품 조회

# %%
import requests
from bs4 import BeautifulSoup 
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
url = "http://search.danawa.com/dsearch.php?query=\
'무선청소기'&tab=main"

# %%
driver.get(url)

# %%
html = driver.page_source
html
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko" class=" js no-touch"><head>\n<title>\'무선청소기\' : 다나와 통합검색</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="title" content="\'무선청소기\' 통합검색 : 다나와 통합검색">\n<meta name="description" content="\'\'무선청소기\'\'의 다나와 통합검색 결과입니다.">\n<meta name="keywords" content="\'무선청소기\', 다나와, 최저가, 가격비교, 검색, 통합검색, 상품 추천, 가격비교사이트, 가격비교 사이트, 가격비교 싸이트, 가격 검색, 추천, 인터넷쇼핑, 온라인쇼핑, 쇼핑, 쇼핑몰, 싸게 파는 곳, 지식쇼핑">\n<meta property="og:title" content="\'무선청소기\' 통합검색 : 다나와 통합검색">\n<meta property="og:description" content="\'\'무선청소기\'\'의 다나와 통합검색 결과입니다.">\n<meta property="og:image" content="http://img.danawa.com/new/tour/img/logo/sns_danawa.jpg">\n<meta content="width=1280" name="viewport">\n<link rel="shortcut icon" href="//img.danawa.com/new/danawa_main/v1/img/danawa_favicon.ico">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/css/common.css?v=2202221040">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/css/navigation.css?v=2202221040">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/wish_pop.css?v=2202221040">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/dictionary.css?v=2111171357">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/search_renew.css?v=2111171357">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/dpg_stamp.css?v=2111171357">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/globaljs/external/nouislider/nouislider.min.css">\n<link rel="canonical" href="http://search.danawa.com/dsearch.php?query=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B">\n<link rel="alternate" href="http://search.danawa.com/mobile/dsearch.php?keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B" media="only screen and (max-width: 640px)">\n<script type="text/javascript" async="" src="http://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="http://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" charset="utf-8" src="//static.dable.io/dist/plugin.min.js"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=AW-631507961&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=AW-963914956&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=G-XWC0NNEPX2&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=G-287B75YQDL&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=G-GESPG2060V&amp;l=dataLayer&amp;cx=c"></script><script defer="" src="https://cdn.megadata.co.kr/dist/prod/enp_tracker_self_hosted.min.js"></script><script type="text/javascript" src="//static.danawa.com/globaljs/external/jquery/core/last/jquery-last.min.js?v=22022215300"></script>\n<script type="text/javascript" charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/gnb_ui.js?v=22022215300"></script>\n<script type="text/javascript" charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/jquery.addProductToWishList.js?v=22022215300"></script>\n<script type="text/javascript" src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.cookie/jquery.cookie.js"></script>\n<script type="text/javascript" charset="utf-8" src="//static.danawa.com/globaljs/com/danawa/common/searchAutocompleteLayer_UTF8.js?v=22022215300"></script>\n<script src="//rum.beusable.net/script/b200115e112333u798/1937c2a118" async="" type="text/javascript"></script><s ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
path = '#productListArea > div.main_prodlist.main_prodlist_list > ul > li'

# %%
len(soup.select(path))
# Out:
# 44

# %%
prod_item = soup.select(path)

# %%
# title = prod_item[0].select('#productItem15170459 > div > div.prod_info > p > a')[0].text
# spec_list = prod_item[0].select('#productItem15170459 > div > div.prod_info > dl > dd > div')[0].text
# price = prod_item[0].select('#productInfoDetail_15170318 > p.price_sect > a')[0].text

# %%
title = prod_item[0].select('div.prod_info > p > a')[0].text
spec_list = prod_item[0].select('div.prod_info > dl > dd > div')[0].text
price = prod_item[0].select('p.price_sect > a')[0].text

print(title)
print(spec_list)
print(price)
# Out:
# 삼성전자 비스포크 제트 VS20A956A3
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 564,030원

# %%
for p in prod_item:
    try:
        title = p.select('div.prod_info > p > a')[0].text
        spec_list = p.select('div.prod_info > dl > dd > div')[0].text
        price = p.select('p.price_sect > a')[0].text
    
        print(title)
        print(spec_list)
        print(price)
        print('-----------------')
    except:
        pass
# Out:
# 삼성전자 비스포크 제트 VS20A956A3
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 564,030원
# -----------------
# 샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 사용시간: 30분 / 소음: 73.8dB / 충전방식: USB C타입 / 배터리용량: 2,000mAh / 색상: 블랙, 화이트 / 크기: 369x72mm / 무게: 560g
# 60,450원
# -----------------
# LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 1,084,720원
# -----------------
# 8RkygRDKyK
#
# 								8RkygRDKyK517411
#
# 517411원
# -----------------
# 베이스어스 차량용 청소기 A3 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 15,000Pa / 최대출력: 135W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 45분 / 배터리 잔량표시 / 소음: 75dB / 충전방식: USB C타입 / 충전시간: 3~5시간 / 색상: 그린, 실버 / 크기: 296x56.5mm
# 49,310원
# -----------------
# 샤오미 미지아 차량용 핸디 무선 청소기
# 차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 9~30분 / 버튼 잠금 장치 / 2단 세기 조절 / 크기: 55x267mm / 무게: 500g
# 36,450원
# -----------------
# LG전자 코드제로 ThinQ A9S AS9370IKT
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 200W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 아이언그레이+딥그레이 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 791,550원
# -----------------
# 샤오미 드리미 V10
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 450W / [성능] 흡입력: 140AW / 흡입력: 22000Pa / 멀티싸이클론 / BLDC모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / [필터] 헤파필터 / H12급 / 5단계여과 / [구성] 바닥 / 침구 / 솔형 / 틈새 / 연장툴 / 거치대 / [부가] 먼지통용량: 0.5L / 색상: 화이트 / 무게: 1.5kg
# 154,990원
# -----------------
# 다이슨 V10 플러피 오리진
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 151AW / 싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / [구성] 소프트롤러 / 미니모터 / 솔형 / 더스팅 / 틈새 / 도킹스테이션 / [부가] 먼지통용량: 0.5L / 색상: 레드 / 무게: 2.5kg / 크기(가로x세로x깊이): 256x1241x250mm
# 498,800원
# -----------------
# LG전자 코드제로 ThinQ A9S AS9470
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 200W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 일체형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 아이언그레이 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 852,470원
# -----------------
# 일렉트로룩스 WELL Q6 WQ61-1OGG
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [배터리] 충전시간: 4시간30분 / 사용시간(개당): 45분 / 내장형 / 리튬이온 / [필터] 5단계여과 / [기능] 브러쉬자동청소 / 셀프스탠딩 / LED라이트 / 배터리잔량표시 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / [부가] 먼지통용량: 0.3L / 색상: 그라나이트그레이 / 무게: 2.65kg / 크기(가로x세로x깊이): 386x692x146mm
# 133,290원
# -----------------
# 삼성전자 비스포크 제트 VS20A957E3
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 868,810원
# -----------------
# 디티 핸디형 미니 무선청소기 DT-CV200
# 차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 120W / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 충전방식: USB C타입 / 배터리용량: 2,000mAh / 크기: 164x147x55mm / 무게: 350g
# 88,110원
# -----------------
# LG전자 코드제로 ThinQ A9S AS9471
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 블랙 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 916,880원
# -----------------
# 샤오미 TROUVER POWER 11
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 400W / [성능] 흡입력: 20000Pa / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 배터리잔량표시 / [구성] 바닥 / 카펫 / 솔형 / 틈새 / 거치대 / [부가] 먼지통용량: 0.4L / 색상: 화이트+오렌지 / 무게: 1.45kg / 크기(가로x세로): 227x1227mm
# 106,980원
# -----------------
# 샤오미 미지아 차량용 핸디 무선 청소기 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 9~30분 / 버튼 잠금 장치 / 2단 세기 조절 / 크기: 55x267mm / 무게: 500g
# 37,700원
# -----------------
# 조아스 차량용 에어건 청소기 JVC-2000
# 차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 60W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 20분 / 충전시간: 2시간 / 충전방식: USB C타입 / 크기: 142x172mm / 무게: 280g
# 38,900원
# -----------------
# 삼성전자 제트 VS20T9210BF
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 550W / [성능] 흡입력: 200W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.6L / 색상: 코타블랙 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1136x215mm
# 454,140원
# -----------------
# 삼성전자 비스포크 제트 VS20A957D3
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 721,790원
# -----------------
# DIBEA 차이슨 ALLNEW29000
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 380W / [성능] 흡입력: 29000Pa / BLDC모터 / 충전시간: 4시간 / 사용시간(개당): 48분 / 분리형 (1개) / [필터] 헤파필터 / H13급 / 4단계여과 / [기능] LED라이트 / 배터리잔량표시 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 패브릭 / 연장툴 / 거치대 / [부가] 먼지통용량: 0.7L / 색상: 폴라나이트그레이, 미드나이트블랙 / 무게: 2.4kg / UV살균 / 크기(가로x세로x깊이): 255x1150x200mm
# 248,000원
# -----------------
# LG전자 오브제컬렉션 코드제로 ThinQ A9S AT9201WB
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 타공/분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 891,700원
# -----------------
# 삼성전자 비스포크 제트 VS20A956A3 + 물걸레
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 623,590원
# -----------------
# LG전자 코드제로 ThinQ A9S A9370
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 2중터보싸이클론 / 인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / IoT기능 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 거치대 / [부가] 색상: 아이언그레이 / 크기(가로x세로x깊이): 250x1120x260mm
# 664,210원
# -----------------
# 샤오미 CLEANFLY 차량용 무선 청소기 3세대 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 사용시간: 25분 / 크기: 369x72mm / 무게: 560g / 충전방식: USB C타입 / 배터리용량: 2,000mAh
# 57,770원
# -----------------
# 다이슨 디지털 슬림 플러피+
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 100AW / 싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 40분 / 분리형 (1개) / [필터] 5단계여과 / [기능] 디스플레이표시창 / [구성] 슬림소프트롤러 / 미니모터 / 솔형 / 스터번더트 / 틈새 / 매트리스 / 연장툴 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.3L / 색상: 오렌지 / 무게: 1.9kg / 크기(가로x세로x깊이): 250x1100x250mm
# 647,970원
# -----------------
# 샤오미 LYDSTO 핸디형 에어펌프 진공청소기
# 차량용청소기 / 무선 / 흡입력: ~7,000Pa / 충전방식: USB C타입 / 배터리용량: 2,500mAH / 크기: 315x54x54mm / 무게: 570g / 압력설정 / 최대압력: 120psi
# 56,220원
# -----------------
# 다이슨 V15 디텍트 컴플리트
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 240AW / 루트싸이클론 / [배터리] 충전시간: 4시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / [필터] 헤파필터 / [기능] 먼지감지센서 / 디스플레이표시창 / [구성] 하이토크 / 레이저슬림플러피 / 헤어스크류 / 솔형 / 더스팅 / 스터번더트 / 틈새 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.54L / 색상: 옐로우/아이언/니켈 / 무게: 3kg / 크기(가로x세로x깊이): 250x1086x250mm
# 1,109,400원
# -----------------
# LG전자 코드제로 A9 A9100N
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 450W / [성능] 흡입력: 140W / 2중터보싸이클론 / 인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 50분 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 배터리잔량표시 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / [부가] 색상: 판타지실버 / 크기(가로x세로x깊이): 250x1120x260mm
# 541,260원
# -----------------
# 한라홀딩스 만도 소형 청소기 MC-100
# 차량용청소기 / 무선 / 흡입력: 8,000Pa / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / LED라이트 / 사용시간: 20분 / 충전방식: USB C타입 / 배터리용량: 6,000mAh 크기: 241x71x50mm / 무게: 550g
# 89,000원
# -----------------
# 일렉트로룩스 에르고라피도 ZB3311
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [배터리] 충전시간: 4시간 / 사용시간(개당): 48분 / 내장형 / 리튬이온 / [필터] 4단계여과 / [기능] 브러쉬자동청소 / 셀프스탠딩 / LED라이트 / 배터리잔량표시 / [구성] 바닥 / 틈새 / 거치대 / [부가] 먼지통용량: 0.42L / 색상: 타이탄블루 / 무게: 3.01kg / 크기(가로x세로x깊이): 303x690x162mm
# 131,070원
# -----------------
# 캐치웰 차량용 핸디 텀블러 청소기 THC1000
# 차량용청소기 / 무선 / 흡입력: 8,000Pa / 최대출력: 75W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 싸이클론 / 사용시간: 20~28분 / 충전시간: 4시간 / 무게: 580g / 색상: 그레이, 화이트, 블랙
# 39,900원
# -----------------
# LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9471WKT
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 1,023,730원
# -----------------
# 샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)
# 차량용청소기 / 무선 / 흡입력: 12,000Pa / 최대출력: 120W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전시간: 2시간30분 / 충전방식: USB C타입 / 크기: 73x76x336mm / 무게: 610g
# 48,940원
# -----------------
# 삼성전자 비스포크 제트 VS20A957D3P
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 728,970원
# -----------------
# 삼성전자 제트 VS15R8577Q5CW
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 410W / [성능] 흡입력: 150W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 틸실버 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm
# 497,170원
# -----------------
# 다이슨 V12 디텍트 슬림 컴플리트
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 150AW / 루트싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / [필터] 헤파필터 / [기능] 먼지감지센서 / 디스플레이표시창 / [구성] 레이저슬림플러피 / 다이렉트드라이브 / 헤어스크류 / 솔형 / 더스팅 / 스터번더트 / 틈새 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.35L / 색상: 옐로우/아이언/니켈 / 무게: 2.2kg / 크기(가로x세로x깊이): 250x1095x251mm
# 954,000원
# -----------------
# 샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 7,000Pa / 최대출력: 90W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전방식: USB C타입 / 충전시간: 2시간30분 / 크기: 73x76x336mm / 무게: 700g
# 28,540원
# -----------------
# 차모아 휴대용 에어건 파워 청소기
# 차량용청소기 / 무선 / 최대출력: ~60W / 2중필터 / 3중필터 / LED라이트 / 충전시간: 4시간 / 충전방식: USB C타입 / 크기: 189x79x131mm / 무게: 475g
# 58,800원
# -----------------
# 삼성전자 제트 VS15R8543Q4CW
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 410W / [성능] 흡입력: 150W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 40분 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 틸바이올렛 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm
# 402,270원
# -----------------
# 제이엠스퀘어 바넥스 차량용 무선 청소기 BX-C30
# 차량용청소기 / 무선 / 흡입력: 5,200Pa / 최대출력: 80W / 헤파필터 / 추가노즐: 솔브러쉬 / 사용시간: 20분 / 크기: 235x65x65mm / 무게: 595g / 충전시간: 4시간 / 먼지통용량: 120ml
# 44,900원
# -----------------
# 삼성전자 비스포크 제트 VS20A957D2
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 767,380원
# -----------------

# %%
items = {}

title_list = []
spec_list = []
price_list = []

for p in prod_item:
    try:
        title = p.select('div.prod_info > p > a')[0].text
        spec = p.select('div.prod_info > dl > dd > div')[0].text
        price = p.select('p.price_sect > a')[0].text
        
        print(title)
        print(spec)
        print(price)
    
        title_list.append(title)
        spec_list.append(spec)
        price_list.append(price)
        print('-----------------')
    except:
        pass
    
print(len(title_list))
print(len(spec_list))
print(len(price_list))
    
items['title'] = title_list
items['spec'] = spec_list
items['price'] = price_list

items
# Out:
# 삼성전자 비스포크 제트 VS20A956A3
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 564,030원
# -----------------
# 샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 사용시간: 30분 / 소음: 73.8dB / 충전방식: USB C타입 / 배터리용량: 2,000mAh / 색상: 블랙, 화이트 / 크기: 369x72mm / 무게: 560g
# 60,450원
# -----------------
# LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 1,084,720원
# -----------------
# 8RkygRDKyK
#
# 								8RkygRDKyK517411
#
# 517411원
# -----------------
# 베이스어스 차량용 청소기 A3 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 15,000Pa / 최대출력: 135W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 45분 / 배터리 잔량표시 / 소음: 75dB / 충전방식: USB C타입 / 충전시간: 3~5시간 / 색상: 그린, 실버 / 크기: 296x56.5mm
# 49,310원
# -----------------
# 샤오미 미지아 차량용 핸디 무선 청소기
# 차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 9~30분 / 버튼 잠금 장치 / 2단 세기 조절 / 크기: 55x267mm / 무게: 500g
# 36,450원
# -----------------
# LG전자 코드제로 ThinQ A9S AS9370IKT
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 200W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 아이언그레이+딥그레이 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 791,550원
# -----------------
# 샤오미 드리미 V10
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 450W / [성능] 흡입력: 140AW / 흡입력: 22000Pa / 멀티싸이클론 / BLDC모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / [필터] 헤파필터 / H12급 / 5단계여과 / [구성] 바닥 / 침구 / 솔형 / 틈새 / 연장툴 / 거치대 / [부가] 먼지통용량: 0.5L / 색상: 화이트 / 무게: 1.5kg
# 154,990원
# -----------------
# 다이슨 V10 플러피 오리진
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 151AW / 싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / [구성] 소프트롤러 / 미니모터 / 솔형 / 더스팅 / 틈새 / 도킹스테이션 / [부가] 먼지통용량: 0.5L / 색상: 레드 / 무게: 2.5kg / 크기(가로x세로x깊이): 256x1241x250mm
# 498,800원
# -----------------
# LG전자 코드제로 ThinQ A9S AS9470
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 200W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 일체형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 아이언그레이 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 852,470원
# -----------------
# 일렉트로룩스 WELL Q6 WQ61-1OGG
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [배터리] 충전시간: 4시간30분 / 사용시간(개당): 45분 / 내장형 / 리튬이온 / [필터] 5단계여과 / [기능] 브러쉬자동청소 / 셀프스탠딩 / LED라이트 / 배터리잔량표시 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / [부가] 먼지통용량: 0.3L / 색상: 그라나이트그레이 / 무게: 2.65kg / 크기(가로x세로x깊이): 386x692x146mm
# 133,290원
# -----------------
# 삼성전자 비스포크 제트 VS20A957E3
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 868,810원
# -----------------
# 디티 핸디형 미니 무선청소기 DT-CV200
# 차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 120W / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 충전방식: USB C타입 / 배터리용량: 2,000mAh / 크기: 164x147x55mm / 무게: 350g
# 88,110원
# -----------------
# LG전자 코드제로 ThinQ A9S AS9471
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 블랙 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 916,880원
# -----------------
# 샤오미 TROUVER POWER 11
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 400W / [성능] 흡입력: 20000Pa / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 배터리잔량표시 / [구성] 바닥 / 카펫 / 솔형 / 틈새 / 거치대 / [부가] 먼지통용량: 0.4L / 색상: 화이트+오렌지 / 무게: 1.45kg / 크기(가로x세로): 227x1227mm
# 106,980원
# -----------------
# 샤오미 미지아 차량용 핸디 무선 청소기 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 9~30분 / 버튼 잠금 장치 / 2단 세기 조절 / 크기: 55x267mm / 무게: 500g
# 37,700원
# -----------------
# 조아스 차량용 에어건 청소기 JVC-2000
# 차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 60W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 20분 / 충전시간: 2시간 / 충전방식: USB C타입 / 크기: 142x172mm / 무게: 280g
# 38,900원
# -----------------
# 삼성전자 제트 VS20T9210BF
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 550W / [성능] 흡입력: 200W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.6L / 색상: 코타블랙 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1136x215mm
# 454,140원
# -----------------
# 삼성전자 비스포크 제트 VS20A957D3
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 721,790원
# -----------------
# DIBEA 차이슨 ALLNEW29000
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 380W / [성능] 흡입력: 29000Pa / BLDC모터 / 충전시간: 4시간 / 사용시간(개당): 48분 / 분리형 (1개) / [필터] 헤파필터 / H13급 / 4단계여과 / [기능] LED라이트 / 배터리잔량표시 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 패브릭 / 연장툴 / 거치대 / [부가] 먼지통용량: 0.7L / 색상: 폴라나이트그레이, 미드나이트블랙 / 무게: 2.4kg / UV살균 / 크기(가로x세로x깊이): 255x1150x200mm
# 248,000원
# -----------------
# LG전자 오브제컬렉션 코드제로 ThinQ A9S AT9201WB
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 타공/분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 891,700원
# -----------------
# 삼성전자 비스포크 제트 VS20A956A3 + 물걸레
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 623,590원
# -----------------
# LG전자 코드제로 ThinQ A9S A9370
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 2중터보싸이클론 / 인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / IoT기능 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 거치대 / [부가] 색상: 아이언그레이 / 크기(가로x세로x깊이): 250x1120x260mm
# 664,210원
# -----------------
# 샤오미 CLEANFLY 차량용 무선 청소기 3세대 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 사용시간: 25분 / 크기: 369x72mm / 무게: 560g / 충전방식: USB C타입 / 배터리용량: 2,000mAh
# 57,770원
# -----------------
# 다이슨 디지털 슬림 플러피+
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 100AW / 싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 40분 / 분리형 (1개) / [필터] 5단계여과 / [기능] 디스플레이표시창 / [구성] 슬림소프트롤러 / 미니모터 / 솔형 / 스터번더트 / 틈새 / 매트리스 / 연장툴 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.3L / 색상: 오렌지 / 무게: 1.9kg / 크기(가로x세로x깊이): 250x1100x250mm
# 647,970원
# -----------------
# 샤오미 LYDSTO 핸디형 에어펌프 진공청소기
# 차량용청소기 / 무선 / 흡입력: ~7,000Pa / 충전방식: USB C타입 / 배터리용량: 2,500mAH / 크기: 315x54x54mm / 무게: 570g / 압력설정 / 최대압력: 120psi
# 56,220원
# -----------------
# 다이슨 V15 디텍트 컴플리트
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 240AW / 루트싸이클론 / [배터리] 충전시간: 4시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / [필터] 헤파필터 / [기능] 먼지감지센서 / 디스플레이표시창 / [구성] 하이토크 / 레이저슬림플러피 / 헤어스크류 / 솔형 / 더스팅 / 스터번더트 / 틈새 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.54L / 색상: 옐로우/아이언/니켈 / 무게: 3kg / 크기(가로x세로x깊이): 250x1086x250mm
# 1,109,400원
# -----------------
# LG전자 코드제로 A9 A9100N
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 450W / [성능] 흡입력: 140W / 2중터보싸이클론 / 인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 50분 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 배터리잔량표시 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / [부가] 색상: 판타지실버 / 크기(가로x세로x깊이): 250x1120x260mm
# 541,260원
# -----------------
# 한라홀딩스 만도 소형 청소기 MC-100
# 차량용청소기 / 무선 / 흡입력: 8,000Pa / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / LED라이트 / 사용시간: 20분 / 충전방식: USB C타입 / 배터리용량: 6,000mAh 크기: 241x71x50mm / 무게: 550g
# 89,000원
# -----------------
# 일렉트로룩스 에르고라피도 ZB3311
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [배터리] 충전시간: 4시간 / 사용시간(개당): 48분 / 내장형 / 리튬이온 / [필터] 4단계여과 / [기능] 브러쉬자동청소 / 셀프스탠딩 / LED라이트 / 배터리잔량표시 / [구성] 바닥 / 틈새 / 거치대 / [부가] 먼지통용량: 0.42L / 색상: 타이탄블루 / 무게: 3.01kg / 크기(가로x세로x깊이): 303x690x162mm
# 131,070원
# -----------------
# 캐치웰 차량용 핸디 텀블러 청소기 THC1000
# 차량용청소기 / 무선 / 흡입력: 8,000Pa / 최대출력: 75W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 싸이클론 / 사용시간: 20~28분 / 충전시간: 4시간 / 무게: 580g / 색상: 그레이, 화이트, 블랙
# 39,900원
# -----------------
# LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9471WKT
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# 1,023,730원
# -----------------
# 샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)
# 차량용청소기 / 무선 / 흡입력: 12,000Pa / 최대출력: 120W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전시간: 2시간30분 / 충전방식: USB C타입 / 크기: 73x76x336mm / 무게: 610g
# 48,940원
# -----------------
# 삼성전자 비스포크 제트 VS20A957D3P
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 728,970원
# -----------------
# 삼성전자 제트 VS15R8577Q5CW
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 410W / [성능] 흡입력: 150W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 틸실버 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm
# 497,170원
# -----------------
# 다이슨 V12 디텍트 슬림 컴플리트
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 150AW / 루트싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / [필터] 헤파필터 / [기능] 먼지감지센서 / 디스플레이표시창 / [구성] 레이저슬림플러피 / 다이렉트드라이브 / 헤어스크류 / 솔형 / 더스팅 / 스터번더트 / 틈새 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.35L / 색상: 옐로우/아이언/니켈 / 무게: 2.2kg / 크기(가로x세로x깊이): 250x1095x251mm
# 954,000원
# -----------------
# 샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)
# 차량용청소기 / 무선 / 흡입력: 7,000Pa / 최대출력: 90W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전방식: USB C타입 / 충전시간: 2시간30분 / 크기: 73x76x336mm / 무게: 700g
# 28,540원
# -----------------
# 차모아 휴대용 에어건 파워 청소기
# 차량용청소기 / 무선 / 최대출력: ~60W / 2중필터 / 3중필터 / LED라이트 / 충전시간: 4시간 / 충전방식: USB C타입 / 크기: 189x79x131mm / 무게: 475g
# 58,800원
# -----------------
# 삼성전자 제트 VS15R8543Q4CW
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 410W / [성능] 흡입력: 150W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 40분 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 틸바이올렛 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm
# 402,270원
# -----------------
# 제이엠스퀘어 바넥스 차량용 무선 청소기 BX-C30
# 차량용청소기 / 무선 / 흡입력: 5,200Pa / 최대출력: 80W / 헤파필터 / 추가노즐: 솔브러쉬 / 사용시간: 20분 / 크기: 235x65x65mm / 무게: 595g / 충전시간: 4시간 / 먼지통용량: 120ml
# 44,900원
# -----------------
# 삼성전자 비스포크 제트 VS20A957D2
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# 767,380원
# -----------------
# 41
# 41
# 41
# {'title': ['삼성전자 비스포크 제트 VS20A956A3',
#   '샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)',
#   'LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571',
#   '8RkygRDKyK',
#   '베이스어스 차량용 청소기 A3 (해외구매)',
#   '샤오미 미지아 차량용 핸디 무선 청소기',
#   'LG전자 코드제로 ThinQ A9S AS9370IKT',
#   '샤오미 드리미 V10',
#   '다이슨 V10 플러피 오리진',
#   'LG전자 코드제로 ThinQ A9S AS9470',
#   '일렉트로룩스 WELL Q6 WQ61-1OGG',
#   '삼성전자 비스포크 제트 VS20A957E3',
#   '디티 핸디형 미니 무선청소기 DT-CV200',
#   'LG전자 코드제로 ThinQ A9S AS9471',
#   '샤오미 TROUVER POWER 11',
#   '샤오미 미지아 차량용 핸디 무선 청소기 (해외구매)',
#   '조아스 차량용 에어건 청소기 JVC-2000',
#   '삼성전자 제트 VS20T9210BF',
#   '삼성전자 비스포크 제트 VS20A957D3',
#   'DIBEA 차이슨 ALLNEW29000',
#   'LG전자 오브제컬렉션 코드제로 ThinQ A9S AT9201WB',
#   '삼성전자 비스포크 제트 VS20A956A3 + 물걸레',
#   'LG전자 코드제로 ThinQ A9S A9370',
#   '샤오미 CLEANFLY 차량용 무선 청소기 3세대 (해외구매)',
#   '다이슨 디지털 슬림 플러피+',
#   '샤오미 LYDSTO 핸디형 에어펌프 진공청소기',
#   '다이슨 V15 디텍트 컴플리트',
#   'LG전자 코드제로 A9 A9100N',
#   '한라홀딩스 만도 소형 청소기 MC-100',
#   '일렉트로룩스 에르고라피도 ZB3311',
#   '캐치웰 차량용 핸디 텀블러 청소기 THC1000',
#   'LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9471WKT',
#   '샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)',
#   '삼성전자 비스포크 제트 VS20A957D3P',
#   '삼성전자 제트 VS15R8577Q5CW',
#   '다이슨 V12 디텍트 슬림 컴플리트',
#   '샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)',
#   '차모아 휴대용 에어건 파워 청소기',
#   '삼성전자 제트 VS15R8543Q4CW',
#   '제이엠스퀘어 바넥스 차량용 무선 청소기 BX-C30',
#   '삼성전자 비스포크 제트 VS20A957D2'],
#  'spec': ['핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 사용시간: 30분 / 소음: 73.8dB / 충전방식: USB C타입 / 배터리용량: 2,000mAh / 색상: 블랙, 화이트 / 크기: 369x72mm / 무게: 560g\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '\n\t\t\t\t\t\t\t\t8RkygRDKyK517411\n\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 15,000Pa / 최대출력: 135W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 45분 / 배터리 잔량표시 / 소음: 75dB / 충전방식: USB C타입 / 충전시간: 3~5시간 / 색상: 그린, 실버 / 크기: 296x56.5mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 9~30분 / 버튼 잠금 장치 / 2단 세기 조절 / 크기: 55x267mm / 무게: 500g\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 200W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 아이언그레이+딥그레이 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 450W / [성능] 흡입력: 140AW / 흡입력: 22000Pa / 멀티싸이클론 / BLDC모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / [필터] 헤파필터 / H12급 / 5단계여과 / [구성] 바닥 / 침구 / 솔형 / 틈새 / 연장툴 / 거치대 / [부가] 먼지통용량: 0.5L / 색상: 화이트 / 무게: 1.5kg ',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 151AW / 싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / [구성] 소프트롤러 / 미니모터 / 솔형 / 더스팅 / 틈새 / 도킹스테이션 / [부가] 먼지통용량: 0.5L / 색상: 레드 / 무게: 2.5kg / 크기(가로x세로x깊이): 256x1241x250mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 200W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 일체형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 아이언그레이 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [배터리] 충전시간: 4시간30분 / 사용시간(개당): 45분 / 내장형 / 리튬이온 / [필터] 5단계여과 / [기능] 브러쉬자동청소 / 셀프스탠딩 / LED라이트 / 배터리잔량표시 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / [부가] 먼지통용량: 0.3L / 색상: 그라나이트그레이 / 무게: 2.65kg / 크기(가로x세로x깊이): 386x692x146mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 120W / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 충전방식: USB C타입 / 배터리용량: 2,000mAh / 크기: 164x147x55mm / 무게: 350g\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 블랙 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 400W / [성능] 흡입력: 20000Pa / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 배터리잔량표시 / [구성] 바닥 / 카펫 / 솔형 / 틈새 / 거치대 / [부가] 먼지통용량: 0.4L / 색상: 화이트+오렌지 / 무게: 1.45kg / 크기(가로x세로): 227x1227mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 9~30분 / 버튼 잠금 장치 / 2단 세기 조절 / 크기: 55x267mm / 무게: 500g\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 60W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 20분 / 충전시간: 2시간 / 충전방식: USB C타입 / 크기: 142x172mm / 무게: 280g\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 550W / [성능] 흡입력: 200W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.6L / 색상: 코타블랙 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1136x215mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 380W / [성능] 흡입력: 29000Pa / BLDC모터 / 충전시간: 4시간 / 사용시간(개당): 48분 / 분리형 (1개) / [필터] 헤파필터 / H13급 / 4단계여과 / [기능] LED라이트 / 배터리잔량표시 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 패브릭 / 연장툴 / 거치대 / [부가] 먼지통용량: 0.7L / 색상: 폴라나이트그레이, 미드나이트블랙 / 무게: 2.4kg / UV살균 / 크기(가로x세로x깊이): 255x1150x200mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 타공/분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 2중터보싸이클론 / 인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / IoT기능 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 거치대 / [부가] 색상: 아이언그레이 / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 사용시간: 25분 / 크기: 369x72mm / 무게: 560g / 충전방식: USB C타입 / 배터리용량: 2,000mAh\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 100AW / 싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 40분 / 분리형 (1개) / [필터] 5단계여과 / [기능] 디스플레이표시창 / [구성] 슬림소프트롤러 / 미니모터 / 솔형 / 스터번더트 / 틈새 / 매트리스 / 연장툴 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.3L / 색상: 오렌지 / 무게: 1.9kg / 크기(가로x세로x깊이): 250x1100x250mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: ~7,000Pa / 충전방식: USB C타입 / 배터리용량: 2,500mAH / 크기: 315x54x54mm / 무게: 570g / 압력설정 / 최대압력: 120psi\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 240AW / 루트싸이클론 / [배터리] 충전시간: 4시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / [필터] 헤파필터 / [기능] 먼지감지센서 / 디스플레이표시창 / [구성] 하이토크 / 레이저슬림플러피 / 헤어스크류 / 솔형 / 더스팅 / 스터번더트 / 틈새 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.54L / 색상: 옐로우/아이언/니켈 / 무게: 3kg / 크기(가로x세로x깊이): 250x1086x250mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 450W / [성능] 흡입력: 140W / 2중터보싸이클론 / 인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 50분 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 배터리잔량표시 / [구성] 바닥 / 솔형 / 틈새 / 거치대 / [부가] 색상: 판타지실버 / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 8,000Pa / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / LED라이트 / 사용시간: 20분 / 충전방식: USB C타입 / 배터리용량: 6,000mAh 크기: 241x71x50mm / 무게: 550g\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [배터리] 충전시간: 4시간 / 사용시간(개당): 48분 / 내장형 / 리튬이온 / [필터] 4단계여과 / [기능] 브러쉬자동청소 / 셀프스탠딩 / LED라이트 / 배터리잔량표시 / [구성] 바닥 / 틈새 / 거치대 / [부가] 먼지통용량: 0.42L / 색상: 타이탄블루 / 무게: 3.01kg / 크기(가로x세로x깊이): 303x690x162mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 8,000Pa / 최대출력: 75W / 헤파필터 / 스테인리스 필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 싸이클론 / 사용시간: 20~28분 / 충전시간: 4시간 / 무게: 580g / 색상: 그레이, 화이트, 블랙\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 12,000Pa / 최대출력: 120W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전시간: 2시간30분 / 충전방식: USB C타입 / 크기: 73x76x336mm / 무게: 610g\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미드나잇블루 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 410W / [성능] 흡입력: 150W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 틸실버 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 150AW / 루트싸이클론 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / [필터] 헤파필터 / [기능] 먼지감지센서 / 디스플레이표시창 / [구성] 레이저슬림플러피 / 다이렉트드라이브 / 헤어스크류 / 솔형 / 더스팅 / 스터번더트 / 틈새 / 거치대 / 도킹스테이션 / [부가] 먼지통용량: 0.35L / 색상: 옐로우/아이언/니켈 / 무게: 2.2kg / 크기(가로x세로x깊이): 250x1095x251mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 7,000Pa / 최대출력: 90W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전방식: USB C타입 / 충전시간: 2시간30분 / 크기: 73x76x336mm / 무게: 700g\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 최대출력: ~60W / 2중필터 / 3중필터 / LED라이트 / 충전시간: 4시간 / 충전방식: USB C타입 / 크기: 189x79x131mm / 무게: 475g\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 410W / [성능] 흡입력: 150W / 싸이클론 / 인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 40분 / 분리형 (1개) / 리튬이온 / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 틸바이올렛 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm\t\t\t\t\t\t\t\t',
#   '차량용청소기 / 무선 / 흡입력: 5,200Pa / 최대출력: 80W / 헤파필터 / 추가노즐: 솔브러쉬 / 사용시간: 20분 / 크기: 235x65x65mm / 무게: 595g / 충전시간: 4시간 / 먼지통용량: 120ml\t\t\t\t\t\t\t\t',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm\t\t\t\t\t\t\t\t'],
#  'price': ['564,030원',
#   '60,450원',
#   '1,084,720원',
#   '517411원',
#   '49,310원',
#   '36,450원',
#   '791,550원',
#   '154,990원',
#   '498,800원',
#   '852,470원',
#   '133,290원',
#   '868,810원',
#   '88,110원',
#   '916,880원',
#   '106,980원',
#   '37,700원',
#   '38,900원',
#   '454,140원',
#   '721,790원',
#   '248,000원',
#   '891,700원',
#   '623,590원',
#   '664,210원',
#   '57,770원',
#   '647,970원',
#   '56,220원',
#   '1,109,400원',
#   '541,260원',
#   '89,000원',
#   '131,070원',
#   '39,900원',
#   '1,023,730원',
#   '48,940원',
#   '728,970원',
#   '497,170원',
#   '954,000원',
#   '28,540원',
#   '58,800원',
#   '402,270원',
#   '44,900원',
#   '767,380원']}

# %%
item_df = pd.DataFrame(items)
item_df.head()
# Out:
#                                    title  \
# 0                삼성전자 비스포크 제트 VS20A956A3
# 1  샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 2      LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 3                             8RkygRDKyK
# 4                베이스어스 차량용 청소기 A3 (해외구매)
#
#                                                 spec       price
# 0  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    564,030원
# 1  차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필...     60,450원
# 2  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...  1,084,720원
# 3  \n\t\t\t\t\t\t\t\t8RkygRDKyK517411\n\t\t\t\t\t...     517411원
# 4  차량용청소기 / 무선 / 흡입력: 15,000Pa / 최대출력: 135W / 헤파필...     49,310원

# %%
drop_idx = []
for i, t in enumerate(item_df.title):
    if len(t.split()) < 2:
        drop_idx.append(i)
drop_idx
# Out:
# [3]

# %%
item_df.drop(drop_idx[0], inplace=True)

# %%
item_df
# Out:
#                                       title  \
# 0                   삼성전자 비스포크 제트 VS20A956A3
# 1     샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 2         LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 4                   베이스어스 차량용 청소기 A3 (해외구매)
# 5                     샤오미 미지아 차량용 핸디 무선 청소기
# 6             LG전자 코드제로 ThinQ A9S AS9370IKT
# 7                               샤오미 드리미 V10
# 8                           다이슨 V10 플러피 오리진
# 9                LG전자 코드제로 ThinQ A9S AS9470
# 10                 일렉트로룩스 WELL Q6 WQ61-1OGG
# 11                  삼성전자 비스포크 제트 VS20A957E3
# 12                 디티 핸디형 미니 무선청소기 DT-CV200
# 13               LG전자 코드제로 ThinQ A9S AS9471
# 14                     샤오미 TROUVER POWER 11
# 15             샤오미 미지아 차량용 핸디 무선 청소기 (해외구매)
# 16                 조아스 차량용 에어건 청소기 JVC-2000
# 17                      삼성전자 제트 VS20T9210BF
# 18                  삼성전자 비스포크 제트 VS20A957D3
# 19                    DIBEA 차이슨 ALLNEW29000
# 20      LG전자 오브제컬렉션 코드제로 ThinQ A9S AT9201WB
# 21            삼성전자 비스포크 제트 VS20A956A3 + 물걸레
# 22                LG전자 코드제로 ThinQ A9S A9370
# 23       샤오미 CLEANFLY 차량용 무선 청소기 3세대 (해외구매)
# 24                          다이슨 디지털 슬림 플러피+
# 25                샤오미 LYDSTO 핸디형 에어펌프 진공청소기
# 26                         다이슨 V15 디텍트 컴플리트
# 27                      LG전자 코드제로 A9 A9100N
# 28                   한라홀딩스 만도 소형 청소기 MC-100
# 29                     일렉트로룩스 에르고라피도 ZB3311
# 30               캐치웰 차량용 핸디 텀블러 청소기 THC1000
# 31     LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9471WKT
# 32  샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)
# 33                 삼성전자 비스포크 제트 VS20A957D3P
# 34                    삼성전자 제트 VS15R8577Q5CW
# 35                      다이슨 V12 디텍트 슬림 컴플리트
# 36      샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)
# 37                       차모아 휴대용 에어건 파워 청소기
# 38                    삼성전자 제트 VS15R8543Q4CW
# 39             제이엠스퀘어 바넥스 차량용 무선 청소기 BX-C30
# 40                  삼성전자 비스포크 제트 VS20A957D2
#
#                                                  spec       price
# 0   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    564,030원
# 1   차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필...     60,450원
# 2   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...  1,084,720원
# 4   차량용청소기 / 무선 / 흡입력: 15,000Pa / 최대출력: 135W / 헤파필...     49,310원
# 5   차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필...     36,450원
# 6   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    791,550원
# 7   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 450W / ...    154,990원
# 8   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 151...    498,800원
# 9   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    852,470원
# 10  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [...    133,290원
# 11  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    868,810원
# 12  차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 120W / 추가노즐...     88,110원
# 13  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    916,880원
# 14  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 400W / ...    106,980원
# 15  차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필...     37,700원
# 16  차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 60W / 헤파필터 ...     38,900원
# 17  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 550W...    454,140원
# 18  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    721,790원
# 19  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 380W...    248,000원
# 20  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    891,700원
# 21  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    623,590원
# 22  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    664,210원
# 23  차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필...     57,770원
# 24  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 100...    647,970원
# 25  차량용청소기 / 무선 / 흡입력: ~7,000Pa / 충전방식: USB C타입 / ...     56,220원
# 26  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 240...  1,109,400원
# 27  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 450W...    541,260원
# 28  차량용청소기 / 무선 / 흡입력: 8,000Pa / 헤파필터 / 스테인리스 필터 /...     89,000원
# 29  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [...    131,070원
# 30  차량용청소기 / 무선 / 흡입력: 8,000Pa / 최대출력: 75W / 헤파필터 ...     39,900원
# 31  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...  1,023,730원
# 32  차량용청소기 / 무선 / 흡입력: 12,000Pa / 최대출력: 120W / 2중필...     48,940원
# 33  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    728,970원
# 34  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 410W...    497,170원
# 35  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 150...    954,000원
# 36  차량용청소기 / 무선 / 흡입력: 7,000Pa / 최대출력: 90W / 2중필터 ...     28,540원
# 37  차량용청소기 / 무선 / 최대출력: ~60W / 2중필터 / 3중필터 / LED라이...     58,800원
# 38  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 410W / ...    402,270원
# 39  차량용청소기 / 무선 / 흡입력: 5,200Pa / 최대출력: 80W / 헤파필터 ...     44,900원
# 40  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    767,380원

# %%
# title을 회사명과 제품명으로 분리하시오

# %%
comp_list = []
prd_nm_list = []

for p in item_df['title']:
    comp = p.split(' ', 1)[0]
    prd_nm = p.split(' ', 1)[1:][0]
    
    comp_list.append(comp)
    prd_nm_list.append(prd_nm)

# %%
item_df['comp_nm'] = comp_list
item_df['prd_nm'] = prd_nm_list

# %%
item_df.head(3)
# Out:
#                                    title  \
# 0                삼성전자 비스포크 제트 VS20A956A3
# 1  샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 2      LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
#
#                                                 spec       price comp_nm  \
# 0  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    564,030원    삼성전자
# 1  차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필...     60,450원     샤오미
# 2  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...  1,084,720원    LG전자
#
#                               prd_nm
# 0                 비스포크 제트 VS20A956A3
# 1  CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 2       오브제컬렉션 코드제로 ThinQ A9S AO9571

# %%
# spec을 사용시간과 흡입력으로 분리하시오

# %%
use_time = []
suction = []

for s in item_df.spec:
    for spec in s.split('/')[1:]:
        if '사용시간' in spec:
            time  =spec.split(':')[1]
        elif '흡입력' in spec:
            suc = spec.split(':')[1]
    use_time.append(time)
    suction.append(suc)
        
print(len(use_time))
print(len(suction))
# Out:
# 40
# 40

# %%
item_df['usetime'] = use_time
item_df['suction'] = suction

# %%
item_df
# Out:
#                                       title  \
# 0                   삼성전자 비스포크 제트 VS20A956A3
# 1     샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 2         LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 4                   베이스어스 차량용 청소기 A3 (해외구매)
# 5                     샤오미 미지아 차량용 핸디 무선 청소기
# 6             LG전자 코드제로 ThinQ A9S AS9370IKT
# 7                               샤오미 드리미 V10
# 8                           다이슨 V10 플러피 오리진
# 9                LG전자 코드제로 ThinQ A9S AS9470
# 10                 일렉트로룩스 WELL Q6 WQ61-1OGG
# 11                  삼성전자 비스포크 제트 VS20A957E3
# 12                 디티 핸디형 미니 무선청소기 DT-CV200
# 13               LG전자 코드제로 ThinQ A9S AS9471
# 14                     샤오미 TROUVER POWER 11
# 15             샤오미 미지아 차량용 핸디 무선 청소기 (해외구매)
# 16                 조아스 차량용 에어건 청소기 JVC-2000
# 17                      삼성전자 제트 VS20T9210BF
# 18                  삼성전자 비스포크 제트 VS20A957D3
# 19                    DIBEA 차이슨 ALLNEW29000
# 20      LG전자 오브제컬렉션 코드제로 ThinQ A9S AT9201WB
# 21            삼성전자 비스포크 제트 VS20A956A3 + 물걸레
# 22                LG전자 코드제로 ThinQ A9S A9370
# 23       샤오미 CLEANFLY 차량용 무선 청소기 3세대 (해외구매)
# 24                          다이슨 디지털 슬림 플러피+
# 25                샤오미 LYDSTO 핸디형 에어펌프 진공청소기
# 26                         다이슨 V15 디텍트 컴플리트
# 27                      LG전자 코드제로 A9 A9100N
# 28                   한라홀딩스 만도 소형 청소기 MC-100
# 29                     일렉트로룩스 에르고라피도 ZB3311
# 30               캐치웰 차량용 핸디 텀블러 청소기 THC1000
# 31     LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9471WKT
# 32  샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)
# 33                 삼성전자 비스포크 제트 VS20A957D3P
# 34                    삼성전자 제트 VS15R8577Q5CW
# 35                      다이슨 V12 디텍트 슬림 컴플리트
# 36      샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)
# 37                       차모아 휴대용 에어건 파워 청소기
# 38                    삼성전자 제트 VS15R8543Q4CW
# 39             제이엠스퀘어 바넥스 차량용 무선 청소기 BX-C30
# 40                  삼성전자 비스포크 제트 VS20A957D2
#
#                                                  spec       price comp_nm  \
# 0   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    564,030원    삼성전자
# 1   차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필...     60,450원     샤오미
# 2   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...  1,084,720원    LG전자
# 4   차량용청소기 / 무선 / 흡입력: 15,000Pa / 최대출력: 135W / 헤파필...     49,310원   베이스어스
# 5   차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필...     36,450원     샤오미
# 6   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    791,550원    LG전자
# 7   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 450W / ...    154,990원     샤오미
# 8   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 151...    498,800원     다이슨
# 9   핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    852,470원    LG전자
# 10  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [...    133,290원  일렉트로룩스
# 11  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    868,810원    삼성전자
# 12  차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 120W / 추가노즐...     88,110원      디티
# 13  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    916,880원    LG전자
# 14  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 400W / ...    106,980원     샤오미
# 15  차량용청소기 / 무선 / 흡입력: 13,000Pa / 최대출력: 120W / 헤파필...     37,700원     샤오미
# 16  차량용청소기 / 무선 / 흡입력: 5,500Pa / 최대출력: 60W / 헤파필터 ...     38,900원     조아스
# 17  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 550W...    454,140원    삼성전자
# 18  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    721,790원    삼성전자
# 19  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 380W...    248,000원   DIBEA
# 20  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    891,700원    LG전자
# 21  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    623,590원    삼성전자
# 22  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...    664,210원    LG전자
# 23  차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필...     57,770원     샤오미
# 24  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 100...    647,970원     다이슨
# 25  차량용청소기 / 무선 / 흡입력: ~7,000Pa / 충전방식: USB C타입 / ...     56,220원     샤오미
# 26  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 240...  1,109,400원     다이슨
# 27  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 450W...    541,260원    LG전자
# 28  차량용청소기 / 무선 / 흡입력: 8,000Pa / 헤파필터 / 스테인리스 필터 /...     89,000원   한라홀딩스
# 29  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 싸이클론 / [...    131,070원  일렉트로룩스
# 30  차량용청소기 / 무선 / 흡입력: 8,000Pa / 최대출력: 75W / 헤파필터 ...     39,900원     캐치웰
# 31  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W...  1,023,730원    LG전자
# 32  차량용청소기 / 무선 / 흡입력: 12,000Pa / 최대출력: 120W / 2중필...     48,940원     샤오미
# 33  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    728,970원    삼성전자
# 34  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 410W...    497,170원    삼성전자
# 35  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 흡입력: 150...    954,000원     다이슨
# 36  차량용청소기 / 무선 / 흡입력: 7,000Pa / 최대출력: 90W / 2중필터 ...     28,540원     샤오미
# 37  차량용청소기 / 무선 / 최대출력: ~60W / 2중필터 / 3중필터 / LED라이...     58,800원     차모아
# 38  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / 소비전력: 410W / ...    402,270원    삼성전자
# 39  차량용청소기 / 무선 / 흡입력: 5,200Pa / 최대출력: 80W / 헤파필터 ...     44,900원  제이엠스퀘어
# 40  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: ...    767,380원    삼성전자
#
#                                  prd_nm   usetime     suction
# 0                    비스포크 제트 VS20A956A3      1시간        210W
# 1     CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)      30분    16,800Pa
# 2          오브제컬렉션 코드제로 ThinQ A9S AO9571      1시간        210W
# 4                     차량용 청소기 A3 (해외구매)      45분    15,000Pa
# 5                     미지아 차량용 핸디 무선 청소기    9~30분    13,000Pa
# 6              코드제로 ThinQ A9S AS9370IKT      1시간        200W
# 7                               드리미 V10      1시간     22000Pa
# 8                           V10 플러피 오리진      1시간       151AW
# 9                 코드제로 ThinQ A9S AS9470      1시간        200W
# 10                    WELL Q6 WQ61-1OGG      45분        200W
# 11                   비스포크 제트 VS20A957E3      1시간        210W
# 12                핸디형 미니 무선청소기 DT-CV200      1시간     5,500Pa
# 13                코드제로 ThinQ A9S AS9471      1시간        210W
# 14                     TROUVER POWER 11      1시간     20000Pa
# 15             미지아 차량용 핸디 무선 청소기 (해외구매)    9~30분    13,000Pa
# 16                 차량용 에어건 청소기 JVC-2000      20분     5,500Pa
# 17                       제트 VS20T9210BF      1시간        200W
# 18                   비스포크 제트 VS20A957D3      1시간        210W
# 19                      차이슨 ALLNEW29000      48분     29000Pa
# 20       오브제컬렉션 코드제로 ThinQ A9S AT9201WB      1시간        210W
# 21             비스포크 제트 VS20A956A3 + 물걸레      1시간        210W
# 22                 코드제로 ThinQ A9S A9370      1시간        210W
# 23       CLEANFLY 차량용 무선 청소기 3세대 (해외구매)      25분    16,800Pa
# 24                          디지털 슬림 플러피+      40분       100AW
# 25                LYDSTO 핸디형 에어펌프 진공청소기      40분    ~7,000Pa
# 26                         V15 디텍트 컴플리트      1시간       240AW
# 27                       코드제로 A9 A9100N      50분        140W
# 28                     만도 소형 청소기 MC-100      20분     8,000Pa
# 29                        에르고라피도 ZB3311      48분     8,000Pa
# 30               차량용 핸디 텀블러 청소기 THC1000   20~28분     8,000Pa
# 31      오브제컬렉션 코드제로 ThinQ A9S AO9471WKT      1시간        210W
# 32  SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)      30분    12,000Pa
# 33                  비스포크 제트 VS20A957D3P      1시간        210W
# 34                     제트 VS15R8577Q5CW      1시간        150W
# 35                      V12 디텍트 슬림 컴플리트      1시간       150AW
# 36      SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)      30분     7,000Pa
# 37                       휴대용 에어건 파워 청소기      30분     7,000Pa
# 38                     제트 VS15R8543Q4CW      40분        150W
# 39                바넥스 차량용 무선 청소기 BX-C30      20분     5,200Pa
# 40                   비스포크 제트 VS20A957D2      1시간        210W

# %%
item_df.drop(['title', 'spec'], axis=1, inplace=True)

# %%
price_s = item_df['price'].str.replace('원', '')
price_s = price_s.str.replace(',', '')
item_df['price'] = price_s.apply(lambda x: int(x))

# %%
item_df.head()
# Out:
#      price comp_nm                             prd_nm usetime     suction
# 0   560310    삼성전자                 비스포크 제트 VS20A956A3    1시간        210W
# 2  1056700    LG전자       오브제컬렉션 코드제로 ThinQ A9S AO9571    1시간        210W
# 3    61850     샤오미  CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)    30분    16,800Pa
# 4    49260   베이스어스                  차량용 청소기 A3 (해외구매)    45분    15,000Pa
# 5   838500    삼성전자                 비스포크 제트 VS20A957E3    1시간        210W

# %%
item_df.suction
# Out:
# 0          210W
# 2          210W
# 3      16,800Pa
# 4      15,000Pa
# 5          210W
# 6       20000Pa
# 7       20000Pa
# 8          210W
# 9         151AW
# 10     13,000Pa
# 11      22000Pa
# 12      22000Pa
# 13     16,800Pa
# 14      25000Pa
# 15         210W
# 16      22000Pa
# 17         210W
# 18         200W
# 19     ~7,000Pa
# 20     ~7,000Pa
# 21         210W
# 22      6,500Pa
# 23         140W
# 24         210W
# 25        150AW
# 26      25000Pa
# 27      29000Pa
# 28      29000Pa
# 29        100AW
# 30        100AW
# 31     13,000Pa
# 32     13,000Pa
# 33         210W
# 34         210W
# 35         210W
# 36         140W
# 37         140W
# 38      7,000Pa
# 39     15,000Pa
# 40     15,000Pa
# Name: suction, dtype: object

# %%
def get_suction(value):
    value = value.upper()
    if 'AW' in value or 'W' in value:
        result = value.replace("A", "").replace('W', '')
        result = int(result.replace(',','').replace('~',''))
    elif 'PA' in value:
        result = value.replace('PA', '')
        result = int(result.replace(',','').replace('~',''))/100
    else:
        result = None
    return result

# %%
item_df['suction'] = item_df['suction'].apply(get_suction)

# %%
item_df.head()
# Out:
#      price comp_nm                             prd_nm usetime  suction
# 0   560310    삼성전자                 비스포크 제트 VS20A956A3    1시간     210.0
# 2  1056700    LG전자       오브제컬렉션 코드제로 ThinQ A9S AO9571    1시간     210.0
# 3    61850     샤오미  CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)    30분     168.0
# 4    49260   베이스어스                  차량용 청소기 A3 (해외구매)    45분     150.0
# 5   838500    삼성전자                 비스포크 제트 VS20A957E3    1시간     210.0

# %%
item_df.usetime
# Out:
# 0                  1시간
# 2                  1시간
# 3                  30분
# 4                  45분
# 5                  1시간
# 6                  1시간
# 7                  1시간
# 8                  1시간
# 9                  1시간
# 10               9~30분
# 11                 1시간
# 12                 45분
# 13                 25분
# 14              1시간30분
# 15                 1시간
# 16              1시간10분
# 17                 1시간
# 18                 1시간
# 19                 1시간
# 20                 48분
# 21                 1시간
# 22                 20분
# 23                 50분
# 24                 1시간
# 25                 1시간
# 26                 50분
# 27                 48분
# 28                 48분
# 29                 40분
# 30                 3시간
# 31     12분(고속),25분(저속)
# 32               9~30분
# 33                 1시간
# 34                 50분
# 35                 30분
# 36                 50분
# 37                 55분
# 38                 30분
# 39              15~28분
# 40                 53분
# Name: usetime, dtype: object

# %%
def convert_time_minute(time):
    if '시간' in time:
        hour = time.split('시간')[0]
        if '분' in time:
            minute = time.split('시간')[-1].split('분')[0]
        else:
            minute=0
    else:
        hour= 0
        minute = time.split('분')[0].split('~')[0]
    return int(hour)*60 + int(minute)

# %%
item_df['usetime'] = item_df['usetime'].apply(convert_time_minute)

# %%
item_df.head()
# Out:
#      price comp_nm                             prd_nm  usetime  suction
# 0   560310    삼성전자                 비스포크 제트 VS20A956A3       60    210.0
# 2  1056700    LG전자       오브제컬렉션 코드제로 ThinQ A9S AO9571       60    210.0
# 3    61850     샤오미  CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)       30    168.0
# 4    49260   베이스어스                  차량용 청소기 A3 (해외구매)       45    150.0
# 5   838500    삼성전자                 비스포크 제트 VS20A957E3       60    210.0

# %%
df = item_df.copy()

# %%
df[(df['price'] < 2000000) & (df['usetime'] > 60) & (df['suction'] > 160)]
# Out:
#      price comp_nm       prd_nm  usetime  suction
# 14  208320     샤오미      드리미 V11       90    250.0
# 16  104900     델로라  V11 파워 300W       70    220.0

# %%
df['price_rank'] = df.price.rank()
df['usetime_rank'] = df.usetime.rank(ascending=False)
df['suction_rank'] = df.suction.rank(ascending=False)

# %%
df['total_rank'] = (df.price_rank + df.usetime_rank + df.suction_rank)

# %%
df.sort_values('total_rank')
# Out:
#       price comp_nm                             prd_nm  usetime  suction  \
# 16   104900     델로라                        V11 파워 300W       70    220.0
# 14   208320     샤오미                            드리미 V11       90    250.0
# 11   154445     샤오미                            드리미 V10       60    220.0
# 6     79050     샤오미                   TROUVER POWER 11       60    200.0
# 26   139000   DIBEA                            M24 MAX       50    250.0
# 28   155090  일렉트로룩스                 에르고라피도 파워프로 ZB3411       48    290.0
# 12   131510  일렉트로룩스                  WELL Q6 WQ61-1OGG       45    220.0
# 27   248000   DIBEA                    차이슨 ALLNEW29000       48    290.0
# 0    560310    삼성전자                 비스포크 제트 VS20A956A3       60    210.0
# 30   177900      로엘                           듀스핀3 PRO      180    100.0
# 21   678300    삼성전자           비스포크 제트 VS20A956A3 + 물걸레       60    210.0
# 19    58940     샤오미              LYDSTO 핸디형 에어펌프 진공청소기       60     70.0
# 18   457600    삼성전자                     제트 VS20T9210BF       60    200.0
# 34   220530  일렉트로룩스                     퓨어 Q9 PQ91-2OG       50    210.0
# 33   731350    삼성전자                 비스포크 제트 VS20A957D3       60    210.0
# 17   770910    삼성전자                 비스포크 제트 VS20A957D2       60    210.0
# 8    807030    LG전자           코드제로 ThinQ A9S AS9370IKT       60    210.0
# 4     49260   베이스어스                  차량용 청소기 A3 (해외구매)       45    150.0
# 5    838500    삼성전자                 비스포크 제트 VS20A957E3       60    210.0
# 7    630600    LG전자               코드제로 ThinQ A9S A9370       60    200.0
# 24   912590    LG전자              코드제로 ThinQ A9S AS9471       60    210.0
# 15   921200    LG전자              코드제로 ThinQ A9S AS9470       60    210.0
# 9    554690     다이슨                        V10 플러피 오리진       60    151.0
# 3     61850     샤오미  CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)       30    168.0
# 13    58540     샤오미     CLEANFLY 차량용 무선 청소기 3세대 (해외구매)       25    168.0
# 2   1056700    LG전자       오브제컬렉션 코드제로 ThinQ A9S AO9571       60    210.0
# 35   191200   에어메이드                           AMC-2150       30    210.0
# 40   278480  일렉트로룩스               퓨어 Q9 파워프로 PQ92-3OBF       53    150.0
# 37   232590  일렉트로룩스                     퓨어 Q9 PQ91-3BW       55    140.0
# 38    25130     샤오미    SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)       30     70.0
# 39    67250     리하스             차량용 미니 무선 청소기 TEB-4120       15    150.0
# 32    38960     샤오미                  미지아 차량용 핸디 무선 청소기        9    130.0
# 10    41020     샤오미           미지아 차량용 핸디 무선 청소기 (해외구매)        9    130.0
# 25  1016870     다이슨                    V12 디텍트 슬림 컴플리트       60    150.0
# 20   133700  일렉트로룩스                      에르고라피도 ZB3311       48     70.0
# 23   543160    LG전자                     코드제로 A9 A9100N       50    140.0
# 22    57900      오아              클린보틀 차량용 청소기 OA-CL002       20     65.0
# 31    89000    인트비즈             MORUN 차량용 무선 미니 청소기 V5       12    130.0
# 36   690100    LG전자                   코드제로 A9 AS9100ST       50    140.0
# 29   629200     다이슨                        디지털 슬림 플러피+       40    100.0
#
#     price_rank  usetime_rank  suction_rank  total_rank
# 16        12.0           3.0           6.0        21.0
# 14        20.0           2.0           3.5        25.5
# 11        16.0          11.5           6.0        33.5
# 6         10.0          11.5          20.0        41.5
# 26        15.0          23.5           3.5        42.0
# 28        17.0          27.0           1.5        45.5
# 12        13.0          29.5           6.0        48.5
# 27        23.0          27.0           1.5        51.5
# 0         28.0          11.5          13.0        52.5
# 30        18.0           1.0          35.5        54.5
# 21        31.0          11.5          13.0        55.5
# 19         7.0          11.5          38.0        56.5
# 18        25.0          11.5          20.0        56.5
# 34        21.0          23.5          13.0        57.5
# 33        33.0          11.5          13.0        57.5
# 17        34.0          11.5          13.0        58.5
# 8         35.0          11.5          13.0        59.5
# 4          4.0          29.5          26.5        60.0
# 5         36.0          11.5          13.0        60.5
# 7         30.0          11.5          20.0        61.5
# 24        37.0          11.5          13.0        61.5
# 15        38.0          11.5          13.0        62.5
# 9         27.0          11.5          24.0        62.5
# 3          8.0          33.0          22.5        63.5
# 13         6.0          35.0          22.5        63.5
# 2         40.0          11.5          13.0        64.5
# 35        19.0          33.0          13.0        65.0
# 40        24.0          21.0          26.5        71.5
# 37        22.0          20.0          30.0        72.0
# 38         1.0          33.0          38.0        72.0
# 39         9.0          37.0          26.5        72.5
# 32         2.0          39.5          33.0        74.5
# 10         3.0          39.5          33.0        75.5
# 25        39.0          11.5          26.5        77.0
# 20        14.0          27.0          38.0        79.0
# 23        26.0          23.5          30.0        79.5
# 22         5.0          36.0          40.0        81.0
# 31        11.0          38.0          33.0        82.0
# 36        32.0          23.5          30.0        85.5
# 29        29.0          31.0          35.5        95.5
