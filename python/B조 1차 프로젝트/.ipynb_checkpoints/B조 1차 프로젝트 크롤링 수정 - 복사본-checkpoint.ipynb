# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re

# %%
df = pd.read_csv('한국소비자원 생필품 및 서비스 가격 정보_20220128.csv', encoding = 'cp949')
df.head()
# Out:
#              상품명         조사일  판매가격       판매업소   제조사 세일여부 원플러스원
# 0  머거본 꿀땅콩(135g)  2022-01-14  3600     CU(본사)   머거본    N     N
# 1  머거본 꿀땅콩(135g)  2022-01-14  2190    롯데슈퍼안양점   머거본    N     N
# 2  허니버터아몬드(210g)  2022-01-14  5990  롯데슈퍼김포전원점  길림양행    N     N
# 3  허니버터아몬드(210g)  2022-01-14  5990    롯데슈퍼길동점  길림양행    N     N
# 4  허니버터아몬드(210g)  2022-01-14  5990    롯데슈퍼구평점  길림양행    N     N

# %%
prods = df['상품명'].unique()
prods
# Out:
# array(['머거본 꿀땅콩(135g)', '허니버터아몬드(210g)', '백설 소면(900g)', '옛날국수 소면(900g)',
#        '고향만두(1.08kg)', '비비고 왕교자(1.05kg)', '생야채돼지고기물만두(800g)',
#        '백설 자른 햇당면(300g)', '옛날 자른당면(300g)', '국산콩두부 부침용(380g)',
#        '국산콩두부 찌개용(380g)', '행복한콩 부침두부(300g)', '행복한콩 찌개두부(300g)',
#        '삼양라면(5개입)', '신라면(5개입)', '진라면 순한맛(5개입)', '곰표 밀가루 중력다목적용(1kg)',
#        '백설 찰밀가루(1kg)', '백설 5가지 재료 부침가루(1kg)', '오뚜기 부침가루(1kg)',
#        '삼립호떡 미니꿀호떡(16개입)', '정통크림빵(3개입)', '보노 콘스프(3개입)',
#        '보노 포르치니버섯스프(3개입)', '오뚜기 크림스프(80g)', '스페셜K 오리지널(480g)',
#        '켈로그 콘푸로스트(600g)', '포스트 콘푸라이트(600g)', '오뚜기 간편 미역국(5개입)',
#        '오뚜기 간편 북엇국(5개입)', '3분 쇠고기짜장(200g)', '3분 쇠고기카레(200g)',
#        '오뚜기 3분 백세카레 약간 매운맛(200g)', '청정원 카레여왕 비프카레(160g)', '오뚜기밥(210g)',
#        '오뚜기밥(3개입)', '오뚜기밥(6개입) ', '햇반(210g)', '햇반(3개입)', '햇반(6개입)',
#        '동원 양반 쇠고기죽(287.5g)', '동원 양반 전복죽(287.5g)', '비비고 소고기죽(280g)',
#        '비비고 전복죽(280g)', '농심 신라면 큰사발면(114g)', '오뚜기 참깨라면 컵(110g)',
#        '팔도 왕뚜껑(110g)', '오뚜기 맛있는 쇠고기미역국밥(162g)', '오뚜기 컵밥 제육덮밥(310g)',
#        '햇반 컵반 고추장 제육덮밥(250g)', '햇반 컵반 미역국밥(167g)', '비비고 사골곰탕(500g)',
#        '비비고 육개장(500g)', '오뚜기 옛날 사골곰탕(350g)', '오뚜기 옛날 육개장(300g)',
#        '오리온 포카칩 오리지널(66g)', '포테토칩 오리지날(125g)', '롯데 자일리톨 오리지날(97g)',
#        '빙그레 참붕어 싸만코(150ml)', '아이비(270g)', '참크래커(280g)', '돼지바(70ml)',
#        '메로나(75ml)', '해태 바밤바(63ml)', '롯데 목캔디 허브민트(217g)',
#        '오리온 통아몬드 캔디(90g)', '농심 새우깡(90g)', '롯데 월드콘 바닐라(160ml)',
#        '투게더 오리지널 바닐라(900ml)', '해태 부라보콘 화이트바닐라(140ml)', '닥터유 에너지바(40g)',
#        '닥터유 에너지바(4개입)', '켈로그 레드베리 에너지바(4개입)', '자유시간(36g)', '자유시간(5개입)',
#        '핫브레이크 미니(714g)', '몽쉘 크림(384g)', '오리온 초코파이(18개입)',
#        '롯데 ABC 초코(187g)', '롯데 빅가나 마일드(110g)', '들기름 재래 도시락김(12팩)',
#        '양반 들기름이 그윽한 김(16팩)', '대림 게맛살 큰잔치(300g)', '동원 싱싱맛살 실속(500g)',
#        '삼호 안심 김밥맛살(264g)', '삼호 안심 부산어묵(400g)', '동원참치 라이트스탠다드(150g)',
#        '동원참치 라이트스탠다드(4캔)', '마일드참치(150g)', '마일드참치(3개)',
#        '사조참치 살코기 안심따개(4캔)', '양조간장 501(500ml)', '진간장 금F3(930ml)',
#        '순창 오리지널 우리쌀 찰고추장(1kg)', '해찬들 우리쌀태양초골드(1kg)',
#        '해표 순창궁 태양초 100% 우리햅쌀 고추장(1.8kg)', '동서 아카시아꿀(600g)', '동서벌꿀(600g)',
#        '샘표 시골집 토장(900g)', '순창 재래식안심생된장(1kg)', '해찬들 재래식 된장(1kg)',
#        '청정원 발사믹 드레싱', '청정원 오리엔탈 드레싱', '오뚜기 고소한 골드 마요네즈(500g)',
#        '청정원 고소한 마요네즈(500g)', '백설 자일로스 설탕(1kg)', '백설 하얀설탕(1kg)',
#        '큐원 하얀설탕(1kg)', '백설 구운소금(500g)', '청정원 미원 맛소금(500g)', '해표 꽃소금(1kg)',
#        '백설 식용유(1.5L)', '오뚜기 콩기름 100%(900ml)', '해표 맑고 신선한 식용유(900ml)',
#        '백설 건강발효 사과식초(800ml)', '백설 건강발효 현미식초(800ml)', '오뚜기 사과식초(900ml)',
#        '청정원 순창 양념듬뿍 쌈장(500g)', '해찬들 사계절 쌈장(500g)', '해표 순창궁 양념쌈장(500g)',
#        '딸기잼(500g)', '복음자리 딸기잼(370g)', '백설 진한참기름', '오뚜기 참기름(320ml)',
#        '오뚜기카레 순한맛(100g)', '청정원 카레여왕 구운마늘&amp;양파(108g)',
#        '오뚜기 토마토 케찹(500g)', '청정원 진한 토마토 케찹(500g)', '산들애 국내산 해물(250g)',
#        '청정원 맛선생 국내산해물(250g)', '달콤한 베지밀 비(16팩)', '달콤한 삼육두유 B',
#        '매일두유 담백한 맛(16팩)', '국순당 생막걸리(750ml)', '국순당 우국생(750ml)',
#        '서울장수생막걸리(750ml)', '제주 위트 에일(500ml)', '카스 프레쉬(500ml)',
#        '카스 프레쉬(6캔)', '테라(500ml)', '하이트 엑스트라 콜드(500ml)', '하이트 엑스트라 콜드(6캔)',
#        '비타500(10개입)', '오로나민C(10개입)', '스프라이트(1.5L)', '칠성사이다 제로(1.5L)',
#        '삼다수(2L)', '삼다수(500ml)', '아이시스(2L)', '아이시스(500ml)', '삼다수(2L*6개)',
#        '삼다수(500ml*20개)', '참이슬 클래식(360ml)', '참이슬 후레쉬(360ml)',
#        '처음처럼(360ml)', '레드불 에너지 드링크(250ml)', '롯데 핫식스(250ml)',
#        '몬스터 에너지(355ml)', '게토레이 레몬(600ml)', '파워에이드 마운틴블라스트(520ml)',
#        '포카리스웨트(620ml)', '델몬트 오렌지 100(1.5L)', '미넷메이드 오렌지(1.5L)',
#        '남양 17차 티백(80개입)', '동서현미녹차(100개입)', '맥심 티오피 마스터 라떼(275ml)',
#        '바리스타룰스 콜드브루 블랙(325ml)', '아카페라 아메리카노(240ml)',
#        '맥스웰 하우스 오리지날(180개입)', '맥심 모카골드 마일드(200개입)',
#        '카누 마일드 로스트 아메리카노(30개입)', '프렌치카페 카페믹스(220개입)', '코카콜라(1.8L)',
#        '펩시콜라(1.8L)', '마주앙 레드(750ml)', '진로 와인(500ml)', '오뚜기 콘마가린(180g)',
#        '떠먹는 불가리스 딸기(4개)', '바이오 플레인 요거트(4개)', '불가리스(4개)', '요플레 오리지널(4개)',
#        '이오(5개)', '앱솔루트 명작 3단계(800g)', '임페리얼 드림 XO 3단계(800g)',
#        '프리미엄 산양분유 1단계(800g)', '그릴후랑크(600g)', '백설 그릴 비엔나(720g)',
#        '의성마늘 빅그릴 비엔나(600g)', '주부9단 프랑크소시지(900g)', '남양유업 맛있는우유GT(1L)',
#        '매일우유 오리지널(900ml)', '서울우유 흰우유(1L)', '파스퇴르우유 후레쉬(930ml)',
#        '드빈치 고칼슘치즈(15매)', '매일유업 뼈로가는 칼슘치즈(270g)', '서울우유 체다슬라이스치즈(400g)',
#        '체다치즈(15매)', '스팸 클래식(200g)', '의성마늘 한입슬라이스햄(60g)',
#        '주부9단 슬라이스햄(300g)', '마미손 고무장갑 중(2세트)', '크린랩 고무장갑 중(2세트)',
#        '크린랩(22cm x 50m)', '크린랩(30cm x 50m)', '맥스 부탄가스(4개)', '썬 부탄가스(4개)',
#        '무균무때 세정제 욕실용(900ml)', '유한락스 레귤러(1.8L)', '유한락스 욕실청소용(1800ml)',
#        '유한락스 후레쉬(1.5L)', '홈스타 락스와세제 후로랄파인(750ml)', '홈스타 욕실용 세정제(900ml)',
#        '에프킬라 에어로졸 무향(500ml)', '컴배트 스피드 에어졸(500ml)', '홈키파 수성 에어졸(500ml)',
#        '다우니 고농축 섬유유연제 엑스퍼트(2L)', '샤프란 아우라 초고농축 섬유유연제 홀리데이판타지(2.3L)',
#        '피죤 섬유유연제 핑크로즈(2.1L)', '샤프란 네이처 섬유탈취제 프레쉬 민트(300ml)',
#        '페브리즈 상쾌한향(370ml)', '페브리즈 상쾌한향(900ml)', '때가 쏙 비트 분말세제(6kg)',
#        '비트 트리플 액션(2.8L)', '스파크 분말세제(6kg)', '테크 UP 분말세제(4kg)',
#        '테크 베이킹소다 액체세제(3L)', '퍼실 파워젤 액체 드럼용(2.7L)', '퍼실 파워젤 액체 일반용(2.7L)',
#        '물먹는하마(3개입)', '피죤 습기제로(8개입)',
#        '3M 후레쉬 슬라이드 지퍼백 중형(21cm x 16cm x 6cm)', '손잡이 크린백(35cm x 45cm)',
#        '지퍼락 지퍼백 냉장 중형(20매)', '크린롤백(25cm x 35cm)', '크린지퍼백(18cm x 20cm)',
#        '메소드 주방세제 핑크(532ml)', '자연퐁 솔잎(490ml)',
#        '프릴 시크릿 오브 베이킹소다 퓨어레몬향(750ml)', '항균 트리오(973ml)', '코디 키친타월(6롤)',
#        '크리넥스 안심 키친타월(6롤)', '밥이보약 CAT 걱정없는 헤어볼', '밥이보약 튼튼한관절',
#        'JB 뉴 베드타임 로션(500ml)', '정말 순한 바디밀크(450ml)', '크리넥스 KF94 4단 마스크',
#        'PACE6 스타일 면도날(4개)', '플로쉴드 옐로우 면도날(4개)', '하이드로8 면도날(8개)',
#        '도브 뷰티 너리싱 바디워시(1kg)', '도브 센스티브 스킨 바디워시(1kg)',
#        '세이 온더바디 고보습 아이리스(900ml)', '오가니스트 히말라야 핑크솔트 바디워시 리프레싱 민트향(865ml)',
#        '해피바스 라벤더 에센스 바디워시(900g)', '도브 뷰티바(4개)', '드봉 스위트로즈(4개)',
#        '해피바스 허브 라벤더 아로마 바(4개)', '쏘피 바디피트 볼록맞춤 날개 중형(32개입)',
#        '좋은느낌 울트라슬림 에어핏쿠션 날개 중형(36개입)', '좋은느낌 좋은순면 울트라 날개 중형(36개입)',
#        '화이트 시크릿홀 날개 중형(36개입)', '려 함빛 극손상엔영양케어 샴푸(550ml)',
#        '미쟝센 퍼펙트세럼 샴푸(680ml)', '엘라스틴 모로칸 아르간 오일 집중영양 샴푸(680ml)',
#        '케라리스 데미지 클리닉 오리지널 샴푸(750ml)', '랩신 핸드워시 센서티브(250ml)',
#        '아이!깨끗해 항균폼 상큼레몬향(250ml)', '려 두피보호 한방염색 짙은 밤색 4.5(60g)',
#        '리엔 흑모비책크림염색 자연갈색(60g)', '미쟝센 쉽고빠른거품염색 3N 흑갈색(40g)',
#        '하기스 매직컴포트 대형 공용 팬티형 4단계(40매)', '하기스 매직컴포트 중형 공용 밴드형 3단계(66매)',
#        '하기스 매직컴포트 특대형 공용 팬티형 5단계(33매)', '메디안 치석 치약 오리지널(3개)',
#        '어드밴스 캐비티 블루(120g)', '어드밴스 캐비티 블루(3개)', '페리오 캐비티케어(3개)',
#        '오랄비 크로스액션(3개입)', '죽염 칫술 잇몸(4개)', '페리오 토탈7 칫솔 힘있는 미세모(4개)',
#        '크리넥스 데코엔소프트 3겹(24롤)', '가그린 오리지널(750ml)', '리스테린 쿨민트(750ml)',
#        '갈치(냉동, 100g)', '갈치(생물, 100g)', '고등어(생물, 300~500g)',
#        '오징어(냉동, 200~300g)', '오징어(생물, 200~300g)', '부세(200~400g)',
#        '참조기(200~400g)', '당근(흙당근, 100g)', '대파(흙대파, 500~800g)',
#        '무(줄기 없는 무, 1.5kg)', '배추(1.5~2kg)', 'CJ 행복한콩 국산콩 콩나물(280g)',
#        '국산아작아작콩나물(350g)', 'CJ 더안심 건강란(대란 15개)', 'CJ 알짜란(대란 15개)',
#        '목초를 먹고 자란 건강한 닭이 낳은 달걀(대란 15개)', '풀무원 동물복지 목초란(대란 10개)',
#        '참프레 동물복지 닭백숙(1.1kg)', '하림 자연실록백숙(830g)', '하림 토종닭백숙(1.05kg)',
#        '돼지고기 목살(100g)', '돼지고기 삼겹살(100g)', '쇠고기 등심(1+등급, 100g)',
#        '쇠고기 등심(1등급, 100g)', '쇠고기 불고기(1+등급, 100g)', '쇠고기 불고기(1등급, 100g)',
#        'CJ 비비고 왕교자(910g)', '해태 오예스(12개입)', '대림선어묵 부산어묵(300g)',
#        '오뚜기 소프트마가린(180g)', '덴마크 오리지널 치즈(14매)', '깨끗한나라 순수 시그니쳐 3겹(30롤)'],
#       dtype=object)

# %%
## 유니크 품목

products = []
for product in prods:
    products.append(product)
products
# Out:
# ['머거본 꿀땅콩(135g)',
#  '허니버터아몬드(210g)',
#  '백설 소면(900g)',
#  '옛날국수 소면(900g)',
#  '고향만두(1.08kg)',
#  '비비고 왕교자(1.05kg)',
#  '생야채돼지고기물만두(800g)',
#  '백설 자른 햇당면(300g)',
#  '옛날 자른당면(300g)',
#  '국산콩두부 부침용(380g)',
#  '국산콩두부 찌개용(380g)',
#  '행복한콩 부침두부(300g)',
#  '행복한콩 찌개두부(300g)',
#  '삼양라면(5개입)',
#  '신라면(5개입)',
#  '진라면 순한맛(5개입)',
#  '곰표 밀가루 중력다목적용(1kg)',
#  '백설 찰밀가루(1kg)',
#  '백설 5가지 재료 부침가루(1kg)',
#  '오뚜기 부침가루(1kg)',
#  '삼립호떡 미니꿀호떡(16개입)',
#  '정통크림빵(3개입)',
#  '보노 콘스프(3개입)',
#  '보노 포르치니버섯스프(3개입)',
#  '오뚜기 크림스프(80g)',
#  '스페셜K 오리지널(480g)',
#  '켈로그 콘푸로스트(600g)',
#  '포스트 콘푸라이트(600g)',
#  '오뚜기 간편 미역국(5개입)',
#  '오뚜기 간편 북엇국(5개입)',
#  '3분 쇠고기짜장(200g)',
#  '3분 쇠고기카레(200g)',
#  '오뚜기 3분 백세카레 약간 매운맛(200g)',
#  '청정원 카레여왕 비프카레(160g)',
#  '오뚜기밥(210g)',
#  '오뚜기밥(3개입)',
#  '오뚜기밥(6개입) ',
#  '햇반(210g)',
#  '햇반(3개입)',
#  '햇반(6개입)',
#  '동원 양반 쇠고기죽(287.5g)',
#  '동원 양반 전복죽(287.5g)',
#  '비비고 소고기죽(280g)',
#  '비비고 전복죽(280g)',
#  '농심 신라면 큰사발면(114g)',
#  '오뚜기 참깨라면 컵(110g)',
#  '팔도 왕뚜껑(110g)',
#  '오뚜기 맛있는 쇠고기미역국밥(162g)',
#  '오뚜기 컵밥 제육덮밥(310g)',
#  '햇반 컵반 고추장 제육덮밥(250g)',
#  '햇반 컵반 미역국밥(167g)',
#  '비비고 사골곰탕(500g)',
#  '비비고 육개장(500g)',
#  '오뚜기 옛날 사골곰탕(350g)',
#  '오뚜기 옛날 육개장(300g)',
#  '오리온 포카칩 오리지널(66g)',
#  '포테토칩 오리지날(125g)',
#  '롯데 자일리톨 오리지날(97g)',
#  '빙그레 참붕어 싸만코(150ml)',
#  '아이비(270g)',
#  '참크래커(280g)',
#  '돼지바(70ml)',
#  '메로나(75ml)',
#  '해태 바밤바(63ml)',
#  '롯데 목캔디 허브민트(217g)',
#  '오리온 통아몬드 캔디(90g)',
#  '농심 새우깡(90g)',
#  '롯데 월드콘 바닐라(160ml)',
#  '투게더 오리지널 바닐라(900ml)',
#  '해태 부라보콘 화이트바닐라(140ml)',
#  '닥터유 에너지바(40g)',
#  '닥터유 에너지바(4개입)',
#  '켈로그 레드베리 에너지바(4개입)',
#  '자유시간(36g)',
#  '자유시간(5개입)',
#  '핫브레이크 미니(714g)',
#  '몽쉘 크림(384g)',
#  '오리온 초코파이(18개입)',
#  '롯데 ABC 초코(187g)',
#  '롯데 빅가나 마일드(110g)',
#  '들기름 재래 도시락김(12팩)',
#  '양반 들기름이 그윽한 김(16팩)',
#  '대림 게맛살 큰잔치(300g)',
#  '동원 싱싱맛살 실속(500g)',
#  '삼호 안심 김밥맛살(264g)',
#  '삼호 안심 부산어묵(400g)',
#  '동원참치 라이트스탠다드(150g)',
#  '동원참치 라이트스탠다드(4캔)',
#  '마일드참치(150g)',
#  '마일드참치(3개)',
#  '사조참치 살코기 안심따개(4캔)',
#  '양조간장 501(500ml)',
#  '진간장 금F3(930ml)',
#  '순창 오리지널 우리쌀 찰고추장(1kg)',
#  '해찬들 우리쌀태양초골드(1kg)',
#  '해표 순창궁 태양초 100% 우리햅쌀 고추장(1.8kg)',
#  '동서 아카시아꿀(600g)',
#  '동서벌꿀(600g)',
#  '샘표 시골집 토장(900g)',
#  '순창 재래식안심생된장(1kg)',
#  '해찬들 재래식 된장(1kg)',
#  '청정원 발사믹 드레싱',
#  '청정원 오리엔탈 드레싱',
#  '오뚜기 고소한 골드 마요네즈(500g)',
#  '청정원 고소한 마요네즈(500g)',
#  '백설 자일로스 설탕(1kg)',
#  '백설 하얀설탕(1kg)',
#  '큐원 하얀설탕(1kg)',
#  '백설 구운소금(500g)',
#  '청정원 미원 맛소금(500g)',
#  '해표 꽃소금(1kg)',
#  '백설 식용유(1.5L)',
#  '오뚜기 콩기름 100%(900ml)',
#  '해표 맑고 신선한 식용유(900ml)',
#  '백설 건강발효 사과식초(800ml)',
#  '백설 건강발효 현미식초(800ml)',
#  '오뚜기 사과식초(900ml)',
#  '청정원 순창 양념듬뿍 쌈장(500g)',
#  '해찬들 사계절 쌈장(500g)',
#  '해표 순창궁 양념쌈장(500g)',
#  '딸기잼(500g)',
#  '복음자리 딸기잼(370g)',
#  '백설 진한참기름',
#  '오뚜기 참기름(320ml)',
#  '오뚜기카레 순한맛(100g)',
#  '청정원 카레여왕 구운마늘&amp;양파(108g)',
#  '오뚜기 토마토 케찹(500g)',
#  '청정원 진한 토마토 케찹(500g)',
#  '산들애 국내산 해물(250g)',
#  '청정원 맛선생 국내산해물(250g)',
#  '달콤한 베지밀 비(16팩)',
#  '달콤한 삼육두유 B',
#  '매일두유 담백한 맛(16팩)',
#  '국순당 생막걸리(750ml)',
#  '국순당 우국생(750ml)',
#  '서울장수생막걸리(750ml)',
#  '제주 위트 에일(500ml)',
#  '카스 프레쉬(500ml)',
#  '카스 프레쉬(6캔)',
#  '테라(500ml)',
#  '하이트 엑스트라 콜드(500ml)',
#  '하이트 엑스트라 콜드(6캔)',
#  '비타500(10개입)',
#  '오로나민C(10개입)',
#  '스프라이트(1.5L)',
#  '칠성사이다 제로(1.5L)',
#  '삼다수(2L)',
#  '삼다수(500ml)',
#  '아이시스(2L)',
#  '아이시스(500ml)',
#  '삼다수(2L*6개)',
#  '삼다수(500ml*20개)',
#  '참이슬 클래식(360ml)',
#  '참이슬 후레쉬(360ml)',
#  '처음처럼(360ml)',
#  '레드불 에너지 드링크(250ml)',
#  '롯데 핫식스(250ml)',
#  '몬스터 에너지(355ml)',
#  '게토레이 레몬(600ml)',
#  '파워에이드 마운틴블라스트(520ml)',
#  '포카리스웨트(620ml)',
#  '델몬트 오렌지 100(1.5L)',
#  '미넷메이드 오렌지(1.5L)',
#  '남양 17차 티백(80개입)',
#  '동서현미녹차(100개입)',
#  '맥심 티오피 마스터 라떼(275ml)',
#  '바리스타룰스 콜드브루 블랙(325ml)',
#  '아카페라 아메리카노(240ml)',
#  '맥스웰 하우스 오리지날(180개입)',
#  '맥심 모카골드 마일드(200개입)',
#  '카누 마일드 로스트 아메리카노(30개입)',
#  '프렌치카페 카페믹스(220개입)',
#  '코카콜라(1.8L)',
#  '펩시콜라(1.8L)',
#  '마주앙 레드(750ml)',
#  '진로 와인(500ml)',
#  '오뚜기 콘마가린(180g)',
#  '떠먹는 불가리스 딸기(4개)',
#  '바이오 플레인 요거트(4개)',
#  '불가리스(4개)',
#  '요플레 오리지널(4개)',
#  '이오(5개)',
#  '앱솔루트 명작 3단계(800g)',
#  '임페리얼 드림 XO 3단계(800g)',
#  '프리미엄 산양분유 1단계(800g)',
#  '그릴후랑크(600g)',
#  '백설 그릴 비엔나(720g)',
#  '의성마늘 빅그릴 비엔나(600g)',
#  '주부9단 프랑크소시지(900g)',
#  '남양유업 맛있는우유GT(1L)',
#  '매일우유 오리지널(900ml)',
#  '서울우유 흰우유(1L)',
#  '파스퇴르우유 후레쉬(930ml)',
#  '드빈치 고칼슘치즈(15매)',
#  '매일유업 뼈로가는 칼슘치즈(270g)',
#  '서울우유 체다슬라이스치즈(400g)',
#  '체다치즈(15매)',
#  '스팸 클래식(200g)',
#  '의성마늘 한입슬라이스햄(60g)',
#  '주부9단 슬라이스햄(300g)',
#  '마미손 고무장갑 중(2세트)',
#  '크린랩 고무장갑 중(2세트)',
#  '크린랩(22cm x 50m)',
#  '크린랩(30cm x 50m)',
#  '맥스 부탄가스(4개)',
#  '썬 부탄가스(4개)',
#  '무균무때 세정제 욕실용(900ml)',
#  '유한락스 레귤러(1.8L)',
#  '유한락스 욕실청소용(1800ml)',
#  '유한락스 후레쉬(1.5L)',
#  '홈스타 락스와세제 후로랄파인(750ml)',
#  '홈스타 욕실용 세정제(900ml)',
#  '에프킬라 에어로졸 무향(500ml)',
#  '컴배트 스피드 에어졸(500ml)',
#  '홈키파 수성 에어졸(500ml)',
#  '다우니 고농축 섬유유연제 엑스퍼트(2L)',
#  '샤프란 아우라 초고농축 섬유유연제 홀리데이판타지(2.3L)',
#  '피죤 섬유유연제 핑크로즈(2.1L)',
#  '샤프란 네이처 섬유탈취제 프레쉬 민트(300ml)',
#  '페브리즈 상쾌한향(370ml)',
#  '페브리즈 상쾌한향(900ml)',
#  '때가 쏙 비트 분말세제(6kg)',
#  '비트 트리플 액션(2.8L)',
#  '스파크 분말세제(6kg)',
#  '테크 UP 분말세제(4kg)',
#  '테크 베이킹소다 액체세제(3L)',
#  '퍼실 파워젤 액체 드럼용(2.7L)',
#  '퍼실 파워젤 액체 일반용(2.7L)',
#  '물먹는하마(3개입)',
#  '피죤 습기제로(8개입)',
#  '3M 후레쉬 슬라이드 지퍼백 중형(21cm x 16cm x 6cm)',
#  '손잡이 크린백(35cm x 45cm)',
#  '지퍼락 지퍼백 냉장 중형(20매)',
#  '크린롤백(25cm x 35cm)',
#  '크린지퍼백(18cm x 20cm)',
#  '메소드 주방세제 핑크(532ml)',
#  '자연퐁 솔잎(490ml)',
#  '프릴 시크릿 오브 베이킹소다 퓨어레몬향(750ml)',
#  '항균 트리오(973ml)',
#  '코디 키친타월(6롤)',
#  '크리넥스 안심 키친타월(6롤)',
#  '밥이보약 CAT 걱정없는 헤어볼',
#  '밥이보약 튼튼한관절',
#  'JB 뉴 베드타임 로션(500ml)',
#  '정말 순한 바디밀크(450ml)',
#  '크리넥스 KF94 4단 마스크',
#  'PACE6 스타일 면도날(4개)',
#  '플로쉴드 옐로우 면도날(4개)',
#  '하이드로8 면도날(8개)',
#  '도브 뷰티 너리싱 바디워시(1kg)',
#  '도브 센스티브 스킨 바디워시(1kg)',
#  '세이 온더바디 고보습 아이리스(900ml)',
#  '오가니스트 히말라야 핑크솔트 바디워시 리프레싱 민트향(865ml)',
#  '해피바스 라벤더 에센스 바디워시(900g)',
#  '도브 뷰티바(4개)',
#  '드봉 스위트로즈(4개)',
#  '해피바스 허브 라벤더 아로마 바(4개)',
#  '쏘피 바디피트 볼록맞춤 날개 중형(32개입)',
#  '좋은느낌 울트라슬림 에어핏쿠션 날개 중형(36개입)',
#  '좋은느낌 좋은순면 울트라 날개 중형(36개입)',
#  '화이트 시크릿홀 날개 중형(36개입)',
#  '려 함빛 극손상엔영양케어 샴푸(550ml)',
#  '미쟝센 퍼펙트세럼 샴푸(680ml)',
#  '엘라스틴 모로칸 아르간 오일 집중영양 샴푸(680ml)',
#  '케라리스 데미지 클리닉 오리지널 샴푸(750ml)',
#  '랩신 핸드워시 센서티브(250ml)',
#  '아이!깨끗해 항균폼 상큼레몬향(250ml)',
#  '려 두피보호 한방염색 짙은 밤색 4.5(60g)',
#  '리엔 흑모비책크림염색 자연갈색(60g)',
#  '미쟝센 쉽고빠른거품염색 3N 흑갈색(40g)',
#  '하기스 매직컴포트 대형 공용 팬티형 4단계(40매)',
#  '하기스 매직컴포트 중형 공용 밴드형 3단계(66매)',
#  '하기스 매직컴포트 특대형 공용 팬티형 5단계(33매)',
#  '메디안 치석 치약 오리지널(3개)',
#  '어드밴스 캐비티 블루(120g)',
#  '어드밴스 캐비티 블루(3개)',
#  '페리오 캐비티케어(3개)',
#  '오랄비 크로스액션(3개입)',
#  '죽염 칫술 잇몸(4개)',
#  '페리오 토탈7 칫솔 힘있는 미세모(4개)',
#  '크리넥스 데코엔소프트 3겹(24롤)',
#  '가그린 오리지널(750ml)',
#  '리스테린 쿨민트(750ml)',
#  '갈치(냉동, 100g)',
#  '갈치(생물, 100g)',
#  '고등어(생물, 300~500g)',
#  '오징어(냉동, 200~300g)',
#  '오징어(생물, 200~300g)',
#  '부세(200~400g)',
#  '참조기(200~400g)',
#  '당근(흙당근, 100g)',
#  '대파(흙대파, 500~800g)',
#  '무(줄기 없는 무, 1.5kg)',
#  '배추(1.5~2kg)',
#  'CJ 행복한콩 국산콩 콩나물(280g)',
#  '국산아작아작콩나물(350g)',
#  'CJ 더안심 건강란(대란 15개)',
#  'CJ 알짜란(대란 15개)',
#  '목초를 먹고 자란 건강한 닭이 낳은 달걀(대란 15개)',
#  '풀무원 동물복지 목초란(대란 10개)',
#  '참프레 동물복지 닭백숙(1.1kg)',
#  '하림 자연실록백숙(830g)',
#  '하림 토종닭백숙(1.05kg)',
#  '돼지고기 목살(100g)',
#  '돼지고기 삼겹살(100g)',
#  '쇠고기 등심(1+등급, 100g)',
#  '쇠고기 등심(1등급, 100g)',
#  '쇠고기 불고기(1+등급, 100g)',
#  '쇠고기 불고기(1등급, 100g)',
#  'CJ 비비고 왕교자(910g)',
#  '해태 오예스(12개입)',
#  '대림선어묵 부산어묵(300g)',
#  '오뚜기 소프트마가린(180g)',
#  '덴마크 오리지널 치즈(14매)',
#  '깨끗한나라 순수 시그니쳐 3겹(30롤)']

# %%
## 유니크 품목을 낮은 가격순으로 검색 했을 때 나오는 모든 제품들 크롤링


from collections import deque
sample_ = deque()
for prod in prods:
    url = 'https://www.coupang.com/np/search?rocketAll=false&q={}&brand=&offerCondition=&filter=&availableDeliveryFilter=&filterType=&isPriceRange=false&priceRange=&minPrice=&maxPrice=&page=1&trcid=&traid=&filterSetByUser=true&channel=user&backgroundColor=&searchProductCount=326&component=&rating=0&sorter=salePriceAsc&listSize=36'
    url = url.format(prod)
    
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36'}
    
    res = requests.get(url, headers = headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    lis = soup.select(' a > dl > dd > div')
    
    for li in lis:
        try:
                sample_.appendleft([li.select('div.name')[0].text,
                        li.select('strong.price-value')[0].text])
                print(li.select('div.name')[0].text)
                print(li.select('strong.price-value')[0].text)
        except:
            pass
# Out:
# 머거본 알땅콩(캔) 135g, 1개
# 1,890
# [BIGHAND] 머거본 알땅콩 캔 135g, 1개
# 1,970
# 머거본 꿀땅콩 135g 식품 > 신선식품 건과/견과류 견과류 일반땅콩, 1개입
# 1,980
# [머거본] 꿀땅콩 135g, 단품
# 2,100
# 상세설명참고 머거본 꿀땅콩 캔 135g
# 2,300
# [머거본] 꿀땅콩 135g 1캔
# 2,300
# 머거본 꿀땅콩 135g, 상세페이지 참조
# 2,330
# 머거본 꿀땅콩 캔 135g 식품 > 스낵/간식 원물간식 기타원물간식, 1, 1개
# 2,390
# 머거본 알땅콩 135g x 1캔
# 2,420
# 머거본 꿀땅콩 135g 너트 피넛 캔 안주 허니 맛땅콩, 1N5R_머거본 꿀땅콩 135g
# 3,000
# 머거본 허니 꿀땅콩 135g 피넛 견과류 마른 안주 간식 군것질 주전부리
# 3,080
# 머거본 원하프꿀땅콩, 135g
# 3,310
# 샘표 질러 부드러운 육포 30G, 단품
# 3,500
# (맛나)꿀땅콩 135G/머거본, 1개
# 3,530
# 무배_꿀땅콩(머거본 135g)/식당, 1
# 3,680
# [머거본] 꿀땅콩 300g 1봉, 없음
# 4,500
# 머거본 꿀땅콩 135g, 상세페이지 참조
# 4,800
# ☞고객대만족↗¶ 견과류 아버지술 소주안주 아빠술 꿀땅콩 맥주안주 머거본 (k‡f*H) 135g, 1개, ♬본 상품 선택하기_Happys™
# 5,250
# ¶⊙핫딜_A+ 아버지 맥주 술안주 견과류 소주 FK 안주 꿀땅콩 머거본 (Mf!♩x) 135g, 1개, ☞ 해당 상품 선택하기_DoDream™
# 5,290
# 머거본 꿀땅콩 135g, 3개입
# 5,310
# Happy 꿀땅콩(머거본 135g) 건강식품 농산물 부모님선물, 해피니스하우스 1, 해피니스하우스 본상품선택
# 5,400
# 머거본 후렌치 후라이드 아몬드 135g, 본상품선택
# 5,900
# 꿀땅콩(머거본 135g) 대용량 업소용 식당용 납품용
# 7,020
# 꿀땅콩 캔 135g X 3 견과류 와인 맥주안주, 1IYM_꿀땅콩 캔 135g X3
# 7,200
# 머거본 꿀땅콩, 55g, 12개
# 8,120
# 머거본 꿀땅콩 135g 마른안주 업소용안주, 1
# 8,210
# 꿀땅콩 머거본 135g
# 8,860
# 브랜드없음 [머거본] 꿀땅콩 300g 3봉, 3개
# 9,600
# 머거본 칼몬드 혼합견과 100g + 새우몬드 80g + 꿀땅콩 135g, 1세트
# 9,800
# [머거본] 꿀땅콩 135g 3캔
# 9,900
# 어린이견과류 오리진 뿌려먹는견과 135g) FK 꿀땅콩(머거본 믹스넛점보 프리미엄한봉견과, 상세페이지 참조
# 10,190
# [머거본] 꿀땅콩 270g 2캔
# 10,200
# 머거본 꿀땅콩-135g, 1개
# 10,380
# 머거본 견과류 간식 대용량 클래식 꿀땅콩 1kg, 선택/단일상품
# 10,900
# [머거본] 꿀땅콩 300g 2봉
# 11,200
# 머거본 맛땅콩 135g x 6캔, 상세설명 참조
# 11,800
# 방자네 사무실 회사 간식 과자 허니버터 아몬드 10g, 1개
# 340
# 【红】 길림)허니버터아몬드30gx1개입 GЯ1+VIP_ 생활용품, GЯ 1
# 1,800
# HBAF 허니버터 아몬드 와사비 떡볶이맛 군옥수수 쿠키앤크림 130g 와사비맛 땅콩 120g, 1개, 0, 군옥수수땅콩 120g
# 2,600
# 길림양행 HBAF 바프 허니버터아몬드120g 민트초코아몬드 인절미맛아몬드 별빛팡팡아몬드 쿠키앤크림아몬드 티라미수아몬드 토피넛라떼아몬드 카마멜아몬드앤프레첼 흑당밀크티아몬드, 별빛팡팡아몬드120g
# 3,440
# HBAF 허니버터 아몬드 와사비 떡볶이맛 군옥수수 쿠키앤크림 130g 와사비맛 땅콩 120g, 떡볶이맛 아몬드 130g, 1개
# 3,700
# HBAF 바프 길림양행 탐스팜 아몬드 (20종) 허니버터 와사비맛 티라미슈 민트초코 군옥수수 등등, 제주말차아몬드 120g
# 3,800
# 길림양행 탐스팜 HBAF 바프 땅콩 아몬드 120g 26종 중 1선택 허니버터 헤이즐넛 당근케이크 체리쥬빌레 군옥수수 와사비 청양마요 흑임자 불닭 민트초코 제주말차 쿠키앤크림 등, 별빛팡팡아몬드(120g)
# 3,900
# 방자네 허니버터 아몬드 210g, 상세페이지 참조
# 4,700
# 길림양행 탐스팜 HBAF 바프 아몬드 19종 중 1선택 대용량 허니버터 210g 청양마요 마늘빵 떡볶이 불닭 그린티라떼 군옥수수 와사비 민트초코 카라멜 인절미 쿠키앤크림 티라미수, 별빛팡팡(190g)
# 4,710
# 길림양행 탐스팜 HBAF 바프 아몬드 19종 중 1선택 대용량 허니버터 210g 청양마요 마늘빵 떡볶이 불닭 그린티라떼 군옥수수 와사비 민트초코 카라멜 인절미 쿠키앤크림 티라미수, 흑임자(190g)
# 4,730
# HBAF 바프 길림양행 아몬드 대용량 허니버터 와사비 당근케이크 군옥수수 흑임자 병아리콩, 16.당근케이크 190g
# 4,970
# 길림양행 탐스팜 HBAF 바프 대용량 아몬드 210g 땅콩 27종 중 1선택 사은품 증정 허니버터 구운당근 당근케이크 헤이즐넛 마늘빵 불닭 군옥수수 와사비 민트초코 쿠키앤크림 등, 떡볶이(210g)
# 4,980
# HBAF 허니버터아몬드(170g 190g 210g) 18종 별빛팡팡 인절미 청양마요 와사비 제주말차 흑당밀크 쿠키앤크림 군옥수수 마늘빵 민트초코 카라멜아몬드 토피넛라떼 티라미수, 당근케이크(190g)
# 4,990
# HBAF 허니버터 아몬드 와사비 떡볶이맛 군옥수수 불닭맛 210g 와사비맛 땅콩 120g, 티라미슈 아몬드 190g, 1개
# 5,100
# 길림양행 HBAF 바프 아몬드 190~210g 허니버터 군옥수수맛 마늘빵 흑임자 와사비 청양마요 민트초코 인절미 불닭 떡볶이 쿠키앤크림 카라멜, 별빛팡팡 190g
# 5,200
# 길림양행 HBAF 바프 아몬드 190~210g 허니버터 군옥수수맛 마늘빵 흑임자 와사비 청양마요 민트초코 인절미 불닭 떡볶이 쿠키앤크림 카라멜, 토피넛라떼 190g
# 5,200
# 길림양행 HBAF 바프 허니버터아몬드 대용량 세일상품, 청양마요아몬드210g
# 5,200
# 길림양행 HBAF 바프 아몬드 190~210g 허니버터 군옥수수맛 마늘빵 흑임자 와사비 청양마요 민트초코 인절미 불닭 떡볶이 쿠키앤크림 카라멜, 쿠키앤크림 190g
# 5,200
# 길림양행 HBAF 바프 아몬드 190~210g 허니버터 군옥수수맛 마늘빵 흑임자 와사비 청양마요 민트초코 인절미 불닭 떡볶이 쿠키앤크림 카라멜, 당근케이크 190g
# 5,200
# 길림양행 HBAF 바프 아몬드 190~210g 허니버터 군옥수수맛 마늘빵 흑임자 와사비 청양마요 민트초코 인절미 불닭 떡볶이 쿠키앤크림 카라멜, 민트초코 190g
# 5,200
# 길림양행 HBAF 바프 아몬드 190~210g 허니버터 군옥수수맛 마늘빵 흑임자 와사비 청양마요 민트초코 인절미 불닭 떡볶이 쿠키앤크림 카라멜, 흑당밀크티 190g
# 5,200
# 길림양행 바프 HBAF 마늘빵 청양마요 흑임자 아몬드 210g, 마늘빵 210g
# 5,300
# 길림양행 바프 HBAF 마늘빵 청양마요 흑임자 아몬드 210g, 흑임자 190g
# 5,350
# 길림양행HBAF 대용량 29종 허니버터아몬드 군옥수수 와사비 마늘빵 당근케이크 흑임자 청양마요 제주말차 쿠키앤크림 인절미 불닭 민트초코 티라미수 카라멜아몬드앤프레첼 복숭아, 허니버터아몬드210g
# 5,390
# [HBAF] 바프 허니버터 아몬드 210g, 단품
# 5,400
# 길림 바프 허니버터 아몬드 210g)
# 5,470
# 바프 아몬드 전지현 티라미수맛 아몬드 210g 별빛팡팡 와사비 허니버터 쿠키앤크림 티라미슈 군옥수수 흑당밀크티 인절미 토피넛라떼 김맛 제주말차 길림양행, 당근케이크아몬드210x1
# 5,490
# 바프 아몬드 전지현 티라미수맛 아몬드 210g 별빛팡팡 와사비 허니버터 쿠키앤크림 티라미슈 군옥수수 흑당밀크티 인절미 토피넛라떼 김맛 제주말차 길림양행, 마늘빵아몬드210gx1
# 5,490
# 길림양행 HBAF 바프 허니버터아몬드 대용량 세일상품, 민트초코아몬드190g
# 5,500
# 머거본 불닭볶음 아몬드 210g, 머거본불닭볶음아몬드210g개
# 5,500
# 방자네 와사비맛 아몬드 210g, 1개
# 5,700
# 바프 허니버터 아몬드, 40g, 6개
# 5,510
# HBAF 길림양행 허니버터 아몬드 130g, 1봉
# 5,890
# 방자네 불닭맛 아몬드 210g, 1개
# 6,100
# 방자네 군옥수수맛 아몬드 10g 210g, 1개
# 6,500
# 탐스팜 불닭맛 아몬드, 불닭 210g
# 6,700
# 백설 중면, 900g, 1개
# 1,980
# [메가마트]백설 제일제면소 칼국수면 9인분 900G, 1개
# 2,500
# CJ제일제당 백설 제일제면소 소면900g 중면900g 칼국수면 비빔장270g, 02백설 중면900g
# 2,600
# 씨제이제일제당 백설 소면 900g x 1개, 단품
# 3,200
# CJ제일제당 백설 제일제면소 소면 900g
# 3,440
# 백설 칼국수면900g
# 3,540
# CJ백설 제일제면소(칼국수)900g, 1개
# 3,630
# 백설 제일제면소 소면(900g)
# 3,760
# 쓰담 CJ백설 제일제면소 칼국수 900g 국수 소면 소바 칼국수 스파게티, 본상품선택
# 3,770
# CJ백설 제일제면소(소면)900g, 1, 본상품선택
# 3,780
# CJ백설 제일제면소(칼국수)900g 국수 소면 소바 칼국수 스파게티, 1
# 3,820
# CJ백설 제일제면소 칼국수 900g 국수 소면 소바 칼국수 스파게티 ffff, 1
# 3,910
# CJ백설 제일제면소(칼국수)900g 국수 소면 소바 칼국수 스파게티, 1
# 3,970
# CJ백설 제일제면소(소면)900g 국수 소면 소바 칼국수 스파게티, 수앤미 1
# 4,000
# CJ백설 제일제면소(소면)900g 국수 소면 소바 칼국수 스파게티, 1, 본제품선택
# 4,010
# [힘몬]_CJ백설 제일제면소(소면)900그램, 상세페이지 참조
# 4,110
# 제일제면소900g 소면 W721040 국수 칼 소바 백설 스파게티, 1, 본상품선택
# 4,150
# [배몬] CJ백설 제일제면소(칼국수)900그램 국수 소면 소바 칼국수 스파게티 _ 핫템 냠냠 BLMON+023487EA, 옵션 :  1, 옵션 :  본상품선택
# 4,160
# [봉몬] CJ백설 제일제면소(칼국수)900그램 국수 소면 소바 칼국수 스파게티 _ 잇템 나혼자산다 VLMON+026415EA, 옵션 :  1, 옵션 :  본상품선택
# 4,160
# [스몬] CJ백설 제일제면소(칼국수)900그램 국수 소면 소바 칼국수 스파게티 _ 핫템 나혼자산다 SEMON+056821EA, 옵션 :  1, 옵션 :  본상품선택
# 4,160
# [달몬] CJ백설 제일제면소(칼국수)900그램 국수 소면 소바 칼국수 스파게티 DLMON+013475EA, 옵션 :  1, 옵션 :  본상품선택
# 4,160
# CJ백설 제일제면소(소면)900g, 본상품선택
# 4,200
# [작은상점] CJ백설 제일제면소(칼국수)900g 국수 소면 소바 칼국수 스파게티 9365EA, 1, 본상품선택
# 4,200
# CJ백설 제일제면소(소면)900g 국수 소면 소바 칼국수 스파게티 +S/No.; 040, 1
# 4,240
# ♪앵콜상품♬♩ 소바 스파게티 칼국수 CJ백설 제일제면소 소면 900g (A!RI‡), 1개
# 4,310
# a핫템bWfqE-n2364qCJ백설 제일제면소(소면)900g_Leq2409y, 1, 쿠팡 본상품선택
# 4,340
# CJ JW721040 백설 소면 소바 제일제면소900g 국수 스파게티 냉장냉동요리, JL 1
# 4,490
# 백설 제일제면소 소면, 1개, 900g
# 4,490
# 백설 제일제면소(칼국수)900g, 본상품
# 4,520
# RW721043 백설 국수 소면 소바 제일제면소900g 스파게티 냉장냉동요리, BR 1
# 4,530
# RW721040 백설 국수 소면 소바 제일제면소900g 스파게티 냉장냉동요리, BR 1
# 4,560
# D1s CJ백설 제일제면소(칼국수)900g 국수 소면 소바 칼국수 스파게티 r777eav, ◉ 1, ◉ 본상품선택
# 4,710
# D1s CJ백설 제일제면소(소면)900g r777eav, ◉ 1, ◉ 본상품선택
# 4,740
# (맛나) 제일제면소소면 900G/백설, 1개
# 5,250
# (무)백설 제일제면소(칼국수)900g
# 5,420
# (무)백설제일제면소(소면)900g
# 5,460
# 오뚜기 옛날 국수 소면 500g, 1개
# 1,370
# 오뚜기옛날 국수 소면, 900g, 1개
# 2,490
# 오뚜기 옛날 수연소면, 300g, 1개
# 3,680
# 오뚜기옛날 국수 소면, 1.5kg, 1개
# 4,220
# 오뚜기 옛날 국수 칼국수, 1.5kg, 1개
# 4,640
# 오뚜기 옛날 수연 소면, 500g, 1개
# 5,470
# [명희마을]운산식품 봉평 국산메밀국수 850g 1개
# 5,500
# 오뚜기옛날 국수 소면, 500g, 2개
# 5,600
# 오뚜기옛날 국수 소면, 2.5kg, 1개
# 6,360
# 오뚜기옛날 국수 중면, 2.5kg, 1개
# 6,680
# 오뚜기 옛날 쌀국수, 500g, 2개
# 7,200
# 오뚜기옛날 국수 소면, 3kg, 1개
# 7,220
# 오뚜기옛날 국수 중면, 3kg, 1개
# 7,300
# 구포명품국수 300gX5 옛날소면 판촉 답례품 대용량 국수선물세트, 메밀/쑥/콩/소면 5P
# 7,590
# 오뚜기 옛날 치자국수, 3kg, 1개
# 7,570
# 오뚜기옛날 국수 소면, 700g, 3개
# 7,900
# 잉어표 구포국수 소면, 1400g, 3개
# 8,400
# 잉어표 구포국수 중면, 1400g, 3개
# 8,400
# 오뚜기옛날 국수 세면, 900g, 2개
# 8,400
# 예이니식품 샘표 그때그추억 국수 8종 각1개씩 세트(총8개) 가락비빔잔치소면멸치김치, 1세트
# 9,470
# 오뚜기옛날 국수 소면, 900g, 3개
# 9,910
# 오뚜기옛날 국수 소면, 1.5kg, 2개
# 10,100
# 오뚜기옛날 국수 중면, 900g, 3개
# 10,430
# 오뚜기옛날 국수 소면, 500g, 5개
# 10,800
# [해표] 부드럽고 쫄깃한 국수, 900g, 4개
# 11,400
# 오뚜기옛날 국수 소면, 900g, 4개
# 11,700
# 샘표 그때그추억 국수 6종 각2개씩 세트(총12개)사리잔치멸치비빔소면김치, 1세트
# 12,350
# 오뚜기옛날 국수 중면, 500g, 6개
# 12,500
# 오뚜기옛날 국수 소면, 700g, 6개
# 12,900
# 오뚜기옛날 자른당면, 100g, 9개
# 13,180
# 오뚜기옛날 국수 소면, 1.5kg, 3개
# 13,400
# 오뚜기옛날 국수 중면, 900g, 5개
# 13,650
# 칠갑농산 칠갑국수 3kg 소면 국수소면 옛날국수 국수면 국수, 1개
# 14,000
# 오뚜기옛날 국수 소면, 2.5kg, 2개
# 14,100
# 예이니종합물류 오뚜기 옛날강황국수 소면 3개(900g*3개)쌀중면비빔수제비 즉석간편요리, 900g, 3개
# 14,700
# 벅스웨이 대용량 구포국수 소면 3kg, 1개
# 14,900
# 해태 고향만두, 415g, 1개
# 3,000
# 해태제과 고향만두 350g+350g, 단품
# 3,920
# 해태 고향만두 415g / 800g+150g, 고향만두415g
# 4,100
# 해태 고향만두300g+고향만두(잡채가득)300g 2set 무배, 1set
# 4,600
# 해태 명가 김치 고향만두 320gx2개/국산돼지고기 김치만두 에어프라이어 얇은피 교자만두 비빔만두 만두국 군만두 찐만두 반찬 간식, 1개, 320g
# 4,800
# 고향만두 415g
# 4,990
# IN777 해태 고향만두 참 잘 빚은 손만두 440g, 1
# 5,030
# 해태제과 얇은 만두피 고향만두 식자재용 1500g, 단품
# 5,280
# 해태 고향만두기획, 300g, 3봉
# 5,580
# 원하프고향만두950g/해태, 단품
# 5,700
# 해태 고향만두 얇은피 김치왕교자 300gX2개, 1개, 600g
# 5,850
# 고향만두350gX2
# 5,890
# 해태 고향만두 녹두지짐 만두 340G x 2개/국내산돼지고기/녹두전/간식/반찬/안주, 1개
# 5,900
# 해태 고향만두기획(고기+김치) 400gX2, 1개, 800g
# 5,900
# 고향만두 고향 얇은피 왕교자 고기 (냉동), 412g, 2개
# 5,930
# 고향만두 고향 얇은피 왕교자 김치 (냉동), 412g, 2개
# 5,930
# [해태] 얇은피 고향만두 415g, 단품, 단품
# 6,100
# 해태 고향만두 350gX2봉 550gX2봉, 해태 고향만두 350gX2
# 6,200
# 해태 고향만두 얇은피 고기왕교자 300gX2개, 1개, 600g
# 6,350
# 해태제과
# 6,420
# 해태제과, 550g, 2개
# 6,670
# (고향만두) 고추지짐 얇은피만두 340g 2개입 녹두지짐 얇은피만두 340g 2개입(선택), 녹두지짐 얇은피만두 340g 1개입
# 6,980
# 해태 고향 쫄깃한 생물만두 350g X 2, 상세페이지 참조
# 7,160
# 해태 속알찬 얇은피 고기만두
# 7,490
# 얇은피 고향만두 1.5kg(식자재용)
# 7,590
# 남대문가메골손만두 김치왕만두 (냉동), 430g, 1개
# 7,600
# 해태제과 고향만두 300g+300g+잡채가득 300g, 단품
# 7,700
# 해태제과 고향만두김치가득(냉동)810g더하기220g
# 7,950
# 고향만두 속 알찬 얇은피 고기만두 (냉동), 400g, 2개
# 8,090
# 고향만두 1200g (국산돼지고기) (아이스박스+냉매 포장) (하루배송 99%)
# 8,240
# [메가마트]해태 고향만두 620g*2, 1개
# 8,300
# 고향만두 종로 할머니도 모르는 고추지짐 맛의 비밀 만두 (냉동), 400g, 2개
# 8,330
# 고향만두 종로 할머니도 모르는 녹두지짐 맛의 비밀 만두 (냉동), 400g, 2개
# 8,330
# 고향만두 속 알찬 얇은피 김치만두 (냉동), 400g, 2개
# 8,330
# 고향만두 바삭한 군만두 (냉동), 1.73kg, 1개
# 8,590
# 해태 고향만두 350g, 4봉
# 8,700
# 씨제이 비비고왕교자만두1.05kg씨제이
# 8,110
# CJ제일제당 [CJ제일제당] 비비고 왕교자 1.05kg x 1개
# 9,980
# CJ 비비고 쉐프솔루션 왕교자만두 1.05kg, 단봉
# 10,700
# 쉐프솔루션 비비고 새우왕교자(약35g/개 1.05Kg)
# 11,900
# CJ 냉장 볼로냐 스파게티 625g/ 까르보나라 600g, 09 (CJ) 비비고 김치왕교자 1.05kg
# 12,000
# 비비고 김치왕교자 [냉동], 420g x 2개입
# 12,000
# 상세설명 참조 (맛나)비비고김치왕교자만두 1.05KG/씨제이, 1개
# 12,600
# CJ 비비고 왕교자 1.05kg x 1개 냉동 식품 만두
# 12,940
# 냉동만두 비비고 쉐프솔루션, 비비고 김치왕교자 1.05kg
# 13,010
# [에이브쇼핑] 비비고 왕교자 1.05kg + 비비고 사골곰탕 500g, 1세트
# 13,500
# 농협하나로 비비고 왕교자만두 1.05kg (냉동)
# 14,200
# [에이브쇼핑] 비비고 김치왕교자 1.05kg + 비비고 사골곰탕 500g, 1세트
# 14,500
# 만두는 비비고 왕교자만두 1.05kg 업소용 식당용 식자재 소스 양념 대용량, 본상품선택, 본상품선택
# 15,240
# 비비고 cj제일제당 비비고왕교자김치만두1.05kg 비비고왕교자만두1.05kg, 2팩
# 16,000
# 업소용 식당 식자재 재료 비비고 왕교자만두 1.05kg M_ 220109EA, 1, 본상품선택
# 16,000
# CJ 비비고 왕만두 1.05kg x 2개 묶음, 2100g
# 16,890
# 비비고 김치왕교자1.05kg, 1.05kg, 2개
# 17,030
# 비비고 왕교자, 1.05kg, 2개
# 17,340
# ☞고객대만족↗¶ 식자재 식당 재료 업소용 비비고 왕교자만두 1.05kg (♭UZ*R), ♬본 상품 선택하기_91Mark™, 1개
# 17,520
# [요기푸드] CJ제일제당 비비고 왕교자 1.05kg x 2개
# 17,800
# [CJ]비비고 왕교자 1.05KG x1봉 김치왕교자 455g x2봉(총3봉), 단품
# 17,960
# 비비고 새우왕교자 315g 2번들 1봉 + 왕교자 1.05kg 1봉, 1세트
# 18,960
# CJ 비비고 왕교자 1.05kg + 수제진한김치만두 400g*2, 왕교자1.05kg+수제진한김치만두400g*2
# 18,960
# 비비고 왕교자1.05KG + CJ비비고김치왕교자420G*2EA, 1.4kg, 1세트
# 18,960
# 왕교자 고기만두 왕교자만두 만두튀김 비비고 1.05kg
# 19,400
# CJ 비비고 왕교자 1.05kg x 2개 냉동 식품 만두
# 19,410
# 비비고 왕교자 1.05kg+ 김치왕교자 1.05kg, 1개, 2.1kg
# 19,430
# 만두는 비비고 김치왕교자 만두 1.05kg _ 0130EA, 1, 본상품선택
# 19,500
# [CJ직배송] 비비고 왕교자1.05Kg X 2개, 단일옵션
# 19,960
# 비비고 김치왕교자 1.05kg x 2개, 상세페이지 참조
# 21,060
# [CJ] 비비고 왕교자 1.05kg+새우왕교자 2개+찰보리감자만두 2개, 단품
# 23,380
# [CJ] 비비고 왕교자 1.05kg x1개 + 한입떡갈비 282g x 4개, 단품
# 23,460
# 비비고 왕만두 1.05kg (2개), 2개
# 23,640
# CJ 비비고 왕교자만두 1.05kg 2봉지 세트, 비비고 왕교자 1.05kg X2개
# 23,800
# [에이브쇼핑] 비비고 왕교자 1.05kg + 비비고 김치 왕교자 1.05kg (2세트이상주문시 비비고 사골곰탕 500gx1개 증정), 1세트
# 23,900
# [CJ] 비비고 왕교자 1.05KG x1개 + 도톰동그랑땡 425gx4개, 단품
# 24,460
# 생야채 돼지고기 물만두 800g (400g 2개입) 3봉, 3개
# 21,630
# CJ제일제당 생야채 돼지고기 생 물만두 (냉동), 400g, 2봉
# 6,930
# 대한민국장사꾼 쇠고기무국 300g, 쇠고기무국 300g(상온)
# 2,490
# 씨제이제일제당 백설 자른햇당면 300g x 1개, 단품
# 2,980
# [CJ] 백설 자른햇당면 300G x 3개, 단품
# 7,440
# 보니또댕댕이 사각큐브 강아지 간식 300g, 양고기, 5개
# 8,130
# 보니또댕댕이 반려동물 사사미 300g, 소고기 빼로로, 5개
# 8,500
# 오뚜기 탕류 옛날 설렁탕 300g, 6개
# 8,900
# 보니또댕댕이 반려동물 사사미 300g, 오리고기 빼로로, 5개
# 9,000
# 보니또댕댕이 양고기 윙 반려동물 간식 300g, 5개
# 11,200
# 수제미트 강아지 건조간식 150g, 오리큐브, 5개
# 11,400
# 청정원 호밍스 한우곰탕, 300g, 12개
# 11,900
# 힘나는 오뚜기밥 300g 9개 흰쌀 즉석밥, 단품
# 13,500
# 씨제이제일제당 백설 자른햇당면 300g x 5개, 단품
# 14,400
# 수제치킨 강아지 건조간식 150g, 어포치킨, 5개입
# 19,590
# 씨제이제일제당 백설 자른햇당면 300g x 10개, 단품
# 28,800
# 맛있는 오뚜기밥 큰밥, 300g, 54개
# 86,360
# 화펑 샤부샤부용당면 300g, 단품, 단품
# 2,600
# 오뚜기 자른당면300g, 상세페이지 참조, 루쿠 본상품선택
# 3,260
# k1생감자+고구마100%면(300gx1개)1분 바로 조리당면 물에 불리지 않는당면 칼면 넙적당면[선택형], 감자면300g + 1개, 8mm넙적면
# 3,430
# k1생고구마+감자100%면(300gx1개)1분 바로 조리당면 물에 불리지 않는 고구마당면 칼면 넙적당면[선택형], 감자면300gx 1개, 5mm칼면
# 3,430
# k1생고구마+감자100%면(300gx1개)1분 바로 조리당면 물에 불리지 않는 고구마당면 칼면 넙적당면[선택형], 감자면300g + 1개, 18m넙적면
# 3,430
# K1감자면+K1고구마100%면300gx1개1분 바로 조리당면 물에불리지 않는 당면/칼면 넙적면[선택형], 감자면300gx 1개, 18mm넙적면
# 3,430
# 오뚜기옛날 자른당면, 300g, 1개
# 3,520
# 예이니종합물류 오뚜기 옛날 당면 1개(300g*1개) 잡채메밀비빔칼국수 즉석간편요리식품, 300g, 1개
# 3,790
# (무)오뚜기 옛날당면300g
# 3,800
# 오뚜기 옛날당면300g
# 3,930
# 오뚜기 옛날자른당면300g오뚜기, 옛날자른당면300g/오뚜기, 없음
# 4,130
# 자른당면300g 오뚜기, 상세페이지 참조
# 4,210
# 용수 샤브샤브용 당면 300g /넓적당면, 단품, 단품
# 4,300
# 오뚜기 옛날자른당면300g, 쿠팡 1, 쿠팡 본상품선택
# 4,730
# 오뚜기 옛날자른당면300g, 1, 본상품선택
# 4,880
# 오뚜기 옛날자른당면300g, 쿠팡 1, 쿠팡 본상품선택
# 5,090
# 오뚜기 옛날 자른당면 300g, 단품, 단품
# 5,500
# 스마트클라우드 옛날 자른당면 300g 당면 자른
# 5,510
# (무)오뚜기 옛날자른당면300g
# 5,630
# (무)오뚜기 자른당면300g
# 5,650
# 건강영양맛 오감만족오뚜기 옛날당면300g W9733C8오뚜기 옛날당면 당면 면 자른당면, 오감만족건강영양맛 1
# 5,780
# [오뚜기] 옛날자른당면 300g, one, one
# 6,300
# k1생고구마+감자100%면(300gx2개)1분 바로 조리당면 물에 불리지 않는 고구마당면 칼면 넙적당면[선택형], 감자면300g+2개, 18m넙적면
# 6,840
# 오뚜기 옛날 자른 당면 300G, 옵션2 - 신선포장 (아이스박스포장)
# 7,370
# 오뚜기 옛날 자른당면 300g, 옵션2 - 신선포장 (아이스박스포장)
# 7,970
# [오뚜기]옛날자른당면300g CT1, 단품, 단품
# 8,370
# 오뚜기옛날 자른당면, 300g, 2개
# 8,500
# b31 오뚜기 옛날 자른당면 300g(국내제조), 단품
# 6,300
# 오뚜기옛날 자른당면, 300g, 1개
# 9,020
# 오뚜기 옛날 자른당면 300g 자른당면
# 9,840
# 가공식품 오뚜기 옛날 자른당면 300g(국내제조), 상세페이지 참조
# 9,850
# 오뚜기 옛날 자른당면 300G X 2개, 단품, 단품
# 13,170
# 오뚜기옛날당면300g오뚜기 옛날당면 당면 면 자른당면, 본상품
# 14,000
# 오뚜기자른당면300g오뚜기 옛날당면 당면 면 자른당면, 본상품
# 14,000
# k1생고구마면+감자100%면(300gx5개)1분 바로조리 당면 물에 불리지 않는 고구마당면 칼면 넙적당면[션택형], 감자면300g+5개, 5mm칼면
# 16,600
# 오뚜기옛날 자른당면, 300g, 4개
# 16,900
# 행복한콩 두부 국산콩 100퍼센트 두부 부침용 380g + 찌개용 380g 세트, 1세트
# 6,020
# 풀무원 국산콩두부 (부침용) 380G, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 7,050
# 풀무원 국산콩두부부침 380g
# 7,050
# 풀무원 국산콩두부 (부침용) 380G, 옵션2 - 신선포장 (아이스박스포장)
# 8,250
# 맑은물에 1등급 국산콩 두부, 380g, 2개
# 4,980
# 행복한콩 두부 국산콩 100퍼센트 두부 부침용 380g + 찌개용 380g 세트, 1세트
# 6,020
# ★icebox/사은품★풀무원 국산콩두부찌개380g
# 9,750
# [신앙촌] 생명물 국산콩두부 생식부침겸용 400g, 5팩
# 15,980
# SB/2/해뜨락 국산콩두부(찌개용)380g -12개/찌개두부/두부
# 48,940
# SB/2/해뜨락 국산콩두부(찌개용)380g -12개/찌개두부/두부
# 48,940
# (맛나)노릇하게잘구워지는부침두부 300G/씨제이, 1개
# 1,730
# 행복한콩 2가지로만 국산콩두부 부침용 180g, 1개, 300g
# 1,880
# 행복한콩 2가지로만 국산콩두부 찌개용 300g, 1개
# 2,680
# 행복한콩 2가지로만 국산콩두부 부침용 300g, 1개
# 2,680
# [행복한콩]국산콩두부 찌개용 300g + 부침용 300, 단품
# 4,760
# CJ 행복한콩 부침+국찌개용 국산콩 300g 2입(6개), 상세페이지 참조
# 28,890
# 행복한콩 2가지로만 국산콩 찌개용두부 180g, 1개, 300g
# 1,880
# 행복한콩 2가지로만 국산콩두부 찌개용 300g, 1개
# 2,680
# 보니또댕댕이 사각큐브 강아지 간식 300g, 양고기, 5개
# 8,130
# 보니또댕댕이 반려동물 사사미 300g, 소고기 빼로로, 5개
# 8,500
# 보니또댕댕이 반려동물 사사미 300g, 오리고기 빼로로, 5개
# 9,000
# 보니또댕댕이 양고기 윙 반려동물 간식 300g, 5개
# 11,200
# 수제미트 강아지 건조간식 150g, 오리큐브, 5개
# 11,400
# 힘나는 오뚜기밥 300g 9개 흰쌀 즉석밥, 단품
# 13,500
# 행복한콩 양념이 잘 배는 부드러운 찌개두부, 300g, 1개
# 990
# [행복한콩]국산콩두부 찌개용 300g + 부침용 300, 단품
# 4,760
# CJ 행복한콩 부침+국찌개용 국산콩 300g 2입(6개), 상세페이지 참조
# 28,890
# 삼양라면 골드 120g 맛있는 라면 봉지면
# 820
# 삼양라면 오리지널 멀티팩(5개입) x 1봉/봉지라면
# 2,800
# 삼양라면 오리지널 120g x 5개입/멀티 1팩
# 2,900
# 삼양라면 120g, 5개
# 3,050
# 삼양라면 매운맛 120g, 5개
# 3,050
# [삼양라면] 삼양 쇠고기라면120g x5 초대박, 상세 설명 참조
# 3,200
# 삼양라면 골드 120g, 4개
# 3,580
# 농심 오뚜기 삼양 인기라면 5개 1팩 신라면 진라면 삼양라면 불닭볶음면 냄비라면 봉지라면 한강라면, 원조삼양라면 5입 1팩
# 4,200
# 삼양 원조 삼양라면 120g 5개입 멀티팩/라면/봉지면/멀티면/즉석식품 식품 > 스낵/간식 스낵/시리얼 과자쿠키/비스킷/크래커 과자쿠키, 5
# 4,280
# 삼양 삼양라면 600g(120gX5개입) 멀티팩, 상세페이지 참조
# 4,400
# 용궁마켓 삼양라면 매운맛 120g 5입
# 4,420
# 삼양 원조 삼양라면 5개입, 2개
# 4,430
# 삼양 삼양라면 컵, 6개
# 4,750
# 삼양라면 컵 65 g, 3개
# 4,750
# 삼양라면 골드 120g, 8개입
# 4,800
# 삼양 삼양라면 120gX5개입 멀티 봉지라면, 5개입
# 4,800
# 삼양 사리면 110g X 20개
# 4,820
# 삼양라면 5개입, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 5,250
# 삼양라면 오리지널 멀티팩(5개입) x 1봉/무배
# 5,300
# 삼양라면 매운맛 멀티팩(5개입) x 1봉/무배
# 5,300
# 삼양 라이트 불닭볶음면 110g 5개입, 5개
# 5,440
# 삼양라면 컵 65 g, 5개
# 5,500
# 삼양 원조 삼양라면 5개입, 5개
# 5,560
# 삼양식품 삼양라면 5입, 5개
# 5,590
# 삼양라면 매운맛 멀티팩(5개입) x 2봉/봉지라면
# 5,600
# 삼양라면 오리지널 멀티팩(5개입) x 2봉/봉지라면
# 5,600
# 삼양 삼양라면 120g 5개 (멀티팩)_三養라면 since 1963 라면이 생각날때, 5개입
# 5,650
# 삼양 간짬뽕 140g 5개입, 5개
# 5,670
# 삼양라면 오리지널 만두 (냉동), 315g, 2개
# 5,680
# 삼양식품 삼양라면매운맛5개, 5개입
# 5,790
# 삼양 삼양라면 120g 5개 (멀티팩)_三養라면 since 1963 라면이 생각날때, 5개입
# 5,900
# 삼양 삼양라면소컵 x 6개, 단품
# 6,350
# 삼양라면 스낵 90g, 8개
# 6,890
# 봉지)삼양라면 5개 + 봉지)농심신라면 5개, 10개
# 6,800
# [소공원]농심 삼양 오뚜기 팔도 진라면 매운맛 순한맛 삼양라면 불닭볶음면 멀티 5개입
# 7,000
# 삼양라면 5개입, 옵션2 - 신선포장 (아이스박스포장)
# 7,250
# 농심 신라면 낱개 120g, 1개
# 800
# 농심 신라면컵, 단일속성
# 890
# 농심 신라면 건면 97g/라면/봉지면/멀티면/진라면/신라면 식품 > 가공/즉석식품 면류/라면류 봉지라면
# 1,360
# 농심 신라면 낱개 120g, 2개
# 1,800
# 농심 신라면 낱개 120g, 3개
# 2,650
# 농심 신라면 낱개 120g, 4개
# 3,280
# 농심 신라면 컵 65g, 6개
# 4,280
# 농심 신라면 오뚜기 진라면 삼양 팔도 봉지라면 멀티팩 모음, 01.농심 신라면 120g 5봉
# 4,560
# 신라면 120g 5입 매운라면 맛있는 라면 봉지면 한끼, 상세페이지 참조
# 4,660
# 농심 신라면 멀티팩 5개입, 상세페이지 참조
# 4,670
# 농심 신라면 봉지 라면 5개입, 단품
# 5,000
# 농심 신라면 봉지 번들 매운라면 국민라면 사나이울리는라면 인기라면, 신라면 번들 (5개입)
# 5,000
# 농심 신라면 오뚜기 진라면 삼양 팔도 봉지라면 멀티팩 모음, 09.농심 순한너구리 120g 5봉
# 5,030
# 농심 신라면 블랙 134g 4개입 멀티팩/라면/봉지면/멀티면/진라면/신라면 식품 > 가공/즉석식품 면류/라면류 봉지라면
# 5,480
# 농심 신라면 5개입, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 5,500
# 농심 신라면 오뚜기 진라면 삼양 팔도 봉지라면 멀티팩 모음, 58.삼양 불닭볶음면 140g 5봉
# 5,500
# 신라면 큰사발 114g, 6개
# 6,180
# 농심 신라면 봉지 (5개입), 쿠팡 1, 쿠팡 본상품선택
# 6,220
# 농심)신라면 (멀티) 120g_5개입, 1
# 6,450
# 인기라면 골라 담기 팔도 농심 오뚜기 삼양 신라면 블랙 너구리 짜파게티 진라면 안성탕면, 07_신라면블랙 134g 4입_JG6
# 6,590
# 농심 신라면 건면 5입, 0.094 * 5입(1봉지)
# 6,620
# 농심 새우탕 컵라면 67g + 신라면 컵라면 65g, 12개
# 6,900
# 봉지)농심너구리얼큰한맛 5개 + 봉지)농심신라면 5개, 10개입
# 7,050
# 농심 신라면 삼양 라면 짜파게티 불닭볶음면 얼큰한 너구리 오징어짬뽕 골라담기 (5입 멀티팩 11종), 농심 얼큰 장칼국수 103g 4입 멀티팩
# 7,410
# 농심 신라면 5개입, 옵션2 - 신선포장 (아이스박스포장)
# 7,500
# (라니랜드) 농심 봉지라면 멀티팩 신라면볶음면 1팩
# 8,160
# 농심 신라면 블랙 작은컵 101g, 6개
# 8,220
# [아맛]농심)신라면건면(멀티)97gx5개입, 본상품선택
# 8,390
# 농심 신라면(5입) 진라면 순한맛(5입) 총10개, 10개
# 8,450
# 농심 신라면 낱개 120g, 8개
# 8,500
# 농심 신라면 멀티(5입)1팩+너구리 매운맛 멀티(5입)1팩 봉지라면 매운라면 야식 간식 한끼식사 끓여먹는 사무실 가정용 편의점라면, 멀티(5입)2팩
# 8,750
# [ 농심 ] 신라면 볶음면 131g / 농심 신상라면 출시!!
# 8,800
# 농심 라면 3종 세트, 18개, 신라면컵 x 6 + 새우탕컵 x 6 + 튀김우동컵 x 6
# 9,000
# 봉지)농심안성탕면 5개 + 봉지)농심신라면 5개, 10개
# 6,270
# 오뚜기스낵면 5개 + 봉지)농심신라면 5개, 1개
# 9,550
# 오뚜기진라면매운맛 5개 + 봉지)농심신라면 5개, 10개
# 9,600
# 오뚜기 진라면 순한맛 소컵 65g, 12개
# 560
# 진라면 멀티팩 120g 매운맛 순한맛, 5팩
# 2,400
# 오뚜기 진라면 순한맛 120g, 5개
# 3,080
# 오뚜기 진라면 순한맛 120g x 5개입, 상세페이지 참조
# 3,370
# 오뚜기 진라면순한맛 5개입, 1개
# 3,400
# 오뚜기 진라면 순한맛 소컵 65g, 6개
# 3,540
# 0 오뚜기 진라면 순한맛 5개입, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 4,120
# 오뚜기 진라면 순한맛 5개입, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 4,120
# 농심 오뚜기 삼양 인기라면 5개 1팩 신라면 진라면 삼양라면 불닭볶음면 냄비라면 봉지라면 한강라면, 원조삼양라면 5입 1팩
# 4,200
# 오뚜기 진라면 매운맛 순한맛 봉지라면 멀티팩 봉지라면 5개입, 진라면멀티팩(봉지라면5개입)순한맛
# 4,410
# 오뚜기 진라면 순한맛 5개입, 1개
# 5,600
# 오뚜기 진라면 매운맛 5개입
# 5,650
# 오뚜기 진라면 순한맛 120g, 10개
# 5,790
# 오뚜기 진라면 순한맛 5개입, 옵션2 - 신선포장 (아이스박스포장)
# 6,120
# 0 오뚜기 진라면 순한맛 5개입, 옵션2 - 신선포장 (아이스박스포장)
# 6,120
# 취향존중 오뚜기 봉지라면의 모든것 멀티팩, 라면사리(5개입)x2개
# 6,890
# [소공원]농심 삼양 오뚜기 팔도 진라면 매운맛 순한맛 삼양라면 불닭볶음면 멀티 5개입
# 7,000
# 오뚜기 진라면 순한맛 120g, 15개
# 7,700
# 오뚜기 스낵면멀티팩1개+진라면순한맛멀티팩1개+참깨라면멀티팩1개, 14개
# 7,990
# 오뚜기 진라면 매운맛 5p + 순한맛 15p 1세트, 20개
# 8,020
# 오뚜기 진라면 순한맛 소컵 65g, 15개
# 8,670
# 오뚜기 열라면 120g + 진라면 순한맛 120g 5개입 세트, 10개입
# 8,800
# 오뚜기진라면순한맛 5개 + 삼양라면 5개, 1세트
# 8,900
# 오뚜기 진라면 순한맛 큰컵 110g, 12개
# 9,060
# 오뚜기 진라면 순한맛 멀티팩(5개입) x 2팩
# 9,130
# 농심 짜파게티 5개 + 오뚜기 진라면 순한맛 5개, 1개
# 9,360
# 오뚜기 진라면매운맛10봉 + 진라면순한맛10봉, 1세트
# 9,490
# 진라면 순한맛 5봉 + 신라면 건면 5봉, 10봉
# 10,100
# 오뚜기 진라면 큰컵 매운맛+순한맛+참깨라면+진짬뽕 각2개 총8개, 1개
# 10,180
# 오뚜기 진라면순한맛 멀티+스낵면 멀티+오라면 멀티, 1세트
# 10,370
# 농심 너구리 얼큰한맛 5개 + 오뚜기 진라면 순한맛 5개, 1개
# 10,500
# 오뚜기 진라면 순한맛 소컵 65g, 14개입
# 11,200
# 오뚜기 진라면 멀티팩(봉지라면5개입)순한맛+매운맛, 10개
# 11,500
# 오뚜기 진라면 순한맛 5입 멀티 x 2개, 10개
# 11,500
# 오뚜기 진라면 순한맛 소컵 65g x 6p + 스낵면 소컵 62g x 6p + 컵누들 우동맛 38.1g x 6p, 1세트
# 11,570
# 오뚜기 진라면순한맛5p+오동통면4p+진짜장4p+참깨라면4p 세트, 17개
# 11,580
# 곰표 밀가루 1kg 중력다목적용 곰표 밀가루 중력 분, 단품
# 1,780
# 곰표 밀가루 중력다목적용, 1kg, 1개
# 1,910
# (J.R.M.)곰표밀가루(중력다목적용)1kg9999EA, 쿠팡 1, 쿠팡 본상품선택
# 2,150
# 곰표밀가루(중력다목적용)1kg, 상세페이지 참조
# 2,190
# 곰표밀가루 중력다목적용(1kgx3입)
# 3,920
# EM018 곰표 밀가루 1kg 중력다목적용, 상세페이지 참조
# 4,710
# 곰표밀가루(중력다목적용)1kg 1개 / 2개 / 5개 /20개, 밀가루 1kg x 1개
# 5,900
# 곰표 밀가루 중력다목적용, 1kg, 2개
# 6,500
# 곰표 밀가루 중력다목적용, 1kg, 3개
# 7,100
# 다목적용 곰표 중력 밀가루 1kg 업소용 식당용 식자재 소스 양념 대용량, 본상품선택
# 6,460
# 대한제분 곰표 밀가루 1kg x 3 중력분 중력 다목적용 수제비 칼국수 만두 부침 무표백
# 7,970
# 곰표 밀가루 1kg X 3입 / 중력밀가루1등급
# 7,980
# 곰표밀가루(중력다목적용)1kg 1개 / 2개 / 5개 /20개, 밀가루 1kg x 2개
# 8,100
# 곰표 밀가루 중력다목적용, 1kg, 4개
# 9,700
# 곰표 밀가루 중력다목적용, 1kg, 5개
# 10,400
# 곰표 밀가루 중력다목적용, 1kg, 6개
# 11,500
# 곰표 밀가루 중력다목적용, 1kg, 7개
# 13,000
# 곰표 밀가루 중력다목적용, 1kg, 8개
# 14,300
# 곰표밀가루(중력다목적용)1kg 1개 / 2개 / 5개 /20개, 밀가루 1kg x 5개
# 14,500
# 곰표 밀가루 중력다목적용, 1kg, 9개
# 15,700
# 슈퍼츄 일 킬로그램 가득담은 소프트 져키 1kg, 소고기맛, 1개
# 15,900
# 슈퍼츄 일 킬로그램 가득담은 소프트 져키 1kg, 닭고기맛, 1개
# 17,150
# 인스팅트 전연령용 네이처스버라이어티 BE내추럴 독 키블 강아지 건식사료, 1kg, 닭
# 17,700
# 훔볼트 피오네르 스페셜티 블렌드 원두커피, 홀빈(분쇄안함), 1kg
# 19,000
# BBB819 W/ 곰표밀가루 중력다목적용 1kgx10개 1박스, 단일 수량
# 21,620
# 곰표 밀가루 중력다목적용, 10개, 1kg
# 22,500
# 밀가루(중력 다목적용) 1kgｘ10ea(박스)/곰표
# 23,300
# 대용량마트 곰표밀가루 중력다목적용 1kgx10개 1박스, 상세페이지 참조
# 25,310
# 곰표 밀가루 중력다목적용, 1kg, 10개
# 25,440
# 곰표 밀가루 중력다목적용, 1kg, 11개
# 32,900
# 곰표 밀가루 중력다목적용, 1kg, 12개
# 34,890
# 곰표 밀가루 중력다목적용, 1kg, 13개
# 36,890
# 곰표 밀가루 중력다목적용, 1kg, 14개
# 38,890
# 곰표 밀가루 중력다목적용, 1kg, 15개
# 40,880
# 곰표 밀가루 중력다목적용, 1kg, 16개
# 42,880
# 곰표 밀가루 중력다목적용, 1kg, 17개
# 44,880
# 백설 찰밀가루 면 부침 만두 프리미엄 밀가루, 1kg, 1개
# 1,660
# 백설 찰밀가루 1kg, 상세페이지 참조
# 1,890
# 백설 찰밀가루 1kg 수제비 칼국수 반죽 다목적용
# 2,100
# [CJ] 백설 찰밀가루 1kg, 단품
# 2,200
# CJ제일제당 백설 찰 밀가루 1kg, 단품
# 2,200
# 백설 찰밀가루 1kg
# 2,200
# 백설 찰밀가루 1kg
# 2,200
# [메가마트]백설 찰밀가루 1kg, 1개
# 2,200
# 백설 찰밀가루 (1Kg)
# 2,270
# 찰밀가루 1KG백설, 단품
# 2,310
# (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비, 1
# 2,370
# (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비, 하이니몰 1
# 2,430
# (면)CJ백설 찰밀가루1kg, 본제품구매
# 2,480
# (맛나)찰밀가루 1KG/백설, 1개
# 2,550
# 백설 부드럽고 쫄깃한 찰밀가루 1kg 면 수제비 요리, 1
# 2,800
# CJ제일제당 백설 찰 밀가루, 1kg, 1개
# 2,840
# (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비, 1
# 2,910
# D1s CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비 T233EAs, ◉ 1, ◉ 본상품선택
# 3,050
# CJ 백설찰밀가루중력 1kg, 쿠팡 1, 쿠팡 본상품선택
# 3,080
# 백설 찰밀가루 1KG, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 3,300
# 백설 찰밀가루 1kg
# 3,300
# (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 RHF+C_725679 밀가루 박력 중력 찰 부침 (면)CJ백설 찰밀가루1kg, ■옵, []■션■선택■구매
# 3,480
# [프리티박스] CJ 백설찰밀가루중력 1kg_^^21080700EA^^, 1, 본상품선택
# 3,510
# (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비 91230808ea, 셀링마켓 1, 셀링마켓 본상품선택
# 3,520
# 업소용 식당 식자재 분식점 재료 백설 찰밀가루 1Kg, 스타러브 1
# 3,630
# 업소용 식당 식자재 분식점 재료 백설 찰밀가루 1Kg, 1
# 3,640
# 청정원 튀김요리 전 부침 튀김가루 부침가루 1kg, 쿠팡천 바삭부침가루1kg, 쿠팡천 본상품선택
# 3,720
# 찰밀가루 백설 1kg 식당용 업소용 식자재 전문 식당, 1
# 3,740
# 스마트클라우드 식자재밀가루 업소용 식당 식자재 분식점 재료 백설 찰밀가루 1Kg 대용량밀가루 업소용밀가루, q본상품선택q
# 3,960
# CJ 백설찰밀가루중력 1kg, 1, 본상품선택
# 4,010
# 업소용 식당 식자재 분식점 재료 백설 찰밀가루 1Kg, 1
# 4,110
# 한우주+편리함을더하다:밀가루_ 찰밀가루/백설 밀가루 업소용식자재 찰 (1KgX1포) /19921EA_$, @gks# 1, @gks# 본상품선택
# 4,300
# (무)(면)백설찰밀가루1kg
# 4,320
# (무)(면)백설 찰밀가루1kg, 상세페이지 참조
# 4,320
# CJ 백설찰밀가루중력 1kg 52000820ea, 셀링마켓 1, 셀링마켓 본상품선택
# 4,360
# 스마트클라우드 밀가루 백설 업소용식자재 찰 (1KgX1포) 찰밀가루 식자재 대용량식자재
# 4,520
# 냄새없는 찰순대 토종순대 허파 내장 순대 내장 모듬 병천 고기 쫄깃한 1kg 2kg 야채 아바이 머릿고기 수육 편육 돼지 국산 부속 염통 허파 오소리 감투 고기 볶음, 15g, 14번
# 250
# CJ 5가지 자연에서 얻은 재료 튀김가루 1kg 식품 > 가루/조미료/향신료 가루 밀가루/부침/튀김/빵가루, CJ 자연재료 튀김가루 1KG
# 2,950
# 씨제이제일제당 백설 5가지재료로만 만든 부침가루 1kg x 1개, 단품
# 3,180
# 사조, 1봉, 선택02 : 사조 동그랑땡 1kg
# 3,600
# 바삭 국산 메밀 쌀 주방 대용량 식자재 슈퍼곡물 식당 1kg 바삭한 감자 백설 찹쌀 업소용 자연재료 태국 튀김가루 더욱 W7FD7B5 밀가루 용도:외 5가지 옵션, 튀김가루1kg, 본상품선택
# 4,460
# 바삭 국산 메밀 쌀 주방 대용량 식자재 슈퍼곡물 식당 1kg 바삭한 감자 백설 찹쌀 업소용 자연재료 태국 튀김가루 더욱 W7FD7B5 밀가루 용도:외 5가지 옵션, 부침가루1kg, 본상품선택
# 4,460
# CJ 백설 5가지 재료 부침가루 1KG, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 4,770
# 아이워너 네오프랜컬러아령 0.5~2kg, 1kg
# 5,900
# 백설 우리쌀로 만든 바삭 튀김가루, 1kg, 3개
# 13,480
# 아보덤 내추럴 시니어 애견사료, 1kg, 1개
# 15,700
# 씨제이제일제당 백설 5가지재료로만 만든 부침가루 1kg x 5개, 단품
# 15,900
# 인스팅트 전연령용 네이처스버라이어티 BE내추럴 독 키블 강아지 건식사료, 1kg, 닭
# 17,700
# 수제명가 강아지 대용량 스틱 건조간식 1kg, 오리, 1개
# 17,750
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 5개
# 18,000
# 훔볼트 피오네르 스페셜티 블렌드 원두커피, 홀빈(분쇄안함), 1kg
# 19,000
# 도기맨 강아지 져키 간식 1kg 2종 세트, 1세트, 치킨, 칠면조
# 21,500
# 루프트 커피 콜롬비아 수프리모 원두커피, 홀빈, 1kg
# 23,000
# 씨제이제일제당 백설 5가지재료로만 만든 부침가루 1kg x 10개, 단품
# 31,800
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 10개
# 31,890
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 7개
# 32,370
# 식자재주문 5가지자연에서얻은재료 튀김가루 1KG/상온 X 12개
# 40,500
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 12개
# 51,560
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 11개
# 53,800
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 21개
# 78,900
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 22개
# 82,900
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 17개
# 83,200
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 18개
# 88,100
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 24개
# 90,900
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 19개
# 93,000
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 25개
# 119,380
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 26개
# 127,300
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 27개
# 132,200
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 28개
# 137,100
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 29개
# 142,000
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 30개
# 143,250
# 백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 31개
# 151,800
# 오뚜기 부침가루, 500g, 1개
# 1,350
# 오뚜기 빵가루 200g, 단품
# 1,400
# 오뚜기 부침가루 500g 1kg 국산 찹쌀가루 밀가루 전
# 1,600
# 프레시원 부침가루 1Kg
# 2,000
# 오뚜기 부침가루 1KG 바삭한 부침 요리
# 2,050
# [해표] 튀김가루 1kg, 1개
# 2,110
# [해표] 부침가루 1kg, 1개
# 2,110
# 오뚜기 부침가루 1kg, 튀김가루1k
# 2,160
# [푸드득]오뚜기 바삭하고 고소한 튀김가루 1kg 편의점 사무실 간식 가공식품
# 2,170
# 해표 튀김가루1kg
# 2,200
# 오뚜기 부침가루 1kg, 9999
# 2,210
# 오뚜기 생얼음 1kg
# 2,250
# 오뚜기 튀김가루 1kg 식품 > 가루/조미료/향신료 가루 밀가루/부침/튀김/빵가루
# 2,270
# 부침가루(곰표 1K)
# 2,420
# 오뚜기 튀김가루1kg
# 2,570
# 오뚜기 부침가루1kg
# 2,580
# 오뚜기 부침가루/튀김가루 각 1kg, 부침가루1키로
# 2,500
# (무)오뚜기 튀김가루1kg
# 2,600
# 부침가루(이츠웰 1K)
# 2,630
# 오뚜기 부침가루 1kg
# 2,630
# 오뚜기 부침가루, 500g, 2개
# 2,700
# 킴스클럽 오뚜기 부침가루 1kg
# 2,790
# 부침가루1kg1봉, 1봉
# 2,800
# 튀김가루1kg1봉, 1봉
# 2,800
# (무)오뚜기부침가루 1kg
# 2,880
# 오뚜기 부침가루1kg
# 2,900
# 프레시원 부침가루 1Kg /식당용 /식자재, 1
# 2,980
# 오뚜기 튀김가루1kg
# 3,000
# 오뚜기 부침가루 1kg 식품 > 가루/조미료/향신료 가루 밀가루/부침/튀김/빵가루, 1
# 3,150
# 농협하나로 오뚜기 부침가루 1kg
# 3,200
# 부침가루(백설 1K)
# 3,470
# 오뚜기부침가루 1kg, 1, 본상품선택
# 3,490
# 건강영양맛 오감만족오뚜기 부침가루1kg W976FBA오뚜기 튀김가루 부침가루 튀김 부침, 오감만족건강영양맛 1, 오감만족건강영양맛 본상품선택
# 3,530
# 부침가루(오뚜기 1K)
# 3,570
# 튀김가루(오뚜기 1K)
# 3,570
# J0197/오뚜기 부침가루1kg, 상세페이지 참조
# 3,600
# [메가마트]삼립 미니 꿀호떡 322g, 1개
# 2,980
# 삼립 사계절 내내 즐기는 달콤한 미니미니 꿀호떡 요요 192g x 2개 제과
# 9,980
# [GFS삼립] 미니꿀호떡 16입 3봉, 단품
# 10,900
# 삼립 미니꿀호떡 16개입 7봉
# 22,900
# 삼립 요요 꿀호떡 (16개입) 400g x 7봉, 1박스
# 25,200
# 삼립 미니 꿀호떡 322g x 2개 제과, 644g
# 11,980
# 삼립 정통 크림빵 75g, 1개, 120g
# 910
# 삼립 고소한 옥수수 크림 소보루
# 1,050
# 삼립 옥수수빵 모음전/옥수수크림빵/옥수수크림소보루/옥수수이야기/옥수수꿀호떡/옥수수식빵, 삼립 옥수수 식빵
# 2,000
# FUNET 프랑스 정통빵 크로와상 냉동생지, 1개, 1g
# 2,200
# 몽블랑제 정통단팥빵 1개입, 일반포장 동절기만
# 2,300
# 삼립 인기빵 싸고 크림 듬뿍 정통 크림빵 3입
# 2,640
# FUNET 프랑스 브리도 크로와상 냉동생지, 1개, 1g
# 3,000
# FUNET 프랑스 브리도 미니 크로와상 냉동생지, 1개, 1g
# 3,000
# FUNET 프랑스 정통빵 미니 크로와상, 1개, 1g
# 3,000
# 삼립 허니브레드 300g 1봉(2입)
# 3,200
# 몽블랑제 정통단팥빵 1개입, 아이스팩 포장
# 3,300
# [새벽배송][우리가락]삼립 정통크림빵 3입 255g
# 3,800
# 삼립 간식빵 정통크림빵 70g (2일 후 출고), 5봉
# 4,200
# 몽블랑제 정통단팥빵 1개입, 아이스박스 포장
# 4,300
# 삼립 정통 크림빵 240g, 일반포장 동절기만
# 4,700
# 삼립 정통 크림빵3
# 4,920
# 삼립 정통 크림빵 240g, 아이스팩 포장
# 5,700
# 삼립 정통 생크림 보름달빵 케익 케잌 45g x 12봉지 코스트코, 1개
# 5,840
# 삼립 간식빵 정통크림빵 70g (2일 후 출고), 8봉
# 6,400
# [달섬브레드]프랑스 정통 무화과살구 깜빠뉴 단호박리코타 크림치즈 올리브더블치즈깜빠뉴 정통바게트 통호밀바게트 올리브치아바타 비건빵 더블치즈치아바타, 무화과살구깜빠뉴
# 6,400
# [삼립간식빵] 정통크림빵 70g (2일 후 출고), 5봉
# 6,500
# 삼립 냉동 베이글3종/ 가능, 단품, 1개
# 6,500
# 삼립빵 허쉬 초코롤 85g/삼립/삼립초코롤/허쉬초코롤/삼립초코빵/크림빵 식품 > 스낵/간식 빵/베이커리 케이크/롤케이크/카스텔라 케이크, 1, 1개, 85g
# 6,500
# 삼립빵 정통 보름달 85g/삼립/삼립보름달/크림빵/딸기빵/딸기크림/옛날간식 식품 > 스낵/간식 스낵/시리얼 과자쿠키/비스킷/크래커 과자쿠키, 1, 85g, 85g
# 6,500
# 삼립 정통미니와플, 600g, 1봉
# 6,510
# 삼립 정통 크림빵 75g x 5봉
# 6,680
# 삼립 정통 크림빵 240g, 아이스박스 포장
# 6,700
# 삼립 정통 크림빵 8입
# 6,890
# 통밀빵 통호밀빵 100% 우리밀 통곡물빵 다이어트 비건 당뇨간식 호밀 모닝빵 맘모스빵 팥빵 햄버거빵 건빵 국산밀 빵 현미식빵 바게트빵 정통 옛날 크림빵 현미크래커 보리크래커, 15. 현미크래커 2봉
# 7,000
# 삼립 정통 크림빵, 5봉, 75g
# 7,500
# 삼립 정통 크림빵 8개입, 600g, 1개
# 7,780
# 롯데제과 옛날 크림빵 정통 100g, 5개
# 7,800
# [자연맛남] 겉바속촉 정통 미니붕어빵 500g/1kg 맛 골라담기, 02. 미니붕어빵(카스타드크림) 500g, 상세설명 참조
# 7,900
# 삼립 정통 크림빵 70G, 5개
# 7,900
# [자연맛남] 겉바속촉 정통 미니붕어빵(카스타드크림) 500g, 단품
# 7,900
# 삼립 정통크림빵 3입 240g, 단품, 단품
# 8,070
# 보노 스프 콘스프 57.3g (19.1gx3개입), 1개
# 2,280
# 보노스프 콘스프 1각 (총 3봉입), 55.8g
# 2,300
# 보노스프 5종 3입 골라담기 콘스프 포르치니버섯 체다치즈 크림 어니언, 콘스프 3입, 상세페이지 참조
# 2,350
# 보노스프 5종 3입 골라담기 콘스프 포르치니버섯 체다치즈 크림 어니언, 체디치즈 3입
# 2,350
# vono 보노스프(3개입) 콘스프 x 1개/옥수수스프
# 2,550
# vono 보노스프(3개입) x 1개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프
# 2,550
# [VONO 보노] vono 보노스프(3개입) x 1개/아침대용/간편스프/즉석스프/보노스프 6종 택1, 보노 크림스프포타주(3개입), 1개
# 2,550
# vono 보노스프(3개입) x 1개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프, 01 보노 콘스프(3개입)
# 2,550
# 보노 포르치니 버섯 스프, 51.6g, 1개
# 2,550
# [VONO 보노] vono 보노스프(3개입) x 1개/아침대용/간편스프/즉석스프/보노스프 6종 택1, 보노 체다치즈스프(3개입), 1개
# 2,550
# 보노스프(3봉입) 콘스프 포르치니버섯 체다치즈 크림스프 어니언 5종 택1, 크림스프3봉입
# 2,600
# 보노 콘스프 57g (19gx3개입)/컵스프/즉석스프/즉석식품/아침대용/식사대용 식품 > 가공/즉석식품 즉석밥/간편조리 즉석죽/스프 즉석스프, 1
# 2,900
# 농심 보노 콘스프 55.8g, 3개입, 18.6g
# 2,920
# 보노 스프 4종, 1개, 보노 콘스프 55.8g(3개입)
# 3,000
# 농심 보노 콘스프 3개입 55.8g
# 3,570
# 농심 VONO 콘스프(3개입)_N7704220, 상세페이지 참조
# 3,720
# 농심 VONO 콘스프(3개입), 단품
# 4,040
# 농심 VONO 콘스프 3개입 즉석식품 반조리식품, 단일상품(SZG9359)
# 4,050
# 보노 콘스프 18.6Gx3입 (총중량 55.8G), 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 4,270
# 농심 보노 콘스프 3개입 55.8g, 쿠팡 1, 쿠팡 본상품선택
# 4,360
# 문구사무/농심 VONO 콘스프(3개입), 수앤미 1
# 4,450
# 도깨비천국 문구사무/농심 VONO 콘스프(3개입) (ijkhu&FR$%), 도깨비천국 1
# 4,470
# 농심 보노 콘스프 3개입 55.8g, 1, 본상품선택
# 4,680
# 농심 보노 콘스프 3개입 55.8g, 쿠팡 1, 쿠팡 본상품선택
# 4,910
# 《_BQ'L》 보노 농심 (좋음) 콘스프 3개입 55.8g 스프추천 가공식품추천 식품추천 『멋있는 감사의 선물하기좋은 핫한상품 ;srn&1.80al~#EA, 1, 본상품선택
# 5,200
# 보노 콘스프 컵 19g x 4개 농심 한컵
# 5,480
# ☞고객대만족↗¶ 콘스프 수프 스콘 월계수잎 스프 보노 농심 3개입 55.8g (qNw‡!), 1개, ♬본 상품 선택하기_Ethan™
# 5,520
# 보노 콘스프 3p, 57g, 2개
# 5,800
# 농심 VONO 콘스프 3개입
# 6,910
# 미트볼 순두부 타코와사비 아이스군고구마 이산호쿡솜씨 리얼미니군고구마 농심 VONO 콘스프 3개입, 1, 본상품선택
# 7,140
# 콘스프농심개입 QD4+D8U VONO u7CF0AD, 선택은>>이걸로골랐어요
# 7,360
# [캠핑:도구] 농심 ADx7CxF0VONO 콘스프 3개입 N/W:JT+ N3, 1
# 7,400
# 아이도매/농심 VONO 콘스프(3개입), 오피스풀 1
# 7,500
# vono 보노스프(3개입) x 2개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프/무료배송, 01 보노 콘스프(3개입)
# 7,600
# vono 보노스프(3개입) 콘스프 x 2개/옥수수스프/무배
# 7,600
# vono 보노스프(3개입) x 2개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프/무료배송, 06 보노 클램차우더(3개입)
# 7,600
# 보노 포르치니 버섯 스프, 54g, 1개
# 2,380
# vono 보노스프(3개입) 포르치니버섯스프 x 1개/스프
# 2,550
# vono 보노스프(3개입) x 1개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프
# 2,550
# [VONO 보노] vono 보노스프(3개입) x 1개/아침대용/간편스프/즉석스프/보노스프 6종 택1, 보노 크림스프포타주(3개입), 1개
# 2,550
# vono 보노스프(3개입) x 1개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프, 01 보노 콘스프(3개입)
# 2,550
# 보노 포르치니 버섯 스프, 51.6g, 1개
# 2,550
# [VONO 보노] vono 보노스프(3개입) x 1개/아침대용/간편스프/즉석스프/보노스프 6종 택1, 보노 체다치즈스프(3개입), 1개
# 2,550
# 보노 포르치니 버섯 스프 53g (18gx3개입)/컵스프/즉석스프/즉석식품/아침대용 식품 > 가공/즉석식품 즉석밥/간편조리 즉석죽/스프 즉석스프, 1
# 2,890
# 농심 보노 포르치니버섯스프 3개입 51.6g, 1, 본상품선택
# 3,350
# 아지노모도 보노 포르치니 버섯스프 42g 14g * 3개입
# 4,010
# 아지노모도 보노 포르치니 버섯스프 51.6g 17.2g * 3개입
# 4,370
# 농심 보노 포르치니버섯스프 3개입 51.6g, 쿠팡 1, 쿠팡 본상품선택
# 4,400
# 《OcT'n》 보노 농심 (좋음) 포르치니버섯스프 3개입 51.6g 스프추천 가공식품추천 식품추천 『멋있는 감사의 선물하기좋은 ;srn&1.80al~#EA, 1, 본상품선택
# 5,200
# vono 보노스프(3개입) x 2개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프/무료배송, 01 보노 콘스프(3개입)
# 7,600
# vono 보노스프(3개입) x 2개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프/무료배송, 06 보노 클램차우더(3개입)
# 7,600
# 보노 포르치니 버섯 스프, 54g, 2개
# 7,600
# 보노 컵스프 체다치즈 3개입X2통
# 7,700
# 보노 컵스프 어니언크림스프 3개입X2통
# 7,700
# 농심 보노 포르치니버섯스프 3개입 51.6g, 1, 본상품선택
# 7,710
# 보노 컵스프 크림스프포타주 3개입X2통
# 8,600
# 보노 컵스프 클램차우더 3개입X2통 무/료/배/송
# 8,600
# 뜨거운물에 15초 농심 보노(VONO) 컵스프 포르치니버섯스프 17.2g*3개입 1개
# 9,500
# [농심]보노 스프 3개입x4개 맛선택/콘 체다치즈 포르치니버섯, B 상품선택:04_보노 어니언 스프 3입x4개
# 9,900
# [농심]보노 스프 3개입x4개 맛선택/콘 체다치즈 포르치니버섯, B 상품선택:02_보노 체다치즈스프 3입x4개
# 9,900
# [농심]보노 스프 3개입x4개 맛선택/콘 체다치즈 포르치니버섯, B 상품선택:05_보노 크림스프 3입x4개
# 9,900
# [농심]보노 스프 3개입x4개 맛선택/콘 체다치즈 포르치니버섯, B 상품선택:03_보노 포르치니버섯스프 3입x4개
# 9,900
# [농심]보노 스프 3개입x4개 맛선택/콘 체다치즈 포르치니버섯, B 상품선택:06_보노 클램차우더스프 3입x4개
# 9,900
# 아지노모도 보노 포르치니 버섯스프 3개입 1박스
# 9,900
# [농심]보노 스프 3개입x4개 맛선택/콘 체다치즈 포르치니버섯, B 상품선택:01_보노 콘스프 3입x4개
# 9,900
# vono 보노스프(3개입) 포르치니버섯스프 x 3개/무배
# 10,150
# 보노 포르치니 버섯 스프, 54g, 3개
# 11,020
# 보노 포르치니 버섯 스프, 54g, 4개
# 11,550
# 보노 포르치니 버섯 스프, 18g, 18개
# 12,540
# 보노 포르치니 버섯 스프, 54g, 6개
# 12,540
# 보노 포르치니 버섯 스프, 54g, 5개
# 12,680
# 아지노모도 보노 포르치니 버섯스프 3개입 2박스
# 12,900
# 오뚜기 양송이스프80g오뚜기, 04.양송이스프
# 3,910
# 오뚜기 크림스프80g, 미들퐁 쿠팡 1, 미들퐁 쿠팡 본상품선택
# 5,490
# 오뚜기 크림 스프, 80g, 2개
# 5,520
# [김멜헤이] 오뚜기 쇠고기스프 80g 300g 500g 1kg 대용량 소고기 스프 영양성분 비프 크림스프 업소용 식자재 쇠고기 수프
# 6,120
# 오뚜기 크림 스프, 80g, 7개
# 6,860
# 오뚜기 양송이 스프, 80g, 3개
# 6,890
# 오뚜기 크림 스프, 80g, 3개
# 7,090
# 오뚜기 야채스프 80g 3개
# 7,100
# 오뚜기 쇠고기 스프 80g x 2p + 크림 스프 80g x 2p, 1세트
# 8,470
# 오뚜기 크림 스프 80g x 2p + 양송이 스프 80g x 2p, 1세트
# 8,900
# 오뚜기 크림 스프, 80g, 5개
# 10,250
# 예이니식품 오뚜기 쇠고기 스프 6개(80gx6개) 양송이콘야채크림
# 10,600
# 예이니식품 오뚜기 스프 인기5종 각1개씩 세트(80gx5개) 양송이크림콘쇠고기야채, 80g, 5개
# 10,650
# [로적마켓] 오뚜기 스프 5종 혼합세트 각1개씩(각80g) (쇠고기+양송이+옥수수+크림+야채), 1세트
# 10,950
# 오뚜기 크림 스프, 80g, 6개
# 11,240
# 예이니식품 오뚜기 야채 스프 6개(80gx6개) 양송이콘쇠고기크림, 80g, 6개
# 11,400
# 오뚜기 옥수수스프 80gx6개입, 80g, 6개입
# 11,550
# 오뚜기 크림 스프 80g x 2p + 옥수수 스프 80g x 2p, 1세트
# 11,600
# 오뚜기 양송이 스프, 80g, 6개
# 11,780
# 오뚜기 크림 스프, 80g, 4개
# 12,990
# 오뚜기 크림스프 80gx10입, 아이스박스포장
# 13,080
# 오뚜기 크림 스프, 80g, 10개
# 13,480
# 오뚜기 크림 스프, 80g, 10개
# 13,500
# 오뚜기 쇠고기 스프 80g x 2p + 크림 스프 80g x 2p, 2세트
# 13,770
# 양송이 크림스프 80g X 7 간편식 즉석스프
# 14,580
# 오뚜기 크림 스프 80g x 2p + 양송이 스프 80g x 2p, 2세트
# 15,300
# 예이니식품 오뚜기 쇠고기 스프 1박스(80gx10개) 양송이콘야채크림
# 16,320
# 오뚜기 크림 스프, 80g, 9개
# 16,560
# 오뚜기 크림스프 80g+10개 1팩, 1
# 16,900
# √노마드¶몰〕_오뚜기 크림스프 80gx6개입_[Œì스프#크림스프#크림수프, 주문GO ▶1, 주문GO ▶본상품선택
# 17,190
# √노마드¶몰〕_오뚜기 옥수수스프 80gx6개입_[Œì스프#콘크림스프#콘스프, 주문GO ▶1, 주문GO ▶본상품선택
# 17,190
# 예이니식품 오뚜기 양송이 스프 9개(80gx9개) 쇠고기콘야채크림, 80g, 9개
# 17,260
# 양송이스프 80G 10개
# 17,400
# 힘찬상회_오뚜기 크림스프 80gx6개입_힘찬Hcmar+ㅋ, 단일상품^, 단일상품^
# 15,840
# 오뚜기 야채스프 80g 10개
# 17,740
# 예이니식품 오뚜기 옥수수 스프 1박스(80gx10개) 콘양송이쇠고기크림야채, 80g, 10개
# 17,900
# 켈로그 스페셜K 오리지널 시리얼, 480g, 1개
# 4,980
# 켈로그 스페셜 K 오리지널, 270g, 1개
# 6,320
# 켈로그 스페셜케이 오리지널 시리얼, 480g, 1개
# 6,670
# 켈로그 스페셜케이 오리지널 시리얼, 480g, 1개
# 8,500
# 켈로그 스페셜K 오리지널 480g, 단품
# 8,500
# 켈로그 스페셜K 오리지널 270g x2개+ 매쉬백, 없음, 상세설명 참조
# 9,900
# 켈로그 스페셜K 오리지널 480g, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 11,070
# 켈로그 스페셜K 오리지널 480g, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 11,070
# 켈로그 스페셜K 오리지널 480g 가공식품 시리얼, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 11,070
# 켈로그 스페셜K 오리지널 시리얼, 480g, 2개
# 11,550
# 켈로그 스페셜K + 리얼그래놀래 / 스페셜K 오리지널 480g X 2개 /리얼 그래놀라 400g X 2개 중 택1, 스페셜K X 2개
# 11,810
# 스페셜K 오리지널 480g +첵스초코 마시멜로 400g, 옵션선택
# 12,640
# 켈로그 콘푸로스트 600g + 스페셜 K 오리지널 480g 시리얼, 1세트
# 12,900
# 켈로그 스페셜K 오리지널 480g 가공식품 시리얼, 옵션2 - 신선포장 (아이스박스포장)
# 13,070
# 스페셜K 오리지널 480g + 리얼 그래놀라 400g + (사은품) 켈로그 썸머 비치백 1개
# 13,400
# 스페셜K 오리지널 480g x2 + (사은품) 켈로그 썸머 비치백 1개
# 13,400
# 켈로그 스페셜K 오리지널 CT1 480g, 단품, 단품
# 13,470
# 스페셜K 오리지널 480g +오곡 첵스초코 마시멜로 400g, 단품
# 13,500
# 켈로그 스페셜k 오리지널 480g x 2입, 480g x 2P
# 13,800
# 켈로그 스페셜케이 오리지널 시리얼, 480g, 2개
# 13,900
# 켈로그 스페셜K 오리지널 480g x2개+증)매쉬백, 단품
# 13,900
# 켈로그 스페셜K 오리지널 480g x 2입 V, 단품
# 14,400
# 켈로그 시리얼 스페셜 K 오리지널 480g + 크랜베리 아몬드 그래놀라 550g, 1세트
# 14,900
# 켈로그 스페셜K 오리지널 시리얼, 480g, 3개
# 16,400
# 스페셜 K 오리지널 480g x3개
# 19,500
# 켈로그 스페셜K 오리지널 480g x3개+증)요가매트, 단품
# 19,900
# 스페셜K 오리지널 480GX2입 코스트코/다이어트기타다이어트식품
# 20,890
# 켈로그 스페셜K 오리지널 시리얼, 480g, 4개
# 21,000
# 켈로그 스페셜K 오리지널 480g x3개, 상세페이지 참조
# 24,460
# 켈로그 스페셜K 오리지널 480g x4개, 단품
# 24,500
# 켈로그 스페셜 K 오리지널, 270g, 6개
# 24,750
# 켈로그 스페셜K 오리지널 시리얼, 480g, 5개
# 24,980
# 시리얼 디스펜서(핑크)+스페셜K 오리지널 480g, 단품
# 26,900
# 켈로그 [T] 시리얼 디스펜서(핑크)+스페셜 K 오리지널 480g
# 26,900
# 켈로그 [T] 시리얼 디스펜서(레드)+스페셜 K 오리지널 480g
# 26,900
# 켈로그 [T] 시리얼 디스펜서(민트)+스페셜 K 오리지널 480g
# 26,900
# 켈로그 콘푸로스트 600g x 1갑, 상세페이지 참조
# 3,890
# 켈로그 콘푸로스트600g켈로그, 콘푸로스트600g/켈로그, 없음
# 4,400
# 켈로그 콘푸로스트 600g, 쿠팡 1, 쿠팡 본상품선택
# 4,790
# 켈로그 콘푸로스트 시리얼, 660g, 1개
# 4,830
# 켈로그 콘푸로스트 시리얼, 660g, 1개
# 4,830
# 켈로그 콘푸로스트 600g, 쿠팡 1, 쿠팡 본상품선택
# 5,130
# 켈로그 아몬드 푸레이크 or 크랜베리아몬드 그래놀라 선택+캐릭터볼펜증정, 아몬드 후레이크 600g+캐릭터볼펜
# 5,490
# 켈로그 아몬드 푸레이크, 600g, 1개
# 5,490
# 켈로그 콘푸로스트 600g 씨리얼 간식 콘푸라이트
# 5,500
# 켈로그 오곡으로만든 첵스초코 시리얼, 340g, 1개
# 5,900
# 켈로그 콘푸로스트 600G, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 5,970
# 농심 켈로그 콘푸로스트 클럽팩 600g x 1개, 없음
# 6,440
# [농심] 켈로그 콘푸로스트 600g, 없음, 단일속성
# 6,550
# 켈로그 콘푸로스트 시리얼, 1개, 600g
# 6,900
# 켈로그 콘푸로스트 600g, 단품
# 7,500
# 켈로그 시리얼 콘푸로스트 600g x 1개, 단품
# 7,500
# 포스트 콘푸라이트 300g X 2개(600g) 시리얼 콘푸로스트 켈로그
# 7,980
# 포스트 콘푸라이트 600g ] 시리얼 콘프라이트 한끼 대용 간편식 건강 씨리얼 아침 도매 대용량 식사 하루 다이어트 쉐이크 저칼로리 선식 단백질 파우더 아몬드 후레이크 현미 귀리 통밀 곡물 견과류 간식 구운 견과류바 오트밀 콘프레이크 콘푸로스트 켈로그 그레놀라, 포스트콘푸라이트600g
# 8,440
# 켈로그 콘푸로스트 600g 시리얼 22021089EA, 1, 본상품선택
# 8,500
# 포스트 아몬드 후레이크 300g X 2개(600g) 켈로그 시리얼 씨리얼
# 8,820
# 켈로그 콘푸로스트 600g + 230g, 1세트
# 8,900
# 켈로그콘푸로스트600g, 빠른배송
# 9,070
# 켈로그 콘푸로스트 600g, 일반종이박스포장
# 9,070
# 켈로그 콘푸로스트 600g, 1, 본상품선택
# 9,070
# 켈로그 콘푸로스트 시리얼, 600g, 2개
# 9,120
# CM 켈로그 콘푸로스트 600g 외국 미국 시리얼 씨리얼 초코 쵸코 콘 후레이크 프레이크 해외
# 9,300
# 켈로그 콘푸로스트 600g+첵스초코 마시멜로 200g
# 9,500
# 켈로그 콘푸로스트 600g+첵스초코 스노우초코볼 230g
# 9,900
# 농심켈로그 오곡 첵스초코 570g +콘푸로스트 600g, 단품, FREE
# 10,200
# 켈로그 시리얼 첵스초코 마시멜로 800g 400g x2개
# 10,500
# 콘푸로스트 1200g( 600gX2개)
# 10,800
# 켈로그 콘푸로스트 600g+첵스초코 340g 씨리얼 간식
# 11,000
# New 첵스초코 팥맛 350g + 콘푸로스트 600g, 없음
# 11,300
# 켈로그 New 첵스초코 팥맛 350g + 콘푸로스트 600g
# 11,300
# [인기] 켈로그 콘푸로스트 600g 175231EA, 1, 본상품선택
# 9,300
# 켈로그 콘푸로스트 600g 2개입, 상세페이지 참조
# 11,520
# 동서식품 포스트 콘푸라이트 600g, 단품
# 3,800
# 포스트 콘푸라이트 600g, 상세페이지 참조
# 4,050
# 콘푸라이트 600g, 상세페이지 참조
# 4,080
# 포스트 콘푸라이트 600g
# 4,240
# _포스트 콘푸라이트 600g, 상세페이지 참조
# 4,270
# 포스트 콘푸라이트 600g, 단품
# 4,300
# 포스트 콘푸라이트 600 g
# 4,400
# 포스트 콘푸라이트 코코볼 아몬드후레이크 오레오오즈, 포스트콘푸라이트600g
# 4,460
# g3)포스트 콘푸라이트600g (1개)
# 4,500
# 서진네 콘푸라이트 600g 포스트, 1개
# 4,550
# 포스트 콘푸라이트 코코볼 아몬드후레이크 오레오오즈
# 5,570
# 포스트 콘푸라이트 600g 시리얼 간편식 아침식사대용
# 5,760
# 포스트 콘푸라이트 600g, 상세페이지 참조, 상세페이지 참조
# 5,820
# 동서식품 콘푸라이트 600G, 단일 수량
# 5,890
# 포스트 콘푸라이트 600g/켈로그/포스트/시리얼/곡물/그래놀라/첵스파맛, 8.건강한칠곡 450g
# 5,900
# 【 소.바 식품 코너 ▶ 포스트 콘푸라이트 600g 시리얼 간편식 아침식사대용 2207210EA+ ◀ 】, 쿠팡 포스트 콘푸라이트 600g, 쿠팡 본상품선택
# 5,900
# 포스트 콘푸라이트 시리얼, 600g, 1개
# 6,100
# 포스트 콘푸라이트 600g 시리얼 9가지 비타민 영양식, 상세페이지 참조, 상세페이지 참조, 콘푸라이트600g
# 6,110
# 동서 포스트 콘푸라이트 600g 1개, 1
# 6,150
# IT+02/15* 포스트 콘푸라이트 600g 시리얼 간편식 아침식사대용 시리얼 간편식 761020w+[git-rs], 굿아이템 포스트 콘푸라이트 600g
# 6,260
# [W46DF8F] 포스트 콘푸라이트 600g 시리얼 9가지 비타민 영양식 (59655), 콘푸라이트600g, 본상품선택
# 6,420
# Post 포스트 콘푸라이트 600g 1개, 단일 수량
# 6,500
# 포스트 콘푸라이트 오레오오즈 그래놀라 씨리얼 아몬드 현미 초코 후레이크 쵸코 콘프라이트 콘푸로스트 그레놀라 시리얼 콘프로스트 콘프레이크 박나래 유나 콘프러스트, 콘푸라이트 600g
# 6,570
# 동서식품 포스트 콘푸라이트 600g, 단품
# 6,600
# 포스트 콘푸라이트 (지퍼백) 600G, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 6,720
# 포스트 그래놀라 시리얼 콘푸라이트 오레오오즈 현미 간편식사, 콘푸라이트600g
# 7,000
# kKW71D2B3 동서 포스트 콘푸라이트 600g 1개 씨리얼 식사대용 콘푸로스트, 1, 본상품선택
# 7,150
# WDBB_ 포스트 콘푸라이트 600g, 단일 수량
# 7,230
# 동서 포스트 콘푸라이트 600g, 1개
# 7,300
# Post 포스트 콘푸라이트 600g 1개, 단일 수량
# 7,440
# T몰 / 포스트 콘푸라이트 600g, 단일 수량
# 7,530
# 포스트 콘푸라이트 600g, 단일 수량
# 10,150
# 현아몰 포스트 코코볼 콘푸라이트 씨리얼 그래놀라 초코후레이크, 포스트 콘푸라이트 600g
# 7,900
# 포스트 콘푸라이트 300g X 2개(600g) 시리얼 콘푸로스트 켈로그
# 7,980
# WDBB_ 포스트 콘푸라이트 600g, 단일 수량
# 7,980
# 0 포스트 콘푸라이트 600g, 옵션2 - 신선포장 (아이스박스포장)
# 8,270
# [로적마켓] 오뚜기 간편 블럭 북어국(즉석국) 10.05gx5개입, 간편북어국(즉석국) (10.05X5)G
# 2,370
# 오뚜기 간편 닭곰탕(5개입), 1개
# 2,620
# 오뚜기 블럭국 북어국 미역국 버섯해장국 닭곰탕 사골우거지국, 옵션5. 오뚜기 간편미역국 5개입
# 2,800
# 오뚜기 간편 닭곰탕 50g(10g X 5개입), 50g, 1개
# 2,800
# 오뚜기 간편 버섯해장국 45g(9g X 5개입), 1개, 45g
# 5,130
# [로적마켓] 오뚜기 간편 블럭 닭곰탕(즉석국) 10gx5개입, 1개
# 5,200
# 오뚜기 간편 북어국 5개입 X 10개/즉석국 블럭국, 52.5g, 단품
# 5,200
# 오뚜기 간편 미역국 5개입 X 2개/즉석국 블럭국
# 5,890
# 오뚜기 간편 미역국 컵국, 옵션선택, 5개
# 7,030
# 오뚜기 맛있는 미역국18gx6개입, 18g, 6개입
# 10,630
# [로적마켓] 오뚜기 간편 즉석국 블럭국 미역국 9.5g 5개입
# 10,870
# [로적마켓] 오뚜기 간편 블럭 북어국(즉석국) 10.05gx5개입, 10.5g, 5개
# 12,000
# 오뚜기 간편 미역국, 47.5g, 4개
# 12,310
# 오뚜기 컵밥 진한쇠고기 미역국밥, 284g, 5개입
# 12,800
# 오뚜기 간편 블럭국 5종 X 5개 (택 1), 01. 간편미역국(9.5gx5) X 5개
# 13,500
# 오뚜기 컵밥 진한쇠고기 미역국밥, 314g, 5개입
# 14,500
# [로적마켓] 오뚜기 간편 즉석국 블럭국 미역국 9.5g 5개입, 5개
# 15,500
# pulmuone 생가득 미소된장국(8g*5개입), 20개입, 8g
# 16,750
# [로적마켓] 오뚜기 간편 즉석국 블럭국 미역국 9.5g 5개입
# 17,500
# 오뚜기 돼지고기김치찌개, 280g, 5개입
# 17,800
# 오뚜기 간편 미역국, 47.5g, 6개
# 18,300
# [로적마켓] 오뚜기 간편 즉석국 블럭국 미역국 9.5g 5개입, 47.5g, 8개
# 21,570
# 오뚜기 간편 미역국, 47.5g, 10개
# 26,800
# [로적마켓] 오뚜기 간편 즉석국 블럭국 미역국 9.5g 5개입, 12개
# 31,000
# [로적마켓] 오뚜기 간편 즉석국 블럭국 미역국 9.5g 5개입, 15개
# 39,500
# 오뚜기 남도식 한우미역국 500g, 12개
# 45,000
# 오뚜기 간편 미역국, 47.5g, 20개
# 46,700
# [로적마켓] 오뚜기 간편 즉석국 블럭국 미역국 9.5g 5개입, 20개
# 49,500
# 오뚜기 쇠고기미역국 500g 5개입 양지 청정 남해안 미역 사골 한끼 든든 생일 5분조리
# 19,980
# [로적마켓] 오뚜기 간편 블럭 북어국(즉석국) 10.05gx5개입, 간편북어국(즉석국) (10.05X5)G
# 2,370
# 오뚜기 간편 닭곰탕(5개입), 1개
# 2,620
# 오뚜기 블럭국 북어국 미역국 버섯해장국 닭곰탕 사골우거지국, 옵션5. 오뚜기 간편미역국 5개입
# 2,800
# 오뚜기 간편 닭곰탕 50g(10g X 5개입), 50g, 1개
# 2,800
# 오뚜기 간편 즉석국 북어국 10.5gx5개입, 1개
# 3,000
# 오뚜기 간편 버섯해장국 45g(9g X 5개입), 1개, 45g
# 5,130
# 오뚜기 간편 북어국 5개입 X 10개/즉석국 블럭국, 52.5g, 단품
# 5,200
# 오뚜기 간편 미역국 5개입 X 2개/즉석국 블럭국
# 5,890
# 오뚜기 간편 북어국 컵국, 10.5g, 5개입
# 6,900
# [로적마켓] 오뚜기 간편 블럭 북어국(즉석국) 10.05gx5개입, 10.5g, 5개
# 12,000
# [로적마켓] 오뚜기 간편 블럭 북어국(즉석국) 10.05gx5개입, 3개
# 12,200
# 오뚜기 간편 북어국 10.5g x5개입 x3, 1
# 12,900
# 숙취해소해장세트 큐원 상쾌환+오뚜기 간편북어국 x 5개입, 단품, 단품
# 20,900
# 큐원 상쾌환+오뚜기 간편북어국 x 5개입, 1개, 개당 용량/중량/정
# 20,900
# 오뚜기 간편북엇국 52.5g(5개입) x 10개
# 27,900
# 오뚜기 간편북엇국 52.5g(5개입) x 10개, 단품
# 29,900
# [오뚜기] 간편 북어국(10.5gX5개입) x 20개, 상세 설명 참조
# 60,900
# 오뚜기 [오뚜기] 간편 북어국(10.5gX5개입) x 20개, 기타, 기타
# 61,900
# [시엘] 2분이면 국 한그릇 뚝딱 간편국 북어국 5개입
# 4,500
# 오뚜기 짜장 3분 소고기간짜장 200g 1개 간편식 짜장밥, 단품, ☞ 해당 상품 선택하기_Onhoyo™
# 2,420
# 3분 쇠고기 간짜장, 200g, 1개
# 6,400
# 예이니식품 오뚜기 3분 쇠고기 간짜장 3개(200gx3개) 소스그대로야채해물사천, 200g, 3개
# 6,880
# 오뚜기 3분쇠고기짜장 200g 2개+3분쇠고기카레 2개 1세트
# 6,900
# 오뚜기 3분 쇠고기간짜장, 6개, 200g
# 7,230
# 오뚜기 3분요리 세트, 쇠고기카레 200g x 2개 + 쇠고기짜장 200g x 2개, 1세트
# 7,500
# 오뚜기 3분 쇠고기간짜장, 200g, 2개
# 8,900
# 오뚜기 즉석 3분 쇠고기 카레 4p + 짜장 2p 세트, 200g, 1세트
# 9,320
# . g2)오뚜기 3분 소고기간짜장200G (4개)
# 9,400
# 오뚜기 즉석 3분 카레 매운맛 200g x 2p + 즉석 쇠고기 간짜장 200g x 2p, 1세트
# 10,800
# 오뚜기 즉석 3분 카레 순한맛 200g x 2p + 즉석 쇠고기 간짜장 200g x 2p, 1세트
# 10,800
# 오뚜기 즉석 3분 카레 약간 매운맛 200g x 2p + 즉석 쇠고기 간짜장 200g x 2p, 1세트
# 10,800
# 예이니식품 오뚜기 3분 사천짜장+쇠고기간짜장 각3개씩 세트(200gx6개)프리미엄, 200g, 6개
# 11,260
# 오뚜기 쇠고기 짜장 200g, 10개
# 11,500
# 오뚜기 3분 쇠고기카레 200g x 5p + 쇠고기짜장 200g x 5p, 1세트
# 11,900
# 오뚜기 즉석 3분 백세카레 약간 매운맛 200g x 2p + 즉석 쇠고기 간짜장 200g x 2p, 1세트
# 13,500
# (무)오뚜기 3분쇠고기간짜장200gX10개
# 14,360
# 오뚜기 3분 쇠고기간짜장, 200g, 5개
# 14,800
# 오뚜기 3분 쇠고기카레 200g *6개 + 오뚜기 3분 쇠고기짜장 200g*6개, 1개
# 14,900
# 쇠고기카레 5개 + 쇠고기짜장 5개 + 그레잇물티슈, 10개
# 15,000
# 예이니식품 오뚜기 3분 쇠고기간짜장 9개(200gx9개) 소스그대로야채해물사천, 200g, 9개
# 15,640
# 오뚜기 3분 쇠고기간짜장, 200g, 6개
# 16,050
# 오뚜기 3분 쇠고기카레200g 8입+쇠고기짜장200g 4입+워킹맘's 떡볶이소스50g 1개, 1세트
# 16,100
# 오뚜기 3분쇠고기짜장 200g x 10개, 1
# 16,400
# 오뚜기 3분카레약간매운맛(200g) 5개+쇠고기짜장(200g) 5개+그레잇물티슈(10매), 1세트
# 16,800
# 오뚜기 3분미트볼2개+3분햄버그스테이크2개+쇠고기카레2개+쇠고기짜장2개+그레잇물티슈(10매), 1세트
# 16,800
# 오뚜기 3분카레순한맛(200g) 5개+쇠고기짜장(200g) 5개+그레잇물티슈(10매), 1세트
# 16,800
# 예이니식품 오뚜기 3분 사천짜장+쇠고기간짜장 각5개씩 세트(200gx10개)프리미엄, 200g, 10개
# 17,100
# 3분 쇠고기 간짜장, 200g, 7개
# 17,800
# 오뚜기 3분 쇠고기 짜장 카레 200g 12입 즉석 간편 요리 음식 소고기 커리 오뚜기밥
# 17,900
# 오뚜기3분 쇠고기카레 200g x 10p + 쇠고기짜장 200g x 10p, 1세트
# 18,020
# 오뚜기 3분 쇠고기간짜장, 200g, 8개
# 19,600
# 오뚜기 3분 카레 소스 5종 10개입 (3분카레 매운맛2 + 3분카레 약간매운맛2 + 쇠고기짜장2 + 햄버그스테이크2 + 미트볼2) + 블루존물티슈, 1세트
# 19,800
# 오뚜기 3분 쇠고기 짜장, 200g, 24개
# 21,490
# 3분 쇠고기 간짜장, 200g, 9개
# 21,600
# 오뚜기 3분 쇠고기카레, 200g, 24개
# 21,600
# 3분 쇠고기카레 200g 간편식 즉석 카레, 상세페이지 참조
# 1,050
# 오뚜기 3분 쇠고기간짜장 200g 식품 > 가공/즉석식품 즉석밥/간편조리 카레/짜장/덮밥 즉석카레, 1
# 1,100
# 오뚜기 3분쇠고기카레200g
# 1,110
# 오뚜기 3분 쇠고기카레 200g
# 1,110
# 오뚜기3분 쇠고기카레, 200g, 1개
# 1,180
# 오뚜기 3분 쇠고기짜장 200g 식품 > 가공/즉석식품 즉석밥/간편조리 카레/짜장/덮밥 즉석카레, 1
# 1,200
# 오뚜기 3분쇠고기짜장200g
# 1,290
# 오뚜기 3분쇠고기카레200g, 쿠팡 1, 쿠팡 본상품선택
# 1,360
# 3분 쇠고기카레 200G, 단품, 단품
# 1,400
# 오뚜기 3분 쇠고기짜장 200g 쇠고기카레 200g, 3분쇠고기짜장200g
# 1,400
# 3분쇠고기카레 200G
# 1,420
# 오뚜기 3분요리 쇠고기카레 200g 1개, 단일 수량
# 1,450
# 오뚜기 3분 쇠고기카레 3분 카레 순한맛 약간매운맛 매운맛 200g, 2 오뚜기 3분 카레 순한맛 200g
# 1,450
# 오뚜기 3분쇠고기카레200g, 쿠팡 1, 쿠팡 본상품선택
# 1,460
# 오뚜기 3분쇠고기카레200g, 상세페이지 참조
# 1,470
# 오뚜기 3분 쇠고기짜장 200g 쇠고기카레 200g, 3분 쇠고기카레
# 1,570
# 간단 오뚜기 3분쇠고기짜장200g 커리 인스턴트 캠핑요리 간편식 한끼식사 도시락 야식, 단품, 단품
# 1,600
# 간단 오뚜기 3분쇠고기카레200g 커리 인스턴트 캠핑요리 간편식 한끼식사 도시락 야식, 단품, 단품
# 1,600
# 오뚜기 3분쇠고기카레200g 즉석식품 카레 3분요리
# 1,600
# 오뚜기 3분쇠고기짜장200g, 쿠팡 1, 쿠팡 본상품선택
# 1,630
# (실온)[오뚜기]3분쇠고기카레 200G
# 1,650
# 오뚜기 3분 쇠고기카레200g, 1개
# 1,720
# 오뚜기 3분 쇠고기 카레 200g
# 1,770
# 스마트클라우드 짜장 오뚜기 3분 쇠고기짜장 200g 간편음식 간편조리음식 즉석음식 즉석조리음식 즉석조리
# 1,990
# ☞고객대만족↗¶ 쇠고기카레 에어건 오뚜기 3분요리 물호스 우레탄호스 (GZA♭*) 200g 1개, ♬본 상품 선택하기_Hmarket™
# 2,040
# ♪앵콜상품♬♩ 오뚜기 쇠고기카레 3분요리 200g 1개 (♩‡cOQ), ☞ 해당 상품 선택하기_91Mark™
# 2,040
# 오뚜기 3분쇠고기카레200g, 1
# 2,320
# 오뚜기 3분 백세카레 매운맛 200g, 1
# 2,320
# 오뚜기 짜장 3분 소고기간짜장 200g 1개 간편식 짜장밥, 단품, ♬본 상품 선택하기_Qurrier™
# 2,320
# 예이니식품 오뚜기 3분 백세카레 매운맛 1개(200gx1개)소스야채쇠고기강황프리미엄, 200g, 1개
# 2,390
# 오뚜기 짜장 3분 소고기간짜장 200g 1개 간편식 짜장밥, 단품, ☞ 해당 상품 선택하기_Onhoyo™
# 2,420
# 예이니식품 오뚜기 3분 렌틸콩 카레+짜장 각1개씩 세트(200gx2개)야채쇠고기강황, 200g, 2개
# 2,580
# ☞고객대만족↗¶ 오뚜기 소고기간짜장 3분요리 200g 1개 (‡Qs†o), ♬본 상품 선택하기_Wealth™
# 2,750
# [AK2K] 오뚜기 3분쇠고기카레200g 8090001EA, AK2K  본상품선택, AK2K  1
# 2,900
# 예이니식품 오뚜기 3분 사천짜장+쇠고기간짜장 각1개씩 세트(200gx2개)프리미엄, 200g, 2개
# 2,920
# 오뚜기 3분 쇠고기카레 200g
# 3,680
# 오뚜기 백세카레 3분 약간매운맛 200g
# 1,850
# [오뚜기]오뚜기 3분 백세카레 약간매운맛 200g, 상세페이지 참조
# 2,190
# 3분 백세카레 약간매운맛 200G, 단품, 단품
# 2,200
# 오뚜기 3분카레 백세카레 숙성카레 그대로짜장, E오뚜기 그대로카레200g 약간매운맛
# 2,380
# 예이니식품 오뚜기 3분 백세카레 매운맛 1개(200gx1개)소스야채쇠고기강황프리미엄, 200g, 1개
# 2,390
# 오뚜기 3분백세카레(약간매운맛)200g, 본상품선택
# 2,390
# 백세카레3분_약간매운맛 200G
# 2,500
# 오뚜기 3분 백세카레 약간매운맛 200g 식품 > 가공/즉석식품 즉석밥/간편조리 카레/짜장/덮밥 즉석카레, 1
# 2,500
# 예이니식품 오뚜기 3분 렌틸콩 카레+짜장 각1개씩 세트(200gx2개)야채쇠고기강황, 200g, 2개
# 2,580
# 【红】 오뚜기 3분 백세카레 약간매운맛 200g GЯ1+VIP_ 오뚜기 식품, GЯ 1
# 2,760
# 오뚜기 3분 백세카레 약간매운맛 200g, 디더블유 1
# 2,870
# 예이니식품 오뚜기 3분 사천짜장+쇠고기간짜장 각1개씩 세트(200gx2개)프리미엄, 200g, 2개
# 2,920
# 오뚜기 3분 백세카레 (약간매운맛) 200G, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 2,970
# 오뚜기 백세카레 3분카레 3일 숙성카레 그대로카레 그대로 짜장, 오뚜기3일숙성카레200g약간매운맛
# 2,980
# 오뚜기 3분카레 백세카레 숙성카레 그대로짜장, E오뚜기 백세카레3분200g 약간매운맛
# 3,080
# [도매직방] 오뚜기 3분카레 백세카레 숙성카레 그대로짜장, E오뚜기 백세카레3분200g 약간매운맛
# 3,110
# 예이니식품 오뚜기 그대로카레 매운맛+그대로짜장 각1개씩 세트(200gx2개)프리미엄, 200g, 2개
# 3,320
# 예이니식품 오뚜기 그대로카레 순한맛+그대로짜장 각1개씩 세트(200gx2개)프리미엄, 200g, 2개
# 3,320
# 예이니식품 오뚜기 그대로카레 약간매운맛+그대로짜장 각1개씩 세트(200gx2개)야채, 200g, 2개
# 3,320
# 백세카레3분_약간매운맛 200G, 1, 본상품선택
# 3,670
# 예이니식품 오뚜기 프리미엄 바몬드카레 고형 순한맛 1개(200gx1개)야채쇠고기해물, 1개, 200g
# 3,850
# 예이니식품 오뚜기 프리미엄 바몬드카레 고형 매운맛 1개(200gx1개)야채쇠고기해물, 200g, 1개
# 3,850
# WDBB_ 오뚜기 3분 백세카레 약간매운맛 200g, 단일 수량
# 3,880
# T몰 / 오뚜기 3분 백세카레 약간매운맛 200g, 단일 수량
# 4,040
# WDBB_ 오뚜기 3분 백세카레 약간매운맛 200g, 단일 수량
# 4,270
# 예이니식품 오뚜기 백세카레 고형 매운맛 1개(200gx1개)요리소스야채쇠고기해물강황, 200g, 1개
# 4,310
# (무)오뚜기 3분백세카레(약간매운맛)200g
# 4,480
# 오뚜기 백세카레 3분 약간매운맛 200g
# 4,950
# 오뚜기 3분 백세카레 약간매운맛 200g, 쿠팡 1
# 5,730
# [도매직방] 오뚜기 3분카레 백세카레 숙성카레 그대로짜장, E오뚜기 그대로카레200g 약간매운맛
# 5,770
# [ct] 오뚜기 3분 백세카레 약간매운맛 200g#177EA, 쏭쏭 본상품선택, 쏭쏭 1
# 6,240
# 예이니식품 오뚜기 3분 렌틸콩 짜장 3개(200gx3개) 소스그대로야채쇠고기해물, 200g, 3개
# 6,370
# 예이니식품 오뚜기 3분 렌틸콩 카레 3개(200gx3개)소스그대로야채쇠고기백세강황, 3개
# 6,370
# 오뚜기 3분 백세카레 약간매운맛 200g오뚜기 식품 음식 푸드 재료 간편, v본상품선택V
# 6,460
# 오뚜기 3분카레 백세카레 숙성카레 그대로짜장, E오뚜기 3일숙성카레200g 약간매운맛
# 6,470
# 카레는 역시!! 오뚜기 백세카레 3분카레 3일숙성카레 즉석식품 간편식 혼밥, 1개, 3일숙성카레200g 약간매운맛
# 6,600
# 대상 PARTSCANNER 청정원 카레 여왕 비프카레 160g 1인분, 1개
# 1,330
# 청정원 카레여왕 비프카레160G, 단일속성, 없음
# 1,580
# [청정원]3분 즉석 카레여왕 비프카레 160g(깊고 진한 맛), 상세페이지 참조
# 1,680
# 청정원 카레여왕 비프 160g, 없음, 상세설명 참조
# 1,820
# 청정원 카레여왕 비프 160g, 없음, 상세설명 참조
# 1,820
# 청정원 카레여왕 비프160g, 카레여왕(비프)160g/청정원
# 1,980
# 청정원 카레 여왕 비프카레 160g 1인분, 단일 수량
# 2,310
# 청정원 3분 카레여왕 비프카레, 14CS_청정원 카레여왕 비프카레 160g
# 2,750
# 청정원 카레여왕160g 비프카레 2개 3분카레 레토르트 카레
# 3,860
# 청정원 카레여왕 비프카레 160gx2개(레트로트), 1set
# 4,250
# 청정원 카레여왕 2개, 청정원 카레여왕 비프카레 160g (레토르트)
# 4,260
# 청정원 카레여왕 2개, 청정원 카레여왕 비프카레 160g(레트로트)
# 4,260
# [얄리얄리]_ 카레여왕 즉석카레 160g 비프카레 즉석식품 간편조리
# 5,560
# (MK) 카레여왕 즉석카레 160g 비프카레 즉석식품 간편조리
# 6,100
# 마트인코리아_MIK 청정원 카레여왕 비프 160g 3개, 단일옵션
# 6,430
# 청정원 3분요리 카레여왕 비프카레 160g, 2개
# 7,240
# 삼은파트너스 칼라레이저전용지 ProDesign 160g, A4, 100매
# 7,410
# 청정원 카레여왕160g 비프카레 4개 3분카레 레토르트 카레
# 7,720
# 대상 PARTSCANNER 청정원 카레 여왕 비프카레 160g 1인분, 4개
# 7,900
# 청정원 카레여왕 비프카레 160g 레토르트 x 6, 단품없음
# 8,200
# TORIMALL 청정원 카레여왕 "비프카레" 부드러운 소고기, 2개, 160g
# 8,500
# TORIMALL 청정원 카레여왕 "비프카레" 부드러운 소고기, 5개, 160g
# 8,500
# 유니크앤몰 강력추천!! 청정원 카레여왕 비프카레 부드러운 소고기의 깊고 진한맛, 2개, 160g
# 8,600
# 카레여왕 비프카레 160g x 3개
# 8,940
# 청정원 3분요리 카레여왕 비프카레 160g, 3개
# 8,950
# 청정원 3분요리 카레여왕 비프카레 160g, 4개
# 10,660
# 대상 PARTSCANNER 청정원 카레 여왕 비프카레 160g 1인분, 2개
# 10,710
# 댕이몰 청정one 카레여왕 비프카레맛 160g - 부드럽고 맛있는 소고기맛카레요리(간편하게 즉석에서), 3개
# 10,900
# 유니크앤몰 강력추천!! 청정원 카레여왕 비프카레 부드러운 소고기의 깊고 진한맛, 3개, 160g
# 10,900
# TORIMALL 청정원 카레여왕 치킨카레 매콤하고 깔끔한맛, 3개, 160g
# 10,900
# TORIMALL 청정원 카레여왕 "비프카레" 부드러운 소고기, 3개, 160g
# 10,900
# 청정원 즉석 카레여왕 비프160g x6개, 6개, 160g
# 11,400
# 청정원 즉석 카레여왕 비프160g x 6개, 160g
# 11,410
# 청정원 카레여왕160g 비프카레 5개 무배 3분카레 레토르트 카레
# 12,650
# 대상 PARTSCANNER 청정원 카레 여왕 비프카레 160g 1인분, 3개
# 13,200
# 유니크앤몰 강력추천!! 청정원 카레여왕 비프카레 부드러운 소고기의 깊고 진한맛, 4개, 160g
# 13,800
# 대한민국장사꾼 오뚜기 즉석밥 오뚜기밥 발아현미밥 210g, 1개
# 1,310
# 오뚜기 맛있는오뚜기밥 오곡, 210g, 3개
# 4,170
# 오뚜기 맛있는 오뚜기밥, 210g, 12개
# 4,760
# 오뚜기 밥플레이크 스틱, 30g, 10개
# 6,760
# 즉석밥 맛있는 오뚜기밥 210g x 10개
# 11,800
# 맛있는 오뚜기밥 발아흑미, 210g, 12개
# 12,890
# 맛있는 오뚜기밥 발아흑미, 210g, 12개
# 12,890
# 맛있는 오뚜기밥 고시히카리, 210g, 12개
# 13,120
# 오뚜기 오뚜기밥 찰현미, 210g, 12개
# 13,270
# 오뚜기 오뚜기밥 찰현미-, 210g, 12개
# 13,270
# 맛있는 오뚜기밥 210gx12개, 상세페이지 참조
# 13,410
# 73 빵빵야 / 입맛따라 즐기는 오뚜기)맛있는 오뚜기밥 210g x 12개 갓도정 밥맛 깨끗 즉석(묶음가능개수 2개) 배관 에어게이지 고무호스 에어노즐/카플러/부속품
# 13,430
# 오뚜기 오뚜기밥 10개(발아흑미5개+오곡5개), 10개
# 13,580
# 오뚜기밥 발아 현미 210g X 12개입 즉석밥 간편 조리 식품, 1세트
# 13,980
# 오뚜기 맛있는 오뚜기밥 12입, 오뚜기밥 백미 210g x 12개
# 14,700
# [오뚜기]오뚜기밥 발아현미 210gX12개입/발아흑미/오곡, 오뚜기발아흑미 12개
# 15,100
# 맛있는 오뚜기밥 발아현미, 210g, 10개
# 15,140
# 맛있는 오뚜기밥 발아흑미오곡찰현미고시히카리 210g x 12개 4종, 02_오뚜기밥 오곡 210g x 12개
# 15,940
# 맛있는 오뚜기밥 오곡, 210g, 12개
# 12,970
# [로적마켓] 오뚜기밥 4종 혼합(12개입) 맛있는밥 3개 + 발아흑미 3개 + 찰현미 3개 + 오곡 3개, 1세트
# 16,440
# 오프라이스 윤기나는 밥 210g, 18개
# 16,900
# 맛있는 오뚜기밥 발아현미, 210g, 12개
# 17,200
# 맛있는 오뚜기밥 발아현미, 210g, 18개
# 17,500
# 오뚜기밥210g 10개+간편국 미역국1개+사골우거지국1개, 상세페이지 참조
# 17,800
# [로적마켓] 맛있는 오뚜기밥 4종 발아흑미 3개 + 찰현미 3개 + 오곡 3개 + 고시히카리 3개, 1세트
# 17,900
# [오뚜기] 맛있는 오뚜기밥, 210g, 1개
# 17,930
# 오뚜기 밥, 210g, 6개
# 18,010
# 오뚜기 오뚜기밥 찰현미, 210g, 18개
# 18,120
# [멸치쇼핑]오뚜기밥 맛있는 오뚜기밥 210g 18개 *1박스, 상세페이지 참조
# 18,200
# 오뚜기 맛있는 오뚜기밥, 210g, 18개
# 18,300
# 맛있는 오뚜기밥 발아흑미, 210g, 18개
# 18,490
# 컵밥 6종세트 (미역국 황태해장국 진짬뽕밥 부대찌개 설렁탕 얼큰쇠고기전골) + 그레잇물티슈(10매), 총 6개 = 1 set
# 19,500
# 오뚜기 맛있는 오뚜기밥, 210g, 210ml, 24개입
# 19,620
# 오뚜기밥 고시히카리 210g 3팩 x 6묶음(총18개)
# 19,980
# 오뚜기밥 210그램12개번들 1세트, 단품
# 20,500
# 오뚜기 맛있는 오뚜기밥, 1
# 21,500
# 오뚜기 맛있는 오뚜기밥 작은밥 150g 3개입/즉석밥/밥/쌀/오뚜기밥/현미밥 식품 > 냉장/냉동식품 냉장냉동 간편조리 냉장/냉동 즉석밥
# 2,900
# 오뚜기 오뚜기밥 오곡 210gx3개입, 1개
# 3,540
# 오뚜기 오뚜기밥 찰현미 210gx3개입, 1개
# 3,540
# [ 21.12.24 유통기한 임박 ] 맛있는 오뚜기밥 찰현미 210g x 3개입
# 3,590
# 오뚜기 맛있는 오뚜기밥 찰현미 210g 3개입/즉석밥/밥/쌀/오뚜기밥/현미밥 식품 > 냉장/냉동식품 냉장냉동 간편조리 냉장/냉동 즉석밥, 3
# 4,260
# 오뚜기 맛있는 오뚜기밥 발아흑미 210g 3개입/즉석밥/밥/쌀/오뚜기밥/현미밥 식품 > 냉장/냉동식품 냉장냉동 간편조리 냉장/냉동 즉석밥, 3
# 4,260
# 맛있는 오뚜기밥 발아현미 3입 묶음(210g X 3개입), 단품, 단품
# 6,100
# 오뚜기 맛있는 오뚜기밥 찰현미 3입 묶음 (210g 3개입), 단품, 단품
# 6,200
# MDT7335 CJ백설 햇반 큰공기300gx3개입 오뚜기밥/오뚜기햇반/즉석밥/cj햇반, 1개
# 16,590
# 오뚜기 맛있는 오뚜기밥 발아흑미 [(210g x 3개입) 6개] 1박스, 210g
# 28,360
# 오뚜기 맛있는 오뚜기밥 210g x 3개입 (1팩), 210g x 3입, 1팩
# 3,200
# 오뚜기 맛있는 컵밥 원조맛집 김치찌개밥 6개, 280g, 6개입
# 15,720
# 오뚜기 컵밥 서울식 설렁탕 국밥 x6개, 171g, 6개입
# 15,860
# 오뚜기 컵밥 진한쇠고기 미역국밥, 284g, 6개입
# 15,860
# 오뚜기 컵밥 쇠고기미역국밥, 202g, 6개입
# 16,800
# 오뚜기 맛있는 컵밥 참치마요 덮밥, 217g, 6개입
# 16,800
# 오뚜기 맛있는 오뚜기밥 (210gX4개) 6개입 박스/즉석밥/밥/쌀/오뚜기밥/현미밥 식품 > 냉장/냉동식품 냉장냉동 간편조리 냉장/냉동 즉석밥, 6
# 33,930
# 오뚝이 큰 오뚜기밥 300그램 30+6개입 즉석밥 큰공기, 2박스
# 49,980
# 햇반컵반 버터장조림 비빔밥 216gx6개입/즉석밥 햇반 캠핑푸드
# 21,880
# 햇반 백미밥, 210g, 6개
# 5,990
# 햇반 백미밥, 210g, 6개
# 5,990
# 햇반 매일 찰잡곡밥, 210g, 8개
# 8,780
# 햇반 현미쌀밥, 210g, 8개
# 9,040
# 햇반 매일콩잡곡밥, 210g, 8개
# 9,980
# 햇반 식후 혈당조절에 도움을 줄 수 있는 밥, 210g, 6개
# 10,560
# 햇반 백미밥, 210g, 10개
# 11,330
# 햇반 매일잡곡밥 210g [+사은품증정], 6개입
# 11,700
# 씨제이제일제당 햇반 식후혈당조절도움밥 210g 6번들 x 1개 총6개, 단품
# 11,800
# 햇반 cj제일제당 이천쌀밥 210g [+사은품증정], 6개입
# 11,900
# 햇반 현미쌀밥, 210g, 12개
# 12,480
# 햇반 매일잡곡밥, 210g, 12개
# 12,580
# 햇반 흑미밥, 210g, 12개
# 12,900
# 햇반 백미밥, 210g, 12개
# 13,190
# 햇반 흑미밥 210g, 8개
# 13,500
# 햇반 유기농 쌀밥, 210g, 12개
# 13,850
# 예이니식품 CJ 햇반 흑미밥210g 4개+작은공기130g 3개(총7개), 1세트
# 14,390
# 햇반 210g x 12개 (백미+잡곡+흑미+콩잡곡)
# 14,500
# 햇반 즉석밥, 210g, 8개
# 14,500
# 햇반 즉석밥 랜덤발송, 210g, 8개
# 14,500
# 햇반 매일콩잡곡밥, 210g, 12개
# 14,730
# CJ제일제당 햇반 아산맑은쌀밥, 210g, 12개
# 14,700
# CJ 햇반 실속 210Gx8개입, 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 14,970
# 햇반 솥반 꿀약밥, 210g, 6개
# 15,120
# CJ제일 햇반 아산쌀밥 210gx12개입 대용량, 210g, 12개
# 15,260
# 햇반 상온 발아현미밥, 210g, 12개
# 16,030
# 햇반 매일 찰잡곡밥, 210g, 12개
# 16,810
# 햇반 이천명품쌀밥, 210g, 12개
# 16,900
# 햇반 솥반 버섯 영양밥 200g x 3p + 솥반 꿀약밥 210g x 3p 세트, 1세트
# 17,110
# 햇반 즉석밥, 200g, 15개
# 17,470
# 햇반 쌀눈 가득 쌀밥, 210g, 12개
# 17,800
# 예이니식품 CJ 햇반 큰공기300g 3개+매일 찰잡곡밥210g 4개(총7개), 1세트
# 17,900
# 햇반 즉석밥, 210g, 15개
# 17,900
# 햇반 유기농 쌀밥, 210g, 12개
# 17,990
# [톡톡92] 찰기있는 찹쌀과 잡곡의 조화 CJ햇반 매일 찰 잡곡밥 210g x 15개+3개 (당일발주), 18개
# 18,800
# 햇반구수한쌀밥 210g, 12개입
# 18,900
# CJ 햇 반 210g 최고의 간편식 가성비갑 비상식량 필수품
# 990
# 【红】 CJ)작은햇반 130g 1개입 GЯ1+VIP_ 즉석밥 햇반, GЯ 1
# 1,640
# 햇반 컵반 강된장 보리 즉석비빔밥, 06_콩나물국밥
# 2,350
# 햇반 컵반 강된장 보리 즉석비빔밥, 02_순두부찌개국밥
# 2,750
# 햇반 즉석밥, 190g, 2개
# 2,870
# 햇반 컵반 강된장 보리 즉석비빔밥, 13_불고기덮밥
# 3,500
# CJ 햇반 컵반 컵밥 5종 골라담기 모음, 중화마파두부덮밥
# 3,680
# 햇반 백미 큰햇반 사각, 300g, 1개
# 3,810
# 햇반 컵반 강된장 보리 즉석비빔밥, 05_육개장국밥
# 4,300
# CJ 햇반 컵반 22종 자유선택 컵밥 골라담기 즉석국밥, 14 마파두부덮밥
# 4,450
# 햇반 컵반 강된장 보리 즉석비빔밥, 11_고추장나물비빔밥
# 4,550
# CJ CJ햇반 컵반 17종/비빔밥 덮밥 컵밥 국밥 즉석밥, 05_육개장국밥
# 4,600
# 예이니식품 CJ 제일제당 햇반 4개(200gx4개) 흰쌀밥백미쎈쿡, 200g, 4개
# 4,700
# CJ제일제당 햇반 발아현미밥 작은 공기 130gx3개, 상세페이지 참조
# 4,870
# CJ 햇반 컵반 22종 자유선택 컵밥 골라담기 즉석국밥, 22 치킨마요(프리미엄)
# 4,890
# CJ 햇반 컵반 22종 자유선택 컵밥 골라담기 즉석국밥, 30 철판고추장제육(프리미엄)
# 4,900
# CJ 햇반 컵반 22종 자유선택 컵밥 골라담기 즉석국밥, 23 불닭마요(프리미엄)
# 4,900
# 햇반 컵반 돼지고기 김찌밥, 379g, 1개
# 4,980
# 햇반 컵반 차돌 된찌밥, 382g, 1개
# 4,980
# CJ햇반 솥반 4종류 택 꿀약밥 버섯영양밥 뿌리채소영양밥 통곡물밥, 꿀약밥 210g
# 4,980
# 햇반 매일 잡곡밥 210g 4개입, 상세페이지 참조
# 5,020
# CJ CJ햇반 컵반 17종/비빔밥 덮밥 컵밥 국밥 즉석밥, 12_직화볶음짜장덮밥
# 5,100
# 햇반 매일잡곡밥 210g x 4입
# 5,230
# 햇반 현미쌀밥 210g x 4입
# 5,320
# ...
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 녹차를 바르다
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 싱겁다 엘로우
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 와인색
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 카메오 색깔 （아가일무늬 ）20 낟알
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 브라운55
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 벚꽃 핑크
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 와인레드 색깔 （아가일무늬 ）20 낟
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 녹차를 바르다 （아가일무늬 ）20 낟
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 피부색
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 스위트 보라색 （아가일무늬 ）20 낟
# 12,700
# 15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 로즈 레드
# 12,700
# 모닝빵 민 상이다 모두 계란 러우쑹 크림 소스를 준비했다 겹 심령 가죽 가방 케익 110G 아침식사 상자 전체, 러우쑹 빵 15 개 _증정 1개 도합
# 13,000
# 풀무원 무항생제 목초란 15구, 780g, 1개
# 6,790
# (냉장)[풀무원]목초란10구
# 9,900
# 풀무원 동물복지 목초란 15구, 일반포장 동절기만
# 12,300
# 풀무원 동물복지 목초란 15구, 아이스팩 포장
# 13,300
# (냉장)[풀무원]목초란10구x2
# 14,900
# (냉장)[풀무원]목초란10구+통통신선란10구
# 14,900
# (냉장)[풀무원]목초란15구x2
# 19,900
# (냉장)[풀무원]목초란10구x3
# 20,900
# (냉장)[풀무원]목초란10구x2+통통신선란10구x2
# 26,900
# (냉장)[풀무원]목초란15구x3
# 27,500
# 풀무원 동물복지 인증 목초란 15구, 780g, 1개
# 7,190
# 아침란 1구 구운 훈제 삶은 찐 계란 HACCP 다이어트 달걀 구운란 훈제란
# 700
# 아침란 2구 구운 훈제 삶은 찐 계란 HACCP 다이어트 달걀 구운란 훈제란
# 1,600
# [정연푸드] [냉장] 참프레 동물복지 수비드 닭가슴살 5종 중 (오리지널/허브/블랙페퍼/불닭/소이갈릭) 스팀 수비드, 03_블랙페퍼130g
# 1,690
# [정연푸드]참프레 동물복지 수비드 닭가슴살 소이갈릭135g 냉장 스팀/수비드 닭가슴살, 1개, 135g
# 1,690
# [정연푸드]참프레 동물복지 수비드 닭가슴살 허브130g 냉장 스팀/수비드 닭가슴살, 1개
# 1,700
# 복지형 닭 병아리 자동급수컵 조류급수 닭모이통 물통, 복지형급수컵
# 1,800
# [메가마트]수비드 닭가슴살 오리지널 130g, 1개
# 2,200
# 참프레 동물복지 닭곰탕(실온) 500g, 1팩
# 3,400
# (100% 파손보상) 푸드번창 무항생제 신선 계란10구
# 3,750
# 참프레 동물복지 닭육수 700g
# 4,000
# 마니커에프앤지 치킨너겟플러스 450g, 1팩
# 4,400
# 참프레 동물복지 닭개장(실온) 500g, 1팩
# 4,600
# 참프레 동물복지 수비드 닭가슴살 허브 130g, 아이스팩 포장
# 4,700
# 참프레-동물복지 바삭너겟 500g/에어프라이어전용제품
# 4,800
# 하림 동물복지 닭다리살 (냉장), 300g, 1개
# 5,310
# 참프레 동물복지 바삭치킨너겟 500g, 1팩
# 5,600
# 참프레 동물복지 수비드 닭가슴살 소이갈릭 135g, 아이스박스 포장
# 5,700
# 참프레 동물복지 수비드 닭가슴살 오리지널 130g, 아이스박스 포장
# 5,700
# 참프레 동물복지 수비드 닭가슴살 페퍼 130g, 아이스박스 포장
# 5,700
# 참프레 동물복지 수비드 닭가슴살 불닭 135g, 아이스박스 포장
# 5,700
# 참프레 동물복지 직화 그릴윙 300g 에어프라이어로 간편조리 간식안주, 1봉
# 5,900
# 하림 동물복지 닭다리 (냉장), 400g, 1개
# 5,900
# 참프레-동물복지 슈퍼곡물 크리스피 텐더500g/에어프라이어전용제품
# 5,900
# 참프레-동물복지 직화 그릴 윙 300g에어프라이어전용제품
# 5,900
# 하림 동물복지 닭가슴살 (냉장), 400g, 1개
# 5,980
# 참프레-동물복지 직화 그릴 닭다리 400g/에어프라이어전용제품
# 6,920
# 참프레 동물복지 닭곰탕(실온) 500g x 2팩, 1세트
# 6,400
# (100% 파손보상) 푸드번창 무항생제 신선 계란10구15구20구, 무항생제20구
# 6,580
# 동물복지 인증 하림 greeners 통닭 백숙용 (냉장), 1050g, 1팩
# 6,800
# 참프레 동물복지 직화그릴윙 300g, 1팩
# 7,000
# 마니커에프앤지 리얼치킨 통살케이준텐더 540g, 1팩
# 7,200
# 참프레 동물복지 직화그릴닭다리 400g, 1팩
# 7,200
# [초록마을] 동물복지닭가슴살(300g), 상세 설명 참조
# 7,500
# 참프레 동물복지 직화 그릴닭다리 400g 에어프라이어로 간편조리, 1봉
# 7,500
# 초록마을 동물복지닭가슴살(300g), 1개
# 7,500
# 마니커에프앤지 치킨너겟플러스 450g x 2팩, 1세트
# 7,900
# 하림 자연실록 냉장 통닭 무항생제 인증 (냉장), 830g, 1팩
# 5,930
# 하림 냉동 삼계탕용 통닭 530g
# 3,900
# 서진네 닭볶음탕용(국내산) 950g이상(아이스박스포장)A&J푸드, 1개, 950g이상
# 5,400
# 풀토래 -신선냉장- 통닭 1마리, 1개, 13호 1마리
# 6,500
# [일계양득] 1+1 올품영계 30호 2마리, 올품영계 30호 2봉
# 7,500
# 서진네 냉동통닭발(국내산) 1kg(아이스박스포장)대운, 1개, 1kg
# 7,800
# 서진네 치킨 팝콘 2kg(아이스박스포장)랜시푸드, 1개, 2kg
# 8,500
# 서진네 닭근위(국내산) 1kgX2개(아이스박스포장)청솔식품, 2개, 1kgX2개
# 9,400
# 하림 참 토종닭 백숙용 (냉장), 1100g, 1개
# 10,450
# 브니엘몰 목우촌 삼계탕 850g 초복 중복 말복 보양식 닭백숙 백숙 반계탕 즉석삼계탕, 1개
# 11,200
# 에그파파 냉장 닭한마리 닭도리 절단육 2kg (1kgX2팩)
# 12,900
# 하림 프레쉬업 냉장 생닭 10호(950g이상) 2봉, 프레쉬업생닭 950g 2봉
# 12,910
# 올계 직영 능이와 씨암탉 백숙 반마리 1kg 레토르트
# 13,600
# 코스트코 하림 영계닭 두마리 1KG 삼계탕용 [아이스박스] + 사은품, 2)택배발송(아이스박스포장)
# 13,930
# 코스트코 하림 영계닭 두마리 1KG 삼계탕용 [아이스박스] + 사은품, 1)직배송(직배송지역확인)
# 13,930
# 올품 토종대왕 백숙용 토종닭 (냉장), 1150g, 1팩
# 13,990
# 하림 프레쉬업 냉장 생닭 11호 (1050g 이상) 2마리, 1050g
# 14,000
# CN 하림 삼계탕용 닭 두마리 냉장 코스트코 삼계 손질 생닭 백숙용 백숙 삼계탕 무항생제
# 14,110
# 올품 친환경 무항생제 생닭 1050g 2봉, 친환경무항생제생닭 1050g 2봉
# 14,900
# [코스트코]하림 백숙용 토종닭 1.3kg (냉장)
# 15,210
# ★icebox★하림참진토종닭백숙1.1Kg
# 15,420
# 1+1 기획 상품 올계 직영 유기농 삼계탕 레토르트 1kg 즉석 삼계탕
# 17,120
# 5+5 기획 상품 올계 직영 유기농 삼계탕 레토르트 1kg 즉석 삼계탕 10개
# 86,000
# [직배송/택배발송]코스트코 하림 백숙용 토종닭 1.3KG 백숙용 + 사은품, 2)택배발송(아이스박스포장)
# 17,890
# [직배송/택배발송]코스트코 하림 백숙용 토종닭 1.3KG 백숙용 + 사은품, 1)직배송(직배송지역확인)
# 17,890
# 하림 냉장 참진 닭볶음탕용1kg 2봉, 냉장참진닭볶음용 1kg 2봉
# 17,900
# 코스트코 하림 동물복지 두마리 통닭 2.4KG 통닭용 [아이스박스] + 사은품, 2)택배발송(아이스박스포장)
# 23,720
# 코스트코 하림 동물복지 두마리 통닭 2.4KG 통닭용 [아이스박스] + 사은품, 1)직배송(직배송지역확인)
# 23,720
# 하림 토종닭 백숙용 18호 생닭 1개, 닭
# 27,000
# 여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 2개
# 27,700
# 광주요 백자 수라인 커피잔 2p + 커피잔 받침 2p 세트, 1세트
# 30,430
# 여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 3개
# 38,700
# 브니엘몰 목우촌 삼계탕 850g 초복 중복 말복 보양식 닭백숙 백숙 반계탕 즉석삼계탕, 5개
# 55,000
# 여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 5개
# 59,700
# 여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 7개
# 79,700
# 브니엘몰 목우촌 삼계탕 850g 초복 중복 말복 보양식 닭백숙 백숙 반계탕 즉석삼계탕, 10개
# 101,400
# 여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 10개
# 109,700
# 큐피드메이드 초콜릿 빼빼로 원재료 모음, 밀크초콜릿100g
# 1,400
# 할매정육점 막창장 100g 막창소스 서라벌막창장 대구막창장, 1개입
# 1,500
# 할매정육점 막창장 100g 막창소스 서라벌막창장 대구막창장, 1개입
# 1,500
# 푸주 목전지 구이용 제육용 250g 보쌈용 500g, 구이용 목전지, 1개
# 1,900
# 푸주 목전지 구이용 제육용 250g 보쌈용 500g, 1개
# 1,900
# 옵션선택/ 한돈100g 갈비찜 LA갈비 목살구이중 택1, 02.한돈_목살구이용100g
# 1,950
# 할매정육점 막창장 100g 막창소스 서라벌막창장 대구막창장, 200g, 2개입
# 2,900
# (맛나)돈육돼지/벌집목심 100G/국산, 1개
# 3,000
# 신풍한우 1 1+등급 국내산 한돈 불고기용 목살, 국내산 한돈 불고기용 목살 100g, 1개
# 3,200
# 신풍한우 1 1+등급 국내산 한돈 목살 로스용 100g, 1개
# 3,200
# 고기천국 왕목살(구이용) 400g, 1팩
# 3,500
# [삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 100g 구이용 등심덧살 특수부위, 가브리살-구이용100g
# 3,800
# 루루축산 왕목살 구이용 500g (미국산), 1팩
# 4,100
# 모디바 냉동 삼겹살 오겹살 구이용 대패 통삼겹살 300g, 1팩, 02. 오겹살(구이용/ 300g )
# 4,100
# 피에이미트마켓 왕목살(목전지)500g, 1팩, 구이용500g
# 4,400
# 도드람 영양스테이크 100g, 1팩
# 4,600
# 시저 불고기 100g
# 5,230
# [피에이미트마켓]비교불가 돼지목뼈 1kg 살이많은 100%목뼈만 선별~, 1개
# 5,900
# [쭌미트] 이베리코 목살 1팩 (100g 150g 200g 250g 500g)
# 6,300
# 도드람 영양스테이크 100g, 2팩
# 6,400
# 루루축산 왕목살 구이용 500g+500g (미국산) 총 1kg, 1팩
# 7,500
# [삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 200g 구이용 등심덧살 특수부위, 가브리살-구이용200g
# 7,600
# [루루축산] 왕목살 제육 불고기용 1+1 총1kg 수입돼지고기, 1set
# 7,700
# [루루축산] 왕목살 찌개용 500g+500g (미국산) 총 1kg, 1set
# 7,700
# [피밀리우리흑돈] 프리미엄 명품흑돼지 뒷다리살 1kg, 1개, 수육용
# 7,800
# 솔트 에이징 숙성 수입산 삼겹살 목살 항정살 각 1팩 100g 수비드 스테이크 캠핑용
# 8,000
# 솔트에이징 숙성 삼겹살+목살+항정살 각100gX3팩 냉장육 오겹살 냉삼 [블루키트]
# 9,000
# 솔트에이징 숙성 삼겹살 목살 항정살 각 1팩X100g 수비드삼겹살 돼지등갈비 냉동 원육
# 9,000
# [육미가] 목살 1kg 2.5kg 10kg (구이용) HACCP 인증, 1팩
# 9,900
# 대한민국장사꾼 국내산 돼지목살 숯불용 500g, 1팩
# 9,900
# 국내산 한돈 목살 400g 냉장 1등급 돼지고기 [프다], 제육/구이용 (5~7mm)
# 9,900
# [쭌미트] 미국산 돼지목살 1팩 (100g 150g 200g 250g 500g 개별진공포장)
# 10,000
# 도드람 영양스테이크 100g, 4팩
# 10,600
# 곰곰 목전지 (냉동) 500g, 2개
# 10,990
# [쭌미트] 한돈 목살 스테이크 1팩 (100g 150g 200g 250g 500g), 500g
# 11,000
# 곰곰 양념 목심칼집구이, 1kg, 1개
# 11,250
# 큐피드메이드 초콜릿 빼빼로 원재료 모음, 밀크초콜릿100g
# 1,400
# 대패삼겹살 칠레산 냉동삼겹살 100g/300g/500g 세자매정육점, 대패삼겹100g
# 1,690
# 푸주 목전지 구이용 제육용 250g 보쌈용 500g, 구이용 목전지, 1개
# 1,900
# [쭌미트] 냉동 핀란드 삼겹살 개별 진공포장 1팩, 100g x 1팩
# 2,400
# [신사강] 가마솥 볶음김치 1팩(100g), 단품
# 2,500
# 키친델리 바베큐 훈제삼겹살 100gX9
# 2,820
# (맛나)돈육돼지/삼겹살(숯불구이용) 100G/국산, 1개
# 3,000
# (맛나)돈육돼지/삼겹살(숯불구이용) 100G/국산, 1개
# 3,000
# 신풍한우 1 1+등급 국내산 한돈 로스용삼겹살, 국내산 한돈 로스용삼겹살 100g, 1개
# 3,200
# 신풍한우 1 1+등급 국내산 한돈 불고기용 삼겹살, 국내산 한돈 불고기용 삼겹살 100g, 1개
# 3,200
# 푸주 프리미엄 삼겹살 구이용 250g 이지팩 1~2인용 소포장, 1개, 프리미엄 삼겹살 250g
# 3,500
# 미트아울렛 신선 삼겹살(구이용) 300g, 1개
# 3,500
# 미트아울렛 신선 삼겹살(숯불용) 300g, 1개
# 3,500
# [메가마트]문경약돌돼지 삼겹살 100g, 1개
# 3,580
# 푸주 프리미엄 삼겹살 구이용 250g 이지팩 1~2인용 소포장, 1개, 한입 큐브 삼겹살 250g
# 3,700
# [삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 100g 구이용 등심덧살 특수부위, 가브리살-구이용100g
# 3,800
# [메가마트]지리산 흑돼지 삼겹살 100g, 1개
# 3,980
# 도드람 영양스테이크 100g, 1팩
# 4,600
# 시저 불고기 100g
# 5,230
# 혼족 자취생 영양한끼 냉동대패삼겹 100g 간편식 싱싱, 대패삼겹 100g
# 6,200
# 혼족 자취생 영양한끼 냉동대패삼겹 100g 간편한 싱싱, 선택사항_대패삼겹 100g, 상세페이지 참조
# 6,240
# 도드람 영양스테이크 100g, 2팩
# 6,400
# [삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 200g 구이용 등심덧살 특수부위, 가브리살-구이용200g
# 7,600
# 고기천국 삼겹살(구이용) 200gx3, 3팩, 200g
# 7,900
# 솔트 에이징 숙성 수입산 삼겹살 목살 항정살 각 1팩 100g 수비드 스테이크 캠핑용
# 8,000
# 대패삼겹살 칠레산 냉동삼겹살 100g/300g/500g 세자매정육점, 대패삼겹500g
# 8,390
# 솔트에이징 숙성 삼겹살+목살+항정살 각100gX3팩 냉장육 오겹살 냉삼 [블루키트]
# 9,000
# 솔트에이징 숙성 삼겹살 목살 항정살 각 1팩X100g 수비드삼겹살 돼지등갈비 냉동 원육
# 9,000
# [신선한고기마을]국내산 돼지고기 냉동삼겹살 냉삼 안심 목살 외 각부위별 국내산 500g, 1박스, 안심500g(냉장)
# 9,900
# 도드람 영양스테이크 100g, 4팩
# 10,600
# 고기연육제 푸로찜 100gX10개 고기연하게 살살녹는고기 파인애플추출첨가, 1팩, 1kg
# 12,600
# 달구지푸드 훈제돼지막창500g(된장소스100g), 1, 500g, 500g
# 13,120
# 도드람 영양스테이크 100g, 6팩
# 14,800
# 냉장/냉동 제주흑돼지 500g x 4팩 균일가전, 4.냉장찌개용 500gx4팩
# 14,900
# [삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 한근 400g 구이용 등심덧살 특수부위, 가브리살-구이용400g
# 15,200
# 고기아찌 프리미엄 에이징 돼지고기 3종 세트 600g [삼겹살+목살+항정살]_냉장, 1세트
# 15,500
# 친절한한우 우둔 300g600g육회 이유식용 1등급이상 소고기 영주한우 설날 설선물 명절선물 신년선물 새해선물 선물세트, 1개, 육회 물회소스 100g
# 2,000
# [강진완도축협] 한우1등급 불고기 100g
# 4,800
# [강진완도축협] 한우1등급 설도 국거리 100g
# 5,400
# [강진완도축협] 한우1등급 장조림 100g
# 5,400
# [강진완도축협] 한우1등급 양지 국거리 100g
# 6,400
# [강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조
# 9,800
# [강진완도축협] 한우1등급 등심 100g
# 13,000
# 브랜드없음 [강진완도축협] 한우1등급 등심 100g, 단품없음
# 13,100
# [강진완도축협] 한우1+등급 등심 100g, 단품
# 14,400
# [강진완도축협] 한우1등급 안심 100g
# 15,500
# [강진완도축협] 한우1+등급 채끝 100g
# 16,000
# [육라운드] 한우1등급 다이어트소고기 한우1+ 안심 구이용 100g 온라인정육점 육라운드 도매
# 16,500
# [강진완도축협] 한우1+등급 안심 100g
# 17,000
# [강진완도축협] 한우1등급 등심 100g, 단품
# 17,900
# 안동 한우등심 1등급 100g
# 18,900
# [강진완도축협] 한우1+등급 등심 100g
# 18,900
# [강진완도축협] 한우1등급 채끝 100g
# 18,900
# 안동한우 안심 1등급 100g, 1등급 안심
# 19,000
# [강진완도축협] 한우1등급 안심 100g, 상세 설명 참조
# 20,900
# 국내산 1등급 이상 육우등심세트(등심400g 치마살100g 제비추리100g) 600g
# 36,900
# 농협안심한우 1등급 등심 [100g/300g], 02.한우 등심-300g
# 52,900
# [강진완도축협] 한우1등급 채끝 400g
# 53,400
# 기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1
# 69,900
# 청정해 제주 한우 1++ 등심, 400g, 1개
# 77,000
# [자연맛남] 마장동한우 명품 구이선물세트 1호 1등급 1kg (등심500g/채끝200g/업진200g/갈비살100g)
# 134,900
# 친절한한우 우둔 300g600g육회 이유식용 1등급이상 소고기 영주한우 설날 설선물 명절선물 신년선물 새해선물 선물세트, 1개, 육회 물회소스 100g
# 2,000
# [강진완도축협] 한우1등급 불고기 100g
# 4,800
# [강진완도축협] 한우1등급 설도 국거리 100g
# 5,400
# [강진완도축협] 한우1등급 장조림 100g
# 5,400
# [강진완도축협] 한우1등급 양지 국거리 100g
# 6,400
# [강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조
# 9,800
# [강진완도축협] 한우1등급 등심 100g
# 13,000
# 브랜드없음 [강진완도축협] 한우1등급 등심 100g, 단품없음
# 13,100
# [강진완도축협] 한우1+등급 등심 100g, 단품
# 14,400
# [강진완도축협] 한우1등급 안심 100g
# 15,500
# [강진완도축협] 한우1+등급 채끝 100g
# 16,000
# [육라운드] 한우1등급 다이어트소고기 한우1+ 안심 구이용 100g 온라인정육점 육라운드 도매
# 16,500
# [강진완도축협] 한우1+등급 안심 100g
# 17,000
# 미트지엥 호주산 우등심 찹스테이크용 (냉장), 300g, 1팩
# 17,400
# 쉐프 파트너 호주산 와규 윗등심구이용 (냉장), 300g, 1개
# 17,640
# [강진완도축협] 한우1등급 등심 100g, 단품
# 17,900
# 크리스탈팜스 미국산 프라임 등심 구이용 (냉장), 500g, 1개
# 18,300
# 이로우 국내산 무항생제 소고기 등심 스테이크용 (냉장), 300g, 1팩
# 18,750
# 이로우 국내산 무항생제 소고기 등심 구이용 (냉장), 300g, 1팩
# 18,750
# 안동 한우등심 1등급 100g
# 18,900
# [강진완도축협] 한우1+등급 등심 100g
# 18,900
# [강진완도축협] 한우1등급 채끝 100g
# 18,900
# 안동한우 안심 1등급 100g, 1등급 안심
# 19,000
# 베스트비프 호주산 등심 스테이크 1kg, 1개
# 19,500
# 제이엘미트 미국산 블랙앵거스 프라임등급 냉장 등심 스테이크 구이 500g, 스테이크용 30mm 500g
# 19,800
# 글랜인스 150 호주산 블랙앵거스 윗등심 구이 400g (냉장), 1개
# 19,900
# [강진완도축협] 한우1등급 안심 100g, 상세 설명 참조
# 20,900
# 목우촌 국내산 소고기 등심 구이용 (냉장), 300g, 1개
# 21,990
# 국내산 1등급 이상 육우등심세트(등심400g 치마살100g 제비추리100g) 600g
# 36,900
# 설성목장 무항생제 인증 한우 1++등급(7이상) 꽃등심 구이용 (냉장), 200g, 1개
# 42,990
# 건화한우 1+ 등급 등심 구이용 (냉장), 300g, 1개
# 46,990
# 고기아찌 솔트에이징 미국산 소고기 4종 세트 600g(냉장) 등심+부채살+살치살+꽃갈비살, 1세트
# 47,900
# 농협안심한우 1등급 등심 [100g/300g], 02.한우 등심-300g
# 52,900
# [강진완도축협] 한우1등급 채끝 400g
# 53,400
# 기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1
# 69,900
# 청정해 제주 한우 1++ 등심, 400g, 1개
# 77,000
# [강진완도축협] 한우1등급 불고기 100g
# 4,800
# 브랜드없음 [강진완도축협] 한우1등급 불고기 100g, 단품없음
# 5,180
# [강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조
# 9,800
# [강진완도축협] 한우1등급 불고기 100g, 단품
# 9,800
# 한우 1등급 불고기 100g
# 9,900
# 앵그리미트 한우 1등급 냉장 소불고기 200g (100g당 5 900원)
# 11,800
# 농협안심한우 1등급 불고기 [100g/300g], 02.한우 불고기-300g
# 23,900
# 기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1
# 69,900
# [강진완도축협] 한우1등급 불고기 100g
# 4,800
# 브랜드없음 [강진완도축협] 한우1등급 불고기 100g, 단품없음
# 5,180
# [강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조
# 9,800
# [강진완도축협] 한우1등급 불고기 100g, 단품
# 9,800
# 한우 1등급 불고기 100g
# 9,900
# 앵그리미트 한우 1등급 냉장 소불고기 200g (100g당 5 900원)
# 11,800
# 농협안심한우 1등급 불고기 [100g/300g], 02.한우 불고기-300g
# 23,900
# 기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1
# 69,900
# 비비고 왕교자 (455gx2봉/910g)
# 7,490
# 씨제이 비비고왕교자만두1.05kg씨제이
# 8,110
# CJ 비비고 왕교자 1.05kg x 2봉+수제고기만두 400g x 2봉, 없음, 상세설명 참조
# 27,320
# CJ 비비고 왕교자 1.05kg x 2개 + 김치왕교자 420g x 2개, 없음, 상세설명 참조
# 27,770
# 해태 오예스 미니 12개입, 상세페이지 참조
# 2,060
# 과자 해태 오예스 12개입 336g
# 4,410
# 해태 오예스 336g(12개입), 1개
# 4,600
# 오예스 12개입1갑, 1갑, 오예스 12개입/1갑
# 4,900
# 해태 오예스미니 12개입x2 (24개), 상세페이지 참조
# 5,070
# 해태 오예스 쿠키앤크림12개입/어린이간식
# 5,900
# 오예스 360g 해태 12개입 스낵, 1
# 6,080
# 해태 오예스 미니 12개입 x 2개, 1
# 6,260
# 해태 오예스6000원 360g(12개입) x 2개, 2개, 360g
# 6,500
# 해태 오예스 피넛버터 30g x 12개입
# 6,500
# 해태 오예스 360g 12개입 탕비 간식 식사 류 대용 과자 여행 캠핑 요리 점심
# 6,690
# 해태 오예스 360g 12개입식음료 식품류 과자류 봉지과자 스낵, 본상품
# 7,000
# 해태 오예스(12개입) 360g + 오뜨 쇼콜라(6개입) 150g 초콜릿 파이 초코 케익 묶음 세트, 1세트
# 7,980
# 해태 오예스 360g 12개입 탕비 간식, 상세페이지 참조
# 8,970
# 해태 오예스 12개입 (360g), 옵션2 - 신선포장 (아이스박스포장)
# 9,170
# 해태 오예스미니 12개입 3박스 (36개), 상세페이지 참조
# 9,210
# 해태 오예스 360g 12개입 캠핑 요리 여행 간식 탕비 점심 간식류 오피스 대용 식사 과자
# 9,240
# 해태 오예스 12개입 360g +오리온 초코파이 468g 초콜릿 케이크 파이 묶음, 1세트
# 9,500
# 해태 오예스미니 12개입 4박스, 상세페이지 참조
# 10,040
# 오예스 12개입/가공식품
# 10,080
# MDS8157 해태 오예스 미니 12개입 x 2개 오예스/미니오예스/미니케익/간식, 본상품선택
# 10,540
# 해태제과 NEW 오예스 mini 192g 묶음 행사, 5개
# 11,810
# 해태 오예스 미니 12개입 x 2개
# 11,910
# ☞고객대만족↗¶ 신상과자 12개입 간식 케익 미니오예스 해태 x 2개 (†bfr♭), 1개, ☞ 해당 상품 선택하기_Pickme™
# 11,960
# ¶⊙핫딜_A+ 케익 신상과자 간식 12개입 오예스 미니 해태 x 2개 (eMF‡♭), 1개, ☞ 해당 상품 선택하기_aplus™
# 11,960
# 오예스 피넛버터 12개입 (360g) x 3ea
# 12,410
# MDG2467 해태 오예스 미니 12개입 x 2개 미니오예스/미니케익/신상과자/오예스, 1개
# 12,780
# 해태 오예스 360g 12입 x 3개 (오리지널), 12개입 3팩
# 13,800
# 해태 오예스 오예스 미니 12개입 6박스, 상세페이지 참조
# 14,490
# 해태 오예스미니 12개입 5박스, 상세페이지 참조
# 14,940
# 오리온 해태 오예스 30p 900g + 초코파이12p 468g, 1set
# 15,900
# [씩씩가게] 오예스 오리지널 12개입 x 2ea + 쿠키앤크림 12개입 x 2ea, 1set, 1440
# 17,900
# 해태 오예스 360g(12개입) x4개, B 상품선택:01_해태오예스360g 4개
# 17,900
# 해태 오예스 360g 쿠키앤크림 (12개입) x4통 / 간식, 단품
# 18,900
# 해태 오예스 360g 쿠키앤크림 12개입 x4통 / 간식, 없음
# 19,710
# 무배 해태 오예스 30g x 48개 (12개입x4팩)
# 20,550
# 대림선 부산어묵 마당놀이 300g, 단품
# 1,900
# IN115 부산어묵 마당놀이 300g, PICK 1
# 2,100
# 쿠디 IN115 부산어묵 마당놀이 300g 674297ea 79073E, 쿠디 1, 쿠디 본상품선택
# 2,170
# IN115 부산어묵 마당놀이 300g, 1
# 2,240
# 대림선 [사조대림] 실속사각어묵 총300g (150g+150g) 어묵>>사각어묵, 단품
# 2,300
# 캠핑가서 부산어묵 부산어묵마당놀이 300g 어묵300g 대림어묵 간단한요리 IN115 맛있 60569666EA, xqhgaifEA_ 1, xqhgaifEA_ 본상품선택
# 2,440
# [K쇼핑][대림선] 부산어묵마당놀이300g
# 2,600
# [대림선] 부산어묵 마당놀이 300g, 단품
# 2,600
# 대림선 [대림선] 부산어묵 마당놀이 300g 어묵, 단품
# 2,600
# 【红】 IN115 부산어묵 마당놀이 300g GЯ1+VIP_ 마당놀이어묵, GЯ 1
# 2,620
# 대림선 부산어묵 사각 마당놀이 300g 납작오뎅 반찬 안주 어묵탕 꼬치 어묵바 핫바
# 2,990
# IN115 부산어묵 마당놀이 300g 91230808ea, 셀링마켓 1, 셀링마켓 본상품선택
# 3,260
# 대림선 부산어묵 마당놀이 300G (냉장), 옵션1 - 기본포장 (박스or비닐포장) (+0원)
# 3,270
# 대림선 부산어묵 마당놀이 300G (냉장), 옵션2 - 신선포장 (아이스박스포장)
# 4,470
# IN115 부산어묵 마당놀이 300g, 1
# 6,240
# 가성비 IN115 부산어묵 마당놀이 300g DB+ 1372EA, 1, 본상품선택
# 6,390
# IN115 부산어묵 마당놀이 300g 가성비 SB+ 8486EA, 1, 본상품선택
# 6,470
# 초등학생반찬 실속사각어묵 300g(150g+150g) 저녁술안주 저녁간식 피쉬볼, 1, 본상품선택
# 7,900
# 보니또댕댕이 사각큐브 강아지 간식 300g, 양고기, 5개
# 8,130
# 보니또댕댕이 반려동물 사사미 300g, 소고기 빼로로, 5개
# 8,500
# 보니또댕댕이 반려동물 사사미 300g, 오리고기 빼로로, 5개
# 9,000
# 보니또댕댕이 양고기 윙 반려동물 간식 300g, 5개
# 11,200
# 사조대림 대림선 부산어묵 마당놀이 300g 20개입 박스/반찬/간식/떡볶이/오뎅 식품 > 냉장/냉동식품 햄/소시지/어묵/맛살 어묵 볼/꼬치/봉어묵, 1, 300gX20, 300gX20
# 40,180
# 대림선 대림 부산어묵 마당놀이 300g 20개 어묵바 부산오뎅
# 58,410
# 오뚜기 담백한 소프트마가린 180g, 1개
# 2,900
# 오뚜기 담백한 소프트 마가린, 180g, 1개
# 3,320
# [동원] 덴마크 짜지 않은 오리지널 치즈 252g 14매 1개, 덴마크 짜지 않은 오리지널 치즈 14매 1개
# 5,100
# 동원 덴마크 짜지않은치즈 오리지널 252g(14매입) x 4봉, 252g
# 15,400
# [동원] 덴마크 짜지 않은 치즈 오리지널 252g 56매 (14매x4개), 상세페이지 참조
# 22,900
# [동원] 덴마크 짜지 않은 치즈 오리지널 252g 56매 (14매x4개), 252g x 4봉
# 22,900
# [동원] 덴마크 짜지 않은 오리지널 치즈 252g 56매 (14매x4개) / 84매 (14매x6개), 덴마크 짜지 않은 오리지널 치즈 84매 (14매x6개)
# 31,900
# [동원] 덴마크 짜지 않은 치즈 오리지널 252g 84매 (14매x6개), 6봉
# 32,500
# 동원 덴마크 짜지않은치즈 오리지널 252g (14매입 x 10봉), 140매, 2520g
# 33,680
# [동원] 덴마크 짜지 않은 치즈 오리지널 252g 84매 (14매x6개), 상세페이지 참조
# 31,050
# 덴마크 짜지않은치즈 오리지널 252g(14매) X 10봉, 10개
# 36,950
# 특가존Yh87Q92 덴마크 짜지않은치즈 오리지널 252g (14매) X 10봉 모짜렐라 슬라이스 리코타치즈 아이간식 술안주
# 46,110
# 헬로 코튼블루 3겹 천연펄프 20m 30롤, 1팩
# 6,850
# 정직한 히트 3겹30롤 화장지 자르지않은 [국산펄프][길이15m이상][두께15g이상][높이95mm이상] 국산정품, 2[정품]크린에스 뉴땡큐 3겹30롤15m+품질UP형
# 6,860
# [아이제이] 천연펄프 무형광 엠보싱(DBD-215) 3겹 5롤 10롤 30롤 화장지, 1박스
# 6,900
# 행운드림 땡큐 화장지 3겹 30롤 x 1팩 펄프는 천연펄프 빠른배송
# 6,900
# 땡큐 3겹 new 프리미엄 30롤 화장지, 1팩
# 7,500
# 복이많은집 목화 3겹 데코 화이트 고급롤화장지 15m, 30롤, 1팩
# 7,590
# 광진산업 땡큐 화장지30롤 롤화장지(3겹), 1팩, 단품
# 8,750
# 모나리자 녹스 플러스 데코 화장지 27m, 30롤, 1팩
# 9,800
# 행복에스앤피 자연에서 온 녹차 3겹 화장지 25m, 30롤, 1팩
# 11,500
# 미소지움 3겹 데코 소프트 화장지 18m, 30롤, 1팩
# 8,820
# 땡큐 CIP 3겹 데코 화장지 15m, 30롤, 1팩
# 12,000
# 수목제지 트루마리 순수 3겹데코 화장지 18m, 30롤, 1팩
# 12,130
# 깨끗한나라 순수 시그니처 3겹 28M X 30롤 X 1팩
# 12,750
# 깨끗한나라 순수시그니처 27m, 30롤, 1팩
# 12,800
# 코디 행복이 술술술 천연펄프 3겹 롤화장지 27m, 30롤, 1팩
# 12,780
# 깨끗한나라 순수시그니처 3겹 28m 30롤 화장지, 1개
# 13,860
# 깨끗한나라 순수 시그니처 3겹 28m 30롤x1팩/화장지, 상세페이지 참조
# 14,340
# 깨끗한나라 순수 시그니처 3겹 28m 30롤, 1개
# 14,500
# 깨끗한나라 순수 시그니처 3겹 화장지 28M 30롤 x1팩, 단품
# 14,900
# [메가마트]깨끗한나라 순수 시그니처 30m*30롤, 1개
# 14,900
# 깨끗한나라 순수 시그니처 3겹 화장지 28M 30롤 x1팩, 단품
# 14,900
# 땡큐온 깨끗한나라 3겹 엠보싱 순수 시그니처 28M 30롤 x1팩, 단품
# 14,900
# 깨끗한나라 순수 시그니처 와이드 27m, 30롤, 1개
# 15,000
# 깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 16,000
# 깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 16,000
# 깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 16,000
# 깨끗한나라 3겹데코 순수시그니처 화장지 28mx30롤x1개/ 무형광/ 천연펄프/ 두루마리, 1개
# 16,100
# 나무를심는사람들 황토의 꿈 롤화장지 22 m, 30롤, 1개
# 16,500
# 순수 시그니처 3겹 데코 천연펄프 28m 30롤 1팩(30롤)
# 16,900
# 깨끗한나라 3겹데코 에어소프트 천연펄프 롤화장지 30m, 1개, 30롤
# 17,080
# 3겹순수시그니처화장지28m*30롤1팩+여행용티슈40매2팩
# 17,500
# 깨끗한나라 순수 시그니처 3겹 화장지 28m 30롤 휴지
# 17,800
# 깨끗한나라 순수 시그니처 3겹데코 28m 30롤 X 1팩, 단품, 단품
# 17,900
# 깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 18,500
# 깨끗한나라 순수 시그니처 3겹 28m 30롤, 1개
# 18,500
# 깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 18,500

# %%
## 크롤링 결과

# sample_.reverse()
sample_
# Out:
# deque([['깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품', '18,500'],
#        ['깨끗한나라 순수 시그니처 3겹 28m 30롤, 1개', '18,500'],
#        ['깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품', '18,500'],
#        ['깨끗한나라 순수 시그니처 3겹데코 28m 30롤 X 1팩, 단품, 단품', '17,900'],
#        ['깨끗한나라 순수 시그니처 3겹 화장지 28m 30롤 휴지', '17,800'],
#        ['3겹순수시그니처화장지28m*30롤1팩+여행용티슈40매2팩', '17,500'],
#        ['깨끗한나라 3겹데코 에어소프트 천연펄프 롤화장지 30m, 1개, 30롤', '17,080'],
#        ['순수 시그니처 3겹 데코 천연펄프 28m 30롤 1팩(30롤)', '16,900'],
#        ['나무를심는사람들 황토의 꿈 롤화장지 22 m, 30롤, 1개', '16,500'],
#        ['깨끗한나라 3겹데코 순수시그니처 화장지 28mx30롤x1개/ 무형광/ 천연펄프/ 두루마리, 1개', '16,100'],
#        ['깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품', '16,000'],
#        ['깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품', '16,000'],
#        ['깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품', '16,000'],
#        ['깨끗한나라 순수 시그니처 와이드 27m, 30롤, 1개', '15,000'],
#        ['땡큐온 깨끗한나라 3겹 엠보싱 순수 시그니처 28M 30롤 x1팩, 단품', '14,900'],
#        ['깨끗한나라 순수 시그니처 3겹 화장지 28M 30롤 x1팩, 단품', '14,900'],
#        ['[메가마트]깨끗한나라 순수 시그니처 30m*30롤, 1개', '14,900'],
#        ['깨끗한나라 순수 시그니처 3겹 화장지 28M 30롤 x1팩, 단품', '14,900'],
#        ['깨끗한나라 순수 시그니처 3겹 28m 30롤, 1개', '14,500'],
#        ['깨끗한나라 순수 시그니처 3겹 28m 30롤x1팩/화장지, 상세페이지 참조', '14,340'],
#        ['깨끗한나라 순수시그니처 3겹 28m 30롤 화장지, 1개', '13,860'],
#        ['코디 행복이 술술술 천연펄프 3겹 롤화장지 27m, 30롤, 1팩', '12,780'],
#        ['깨끗한나라 순수시그니처 27m, 30롤, 1팩', '12,800'],
#        ['깨끗한나라 순수 시그니처 3겹 28M X 30롤 X 1팩', '12,750'],
#        ['수목제지 트루마리 순수 3겹데코 화장지 18m, 30롤, 1팩', '12,130'],
#        ['땡큐 CIP 3겹 데코 화장지 15m, 30롤, 1팩', '12,000'],
#        ['미소지움 3겹 데코 소프트 화장지 18m, 30롤, 1팩', '8,820'],
#        ['행복에스앤피 자연에서 온 녹차 3겹 화장지 25m, 30롤, 1팩', '11,500'],
#        ['모나리자 녹스 플러스 데코 화장지 27m, 30롤, 1팩', '9,800'],
#        ['광진산업 땡큐 화장지30롤 롤화장지(3겹), 1팩, 단품', '8,750'],
#        ['복이많은집 목화 3겹 데코 화이트 고급롤화장지 15m, 30롤, 1팩', '7,590'],
#        ['땡큐 3겹 new 프리미엄 30롤 화장지, 1팩', '7,500'],
#        ['행운드림 땡큐 화장지 3겹 30롤 x 1팩 펄프는 천연펄프 빠른배송', '6,900'],
#        ['[아이제이] 천연펄프 무형광 엠보싱(DBD-215) 3겹 5롤 10롤 30롤 화장지, 1박스', '6,900'],
#        ['정직한 히트 3겹30롤 화장지 자르지않은 [국산펄프][길이15m이상][두께15g이상][높이95mm이상] 국산정품, 2[정품]크린에스 뉴땡큐 3겹30롤15m+품질UP형',
#         '6,860'],
#        ['헬로 코튼블루 3겹 천연펄프 20m 30롤, 1팩', '6,850'],
#        ['특가존Yh87Q92 덴마크 짜지않은치즈 오리지널 252g (14매) X 10봉 모짜렐라 슬라이스 리코타치즈 아이간식 술안주',
#         '46,110'],
#        ['덴마크 짜지않은치즈 오리지널 252g(14매) X 10봉, 10개', '36,950'],
#        ['[동원] 덴마크 짜지 않은 치즈 오리지널 252g 84매 (14매x6개), 상세페이지 참조', '31,050'],
#        ['동원 덴마크 짜지않은치즈 오리지널 252g (14매입 x 10봉), 140매, 2520g', '33,680'],
#        ['[동원] 덴마크 짜지 않은 치즈 오리지널 252g 84매 (14매x6개), 6봉', '32,500'],
#        ['[동원] 덴마크 짜지 않은 오리지널 치즈 252g 56매 (14매x4개) / 84매 (14매x6개), 덴마크 짜지 않은 오리지널 치즈 84매 (14매x6개)',
#         '31,900'],
#        ['[동원] 덴마크 짜지 않은 치즈 오리지널 252g 56매 (14매x4개), 252g x 4봉', '22,900'],
#        ['[동원] 덴마크 짜지 않은 치즈 오리지널 252g 56매 (14매x4개), 상세페이지 참조', '22,900'],
#        ['동원 덴마크 짜지않은치즈 오리지널 252g(14매입) x 4봉, 252g', '15,400'],
#        ['[동원] 덴마크 짜지 않은 오리지널 치즈 252g 14매 1개, 덴마크 짜지 않은 오리지널 치즈 14매 1개',
#         '5,100'],
#        ['오뚜기 담백한 소프트 마가린, 180g, 1개', '3,320'],
#        ['오뚜기 담백한 소프트마가린 180g, 1개', '2,900'],
#        ['대림선 대림 부산어묵 마당놀이 300g 20개 어묵바 부산오뎅', '58,410'],
#        ['사조대림 대림선 부산어묵 마당놀이 300g 20개입 박스/반찬/간식/떡볶이/오뎅 식품 > 냉장/냉동식품 햄/소시지/어묵/맛살 어묵 볼/꼬치/봉어묵, 1, 300gX20, 300gX20',
#         '40,180'],
#        ['보니또댕댕이 양고기 윙 반려동물 간식 300g, 5개', '11,200'],
#        ['보니또댕댕이 반려동물 사사미 300g, 오리고기 빼로로, 5개', '9,000'],
#        ['보니또댕댕이 반려동물 사사미 300g, 소고기 빼로로, 5개', '8,500'],
#        ['보니또댕댕이 사각큐브 강아지 간식 300g, 양고기, 5개', '8,130'],
#        ['초등학생반찬 실속사각어묵 300g(150g+150g) 저녁술안주 저녁간식 피쉬볼, 1, 본상품선택', '7,900'],
#        ['IN115 부산어묵 마당놀이 300g 가성비 SB+ 8486EA, 1, 본상품선택', '6,470'],
#        ['가성비 IN115 부산어묵 마당놀이 300g DB+ 1372EA, 1, 본상품선택', '6,390'],
#        ['IN115 부산어묵 마당놀이 300g, 1', '6,240'],
#        ['대림선 부산어묵 마당놀이 300G (냉장), 옵션2 - 신선포장 (아이스박스포장)', '4,470'],
#        ['대림선 부산어묵 마당놀이 300G (냉장), 옵션1 - 기본포장 (박스or비닐포장) (+0원)', '3,270'],
#        ['IN115 부산어묵 마당놀이 300g 91230808ea, 셀링마켓 1, 셀링마켓 본상품선택', '3,260'],
#        ['대림선 부산어묵 사각 마당놀이 300g 납작오뎅 반찬 안주 어묵탕 꼬치 어묵바 핫바', '2,990'],
#        ['【红】 IN115 부산어묵 마당놀이 300g GЯ1+VIP_ 마당놀이어묵, GЯ 1', '2,620'],
#        ['대림선 [대림선] 부산어묵 마당놀이 300g 어묵, 단품', '2,600'],
#        ['[대림선] 부산어묵 마당놀이 300g, 단품', '2,600'],
#        ['[K쇼핑][대림선] 부산어묵마당놀이300g', '2,600'],
#        ['캠핑가서 부산어묵 부산어묵마당놀이 300g 어묵300g 대림어묵 간단한요리 IN115 맛있 60569666EA, xqhgaifEA_ 1, xqhgaifEA_ 본상품선택',
#         '2,440'],
#        ['대림선 [사조대림] 실속사각어묵 총300g (150g+150g) 어묵>>사각어묵, 단품', '2,300'],
#        ['IN115 부산어묵 마당놀이 300g, 1', '2,240'],
#        ['쿠디 IN115 부산어묵 마당놀이 300g 674297ea 79073E, 쿠디 1, 쿠디 본상품선택', '2,170'],
#        ['IN115 부산어묵 마당놀이 300g, PICK 1', '2,100'],
#        ['대림선 부산어묵 마당놀이 300g, 단품', '1,900'],
#        ['무배 해태 오예스 30g x 48개 (12개입x4팩)', '20,550'],
#        ['해태 오예스 360g 쿠키앤크림 12개입 x4통 / 간식, 없음', '19,710'],
#        ['해태 오예스 360g 쿠키앤크림 (12개입) x4통 / 간식, 단품', '18,900'],
#        ['해태 오예스 360g(12개입) x4개, B 상품선택:01_해태오예스360g 4개', '17,900'],
#        ['[씩씩가게] 오예스 오리지널 12개입 x 2ea + 쿠키앤크림 12개입 x 2ea, 1set, 1440', '17,900'],
#        ['오리온 해태 오예스 30p 900g + 초코파이12p 468g, 1set', '15,900'],
#        ['해태 오예스미니 12개입 5박스, 상세페이지 참조', '14,940'],
#        ['해태 오예스 오예스 미니 12개입 6박스, 상세페이지 참조', '14,490'],
#        ['해태 오예스 360g 12입 x 3개 (오리지널), 12개입 3팩', '13,800'],
#        ['MDG2467 해태 오예스 미니 12개입 x 2개 미니오예스/미니케익/신상과자/오예스, 1개', '12,780'],
#        ['오예스 피넛버터 12개입 (360g) x 3ea', '12,410'],
#        ['¶⊙핫딜_A+ 케익 신상과자 간식 12개입 오예스 미니 해태 x 2개 (eMF‡♭), 1개, ☞ 해당 상품 선택하기_aplus™',
#         '11,960'],
#        ['☞고객대만족↗¶ 신상과자 12개입 간식 케익 미니오예스 해태 x 2개 (†bfr♭), 1개, ☞ 해당 상품 선택하기_Pickme™',
#         '11,960'],
#        ['해태 오예스 미니 12개입 x 2개', '11,910'],
#        ['해태제과 NEW 오예스 mini 192g 묶음 행사, 5개', '11,810'],
#        ['MDS8157 해태 오예스 미니 12개입 x 2개 오예스/미니오예스/미니케익/간식, 본상품선택', '10,540'],
#        ['오예스 12개입/가공식품', '10,080'],
#        ['해태 오예스미니 12개입 4박스, 상세페이지 참조', '10,040'],
#        ['해태 오예스 12개입 360g +오리온 초코파이 468g 초콜릿 케이크 파이 묶음, 1세트', '9,500'],
#        ['해태 오예스 360g 12개입 캠핑 요리 여행 간식 탕비 점심 간식류 오피스 대용 식사 과자', '9,240'],
#        ['해태 오예스미니 12개입 3박스 (36개), 상세페이지 참조', '9,210'],
#        ['해태 오예스 12개입 (360g), 옵션2 - 신선포장 (아이스박스포장)', '9,170'],
#        ['해태 오예스 360g 12개입 탕비 간식, 상세페이지 참조', '8,970'],
#        ['해태 오예스(12개입) 360g + 오뜨 쇼콜라(6개입) 150g 초콜릿 파이 초코 케익 묶음 세트, 1세트',
#         '7,980'],
#        ['해태 오예스 360g 12개입식음료 식품류 과자류 봉지과자 스낵, 본상품', '7,000'],
#        ['해태 오예스 360g 12개입 탕비 간식 식사 류 대용 과자 여행 캠핑 요리 점심', '6,690'],
#        ['해태 오예스 피넛버터 30g x 12개입', '6,500'],
#        ['해태 오예스6000원 360g(12개입) x 2개, 2개, 360g', '6,500'],
#        ['해태 오예스 미니 12개입 x 2개, 1', '6,260'],
#        ['오예스 360g 해태 12개입 스낵, 1', '6,080'],
#        ['해태 오예스 쿠키앤크림12개입/어린이간식', '5,900'],
#        ['해태 오예스미니 12개입x2 (24개), 상세페이지 참조', '5,070'],
#        ['오예스 12개입1갑, 1갑, 오예스 12개입/1갑', '4,900'],
#        ['해태 오예스 336g(12개입), 1개', '4,600'],
#        ['과자 해태 오예스 12개입 336g', '4,410'],
#        ['해태 오예스 미니 12개입, 상세페이지 참조', '2,060'],
#        ['CJ 비비고 왕교자 1.05kg x 2개 + 김치왕교자 420g x 2개, 없음, 상세설명 참조', '27,770'],
#        ['CJ 비비고 왕교자 1.05kg x 2봉+수제고기만두 400g x 2봉, 없음, 상세설명 참조', '27,320'],
#        ['씨제이 비비고왕교자만두1.05kg씨제이', '8,110'],
#        ['비비고 왕교자 (455gx2봉/910g)', '7,490'],
#        ['기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1', '69,900'],
#        ['농협안심한우 1등급 불고기 [100g/300g], 02.한우 불고기-300g', '23,900'],
#        ['앵그리미트 한우 1등급 냉장 소불고기 200g (100g당 5 900원)', '11,800'],
#        ['한우 1등급 불고기 100g', '9,900'],
#        ['[강진완도축협] 한우1등급 불고기 100g, 단품', '9,800'],
#        ['[강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조', '9,800'],
#        ['브랜드없음 [강진완도축협] 한우1등급 불고기 100g, 단품없음', '5,180'],
#        ['[강진완도축협] 한우1등급 불고기 100g', '4,800'],
#        ['기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1', '69,900'],
#        ['농협안심한우 1등급 불고기 [100g/300g], 02.한우 불고기-300g', '23,900'],
#        ['앵그리미트 한우 1등급 냉장 소불고기 200g (100g당 5 900원)', '11,800'],
#        ['한우 1등급 불고기 100g', '9,900'],
#        ['[강진완도축협] 한우1등급 불고기 100g, 단품', '9,800'],
#        ['[강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조', '9,800'],
#        ['브랜드없음 [강진완도축협] 한우1등급 불고기 100g, 단품없음', '5,180'],
#        ['[강진완도축협] 한우1등급 불고기 100g', '4,800'],
#        ['청정해 제주 한우 1++ 등심, 400g, 1개', '77,000'],
#        ['기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1', '69,900'],
#        ['[강진완도축협] 한우1등급 채끝 400g', '53,400'],
#        ['농협안심한우 1등급 등심 [100g/300g], 02.한우 등심-300g', '52,900'],
#        ['고기아찌 솔트에이징 미국산 소고기 4종 세트 600g(냉장) 등심+부채살+살치살+꽃갈비살, 1세트', '47,900'],
#        ['건화한우 1+ 등급 등심 구이용 (냉장), 300g, 1개', '46,990'],
#        ['설성목장 무항생제 인증 한우 1++등급(7이상) 꽃등심 구이용 (냉장), 200g, 1개', '42,990'],
#        ['국내산 1등급 이상 육우등심세트(등심400g 치마살100g 제비추리100g) 600g', '36,900'],
#        ['목우촌 국내산 소고기 등심 구이용 (냉장), 300g, 1개', '21,990'],
#        ['[강진완도축협] 한우1등급 안심 100g, 상세 설명 참조', '20,900'],
#        ['글랜인스 150 호주산 블랙앵거스 윗등심 구이 400g (냉장), 1개', '19,900'],
#        ['제이엘미트 미국산 블랙앵거스 프라임등급 냉장 등심 스테이크 구이 500g, 스테이크용 30mm 500g', '19,800'],
#        ['베스트비프 호주산 등심 스테이크 1kg, 1개', '19,500'],
#        ['안동한우 안심 1등급 100g, 1등급 안심', '19,000'],
#        ['[강진완도축협] 한우1등급 채끝 100g', '18,900'],
#        ['[강진완도축협] 한우1+등급 등심 100g', '18,900'],
#        ['안동 한우등심 1등급 100g', '18,900'],
#        ['이로우 국내산 무항생제 소고기 등심 구이용 (냉장), 300g, 1팩', '18,750'],
#        ['이로우 국내산 무항생제 소고기 등심 스테이크용 (냉장), 300g, 1팩', '18,750'],
#        ['크리스탈팜스 미국산 프라임 등심 구이용 (냉장), 500g, 1개', '18,300'],
#        ['[강진완도축협] 한우1등급 등심 100g, 단품', '17,900'],
#        ['쉐프 파트너 호주산 와규 윗등심구이용 (냉장), 300g, 1개', '17,640'],
#        ['미트지엥 호주산 우등심 찹스테이크용 (냉장), 300g, 1팩', '17,400'],
#        ['[강진완도축협] 한우1+등급 안심 100g', '17,000'],
#        ['[육라운드] 한우1등급 다이어트소고기 한우1+ 안심 구이용 100g 온라인정육점 육라운드 도매', '16,500'],
#        ['[강진완도축협] 한우1+등급 채끝 100g', '16,000'],
#        ['[강진완도축협] 한우1등급 안심 100g', '15,500'],
#        ['[강진완도축협] 한우1+등급 등심 100g, 단품', '14,400'],
#        ['브랜드없음 [강진완도축협] 한우1등급 등심 100g, 단품없음', '13,100'],
#        ['[강진완도축협] 한우1등급 등심 100g', '13,000'],
#        ['[강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조', '9,800'],
#        ['[강진완도축협] 한우1등급 양지 국거리 100g', '6,400'],
#        ['[강진완도축협] 한우1등급 장조림 100g', '5,400'],
#        ['[강진완도축협] 한우1등급 설도 국거리 100g', '5,400'],
#        ['[강진완도축협] 한우1등급 불고기 100g', '4,800'],
#        ['친절한한우 우둔 300g600g육회 이유식용 1등급이상 소고기 영주한우 설날 설선물 명절선물 신년선물 새해선물 선물세트, 1개, 육회 물회소스 100g',
#         '2,000'],
#        ['[자연맛남] 마장동한우 명품 구이선물세트 1호 1등급 1kg (등심500g/채끝200g/업진200g/갈비살100g)',
#         '134,900'],
#        ['청정해 제주 한우 1++ 등심, 400g, 1개', '77,000'],
#        ['기타 기획특가100g 더! 1등급 이상 냉장한우!(등심2 불고기2 국거리1) / 1.kg, 1', '69,900'],
#        ['[강진완도축협] 한우1등급 채끝 400g', '53,400'],
#        ['농협안심한우 1등급 등심 [100g/300g], 02.한우 등심-300g', '52,900'],
#        ['국내산 1등급 이상 육우등심세트(등심400g 치마살100g 제비추리100g) 600g', '36,900'],
#        ['[강진완도축협] 한우1등급 안심 100g, 상세 설명 참조', '20,900'],
#        ['안동한우 안심 1등급 100g, 1등급 안심', '19,000'],
#        ['[강진완도축협] 한우1등급 채끝 100g', '18,900'],
#        ['[강진완도축협] 한우1+등급 등심 100g', '18,900'],
#        ['안동 한우등심 1등급 100g', '18,900'],
#        ['[강진완도축협] 한우1등급 등심 100g, 단품', '17,900'],
#        ['[강진완도축협] 한우1+등급 안심 100g', '17,000'],
#        ['[육라운드] 한우1등급 다이어트소고기 한우1+ 안심 구이용 100g 온라인정육점 육라운드 도매', '16,500'],
#        ['[강진완도축협] 한우1+등급 채끝 100g', '16,000'],
#        ['[강진완도축협] 한우1등급 안심 100g', '15,500'],
#        ['[강진완도축협] 한우1+등급 등심 100g, 단품', '14,400'],
#        ['브랜드없음 [강진완도축협] 한우1등급 등심 100g, 단품없음', '13,100'],
#        ['[강진완도축협] 한우1등급 등심 100g', '13,000'],
#        ['[강진완도축협] 한우1등급 불고기 100g, 상세 설명 참조', '9,800'],
#        ['[강진완도축협] 한우1등급 양지 국거리 100g', '6,400'],
#        ['[강진완도축협] 한우1등급 장조림 100g', '5,400'],
#        ['[강진완도축협] 한우1등급 설도 국거리 100g', '5,400'],
#        ['[강진완도축협] 한우1등급 불고기 100g', '4,800'],
#        ['친절한한우 우둔 300g600g육회 이유식용 1등급이상 소고기 영주한우 설날 설선물 명절선물 신년선물 새해선물 선물세트, 1개, 육회 물회소스 100g',
#         '2,000'],
#        ['고기아찌 프리미엄 에이징 돼지고기 3종 세트 600g [삼겹살+목살+항정살]_냉장, 1세트', '15,500'],
#        ['[삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 한근 400g 구이용 등심덧살 특수부위, 가브리살-구이용400g',
#         '15,200'],
#        ['냉장/냉동 제주흑돼지 500g x 4팩 균일가전, 4.냉장찌개용 500gx4팩', '14,900'],
#        ['도드람 영양스테이크 100g, 6팩', '14,800'],
#        ['달구지푸드 훈제돼지막창500g(된장소스100g), 1, 500g, 500g', '13,120'],
#        ['고기연육제 푸로찜 100gX10개 고기연하게 살살녹는고기 파인애플추출첨가, 1팩, 1kg', '12,600'],
#        ['도드람 영양스테이크 100g, 4팩', '10,600'],
#        ['[신선한고기마을]국내산 돼지고기 냉동삼겹살 냉삼 안심 목살 외 각부위별 국내산 500g, 1박스, 안심500g(냉장)',
#         '9,900'],
#        ['솔트에이징 숙성 삼겹살 목살 항정살 각 1팩X100g 수비드삼겹살 돼지등갈비 냉동 원육', '9,000'],
#        ['솔트에이징 숙성 삼겹살+목살+항정살 각100gX3팩 냉장육 오겹살 냉삼 [블루키트]', '9,000'],
#        ['대패삼겹살 칠레산 냉동삼겹살 100g/300g/500g 세자매정육점, 대패삼겹500g', '8,390'],
#        ['솔트 에이징 숙성 수입산 삼겹살 목살 항정살 각 1팩 100g 수비드 스테이크 캠핑용', '8,000'],
#        ['고기천국 삼겹살(구이용) 200gx3, 3팩, 200g', '7,900'],
#        ['[삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 200g 구이용 등심덧살 특수부위, 가브리살-구이용200g',
#         '7,600'],
#        ['도드람 영양스테이크 100g, 2팩', '6,400'],
#        ['혼족 자취생 영양한끼 냉동대패삼겹 100g 간편한 싱싱, 선택사항_대패삼겹 100g, 상세페이지 참조', '6,240'],
#        ['혼족 자취생 영양한끼 냉동대패삼겹 100g 간편식 싱싱, 대패삼겹 100g', '6,200'],
#        ['시저 불고기 100g', '5,230'],
#        ['도드람 영양스테이크 100g, 1팩', '4,600'],
#        ['[메가마트]지리산 흑돼지 삼겹살 100g, 1개', '3,980'],
#        ['[삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 100g 구이용 등심덧살 특수부위, 가브리살-구이용100g',
#         '3,800'],
#        ['푸주 프리미엄 삼겹살 구이용 250g 이지팩 1~2인용 소포장, 1개, 한입 큐브 삼겹살 250g', '3,700'],
#        ['[메가마트]문경약돌돼지 삼겹살 100g, 1개', '3,580'],
#        ['미트아울렛 신선 삼겹살(숯불용) 300g, 1개', '3,500'],
#        ['미트아울렛 신선 삼겹살(구이용) 300g, 1개', '3,500'],
#        ['푸주 프리미엄 삼겹살 구이용 250g 이지팩 1~2인용 소포장, 1개, 프리미엄 삼겹살 250g', '3,500'],
#        ['신풍한우 1 1+등급 국내산 한돈 불고기용 삼겹살, 국내산 한돈 불고기용 삼겹살 100g, 1개', '3,200'],
#        ['신풍한우 1 1+등급 국내산 한돈 로스용삼겹살, 국내산 한돈 로스용삼겹살 100g, 1개', '3,200'],
#        ['(맛나)돈육돼지/삼겹살(숯불구이용) 100G/국산, 1개', '3,000'],
#        ['(맛나)돈육돼지/삼겹살(숯불구이용) 100G/국산, 1개', '3,000'],
#        ['키친델리 바베큐 훈제삼겹살 100gX9', '2,820'],
#        ['[신사강] 가마솥 볶음김치 1팩(100g), 단품', '2,500'],
#        ['[쭌미트] 냉동 핀란드 삼겹살 개별 진공포장 1팩, 100g x 1팩', '2,400'],
#        ['푸주 목전지 구이용 제육용 250g 보쌈용 500g, 구이용 목전지, 1개', '1,900'],
#        ['대패삼겹살 칠레산 냉동삼겹살 100g/300g/500g 세자매정육점, 대패삼겹100g', '1,690'],
#        ['큐피드메이드 초콜릿 빼빼로 원재료 모음, 밀크초콜릿100g', '1,400'],
#        ['곰곰 양념 목심칼집구이, 1kg, 1개', '11,250'],
#        ['[쭌미트] 한돈 목살 스테이크 1팩 (100g 150g 200g 250g 500g), 500g', '11,000'],
#        ['곰곰 목전지 (냉동) 500g, 2개', '10,990'],
#        ['도드람 영양스테이크 100g, 4팩', '10,600'],
#        ['[쭌미트] 미국산 돼지목살 1팩 (100g 150g 200g 250g 500g 개별진공포장)', '10,000'],
#        ['국내산 한돈 목살 400g 냉장 1등급 돼지고기 [프다], 제육/구이용 (5~7mm)', '9,900'],
#        ['대한민국장사꾼 국내산 돼지목살 숯불용 500g, 1팩', '9,900'],
#        ['[육미가] 목살 1kg 2.5kg 10kg (구이용) HACCP 인증, 1팩', '9,900'],
#        ['솔트에이징 숙성 삼겹살 목살 항정살 각 1팩X100g 수비드삼겹살 돼지등갈비 냉동 원육', '9,000'],
#        ['솔트에이징 숙성 삼겹살+목살+항정살 각100gX3팩 냉장육 오겹살 냉삼 [블루키트]', '9,000'],
#        ['솔트 에이징 숙성 수입산 삼겹살 목살 항정살 각 1팩 100g 수비드 스테이크 캠핑용', '8,000'],
#        ['[피밀리우리흑돈] 프리미엄 명품흑돼지 뒷다리살 1kg, 1개, 수육용', '7,800'],
#        ['[루루축산] 왕목살 찌개용 500g+500g (미국산) 총 1kg, 1set', '7,700'],
#        ['[루루축산] 왕목살 제육 불고기용 1+1 총1kg 수입돼지고기, 1set', '7,700'],
#        ['[삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 200g 구이용 등심덧살 특수부위, 가브리살-구이용200g',
#         '7,600'],
#        ['루루축산 왕목살 구이용 500g+500g (미국산) 총 1kg, 1팩', '7,500'],
#        ['도드람 영양스테이크 100g, 2팩', '6,400'],
#        ['[쭌미트] 이베리코 목살 1팩 (100g 150g 200g 250g 500g)', '6,300'],
#        ['[피에이미트마켓]비교불가 돼지목뼈 1kg 살이많은 100%목뼈만 선별~, 1개', '5,900'],
#        ['시저 불고기 100g', '5,230'],
#        ['도드람 영양스테이크 100g, 1팩', '4,600'],
#        ['피에이미트마켓 왕목살(목전지)500g, 1팩, 구이용500g', '4,400'],
#        ['모디바 냉동 삼겹살 오겹살 구이용 대패 통삼겹살 300g, 1팩, 02. 오겹살(구이용/ 300g )', '4,100'],
#        ['루루축산 왕목살 구이용 500g (미국산), 1팩', '4,100'],
#        ['[삼정포크] 한돈 1+등급 돼지 생 가브리살 냉장 100g 구이용 등심덧살 특수부위, 가브리살-구이용100g',
#         '3,800'],
#        ['고기천국 왕목살(구이용) 400g, 1팩', '3,500'],
#        ['신풍한우 1 1+등급 국내산 한돈 목살 로스용 100g, 1개', '3,200'],
#        ['신풍한우 1 1+등급 국내산 한돈 불고기용 목살, 국내산 한돈 불고기용 목살 100g, 1개', '3,200'],
#        ['(맛나)돈육돼지/벌집목심 100G/국산, 1개', '3,000'],
#        ['할매정육점 막창장 100g 막창소스 서라벌막창장 대구막창장, 200g, 2개입', '2,900'],
#        ['옵션선택/ 한돈100g 갈비찜 LA갈비 목살구이중 택1, 02.한돈_목살구이용100g', '1,950'],
#        ['푸주 목전지 구이용 제육용 250g 보쌈용 500g, 1개', '1,900'],
#        ['푸주 목전지 구이용 제육용 250g 보쌈용 500g, 구이용 목전지, 1개', '1,900'],
#        ['할매정육점 막창장 100g 막창소스 서라벌막창장 대구막창장, 1개입', '1,500'],
#        ['할매정육점 막창장 100g 막창소스 서라벌막창장 대구막창장, 1개입', '1,500'],
#        ['큐피드메이드 초콜릿 빼빼로 원재료 모음, 밀크초콜릿100g', '1,400'],
#        ['여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 10개', '109,700'],
#        ['브니엘몰 목우촌 삼계탕 850g 초복 중복 말복 보양식 닭백숙 백숙 반계탕 즉석삼계탕, 10개', '101,400'],
#        ['여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 7개', '79,700'],
#        ['여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 5개', '59,700'],
#        ['브니엘몰 목우촌 삼계탕 850g 초복 중복 말복 보양식 닭백숙 백숙 반계탕 즉석삼계탕, 5개', '55,000'],
#        ['여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 3개', '38,700'],
#        ['광주요 백자 수라인 커피잔 2p + 커피잔 받침 2p 세트, 1세트', '30,430'],
#        ['여름보양식 초복 중복 말복 몸보신음식 삼계탕 닭한마리 능이삼계탕, 능이 삼계탕 1kg x 2개', '27,700'],
#        ['하림 토종닭 백숙용 18호 생닭 1개, 닭', '27,000'],
#        ['코스트코 하림 동물복지 두마리 통닭 2.4KG 통닭용 [아이스박스] + 사은품, 1)직배송(직배송지역확인)',
#         '23,720'],
#        ['코스트코 하림 동물복지 두마리 통닭 2.4KG 통닭용 [아이스박스] + 사은품, 2)택배발송(아이스박스포장)',
#         '23,720'],
#        ['하림 냉장 참진 닭볶음탕용1kg 2봉, 냉장참진닭볶음용 1kg 2봉', '17,900'],
#        ['[직배송/택배발송]코스트코 하림 백숙용 토종닭 1.3KG 백숙용 + 사은품, 1)직배송(직배송지역확인)', '17,890'],
#        ['[직배송/택배발송]코스트코 하림 백숙용 토종닭 1.3KG 백숙용 + 사은품, 2)택배발송(아이스박스포장)',
#         '17,890'],
#        ['5+5 기획 상품 올계 직영 유기농 삼계탕 레토르트 1kg 즉석 삼계탕 10개', '86,000'],
#        ['1+1 기획 상품 올계 직영 유기농 삼계탕 레토르트 1kg 즉석 삼계탕', '17,120'],
#        ['★icebox★하림참진토종닭백숙1.1Kg', '15,420'],
#        ['[코스트코]하림 백숙용 토종닭 1.3kg (냉장)', '15,210'],
#        ['올품 친환경 무항생제 생닭 1050g 2봉, 친환경무항생제생닭 1050g 2봉', '14,900'],
#        ['CN 하림 삼계탕용 닭 두마리 냉장 코스트코 삼계 손질 생닭 백숙용 백숙 삼계탕 무항생제', '14,110'],
#        ['하림 프레쉬업 냉장 생닭 11호 (1050g 이상) 2마리, 1050g', '14,000'],
#        ['올품 토종대왕 백숙용 토종닭 (냉장), 1150g, 1팩', '13,990'],
#        ['코스트코 하림 영계닭 두마리 1KG 삼계탕용 [아이스박스] + 사은품, 1)직배송(직배송지역확인)', '13,930'],
#        ['코스트코 하림 영계닭 두마리 1KG 삼계탕용 [아이스박스] + 사은품, 2)택배발송(아이스박스포장)', '13,930'],
#        ['올계 직영 능이와 씨암탉 백숙 반마리 1kg 레토르트', '13,600'],
#        ['하림 프레쉬업 냉장 생닭 10호(950g이상) 2봉, 프레쉬업생닭 950g 2봉', '12,910'],
#        ['에그파파 냉장 닭한마리 닭도리 절단육 2kg (1kgX2팩)', '12,900'],
#        ['브니엘몰 목우촌 삼계탕 850g 초복 중복 말복 보양식 닭백숙 백숙 반계탕 즉석삼계탕, 1개', '11,200'],
#        ['하림 참 토종닭 백숙용 (냉장), 1100g, 1개', '10,450'],
#        ['서진네 닭근위(국내산) 1kgX2개(아이스박스포장)청솔식품, 2개, 1kgX2개', '9,400'],
#        ['서진네 치킨 팝콘 2kg(아이스박스포장)랜시푸드, 1개, 2kg', '8,500'],
#        ['서진네 냉동통닭발(국내산) 1kg(아이스박스포장)대운, 1개, 1kg', '7,800'],
#        ['[일계양득] 1+1 올품영계 30호 2마리, 올품영계 30호 2봉', '7,500'],
#        ['풀토래 -신선냉장- 통닭 1마리, 1개, 13호 1마리', '6,500'],
#        ['서진네 닭볶음탕용(국내산) 950g이상(아이스박스포장)A&J푸드, 1개, 950g이상', '5,400'],
#        ['하림 냉동 삼계탕용 통닭 530g', '3,900'],
#        ['하림 자연실록 냉장 통닭 무항생제 인증 (냉장), 830g, 1팩', '5,930'],
#        ['마니커에프앤지 치킨너겟플러스 450g x 2팩, 1세트', '7,900'],
#        ['초록마을 동물복지닭가슴살(300g), 1개', '7,500'],
#        ['참프레 동물복지 직화 그릴닭다리 400g 에어프라이어로 간편조리, 1봉', '7,500'],
#        ['[초록마을] 동물복지닭가슴살(300g), 상세 설명 참조', '7,500'],
#        ['참프레 동물복지 직화그릴닭다리 400g, 1팩', '7,200'],
#        ['마니커에프앤지 리얼치킨 통살케이준텐더 540g, 1팩', '7,200'],
#        ['참프레 동물복지 직화그릴윙 300g, 1팩', '7,000'],
#        ['동물복지 인증 하림 greeners 통닭 백숙용 (냉장), 1050g, 1팩', '6,800'],
#        ['(100% 파손보상) 푸드번창 무항생제 신선 계란10구15구20구, 무항생제20구', '6,580'],
#        ['참프레 동물복지 닭곰탕(실온) 500g x 2팩, 1세트', '6,400'],
#        ['참프레-동물복지 직화 그릴 닭다리 400g/에어프라이어전용제품', '6,920'],
#        ['하림 동물복지 닭가슴살 (냉장), 400g, 1개', '5,980'],
#        ['참프레-동물복지 직화 그릴 윙 300g에어프라이어전용제품', '5,900'],
#        ['참프레-동물복지 슈퍼곡물 크리스피 텐더500g/에어프라이어전용제품', '5,900'],
#        ['하림 동물복지 닭다리 (냉장), 400g, 1개', '5,900'],
#        ['참프레 동물복지 직화 그릴윙 300g 에어프라이어로 간편조리 간식안주, 1봉', '5,900'],
#        ['참프레 동물복지 수비드 닭가슴살 불닭 135g, 아이스박스 포장', '5,700'],
#        ['참프레 동물복지 수비드 닭가슴살 페퍼 130g, 아이스박스 포장', '5,700'],
#        ['참프레 동물복지 수비드 닭가슴살 오리지널 130g, 아이스박스 포장', '5,700'],
#        ['참프레 동물복지 수비드 닭가슴살 소이갈릭 135g, 아이스박스 포장', '5,700'],
#        ['참프레 동물복지 바삭치킨너겟 500g, 1팩', '5,600'],
#        ['하림 동물복지 닭다리살 (냉장), 300g, 1개', '5,310'],
#        ['참프레-동물복지 바삭너겟 500g/에어프라이어전용제품', '4,800'],
#        ['참프레 동물복지 수비드 닭가슴살 허브 130g, 아이스팩 포장', '4,700'],
#        ['참프레 동물복지 닭개장(실온) 500g, 1팩', '4,600'],
#        ['마니커에프앤지 치킨너겟플러스 450g, 1팩', '4,400'],
#        ['참프레 동물복지 닭육수 700g', '4,000'],
#        ['(100% 파손보상) 푸드번창 무항생제 신선 계란10구', '3,750'],
#        ['참프레 동물복지 닭곰탕(실온) 500g, 1팩', '3,400'],
#        ['[메가마트]수비드 닭가슴살 오리지널 130g, 1개', '2,200'],
#        ['복지형 닭 병아리 자동급수컵 조류급수 닭모이통 물통, 복지형급수컵', '1,800'],
#        ['[정연푸드]참프레 동물복지 수비드 닭가슴살 허브130g 냉장 스팀/수비드 닭가슴살, 1개', '1,700'],
#        ['[정연푸드]참프레 동물복지 수비드 닭가슴살 소이갈릭135g 냉장 스팀/수비드 닭가슴살, 1개, 135g', '1,690'],
#        ['[정연푸드] [냉장] 참프레 동물복지 수비드 닭가슴살 5종 중 (오리지널/허브/블랙페퍼/불닭/소이갈릭) 스팀 수비드, 03_블랙페퍼130g',
#         '1,690'],
#        ['아침란 2구 구운 훈제 삶은 찐 계란 HACCP 다이어트 달걀 구운란 훈제란', '1,600'],
#        ['아침란 1구 구운 훈제 삶은 찐 계란 HACCP 다이어트 달걀 구운란 훈제란', '700'],
#        ['풀무원 동물복지 인증 목초란 15구, 780g, 1개', '7,190'],
#        ['(냉장)[풀무원]목초란15구x3', '27,500'],
#        ['(냉장)[풀무원]목초란10구x2+통통신선란10구x2', '26,900'],
#        ['(냉장)[풀무원]목초란10구x3', '20,900'],
#        ['(냉장)[풀무원]목초란15구x2', '19,900'],
#        ['(냉장)[풀무원]목초란10구+통통신선란10구', '14,900'],
#        ['(냉장)[풀무원]목초란10구x2', '14,900'],
#        ['풀무원 동물복지 목초란 15구, 아이스팩 포장', '13,300'],
#        ['풀무원 동물복지 목초란 15구, 일반포장 동절기만', '12,300'],
#        ['(냉장)[풀무원]목초란10구', '9,900'],
#        ['풀무원 무항생제 목초란 15구, 780g, 1개', '6,790'],
#        ['모닝빵 민 상이다 모두 계란 러우쑹 크림 소스를 준비했다 겹 심령 가죽 가방 케익 110G 아침식사 상자 전체, 러우쑹 빵 15 개 _증정 1개 도합',
#         '13,000'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 로즈 레드', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 스위트 보라색 （아가일무늬 ）20 낟', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 피부색', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 녹차를 바르다 （아가일무늬 ）20 낟', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 와인레드 색깔 （아가일무늬 ）20 낟', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 벚꽃 핑크', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 브라운55', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 카메오 색깔 （아가일무늬 ）20 낟알', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 와인색', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 싱겁다 엘로우', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 녹차를 바르다', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 카메오 색깔', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 스위트 보라색', '12,700'],
#        ['15 개 부드러운 젤리볼 임 윤허함 RT 에그 건습 투웨이 똥, 박하 그린', '12,700'],
#        ['1000 칭찬 다꾸 팬시 스티커 _15개 1세트, 계란', '12,570'],
#        ['FS_칭찬스티커판 15개 1세트 3종 숫자판 어린이집 유치원, 계란', '12,500'],
#        ['[슬기로운아이템] 만들기 (T-608)8x15mm 에그타르트(약20g/약15개)슬라임파츠', '6,280'],
#        ['1000계란얌체공(15개세트)', '12,000'],
#        ['실온보관 6개월 바로먹는 계란 아침란, 15개, 50g', '12,000'],
#        ['냉장고수납트레이 가정용 15 개 계란 케이스 수납함 상자 룩 알 정리', '12,000'],
#        ['메이크업퍼프 리자 기 뷰티 에그 거대함 부드러운 핑크 색조메이크업 파운데이션 스폰지 알 절단면 공 건습 투웨이, 블루 요정 (15 개 사슴뿔 통조림',
#         '11,900'],
#        ['메이크업퍼프 리자 기 뷰티 에그 거대함 부드러운 핑크 색조메이크업 파운데이션 스폰지 알 절단면 공 건습 투웨이, 체리 푸딩 (15 개 사슴뿔 통조림',
#         '11,900'],
#        ['메이크업퍼프 리자 기 뷰티 에그 거대함 부드러운 핑크 색조메이크업 파운데이션 스폰지 알 절단면 공 건습 투웨이, 청량 1 여름 (15 개 사슴뿔 통조',
#         '11,900'],
#        ['만두 보관 정리 수납 냉동만두함 전용 냉동만두 가정용 적층 냉장고 수납함 계란함 신선함 식품급 트레이, 01 만두 케이스1층1뚜껑体验款透明（약장15개不划算 신',
#         '11,800'],
#        ['하리보 해피그레이프 25gx10 사무용 칭찬 젤리 간식 계란 모양 콜라 모양 곰 모양 젤리 포켓형 츄잉 캔디, 15개',
#         '11,700'],
#        ['파운데이션 퍼프 포장 가격 10 개 미결점 B품 부드러운 뷰티 에그 물에 담그다 변함 대건습 투웨이 메이크업 핑크, 미니 타입 15 개 색상 타입 식 랜',
#         '10,900'],
#        ['계란보관함 전용 냉장고 사이드도어 달걀넣는 수납함 서랍식 신선보존 계란통 수납대받침 접시, T03-핑크(15개포장)',
#         '10,900'],
#        ['계란보관함 전용 냉장고 사이드도어 달걀넣는 수납함 서랍식 신선보존 계란통 수납대받침 접시, T04-블루색(15개포장)',
#         '10,900'],
#        ['양지뜨레 무항생제 인증 햇살 자연방사 유정란 15구, 780g, 1개', '10,800'],
#        ['EGG 에그 뽑기통 빈 에그타임 계란 캡슐 보관 15개, 에그캡슐', '9,900'],
#        ['아라리 메추리알15g(3알)x15개 1봉/염지란/훈제란/찐계란/아라리계란 식품 > 신선식품 축산물/계란 계란 구운계란/훈제란, 225g, 1',
#         '9,000'],
#        ['조인 무항생제 인증 일판 대란 30구, 1560g, 1개', '8,190'],
#        ['양지뜨레 무항생제 인증 햇살 동물복지 유정란 15구, 780g, 1개', '7,980'],
#        ['(영일) 아라리 메추리알 15g(1팩-15개), 1개', '5,600'],
#        ['ThankQ 계란 달걀 모양스티로폼/중(15개) 대(10개)/, 백색대짜(5X7cm10개)', '1,300'],
#        ['떡편 카스테라새싹보리인절미 (냉동), 45g, 15개', '10,830'],
#        ['삼양라면 120g, 15개', '10,820'],
#        ['맥널티 브라질 벨라비스타 핸드드립 원두 드립백 커피, 8g, 15개', '9,190'],
#        ['떡편 흑미영양찰떡 (냉동), 45g, 15개', '10,660'],
#        ['후라보노 아이스 츄잉껌, 26g, 15개', '10,630'],
#        ['뻥이요 허니, 50g, 15개', '10,600'],
#        ['솔뫼광천 재래 식탁김, 15개, 15g', '10,280'],
#        ['삼양 쇠고기면 120g, 15개', '10,200'],
#        ['팔도 틈새라면 120g, 15개', '10,200'],
#        ['키큰아이 맛있는 찰 핫도그 (냉동), 80g, 15개', '10,200'],
#        ['어가행렬 흑콩차 티백, 2g, 15개', '10,000'],
#        ['베이비스타 대만산 치킨라멘맛 90g, 15개', '9,900'],
#        ['오뚜기 스낵면 108g, 15개', '9,900'],
#        ['팜틱 진한 도라지배즙, 10ml, 15개', '9,900'],
#        ['제주담움 청귤차스틱, 25g, 15개', '9,810'],
#        ['참건강마을 무우차 주전자 티백, 2.5g, 15개', '9,500'],
#        ['팜틱 진한 호박즙, 10ml, 15개', '9,400'],
#        ['롯데 자일리톨 츄잉껌 W, 24g, 15개', '9,330'],
#        ['롯데 자일리톨 츄잉껌 W, 24g, 15개', '9,330'],
#        ['롯데 아라비카커피, 26g, 15개', '9,240'],
#        ['농심 얼큰한 너구리 120g, 15개', '8,900'],
#        ['오뚜기 스낵면 컵라면 62g, 15개', '8,800'],
#        ['농심 안성탕면 125g, 15개', '8,250'],
#        ['만전김 미니언즈 한끼한포 스틱 김자반, 10g, 15개', '8,120'],
#        ['삼육두유 파우치, 190ml, 15개', '8,000'],
#        ['유기농마을 가벼운차, 1.5g, 15개', '7,900'],
#        ['오뚜기 진라면 매운맛 120g, 15개', '7,800'],
#        ['오뚜기 진라면 순한맛 120g, 15개', '7,700'],
#        ['삼양 원조 삼양라면 5개입, 15개', '7,540'],
#        ['쌍계명차 레몬 캐모마일, 1.5g, 15개', '7,500'],
#        ['Camomile Fresh 떼레발_카모마일 프레쉬, 1.5g, 15개', '7,500'],
#        ['쿡팁 고체육수 멸치해물 칼칼한맛, 4g, 15개', '6,900'],
#        ['럽티 팥 팥율무차 티백, 2g, 15개', '6,900'],
#        ['남양이오 유기농인증 요구르트, 80ml, 15개', '6,900'],
#        ['속상하지마 캡타민 건강식품, 2g, 15개', '6,890'],
#        ['농심 사리면 110 g, 15개', '6,470'],
#        ['에코펫위드 더안심닭 반려동물 통살간식 22g, 닭고기, 20개', '15,300'],
#        ['자연싹 안심살균 소독탈취제 1L 강아지', '15,230'],
#        ['바이아우어 더 안심 비타워터 샤워필터 피톤치드 105g, 1개', '15,120'],
#        ['[더푸드] 한우 1+다짐육 300g(냉동), 1팩 300g', '14,530'],
#        ['[사조대림] 사조참치 100gX11캔 /안심따개/통조림, 선택:더매운고추참치 X 11캔{H}', '14,900'],
#        ['[뉴트리원] [3개사면 1개 더 증정!]임영웅 안심 새싹보리정 1박스(1개월분)/100%국, 상세 설명 참조, 상세 설명 참조',
#         '14,900'],
#        ['더페이스샵 미세먼지 안심 듀오 선크림 클렌징폼 세트, 1세트', '13,140'],
#        ['더자리 에코 항균 누빔 방수패드, 밀키그레이', '14,620'],
#        ['밤부베베 순한대나무 안심 천기저귀 더블러, 화이트, 1개', '14,200'],
#        ['더슬로우메이드 로즈마리 치킨텐더 (냉동), 1kg, 1개', '14,000'],
#        ['헬스앤뷰티 더 부드러운 닭가슴살 스노우크림 5팩, 1팩', '14,000'],
#        ['[사조대림] 사조 더매운고추참치(안심따개) 100gx10캔, 상세 설명 참조, 상세 설명 참조, 상세 설명 참조',
#         '13,700'],
#        ['에코펫위드 더안심닭 22g 20개입 강아지 고양이 통살간식 국내산 닭고기 순살', '13,610'],
#        ['[더푸드] 국내산소고기 육전용 200g, 1팩', '13,190'],
#        ['[더푸드] 국내산소고기 양지세절국거리용200g, 1팩', '12,310'],
#        ['걱정말고 기도하라:기도를 통해 더 행복하고 더 멋진 사람이 되는 방법, 안심', '12,600'],
#        ['[더푸드]국내산소고기 구이 스테이크 국거리 모듬골라담기, 8. 세절국거리 1팩(200g)', '11,150'],
#        ['백신 예방접종 완료 스티커 1000매 안심 방역 안내, 09 화이자, 원형30mm', '11,000'],
#        ['다가치더한돈 1등금 뒷다리살1kg (다짐육) 냉장, 1팩, 1kg', '10,900'],
#        ['루나미 더 순한 국내산 초슬림 생리대 대형 날개형, 14개입, 4팩', '10,790'],
#        ['더마시나 촉촉 영양가득 안심반숙란20구, 1개, 무항생제 안심반숙란20구', '10,500'],
#        ['CJ프레시웨이 더안심 동물복지 유정란 15구, 780g, 1팩', '10,490'],
#        ['[당일수확 산지직송] 더안심 무농약인증 국내산 친환경 생목이버섯 1kg 500g', '10,400'],
#        ['꿈토리물티슈 더 도톰한 골드 캡형 엠보싱, 60매, 10개', '9,550'],
#        ['[더샘] #민감한 피부에 저자극 안심 컨실러# 더마 웨어 컨실러 Derma Wear Concealer (01호 02호), 1개, 02 내추럴 베이지',
#         '5,000'],
#        ['더안심 국내산 목이버섯 건목이 무농약 친환경 GAP인증, 50g 건목이 국산', '9,800'],
#        ['미쳤닭 냉동 생닭안심살 (200g포장), 5팩, 생닭안심살200g', '9,800'],
#        ['행사특가(총60매) 3겹 1박스 50매+10매 더 세이프킹 국산 KC인증 3중 MB필터 일회용 덴탈 소형 유아 아동 어린이 마스크 안심 3세~13세까지 사은품증정, 화이트 50매+10매',
#         '9,500'],
#        ['더담은 수제간식 21종, 1봉, 오리안심슬라이스 80g', '9,000'],
#        ['더굿데이 주문제작 코로나 전화스티커 전화번호안내판 출입기록 방문기록 코로나전화 알림스티커 전화인증 안심콜 전화번호판 시트지 인쇄 출력 표지판 방수스티커, 04_그린방문기록안심전화, 시트지+포맥스형',
#         '8,500'],
#        ['더안심 동물복지 유정란 10구, 1개', '7,900'],
#        ['이맛이 설레개 연어 피부 건강에 도움 15g 20개입 [강아지건강하고맛있는안심먹거리], 1개', '7,200'],
#        ['더자리 에코항균 데일리 베개커버 2p, 프링글그레이', '6,900'],
#        ['더클린 펫푸드 강아지 자연식 8종 100g 대용량 수비드 화식 영양식 수제 습식사료, 돼지안심 100g', '6,600'],
#        ['더자리 에코항균 데일리 베개커버 2p, 프링글차콜', '5,900'],
#        ['프리미엄 베비랑 더화이트 물티슈 120매 캡형ㅣ애견 베이비 위생두꺼운 차량용 깨끗한 도톰한 업소용 안심', '1,790'],
#        ['오가다 유자 모과차, 350g, 1개', '8,400'],
#        ['내츄럴스파이스 오레가노 분말, 350g, 1개', '8,330'],
#        ['갑당약초 느릅나무껍질환 병타입, 350g, 1개', '8,050'],
#        ['올페이퍼 마분지 350g 100p, A4, 1개', '8,040'],
#        ['건강스토리 현미쌀눈 볶음 분말, 350g, 1개', '8,000'],
#        ['오뚜기 Premium X.O. 굴림만두 삼선해물 (냉동), 350g, 2개', '7,980'],
#        ['김재식헬스푸드 땅콩크림, 350g, 1개', '7,900'],
#        ['엠수산 국내산 굴(냉동), 350g, 1개', '7,900'],
#        ['누리웰 메추리알 장조림, 350g, 2입', '7,800'],
#        ['GAP 인증 국내산 표고버섯, 350g, 1팩', '7,680'],
#        ['오뚜기 얇은피 잎새만두 김치 (냉동), 350g, 2개', '7,530'],
#        ['천애지하늘사랑 카카오닙스, 350g, 1개', '7,400'],
#        ['몬스툴 탄력핸들 고무망치 350g, 1개', '7,370'],
#        ['오로라 샌드 대 350g, 혼합색상, 2개', '7,320'],
#        ['밀당의고수 김말이 (냉동), 350g, 2개', '7,190'],
#        ['오뚜기 X.O.굴림만두 고기 (냉동), 350g, 2개', '6,970'],
#        ['햇님마을 감자맛전분, 350g, 1개', '6,900'],
#        ['쿠치나앤아모레 링곤베리 프리미엄 프리저브 글루텐 프리, 1개, 350g', '6,830'],
#        ['산타로사 오렌지마말레이드잼, 350g, 1개', '6,510'],
#        ['설탕 0g 스키니 스테비아, 1개, 350g', '6,780'],
#        ['유기농 어린잎 모음, 350g, 1팩', '6,760'],
#        ['곰곰 순살 임연수어, 350g, 1개', '6,500'],
#        ['지하암반해수로 씻어낸 생굴, 350g, 1개', '6,440'],
#        ['수월한 수입산 양념무뼈닭발 (냉동), 350g, 1개', '6,430'],
#        ['사조 0.6 고기만두 (냉동), 350g, 2개', '6,290'],
#        ['쿠치나앤아모레 피그 프리미엄 프리저브 글루텐 프리, 1개, 350g', '6,200'],
#        ['메스테마허 플랙스 씨드 앤 치아 브레드, 350g, 1개', '6,120'],
#        ['하림 자연실록 무항생제 인증 닭윙 아랫날개 (냉장), 350g, 1개', '5,900'],
#        ['하림 자연실록 무항생제 인증 닭봉 윗날개 (냉장), 350g, 1개', '5,900'],
#        ["Patak's Original 시머 소스 핫 앤 스파이시 빈달루, 350g, 1개", '5,890'],
#        ['퀘이커 그래놀라 믹스업 딸기맛, 350g, 1개', '5,780'],
#        ['올가홀푸드 유기농 생 찹쌀가루, 350g, 1개', '5,720'],
#        ['배대감 옥수수맛 전분, 350g, 4개', '5,720'],
#        ['하림 자연실록 무항생제 인증 닭 안심 (냉장), 350g, 1개', '5,500'],
#        ['하림 자연실록 무항생제 인증 닭다리살 정육 (냉장), 350g, 1개', '4,800'],
#        ['곰곰 우유토스트 식빵, 350g, 2개', '4,490'],
#        ['비비고 통단팥죽, 280g, 18개', '34,860'],
#        ['알배기배추 국내산, 1kg, 1개', '4,660'],
#        ['국내산 손질 배추, 1통', '4,620'],
#        ['알배기배추, 800g, 1팩', '4,260'],
#        ['우리조명 장수램프 LED 5인치 매입등 12W, 1개, 주광색', '4,200'],
#        ['마당발 냉동 배추 얼갈이 1kg, 단품', '4,200'],
#        ['아이워너 삼각아령 0.5kg 1kg 1.5kg 2kg 3kg 4kg 5kg 1개입', '4,180'],
#        ['UR+03/16** 핸드폰 멀티 충전 케이블 마이크로 5핀 30핀 2in1 W76 GI+1020EA', '4,100'],
#        ['velton 각종변환젠더 이어폰젠더 이어폰연장젠더 마이크젠더 RCA젠더 AUX케이블, ., SW0027 (양 3.5 ST 코드 5M)',
#         '4,000'],
#        ['알배추 1통 알배기배추 쌈배추 작은 통배추', '4,000'],
#        ['모닝글로리 초등 스프링노트 1-2 국어 10칸(여/5입)', '4,000'],
#        ['국내산 봄동, 1kg, 1봉', '3,970'],
#        ['부드러운 삶은 우거지 1kg 배추 냉장 진공', '3,900'],
#        ['(특품) 국내산 제철 봄동 1kg ~', '3,900'],
#        ['모디스 스피디 1.2A 가정용 충전기(5핀 8핀 C타입 일체형 충전기), 1개, C타입(화이트)', '3,900'],
#        ['알배추 1포기 600g내외 팔팔마켓 알배기 채소 쌈 배추, g', '3,900'],
#        ['PRIME 1+1 메탈 고속 급속지원 1.5M 5핀 8핀 C타입 충전 데이터 케이블, 프라임메탈 1.5M 8핀(블랙)1+1',
#         '3,900'],
#        ['바나다 메탈 플랫 칼국수 마이크로 5핀 고속 충전 숏케이블, BND5PMK12 화이트, 1개', '3,750'],
#        ['온샘팜 알배기배추 1통 알배기 쌈배추', '3,500'],
#        ['[맛다름] 알배기 쌈배추 1통, 1개', '3,500'],
#        ['취화 중국식 절임 신 배추 500g, 2봉', '3,230'],
#        ['[프레시팜] 쌈채소 알배기 알배추 쌈배추 1통', '2,990'],
#        ['원동FS 국내산 알배기 배추 알배추 특 1개', '2,950'],
#        ['황토 삶은시래기&배추우거지, 01 삶은 무청시래기 300g*1팩, 상세설명 참조', '2,900'],
#        ['원동FS 국내산 단배추 1단(1kg내외), 1단, 1kg내외', '2,750'],
#        ['[메가마트]얼갈이/단배추 단, 1개', '2,490'],
#        ['자바펜 0.5 네온5 볼펜, 형광5색, 1개', '2,200'],
#        ['가이라 C타입젠더 3.1 5핀8핀 아이폰 갤럭시노트10 S10 이어폰젠더 USB3.0 to OTG 라이트닝변환, 1개, N8 8pin(암)-C-type(수)블랙',
#         '2,000'],
#        ['액티몬 5V 1.5A USB 1포트 가정용충전기 미케이블', '1,600'],
#        ['아이워너 삼각아령 0.5kg 1kg 1.5kg 2kg 3kg 4kg 5kg 1개입', '1,580'],
#        ['똘박이 알배기배추1통, 1개', '1,500'],
#        ['명호전자 12V 아답터 0.5A 1A 1.5A 2A 3A 3.5A 4A 5A 6A 8A 10A 12A 15A 500mA dc 어댑터, 66. 3종 잰더세트(단품구매불가)',
#         '1,300'],
#        ['R12065 휴즈 2cm 250v 1.5A 5개 제작 단자 작업 부품, 1', '1,000'],
#        ['엠포플러스(주) RFID 태그 RF 메탈 MF 13.56Mhz 14443A 라벨 스티커, 1개, 5. 원형 지름26mm (인쇄)',
#         '1,000'],
#        ['전해콘덴서1uF 100V 85도 SHL Series Aluminum Capacitor (10개 size 5*11)',
#         '500'],
#        ['WCR 와트저항 시멘트저항 10옴 5W (10개묶음), 1', '250'],
#        ['저항10옴5%(J급)1/4W(10개) 카본필름저항10옴(10개) 고정저항10옴 Carbon Film Resistor 0.25w +.- 5% 10옴 J급 탄소피막저항10옴',
#         '200'],
#        ['못난이무 1박스 10kg 파격할인, 단품', '8,900'],
#        ['제주산 무말랭이 500g', '8,500'],
#        ['그린피아 냉동 무 국용 (냉동), 350g, 2개', '8,490'],
#        ['국내산 무청제거 다발무, 5kg, 1봉', '8,440'],
#        ['빛고을장터 맛좋은 제주 무 무우 10kg 5kg내외, 무우 5kg내외, 1box', '8,400'],
#        ['핸디엄 골목커피 더치커피 원액 디카프, 400ml, 1개', '8,400'],
#        ['국내산 맛있는 햇 무, 1박스, 5kg', '7,900'],
#        ['동치미무 5kg 10kg 동치미 무우 동치미용 겨울무 제주 월동무, 동치미용-제주무5kg', '7,500'],
#        ['강경신안 무말랭이 무침, 500g, 1개', '6,900'],
#        ['프로그 무흠집 반짝이 망사 수세미, 6개입, 1개', '6,840'],
#        ['반찬천국 삭힌마늘쫑, 230g, 1개', '6,800'],
#        ['오늘의 밥상 양념무말랭이, 1kg, 1팩', '6,800'],
#        ['싱싱한 제주월동무5kg 세척무우 싱싱지오', '5,900'],
#        ['반찬천국 햇마늘 쫑무침, 200g, 1개', '5,600'],
#        ['기타 초록이슬새싹/새싹채소+어린잎채소(총300g)/브로콜리/유채/콜라비/적무/배추/무공해식품/무농약, 단품없음',
#         '5,570'],
#        ['동서 보리차 식수용 15백X2통 무/료/배/송, 30티백', '5,400'],
#        ['친환경 인증 국내산 절단대파, 500g, 1봉', '5,000'],
#        ["셀레셜시즈닝스 재민' 레몬 생강 허벌 티 무카페인 글루텐 프리, 2.3g, 20개입", '4,420'],
#        ['국내산 세척 무, 2개', '3,990'],
#        ['제주 세척 무, 2입', '3,880'],
#        ['곰곰 국내산 세척 무, 2개입', '3,680'],
#        ['제주도 친환경 무우, 1.2kg, 1개', '3,300'],
#        ['곰곰 친환경 햇 무, 1kg, 1개', '3,290'],
#        ['곰곰 제주도 친환경 무, 1.2kg, 1개', '3,130'],
#        ['[신중국식품]중국청무. 동북칭뤄버, 1개', '2,900'],
#        ['국내산 무, 2입, 1개', '2,810'],
#        ['곰곰 국내산 무, 2입', '2,520'],
#        ['제주 무 1개 1.5kg내외 팔팔마켓 월동무 김장 무우, kg', '2,400'],
#        ['국내산 세척 무, 1개', '2,080'],
#        ['제주 세척 무, 1입', '2,040'],
#        ['친환경인증 무 1입, 1개', '1,980'],
#        ['곰곰 국내산 세척 무, 1개입', '1,950'],
#        ['친환경 인증 국내산 절단무, 400g, 1개', '1,690'],
#        ['국내산 절단 무 2입, 500g 이상, 1봉', '1,460'],
#        ['국내산 무, 900g, 1개', '1,450'],
#        ['국내산 무, 1입, 1개', '1,450'],
#        ['친환경 인증 국내산 손질한 흰줄기 대파, 350g, 1개', '5,070'],
#        ['친환경 인증 국내산 절단대파, 500g, 1봉', '5,000'],
#        ['국내산 절단 손질대파, 1kg, 1봉', '5,000'],
#        ['겟팜스 대파 국내산 반 절단대파 420g 손질대파 당일생산(냉동x), 1팩', '4,930'],
#        ['대파 국내산 손질대파 2단 2kg', '4,900'],
#        ['팜피아 냉동 대파 1kg+1kg 총2kg', '4,900'],
#        ['대파 2kg내외 팔팔마켓 국산 파 뿌리대파 한단, kg', '4,900'],
#        ['곰곰 국내산 절단대파, 1kg, 1개', '4,850'],
#        ['바로한끼 동결건조 대파, 30g, 1개', '4,770'],
#        ['국내산 깐 대파 1kg, 단품', '4,600'],
#        ['곰곰 친환경 인증 국내산 흙대파, 1개', '4,530'],
#        ['깐대파 국내산, 1kg, 1개', '4,100'],
#        ['매직 대파, 30g, 1개', '4,000'],
#        ['조은먹거리 국내산 대파, 대파 1단, 1kg 내외', '3,500'],
#        ['우주농원 국내산 신선한 대파, 1단', '3,150'],
#        ['[인기용량] 손질 대파 500g, 1팩', '3,090'],
#        ['양배추1통, 1개', '3,000'],
#        ['곰곰 친환경인증 절단대파, 300g, 1개', '3,000'],
#        ['친환경 제주 절단대파, 300g, 1봉', '2,920'],
#        ['모들채소 절단대파 300g 1팩', '2,900'],
#        ['곰곰 국내산 흙대파, 1kg, 1개', '2,680'],
#        ['국내산 흙대파, 1kg, 1개', '2,680'],
#        ['곰곰 국내산 깐대파, 500g, 1봉', '2,680'],
#        ['국내산 깐대파, 500g, 1개', '2,660'],
#        ['[당일발송] 새벽들 대파 1단, 1kg내외', '2,500'],
#        ['곰곰 국내산 절단대파, 500g, 1개', '2,500'],
#        ['국내산 절단 손질대파, 500g, 1봉', '2,500'],
#        ['국내산 대파 1단 싱싱하고 하부가 긴 하우스대파, 01. 대파 1단', '2,500'],
#        ['일등야채 진도대파 1단 부산 강원도 깐대파, 1-1.2kg내외', '2,500'],
#        ['GAP인증 절단대파, 500g, 1봉', '2,370'],
#        ['우주농원 신선한국내산 손질대파, 1팩, 300g', '2,350'],
#        ['곰곰 국내산 깐대파, 300g, 1봉', '1,990'],
#        ['국내산 깐대파, 300g, 1봉', '1,810'],
#        ['곰곰 국내산 절단 대파, 300g, 1개', '1,730'],
#        ['무농약인증 국내산 대파, 300g, 1봉', '1,700'],
#        ['손질 대파, 80g, 1봉', '990'],
#        ['슬로시 슬로시 김장 채소 씨앗 무 배추 당근 씨 종자, 초동무20g(아람)', '5,000'],
#        ['건강한 흙당근 국내산 햇당근 빨간 당근, 1box, 중-1kg', '4,900'],
#        ['ardo 유기가공식품인증 당근 슬라이스 (냉동), 600g, 1봉', '4,900'],
#        ['신금 당근스틱 간편야채 380g 한입채소 저칼로리 간식 스틱야채', '4,830'],
#        ['올찬몰 미니 당근 1kg 냉동, 1개', '4,790'],
#        ['권정기님의 친환경 유기농 녹즙용 케일 비트 신선초 샐러리 당근 밀싹 보리싹, 1개, 밀싹 200g', '4,700'],
#        ['권정기님의 친환경 유기농 녹즙용 케일 비트 신선초 샐러리 당근 밀싹 보리싹, 1개, 보리싹 200g', '4,700'],
#        ['권정기님의 친환경 유기농 녹즙용 케일 비트 신선초 샐러리 당근 밀싹 보리싹, 1개, 유기농 신선초(즙용) 1kg',
#         '4,700'],
#        ['하늘농부 친환경 당근 500g, 1봉, 당근 1kg', '4,500'],
#        ['제주 흙당근, 1.5kg, 1봉', '4,410'],
#        ['미니 당근, 300g, 1봉', '4,140'],
#        ['곰곰 친환경 당근, 1.5kg, 1개', '4,020'],
#        ['친환경 인증 국내산 당근, 1.5kg, 1봉', '4,020'],
#        ['곰곰 친환경 흙당근, 1.5kg, 1봉', '4,020'],
#        ['모들채소 당근 채썰기 150g 1팩, 당근채썰기500g', '3,900'],
#        ['모들채소 깐당근 500g 1팩, 1봉', '3,800'],
#        ['국내산 흙당근 1kg', '3,210'],
#        ['쥬스용 흙당근, 3kg', '3,200'],
#        ['가성비 못난이 흙당근 주스용, 3kg', '3,200'],
#        ['국내산 주스용 당근 못난이당근 3kg 5kg', '3,200'],
#        ['모들채소 깐당근 500g 1팩, 1봉, 흙당근 1kg', '3,000'],
#        ['영호네농산물 국산 흙당근 특품 3kg 5kg, 1개, 1kg', '3,000'],
#        ['[메가마트]세척 당근 봉, 1개', '2,990'],
#        ['모들채소 국산 깐당근 150g 1팩, 1봉, 깐당근 300g', '2,900'],
#        ['[프레시팜] 근채류 국내산 흙당근 특품/상품, 상품, 1kg', '2,700'],
#        ['엉클레이팜 냉동 당근 슬라이스 500g, 1개', '2,600'],
#        ['[맛다름] 흙당근 1kg 봉, 1개', '2,500'],
#        ['새벽들 흙당근특품(1kg 3kg 5kg 10kg), 1봉, 1kg', '2,500'],
#        ['[프레시팜] 근채류 수입산 세척당근 1kg 내외', '2,500'],
#        ['[메가마트]흙당근 기획 봉, 1개', '2,490'],
#        ['abc주스 건강주스용 세척당근 or 레드비트 1kg 단위 각각 골라담기, 1box, 세척당근 1kg', '2,000'],
#        ['우주농원 향긋한 국내산 흙당근 1개, 1개입, 150g', '1,950'],
#        ['abc주스 건강주스용 세척당근 or 레드비트 1kg 단위 각각 골라담기, 1box, 레드비드 1kg', '1,900'],
#        ['모들채소 국산 깐당근 150g 1팩, 1봉, 흙당근 500g', '1,900'],
#        ['야채왕 당근 2개 흙당근', '1,700'],
#        ['모들채소 당근 채썰기 150g 1팩, 당근채썰기150g', '1,500'],
#        ['[엔젤쿡] [엔젤쿡]특대부세굴비&자연산왕새우장&강화새우젓 새우젓, 1개, 0709_손질 민어500g+손질 적돔(도미)400g(200/400)',
#         '22,900'],
#        ['생활공작소 실리카겔 제습제 본품, 20g, 20개', '9,900'],
#        ['메이키즈 아동용 심플도트하트 오가닉 20수 후라이스 내의 상하세트', '7,920'],
#        ['바다 100층짜리 집', '9,900'],
#        ['메이키즈 아동용 통통디노 오가닉 20수 후라이스 내의 상하세트', '9,900'],
#        ['대시앤도트 페이스메이커 100일 카운터 2p, 혼합색상', '9,890'],
#        ['베이스어스 C to C PD 케이블 100W, 그레이 + 블랙, 1개', '9,830'],
#        ['랩씨 이지스 풀커버 우레탄 휴대폰 액정보호필름, 4개', '9,750'],
#        ['스카이 비트 Gen1 C to C타입 고속충전 케이블, 2m, 블랙', '9,700'],
#        ['아이시스 8.0 생수, 200ml, 40개', '8,500'],
#        ['영아트 10칸 국어 초등노트, 랜덤 발송, 15개', '9,390'],
#        ['보누맘 아동용 민트냥이 9부 20수 후라이스 상하내의세트', '8,230'],
#        ['탐사 분리수거 쓰레기용 비닐봉투(투명), 20L, 200매', '8,960'],
#        ['4종 축하 가랜드 신생아 아기 30일 50일 100일 200일 300일 400일 500일 600일 700일 800일 900일 1000일 천일 백일 셀프 촬영 소품 사진 풍선, 6',
#         '8,900'],
#        ['태광 마크라메 실 6mm 2p, 무지, 91m', '8,900'],
#        ['바비조아 물만부어 몸에조아10곡, 1kg, 1팩', '8,900'],
#        ['삼성 갤럭시탭 A 8.0 2019 SM-P200 SM-P205 with S PEN 스마트 프리미엄 북커버 케이스, 검정',
#         '8,800'],
#        ['C TO C GEN2 PD 케이블 0.5m, 혼합색상, 1개', '8,730'],
#        ['블랙 직사각 1칸 일회용 도시락 PET-202, 1개입, 25개', '8,710'],
#        ['지하 100층짜리 집, 북뱅크', '8,550'],
#        ['삼성 갤럭시탭A 8.0 2019 SM-P200 SM-P205 with S pen 강화유리 보호필름 1+1 2매',
#         '8,500'],
#        ['영아트 스머프 10칸국어 스프링노트 10p세트, 혼합색상, 1세트', '8,290'],
#        ['코멧 접착식 OPP 무지 쿠키봉투 10 x 10 cm, 400매', '8,290'],
#        ['메이키즈 아동용 블랙스타 오가닉 7부 슬라브 실내복', '7,900'],
#        ['파티해 LOVE 컨페티풍선 + 손펌프 랜덤발송 +컬링리본 + 스펀지닷 세트, 로즈골드, 1세트', '7,650'],
#        ['나우푸드 내추럴 E- 200 소프트젤 글루텐 프리, 100개입, 1개', '7,200'],
#        ['크라시에 나이브 메이크업 리무버 페이스 워쉬 폼 리프레시, 200g, 1개', '7,200'],
#        ['다원 급냉 국산 백조기 10미, 900g~1000g 사이', '6,500'],
#        ['(원폴리머) MT-200V 1L 스텐레스 철 법랑 타일 물때 녹산화물 mt200v st100v 대체품', '6,000'],
#        ['반디 10T 트윈 벌브 차량용 LED 실내등, 혼합 색상, 4개입', '6,000'],
#        ['반디 10T 파워 벌브 차량용 LED 실내등, 혼합 색상, 2개입', '5,730'],
#        ['치과용 가정용 대용량 치실 200yd (구취잇몸병 예방)치과치실 구강용품 Dental Floss, 1개, 1개',
#         '5,400'],
#        ['갤럭시탭A SM-P200 SM-P205 8.0 2019 with S pen 강화유리 액정 보호필름, 강화유리 액정필름1장',
#         '5,400'],
#        ['갤럭시탭A 8.0 2019 SM-P200 SM-P205 with S pen 고광택 액정 보호필름 1+1 2매, 액정 보호필름1+1',
#         '5,000'],
#        ['국내산 품질 맛좋은 건강한 적두 팥 200g, 1OPD_국산 적두 200g', '4,000'],
#        ['한울 꼬마 김치 맛김치, 200g, 1개', '2,100'],
#        ['국산 밀폐유리병, 200g 실버', '1,000'],
#        ['바다한끼 제주 갑오징어(내장제거) + 볶음소스(70g) 증정, 1마리, 200g-300g', '7,000'],
#        ['활낙지(200-300 중국)830g, 830g, 없음', '10,930'],
#        ['냉동 생문어 500g~600g 모리타니아산 수입문어 자숙문어, 1마리, 200g-300g내외', '7,800'],
#        ['강쓰푸드 손질 오징어 500g 1팩 (약 5미-6미)', '6,500'],
#        ['다헤음 오징어스틱, 150g, 1개', '9,120'],
#        ['썬푸드 바베큐조미 오징어, 40g, 4개', '9,000'],
#        ['꾸이꾸이 철판구이 오징어, 150g, 1개', '8,990'],
#        ['오꾸이 오징어다리, 155g, 1개', '8,930'],
#        ['꾸이꾸이 땅콩버터맛 오징어, 130g, 1개', '8,990'],
#        ['쫀득쫀득 가문어 속살 (냉동), 60g, 3개', '8,900'],
#        ['국내가공 쥐어채 (냉동), 200g, 3개', '8,900'],
#        ['파지 손질 오징어 (냉동), 1kg, 1팩', '8,900'],
#        ['꾸이꾸이 불갈비맛 오징어, 150g, 1개', '8,900'],
#        ['금한산업 오감만족 땅콩버터 오징어, 26g, 5개', '8,700'],
#        ['입점특가 순천농협 남도김치 오징어젓갈 350g', '8,500'],
#        ['곰곰 땅콩버터를 품은 오징어, 130g, 1개', '8,300'],
#        ['정화식품 자연오감 오징어 굿다리, 120g, 1개', '8,300'],
#        ['푸드마을 튀김용 오징어채 IQF(영희네) 700g 북양오징어 튀김 오징어', '8,080'],
#        ['황토마을 페스츄리 바베큐 오징어 200g, 1팩', '7,900'],
#        ['오꾸이 오징어, 150g, 1개', '7,810'],
#        ['냉동 생문어 500g~600g 모리타니아산 수입문어 자숙문어, 1마리, 200g-300g내외', '7,800'],
#        ['코봉이푸드 [ ] 프리미엄 오징어젓 500g/THE맛, 1개, 500g', '7,800'],
#        ['참맛통 구이 오징어 (냉동), 150g, 1개', '7,500'],
#        ['정화식품 자연오감 허니버터오징어, 120g, 1개', '6,300'],
#        ['알찬해 통마리 손질 국산 오징어채 (냉동), 300g, 1개', '6,800'],
#        ['새우몰 선동 오징어 2마리 중이상 500g이상 원양산 선동 채낚기', '5,900'],
#        ['김선생 오징어젓갈, 1통, 250g', '5,900'],
#        ['입점특가 순천농협 남도김치 오징어젓갈 200g', '5,000'],
#        ['해맑은푸드 통족, 200g, 1개', '4,800'],
#        ['해맑은푸드 오징어 눌린장족, 100g, 1개', '4,580'],
#        ['미다몰 오븐에 구운 컷팅 오징어 30g [MD1], 1개', '3,500'],
#        ['냉동밥 보관용기-200ml', '3,500'],
#        ['미다몰 오븐에 구운 바베큐 갈비 오징어 50g [MD1], 1개', '3,300'],
#        ['미다몰 참숯으로 구운 오징어 50g [MD1], 1개', '3,300'],
#        ['새우몰 손질오징어 1마리(냉동)', '2,990'],
#        ['상세설명참고 정화 불고기통오징어 45g, 6번불고기통오징어45g', '2,900'],
#        ['삼호 두툼조미 오징어 50g, 1개', '2,850'],
#        ['[화접항] 포켓 맥반석구이 꽃징어 20g 1봉 신제품 쫄깃쫄깃 오징어', '1,800'],
#        ['한성기업 버터구이 오징어, 20g, 1개', '1,560'],
#        ['홈애니 원터치 보온보냉병, 네이비, 200ml', '7,390'],
#        ['비프로젝트 BULKUCK 레이디 미니 슬림 보틀 2종 세트', '7,150'],
#        ['티스탠다드 마이워터 300ml X 30p 생수 물, 30개', '7,150'],
#        ['집으로ON 어린이순살생선 고등어구이 (냉동), 30g, 6개', '7,030'],
#        ['히카리 초경량 라탄물병 300ml 500ml, 레드', '7,000'],
#        ['휘오 다이아몬드 EC생수', '7,000'],
#        ['그레잇츠 간편 국내산 고등어 구이, 250g, 1개', '7,000'],
#        ['사랑해어 간편한 고등어 조림 (냉동), 400g, 1개', '6,800'],
#        ['델리시우스 고등어 필렛 칠리, 125g, 1개', '6,700'],
#        ['업소용 식당 식자재 안동 간고등어 330g 냉동보관, 1', '6,560'],
#        ['휴대용 내열유리 물병, 핑크, 300ml', '6,500'],
#        ['국산 자반 고등어 (냉장), 840g, 1팩', '6,500'],
#        ['[시온견과] 깐밤 (대)300g, 1Ea, 300g', '6,130'],
#        ['아이시스 8.0 생수, 300ml, 20개', '6,060'],
#        ['귀여운 캐릭터 인테리어 눈금 유리 보틀 물병, 캐릭터눈금물병300ml(랜덤)', '6,000'],
#        ['비프로젝트 가볍고 슬림한 스키니 미니 보틀 2p, 블랙, 레드, 300ml', '5,850'],
#        ['스위스밀리터리 루앙 보틀 OKK-LSB300, 민트, 300ml', '5,510'],
#        ['사랑해어 노르웨이 고등어 필렛 (냉동), 170g 이상(특대), 2개', '5,300'],
#        ['냉동 찐 고등어 빠투능 200g', '4,990'],
#        ['[시온견과] 깐밤 (중)300g, 1Ea, 300g', '4,960'],
#        ['오뚜기 고등어 통조림, 400g, 1개', '4,850'],
#        ['사다프 로즈 워터, 1개, 300ml', '4,350'],
#        ['사조해표 간편고등어 매콤한맛 120g, 단품', '3,850'],
#        ['롯데)아이시스먹는샘물300㎖커피 음료 생수 기타브랜드생수 백산수', '3,630'],
#        ['캘리포니아걸 맥커렐 고등어 인 내추럴 오일 솔트 애디드, 425g, 1개', '3,610'],
#        ['아워홈 지리산수 핑크에디션 300ml 20개, 상세페이지 참조, 상세페이지 참조', '3,170'],
#        ['마이보틀 스텐캡 트라이탄 눈금 물병 쉐이커 프로틴 물통 미니 300ml 500ml 600ml, 300ml 트라이탄 눈금물병/스트랩형 뚜껑 (끈 달림)',
#         '3,000'],
#        ['[샘표] 조림용고등어 400g', '2,990'],
#        ['스타벅스 유리보틀 유리병 빨대 텀블러 스벅 300ml', '2,890'],
#        ['[샘표]고등어원터치 400g, 1개', '2,830'],
#        ['배동바지) 고등어(삼포) 고등어통조림 400g, 1통', '2,500'],
#        ['고등어보일드(유동 400g), 상세페이지 참조', '2,300'],
#        ['펭귄 고등어통조림 400g, 1', '2,300'],
#        ['노르웨이 순살 고등어 1팩(130g내외), 1팩', '1,490'],
#        ['어부수산 국내산 순살 고등어 삼치 갈치 노르웨이, 1팩, 국내산 고등어(110g내외)', '890'],
#        ['국내산 순살 고등어 1팩(110g내외), 1팩', '890'],
#        ['프리미엄갈치 180g(3토막)*4팩 12토막', '10,910'],
#        ['비비수산 무염 가자미 10마리(대) (손질 후 1.4kg내외), 1개', '10,900'],
#        ['[고래푸드] 국내산 냉동 간고등어 7손(14마리), 2.1kg, 14마리', '10,900'],
#        ['더도톰한 손질 갈치 특대 (냉동), 500g, 1팩', '10,880'],
#        ['사랑해어 대서양 손질 갈치 (냉동), 550g, 1팩', '10,800'],
#        ['새우몰 왕갈치 800g 손질 절단 냉동, 1개', '10,600'],
#        ['새우몰 맛있는 갈치 (특대) 800g 손질 절단 냉동, 1개', '10,500'],
#        ['속초젓갈 동해랑 갈치쌈젓 500g/1kg 순태젓 반찬 풍미식품, 500g', '9,900'],
#        ['그레잇츠 간편 갈치 구이, 200g, 1개', '9,900'],
#        ['산지직송 거제도 먹갈치 10마리 통갈치, 중-10마리', '9,900'],
#        ['곰소어부가 직접 담은 갈치액젓, 750ml, 1개', '9,900'],
#        ['사랑해어 간편한 갈치 조림 (냉동), 400g, 1개', '9,900'],
#        ['새우몰 맛있는 갈치 (대) 800g 손질 절단 냉동, 1개', '9,800'],
#        ['국내산 순살갈치 200g x 2팩, 1개', '9,790'],
#        ['입점특가 순천농협 남도식품 갈치속젓 1kg, 3.창란젓, 350g', '9,500'],
#        ['수입 왕갈치 낚시바리 대왕갈치 한마리 500g이상 특대갈치 수입갈치 먹갈치 은갈치, 1마리', '9,000'],
#        ['새우몰 제주 은갈치 4미(750g이상) 낚시로 잡아 은비늘이 선명한 A급 갈치, 1개', '8,900'],
#        ['순살 갈치살 (냉동), 500g, 1팩', '8,880'],
#        ['바다자리 참조기 개별포장 중 5미 (냉동), 350g, 1개', '8,600'],
#        ['한수위 제주바당 갈치살 (냉동), 200g, 1개', '8,500'],
#        ['비비수산 두툼한 A급 왕특대갈치 600g 갈치, 1팩', '8,500'],
#        ['씨푸드몰 대서양 손질 갈치 700g (5토막 내외), 1개', '8,070'],
#        ['서풍앤쿡 줄줄이 왕갈치 (냉동), 550g, 1팩', '8,000'],
#        ['갈치 풀치 10마리 1kg전후 목포, 10', '7,900'],
#        ['오늘식탁 강경 갈치 젓갈쌈장, 250g, 1개', '7,100'],
#        ['바다자리 손질 순살 고등어 대 1미 2쪽, 200g, 1개', '6,800'],
#        ['양반 갈치 조림 260g/갈치조림/코스트코갈치조림/동원양반갈치조림/양반갈치조림', '6,700'],
#        ['나래밥상 갈치젓, 180g, 1개', '6,560'],
#        ['안동 하회마을 신선한 갈치 세네갈산 약 500g( 절단갈치 냉동갈치 도막갈치 삼치 오징어), 갈치(세네갈산) 500g',
#         '6,500'],
#        ['냉동갈치 수입갈치 대서양 모로코 특대 1마리 600g(6토막)', '6,500'],
#        ['마산어시장 반건조 마른갈치 건갈치 조림용 촉촉하게 말린갈치 4마리', '5,500'],
#        ['새우몰 국산 건갈치(대) 4마리 조림용 핏물완벽제거로 덜비려요', '4,990'],
#        ['국내산 풀치 (실갈치) 300g 500g', '4,900'],
#        ['국내산 여수 순살 갈치 200g 1팩', '2,790'],
#        ['샘표 갈치조림소스200g, 200g, 1개', '2,200'],
#        ['다담 갈치조림양념, 150g, 1개', '1,480'],
#        ['한림수협 수산세트 2호 굴비 80g x 15미 + 고등어 100g x 10미 (냉동), 1세트', '89,000'],
#        ['[해선유통] 손질 간 갈치 살 (100g X 10팩) 1kg 냉동', '27,500'],
#        ['데친 곰피 미역 8팩 + 갈치속젓 100g 쇠미역, 곰피미역 8팩+ 갈치속젓 3개', '26,900'],
#        ['업소용 음식점 식자재 안동 간고등어 순살 100g X10, 쿠팡집방 1', '35,300'],
#        ['미소순살왕갈치 뼈없는 수제 손질 순살 대왕 갈치(약100g 진공포장), 1kg(약100g*10팩)', '27,500'],
#        ['신선해어 갈치 내장제거 토막당 80~100g (냉동), 2kg, 1개', '20,900'],
#        ['미소순살왕갈치 뼈없는 수제 손질 순살 대왕 갈치(약100g 진공포장), 500g(약100g*5팩)', '14,750'],
#        ['국내산 순살 고등어 개별 포장, 순살고등어 100g X 5팩', '13,600'],
#        ['가정용 업소용 식자재 안동 간고등어 순살 100g X2, 쿠팡 1', '11,620'],
#        ['가정용 업소용 식자재 안동 간고등어 순살 100g X2, 쿠팡집방 1', '9,970'],
#        ['리스테린 [무료배송]리스테린 쿨민트(750ml+750ml+100ml) 구강청결제, 1세트', '13,350'],
#        ['(1+2) 무알콜 리스테린 그린티마일드 750ml + 쿨민트마일드 100ml + 쿨민트마일드 100ml, 1세트',
#         '12,980'],
#        ['리스테린 [무료배송]리스테린 쿨민트(750ml+250ml+100ml) 구강청결제, 1세트', '12,900'],
#        ['리스테린 쿨민트 750ml+250ml 구강청결제, 1개', '12,900'],
#        ['(1+2) 무알콜 리스테린 쿨민트 750ml + 검케어마일드 100ml + 검케어마일드 100ml, 1세트',
#         '12,770'],
#        ['존슨앤존슨 리스테린 750ml 구강청결제 입속 상쾌 가글 750ml, 쿨민트', '12,680'],
#        ['리스테린 쿨민트750ml-2개 (1+1)무료배송 구강청결제, 1세트', '12,250'],
#        ['[무료배송]리스테린 세균억제 구강청결제 쿨민트(750ml+250ml+100ml), 1세트', '12,200'],
#        ['리스테린 리스테린750ml 250ml 구강청결제, 쿨민트750ml×2+250ml, 1세트', '11,500'],
#        ['리스테린 쿨민트 750ml 2개 + 250ml 1개', '11,400'],
#        ['구강청결제 리스테린 메디가글잇몸케어대용량구강케어구강청정제:ml LCWPMN 써밋커머스 빠른배송 +50001933 가그린가글액 리스테린쿨민트, l눌러서구매하기ㅣ:메디가글750ml 잇몸케어마일드1개',
#         '11,180'],
#        ['구강청결제 리스테린 메디가글잇몸케어대용량구강케어구강청정제:ml LCWPMN 써밋커머스 빠른배송 +50001933 가그린가글액 리스테린쿨민트, l눌러서구매하기ㅣ:메디가글750ml 순한맛복숭아향 1개',
#         '11,180'],
#        ['구강청결제 리스테린 메디가글잇몸케어대용량구강케어구강청정제:ml LCWPMN 써밋커머스 빠른배송 +50001933 가그린가글액 리스테린쿨민트, l눌러서구매하기ㅣ:메디가글750ml 순한맛복숭아향 1개',
#         '11,180'],
#        ['구강청결제 리스테린 메디가글잇몸케어대용량구강케어구강청정제:ml LCWPMN 써밋커머스 빠른배송 +50001933 가그린가글액 리스테린쿨민트, l눌러서구매하기ㅣ:메디가글750ml 잇몸케어마일드1개',
#         '11,180'],
#        ['(2개선택) 존슨앤존슨 구강청결제 리스테린 750ml, 토탈케어마일드 750ml, 쿨민트 750ml', '11,100'],
#        ['(2개선택) 존슨앤존슨 구강청결제 리스테린 750ml, 쿨민트 750ml, 토탈케어플러스 750ml', '11,100'],
#        ['(2개선택) 존슨앤존슨 구강청결제 리스테린 750ml, 토탈케어플러스 750ml, 쿨민트 750ml', '11,100'],
#        ['(2개선택) 존슨앤존슨 구강청결제 리스테린 750ml, 토탈케어마일드 750ml, 쿨민트마일드 750ml',
#         '11,100'],
#        ['(2개선택) 존슨앤존슨 구강청결제 리스테린 750ml, 쿨민트마일드 750ml, 토탈케어마일드 750ml',
#         '11,100'],
#        ['(2개선택) 존슨앤존슨 구강청결제 리스테린 750ml, 쿨민트마일드 750ml, 토탈케어플러스 750ml',
#         '11,100'],
#        ['리스테린 리스테린750ml-2개(1+1) 묶음상품 구강청결제, 쿨민트+토탈케어, 1세트', '10,900'],
#        ['리스테린 리스테린750ml-2개(1+1) 묶음상품 구강청결제, 쿨민트+내츄럴그린티, 1세트', '10,500'],
#        ['리스테린 쿨민트750ml+100ml+100ml 대용량 구강청결제 구취제거 가글 가그린', '9,980'],
#        ['오너클랜 존슨앤존슨 리스테린 750ml 쿨민트 구강청결제, 단일', '9,970'],
#        ['리스테린 구강청결제 시트러스 250ml 750ml, 3개', '9,900'],
#        ['리스테린 리스테린750ml-2개(1+1) 묶음상품 구강청결제, 쿨민트+후레쉬버스트, 1세트', '9,600'],
#        ['리스테린 리스테린750ml-2개(1+1) 묶음상품 구강청결제, 시트러스+쿨민트, 1세트', '9,600'],
#        ['리스테린 쿨민트 750ml + 750ml (1 SET) 임박재고', '8,900'],
#        ['케이알글로벌리스테린 750ml 토탈케어 구강청결제 가글 리스태린빠른배송, 리스테린750ml 쿨민트', '8,870'],
#        ['리스테린 쿨민트 마일드 구강청결제, 750ml, 2개', '8,820'],
#        ['리스테린 쿨민트 구강청결제, 750ml, 2개', '8,650'],
#        ['FAMSCUBE리스테린 쿨민트 마일드750ml, 단일 수량', '8,490'],
#        ['리스테린 내추럴 그린티 마일드 구강청결제, 750ml, 1개', '7,880'],
#        ['리스테린 시트러스 구강청결제, 750ml, 1개', '6,570'],
#        ['리스테린 쿨민트 마일드 구강청결제, 250ml, 2개', '6,480'],
#        ['리스테린 쿨민트 구강청결제, 100ml, 4개', '6,370'],
#        ['검가드 오리지널 750ml / 잇몸 가그린 리뉴얼, 1개', '13,950'],
#        ['[무료배송]동아제약 가그린 오리지널(750ml+750ml+100ml) 구강청결제, 1세트', '13,000'],
#        ['IS 가그린 오리지널 750ML가그린 구강청결제 구강청결 구강위생용품 구강위생 구강가그린 치아가그린, 본상품',
#         '12,900'],
#        ['동아제약 가그린 오리지널 750ml 2개 + 100ml 1개', '12,900'],
#        ['동아제약 가그린 제로 3종세트 (750ml/250ml/100ml), 단품', '12,900'],
#        ['가그린 오리지널 3종세트 (750ml/250ml/100ml), 단품', '12,900'],
#        ['Dentalcare 가그린 오리지널750ml/ 충치예방/ 대용량, 가그린오리지널 750ml', '12,840'],
#        ['검가드 잇몸 가그린 동아제약 오리지널 750, 1개, 750ml', '12,700'],
#        ['동아제약 가그린 오리지널 750ml 2개 + 100ml 1개', '12,600'],
#        ['750ML IS 가그린 오리지널, 상세페이지 참조', '12,490'],
#        ['동아 오리지널 가그린 750ML, 상세페이지 참조', '12,010'],
#        ['가그린 오리지널 구강청결제, 2개, 1100ml', '12,000'],
#        ['가그린 750ml 오리지널X2, 1개', '11,900'],
#        ['동아제약 가그린 사이즈별 어린이가그린까지, 오리지널 750ml x 2개+증정100ml', '11,900'],
#        ['국민가글 가그린 오리지날 750ml 청결하게 순한맛 휴대용가글/사무실가글/구강관리/칫솔대신/입안의상쾌함/구취제거/구취제/여행용가글/리필가글/여행용품, 1',
#         '11,790'],
#        ['가그린 오리지널 750ml, 1', '11,770'],
#        ['최신품 가그린 380ml / 750ml, 스트롱 750ml 2개, 스트롱 750ml', '11,700'],
#        ['가그린 구강청결제 오리지널 250ml+750ml, 1개, 1000ml', '11,400'],
#        ['Dentalcare 가그린 오리지널750ml 충치예방 대용량, 가그린오리지널 750ml', '11,310'],
#        ['블루몬 가그린 덴탈케어 후레쉬라임 750ml/ 대용량 가글/ 라 가글액 구강청결제 가그린오리지날', '10,980'],
#        ['가그린 오리지날 100ml 250ml 1000ml Danert Care, 1개, 750ml', '10,550'],
#        ['가그린 오리지널 구강청결제, 750ml, 2개', '10,400'],
#        ['가그린 검가드 오리지널 750ml', '10,000'],
#        ['가그린 오리지널 구강청결제, 2개, 750ml', '9,930'],
#        ['가그린 검가드 오리지널 380ml 750ml', '9,900'],
#        ['가그린 오리지널 구강청결제, 250ml, 5개', '9,530'],
#        ['가그린 오리지널 구강청결제, 5개, 250ml', '9,050'],
#        ['동아제약 가그린 라임 380ml 구강청결제, 3개', '9,100'],
#        ['가그린 오리지널 세트 750ml+250ml, 1개, 750ml', '8,900'],
#        ['가그린 오리지널 380ml', '8,800'],
#        ['가그린 오리지널 구강청결제, 2개, 750ml', '8,220'],
#        ['가그린 오리지널 구강청결제, 1개, 1200ml', '6,800'],
#        ['가그린 오리지널 구강청결제, 1.2L, 1개', '7,160'],
#        ['가그린 오리지널 750ml + 250ml, 1세트', '6,990'],
#        ['가그린 오리지널 750ml + 250ml, 1세트', '6,640'],
#        ['스마트클라우드 세정제 동아제약 가그린 오리지널 구강세정제 750ml 세탁크리너 세탁세제, 1개', '6,460'],
#        ['크리넥스 데코소프트 3겹 24롤, 단품, 단품', '21,800'],
#        ['24롤 데코소프트 30m 크리넥스 화장지, 상세페이지 참조', '21,580'],
#        ['문구사무/크리넥스 데코_소프트 3겹 화장지(30M×24롤/무향/유한킴벌리), 1', '21,000'],
#        ['크리넥스 두루마리휴지 데코앤소프트 화장지 30m 24롤', '20,900'],
#        ['Z09-크리넥스 데코소프트 화장지 30m 24롤 1팩, 상세페이지 참조', '20,590'],
#        ['유한킴벌리 크리넥스 데코 소프트 3겹 24롤 화장지', '20,500'],
#        ['크리넥스 데코소프트 3겹 화장지 30M 24롤 두루마리휴지 티슈, 1개', '20,500'],
#        ['땡큐온 크리넥스 데코 소프트 천연코튼 3겹 30M 24롤 x1팩, 단품', '20,300'],
#        ['45178 크리넥스 데코 소프트 화장지 30m-24롤(무향), 단품', '20,200'],
#        ['크리넥스 데코앤소프트 와이드 롱 3겹 30m*24롤, 1팩', '20,190'],
#        ['크리넥스 데코&소프트 3겹 30m X 24롤, 상세페이지 참조', '20,100'],
#        ['크리넥스 크리넥스순수3겹 화장지 25M 24롤 휴지 두루마리휴지 롤휴지 3겹휴지 고급휴지 순수3겹 롤화장지 티슈, 1개',
#         '20,050'],
#        ['크리넥스 데코&소프트 30m 3겹 24롤x1팩~3팩/케이에이치샵, 24롤x1팩', '20,000'],
#        ['미라클세일 유한킴벌리 크리넥스 롤 티슈, 미라클세일 울트라클린 27m 30롤', '19,950'],
#        ['[텐바이텐] 45178 크리넥스 데코&소프트화장지 티슈 (3겹) 30m 24롤 1팩, 옵션선택, 옵션선택',
#         '19,910'],
#        ['크리넥스 데코소프트 화장지 3겹 30m 24롤', '19,900'],
#        ['크리넥스 데코&소프트 3겹 화장지 30m×24롤', '19,900'],
#        ['크리넥스 데코앤소프트 30m 3겹 두루마리화장지 24롤', '19,800'],
#        ['크리넥스 데코 앤 소프트 3겹 35m X 24롤, 24개, 1팩', '19,700'],
#        ['크리넥스 데코앤소프트 3겹 35M 12롤 1팩 롤 화장지', '19,500'],
#        ['유한킴벌리 크리넥스 데코앤소프트 화장지 3겹 35m 24롤', '19,400'],
#        ['크리넥스 데코앤소프트3겹 30M 24롤 화장지(휴지)', '19,300'],
#        ['크리넥스 데코 앤 소프트 24롤 3겹 천연코튼 휴지, 단품', '19,200'],
#        ['크리넥스 데코 앤 소프트 24롤 3겹 천연코튼 휴지, 단품', '19,200'],
#        ['크리넥스 데코 소프트(향) 3겹 35Mx24롤, 1개, 24롤', '18,900'],
#        ['크리넥스 데코&소프트 30m24롤 x 1팩 (총24롤)', '18,900'],
#        ['크리넥스 데코&소프트 화장지 3겹 30m 24롤, 1팩', '18,900'],
#        ['크리넥스 45178데코앤소프트 두루마리 화장지 30m 24롤 3겹, 45178 데코앤소프트 30Mx24롤',
#         '18,500'],
#        ['크리넥스 데코 앤 소프트 롤화장지 30m 24롤, 1팩', '18,400'],
#        ['크리넥스 데코앤소프트 와이드롱 3겹 30m 24롤화장지 두루마리, 1팩', '18,250'],
#        ['크리넥스 화장지 데코 & 소프트 24롤 1개', '18,100'],
#        ['크리넥스 천연펄프 데코앤소프트 에어엠보싱 도톰한 3겹 30M 24롤 비데사용가능, 1팩', '17,500'],
#        ['크리넥스 데코 앤 소프트 화장지 30m 24롤x1팩 45178, 단품', '17,500'],
#        ['크리넥스 데코&소프트 3겹 화장지 30m 24롤 1팩, 45178 크리넥스 데코&소프트(3겹) 24롤 1팩',
#         '15,400'],
#        ['45178 크리넥스 데코앤소프트 롤화장지 30m 24롤 1백, 단품', '12,600'],
#        ['미래생활 잘풀리는집 나무야 3겹 24롤 25M, 1, 본상품선택', '10,760'],
#        ['페리오 토탈7 메디컬허브 칫솔 힘있는 미세모, 4개', '8,500'],
#        ['히말라야 핑크솔트 바이옴 펌핑치약 285g 3개 + 토탈7 힘있는 미세모 4개 + 양치컵케이스(옵션별 색상), ①바이옴 펌핑 285g 3개+증정(아',
#         '38,800'],
#        ['페리오 토탈7 힘있는 미세모 칫솔 1개입, 4개', '5,900'],
#        ['뽀로로 떡볶이 버스팩 크림맛, 115g, 4개', '9,200'],
#        ['내린천원당 콩비지, 300g, 4개', '9,200'],
#        ['아이비스 PP 반반 좌철 노트 SP11479, 소이밀크, 4개', '8,190'],
#        ['아이비스 PP 반반 좌철 노트 SP11479, 아이보리, 핑크, 블루, 소이밀크, 4개', '8,190'],
#        ['아이비스 PP 반반 좌철 노트 SP11479, 핑크, 4개', '8,190'],
#        ['반찬애 콩자반, 100g, 4개', '9,040'],
#        ['파미유 초코머핀 (냉동), 140g, 4개', '9,000'],
#        ['포스트바이오틱스 이너케어 위 프로텍트, 136g, 4개', '8,980'],
#        ['포스트바이오틱스 이너케어 간 프로텍트, 136g, 4개', '8,980'],
#        ['부케가르니 퍼퓸드 샤쉐 옷장방향제 베이비파우더 L, 20g, 4개', '8,900'],
#        ['가든클래식스 고구마 말랭이, 60g, 4개', '8,900'],
#        ['곰곰 바닐라 아이스크림, 474ml, 4개', '8,900'],
#        ['랩신 센서티브 핸드워시 리필 파우더리 허브향, 200ml, 4개', '7,040'],
#        ['조르단 유아 칫솔 스텝1단계, 랜덤발송, 4개', '8,360'],
#        ['바다모음 초록초록 파래가루 20g, 파래맛, 4개', '8,800'],
#        ['듀라셀 코인 리튬 건전지 CR2450, 1개입, 4개', '8,790'],
#        ['오뚜기 참치, 135g, 4개', '8,790'],
#        ['리빙웰 과일꽂이, 160개입, 4개', '8,780'],
#        ['레인보우샵 과탄산소다 솝 세탁비누, 160g, 4개', '8,320'],
#        ['곰곰 김자반, 70g, 4개', '8,680'],
#        ['곰곰 김자반, 70g, 4개', '8,680'],
#        ['코맥 무표맥 커피여과지 #2Y, 100매입, 4개', '8,600'],
#        ['대박테이프 크라프트 종이 박스테이프 48mm x 40m, 베이지, 4개', '8,500'],
#        ['스카트 테이프클리너 이지앤퀵 대형 리필, 4개', '8,500'],
#        ['쿤달 시그니처 퍼퓸 옷장 방향제 본품 체리블라썸향, 20g, 4개', '8,500'],
#        ['모란카노 플래쉬 강화유리 휴대폰 액정보호필름, 4개', '8,400'],
#        ['코멧 홈 청소도구 후크 홀더, 4개', '8,390'],
#        ['주방 욕실 곰팡이 다기능방수 테이프 그레이 38mm x 3.2m, 4개', '8,240'],
#        ['뭉구 시스템 노트, 그리드, 4개', '8,220'],
#        ['파울러스 추억의 양은 막걸리잔, 노랑, 4개', '8,000'],
#        ['오죤로얄 닥터 롱칫솔, 1개입, 4개', '8,000'],
#        ['클라인 장미목 요거트 앤 티스푼, 4개', '7,900'],
#        ['젤로젤로 지브라 반달 고급형 파일, 4개', '7,900'],
#        ['유하우스 일회용 위생 멀티백 대형, 15매입, 4개', '7,660'],
#        ['기본에 크린지퍼백 미니 50매, 4개', '7,900'],
#        ['맨허스트 대왕 샤워볼 60g, 블랙, 4개', '7,280'],
#        ['오랄비 크로스액션 탁월한 세정력 칫솔, 1개, 3개입', '10,700'],
#        ['오랄비 크로스액션 35모 칫솔, 5개입, 1개', '10,500'],
#        ['오랄비 크로스액션 프로-엑스퍼트 (35모) 3+2입', '10,450'],
#        ['오랄비 칫솔 크로스액션 프로 엑스퍼트 탁월한 세정력 3개입', '10,150'],
#        ['오랄비 크로스액션 토탈케어 프로헬스7 칫솔 X 4개, 1개, 4개입', '9,900'],
#        ['오랄비 크로스액션 프로엑스퍼트 컴플리트7 부드러운모/35모 칫솔 3개입, 1팩', '9,900'],
#        ['오랄비 크로스액션 35모 탁월한 세정 칫솔, 3개입, 2개', '9,830'],
#        ['오랄비 크로스액션 컴플리트7 35모 칫솔, 1개, 3개입', '9,700'],
#        ['오랄비 크로스액션 프로 엑스퍼트 컴플리트7 칫솔 3입', '9,600'],
#        ['오랄비 크로스액션 탁월한 세정력 부드러운 35모 3+2개입, 5입 1개', '9,540'],
#        ['오랄비 크로스액션 탁월한 세정력 35모 칫솔 3+2', '9,500'],
#        ['오랄비 크로스액션 프로 엑스퍼트 향균 35모 칫솔 랜덤발송, 3개입, 1개', '9,410'],
#        ['오랄비 크로스액션 화이트닝 차콜 35모 칫솔 3개입, 1팩, 3개', '9,300'],
#        ['오랄비 크로스액션 35모 칫솔, 5개입, 1개', '9,280'],
#        ['오랄비 크로스액션 프로엑스퍼트 향균 35모 칫솔, 3개입, 1개', '9,200'],
#        ['오랄비 크로스액션 컴플리트7 칫솔, 3개입, 1개', '8,980'],
#        ['오랄비 크로스액션 프로 엑스퍼트 향균 35모 칫솔 랜덤발송, 1개, 3개입', '8,900'],
#        ['오랄비 컴플리트 교체용 칫솔 헤드, 2개입', '8,600'],
#        ['오랄비 크로스액션 화이트닝 차콜 칫솔, 1개, 3개입', '8,330'],
#        ['오랄비 크로스액션 칫솔(3입), 크로스액션 탁월한세정력 35모 5개', '7,900'],
#        ['오랄비 크로스액션 젠틀케어 칫솔 3개입, 1개', '7,900'],
#        ['오랄비 크로스액션 탁월한 세정력 칫솔 X 5개, 1개, 5개입', '7,800'],
#        ['오랄비 크로스액션 플라그가드 40모 칫솔, 1개, 3개입', '7,730'],
#        ['오랄비 크로스액션 그린티 35모 칫솔, 3개입, 1개', '7,700'],
#        ['오랄비 컴플리트 5웨이 후레쉬 클린 칫솔, 3개입, 1개', '7,350'],
#        ['오랄비 크로스액션 프로-엑스퍼트 칫솔 5입 1개', '7,300'],
#        ['오랄비 크로스액션 컴플리트7 35모 칫솔, 3개입, 1개', '7,130'],
#        ['오랄비 크로스액션 프로엑스퍼트 부드러운 모 35 x 3개입', '7,100'],
#        ['오랄비 크로스액션 컴플리트7 부드러운모 3개입 1개', '6,950'],
#        ['오랄비 크로스액션 토탈케어 TAJ 칫솔 랜덤발송, 4개입, 1개', '6,930'],
#        ['오랄비 크로스액션 화이트닝 차콜35모 칫솔- 3개입', '6,900'],
#        ['오랄비 크로스액션 엑스퍼트 향균케어 칫솔 4입 1개', '6,800'],
#        ['오랄비 크로스액션 화이트닝 차콜 칫솔, 3개입, 1개', '6,620'],
#        ['오랄비 크로스액션 35모 탁월한 세정 칫솔, 3개입, 1개', '5,870'],
#        ['오랄비 초미세모 크로스액션 차콜 칫솔', '2,140'],
#        ['오랄비 어드밴티지 5웨이 후레쉬 클린/크로스액션 칫솔, 오랄-비 어드밴티지 5웨이 칫솔', '1,260'],
#        ['[마루몰]청량한 허브향~페리오 캐비티 케어 알파치약[160g 3개입], 3개', '17,000'],
#        ['YB[미르쇼핑] LG 페리오 캐비티 케어 충치케어치약150gX4개입 & 알파치약160gX3개입 !!!, 알파치약 3개',
#         '16,000'],
#        ['[유니크앤몰] 스피아민트와 멘톨!! 페리오 캐비티 케어 알파 치약 160gX3, 3개', '15,300'],
#        ['치아를 더 건강하게 ~! [조이스몰] 페리오 캐비티케어 알파치약160g*3개입, 3개', '14,900'],
#        ['댕이몰 페리오 캐비티케어 알파치약 160g*3개입 - 치아전문가용 치약 멘톨향 상쾌함, 3개', '13,970'],
#        ['[제이원마켓] 페리오 캐비티케어 어드벤스드 충치케어치약 150g X 4개입, 150gX4개입, 1묶음', '11,900'],
#        ['ⓥ 페리오 캐비티케어 알파치약 160gX3개 구취제거 OC/SIU_ 치약 죽염치약( 21070857007EA ) #, 본상품',
#         '11,680'],
#        ['LG생활건강 페리오 캐비티 케어 알파 치약 160g, 9개', '10,800'],
#        ['페리오 충치케어 구취 프라그 제거 캐비티케어 브레쓰케어 치약 160gX3개, 캐비티케어알파', '9,900'],
#        ['LG생활건강 페리오 케비티 케어 알파 치약 160g, 10개', '9,720'],
#        ['RNRKD페리오 캐비티케어 알파치약 160gX3개 구취제거 치약 -EA, esgshop 1, esgshop 본상품선택',
#         '9,660'],
#        ['[NIC]_페리오치약 충치케어 페리오 캐비티케어 충치케어치약150gX4개입ship_$, nic 1', '9,510'],
#        ['페리오 캐비티케어 알파치약 160gX3개 구취제거 치약 50014, 해피한마트 1, 해피한마트 본상품선택', '9,050'],
#        ['1등 페리오가 쏜다 브레쓰160G 3개+캐비티160G3개+칫솔 4+4입, 상세 설명 참조', '8,900'],
#        ['페리오 캐비티케어 알파치약 160gX3개 구취제거 치약', '8,590'],
#        ['페리오 캐비티 케어 알파 160g 치약 대용량 충치예방 5개', '8,200'],
#        ['페리오 치약 캐비티케어 알파 160g 3개입 X 3개, 1개', '8,150'],
#        ['페리오 캐비티케어 치약(케이스) 50g x 10개, 1개', '7,900'],
#        ['페리오 캐비티케어 알파치약 160gX3개 구취제거 치약 다이소 올리브영 어금니 미세모 교정 부드러운 휴대용 치간 칫솔 치실, 1, 본상품선택',
#         '7,030'],
#        ['PG 엘지생활건강 치은염 치태 충치케어 알파 치약 160g X 3개 세트, 캐비티케어알파 160g X 3개',
#         '7,000'],
#        ['페리오 캐비티케어 치약 160g 6개, 1개', '6,680'],
#        ['페리오 구취제거 안전한 캐비티케어 알파 160gX3개 입냄새 펌핑 치약 달리 소금', '6,600'],
#        ['페리오 캐비티케어 알파치약 160gX3개 구취제거 치약, ydh_ 1', '6,050'],
#        ['페리오 캐비티케어 플러스 130g 3개', '6,000'],
#        ['페리오 캐비티케어 알파치약 160gX3개 구취제거 치약, 1', '5,800'],
#        ...])

# %%
## 크롤링해서 뽑아온 데이터를 DataFrame으로 만듬

present_prod = pd.DataFrame(sample_, columns = ['상품명', '가격'])
present_prod
# Out:
#                                               상품명      가격
# 0        깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품  18,500
# 1                    깨끗한나라 순수 시그니처 3겹 28m 30롤, 1개  18,500
# 2        깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품  18,500
# 3         깨끗한나라 순수 시그니처 3겹데코 28m 30롤 X 1팩, 단품, 단품  17,900
# 4                 깨끗한나라 순수 시그니처 3겹 화장지 28m 30롤 휴지  17,800
# ...                                           ...     ...
# 8923                        상세설명참고 머거본 꿀땅콩 캔 135g   2,300
# 8924                           [머거본] 꿀땅콩 135g, 단품   2,100
# 8925  머거본 꿀땅콩 135g 식품 > 신선식품 건과/견과류 견과류 일반땅콩, 1개입   1,980
# 8926                 [BIGHAND] 머거본 알땅콩 캔 135g, 1개   1,970
# 8927                          머거본 알땅콩(캔) 135g, 1개   1,890
#
# [8928 rows x 2 columns]

# %%
present_prod.to_csv('present_prod.csv')

# %%
present_prod['상품명']
# Out:
# 0          깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 1                      깨끗한나라 순수 시그니처 3겹 28m 30롤, 1개
# 2          깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 3           깨끗한나라 순수 시그니처 3겹데코 28m 30롤 X 1팩, 단품, 단품
# 4                   깨끗한나라 순수 시그니처 3겹 화장지 28m 30롤 휴지
#                            ...
# 8923                          상세설명참고 머거본 꿀땅콩 캔 135g
# 8924                             [머거본] 꿀땅콩 135g, 단품
# 8925    머거본 꿀땅콩 135g 식품 > 신선식품 건과/견과류 견과류 일반땅콩, 1개입
# 8926                   [BIGHAND] 머거본 알땅콩 캔 135g, 1개
# 8927                            머거본 알땅콩(캔) 135g, 1개
# Name: 상품명, Length: 8928, dtype: object

# %%
# ## 유니크 품목들의 '()'을 제거한 것

# li_list = []
# for prodc in products:
#     if ')' in prodc:
        
#         # print(prodc.split(')')[0].split('('))
# #         pr1 = prodc.split(')')[0].split('(')
        
#         prodc = prodc.replace('(', " ")
#         prodc = prodc.replace(')', "")
#         li_list.append(prodc)
#     else:
# #         print([prodc])
# #         pr2 = [prodc]
        
#         li_list.append(prodc)
# li_list
# Out:
# ['머거본 꿀땅콩 135g',
#  '허니버터아몬드 210g',
#  '백설 소면 900g',
#  '옛날국수 소면 900g',
#  '고향만두 1.08kg',
#  '비비고 왕교자 1.05kg',
#  '생야채돼지고기물만두 800g',
#  '백설 자른 햇당면 300g',
#  '옛날 자른당면 300g',
#  '국산콩두부 부침용 380g',
#  '국산콩두부 찌개용 380g',
#  '행복한콩 부침두부 300g',
#  '행복한콩 찌개두부 300g',
#  '삼양라면 5개입',
#  '신라면 5개입',
#  '진라면 순한맛 5개입',
#  '곰표 밀가루 중력다목적용 1kg',
#  '백설 찰밀가루 1kg',
#  '백설 5가지 재료 부침가루 1kg',
#  '오뚜기 부침가루 1kg',
#  '삼립호떡 미니꿀호떡 16개입',
#  '정통크림빵 3개입',
#  '보노 콘스프 3개입',
#  '보노 포르치니버섯스프 3개입',
#  '오뚜기 크림스프 80g',
#  '스페셜K 오리지널 480g',
#  '켈로그 콘푸로스트 600g',
#  '포스트 콘푸라이트 600g',
#  '오뚜기 간편 미역국 5개입',
#  '오뚜기 간편 북엇국 5개입',
#  '3분 쇠고기짜장 200g',
#  '3분 쇠고기카레 200g',
#  '오뚜기 3분 백세카레 약간 매운맛 200g',
#  '청정원 카레여왕 비프카레 160g',
#  '오뚜기밥 210g',
#  '오뚜기밥 3개입',
#  '오뚜기밥 6개입 ',
#  '햇반 210g',
#  '햇반 3개입',
#  '햇반 6개입',
#  '동원 양반 쇠고기죽 287.5g',
#  '동원 양반 전복죽 287.5g',
#  '비비고 소고기죽 280g',
#  '비비고 전복죽 280g',
#  '농심 신라면 큰사발면 114g',
#  '오뚜기 참깨라면 컵 110g',
#  '팔도 왕뚜껑 110g',
#  '오뚜기 맛있는 쇠고기미역국밥 162g',
#  '오뚜기 컵밥 제육덮밥 310g',
#  '햇반 컵반 고추장 제육덮밥 250g',
#  '햇반 컵반 미역국밥 167g',
#  '비비고 사골곰탕 500g',
#  '비비고 육개장 500g',
#  '오뚜기 옛날 사골곰탕 350g',
#  '오뚜기 옛날 육개장 300g',
#  '오리온 포카칩 오리지널 66g',
#  '포테토칩 오리지날 125g',
#  '롯데 자일리톨 오리지날 97g',
#  '빙그레 참붕어 싸만코 150ml',
#  '아이비 270g',
#  '참크래커 280g',
#  '돼지바 70ml',
#  '메로나 75ml',
#  '해태 바밤바 63ml',
#  '롯데 목캔디 허브민트 217g',
#  '오리온 통아몬드 캔디 90g',
#  '농심 새우깡 90g',
#  '롯데 월드콘 바닐라 160ml',
#  '투게더 오리지널 바닐라 900ml',
#  '해태 부라보콘 화이트바닐라 140ml',
#  '닥터유 에너지바 40g',
#  '닥터유 에너지바 4개입',
#  '켈로그 레드베리 에너지바 4개입',
#  '자유시간 36g',
#  '자유시간 5개입',
#  '핫브레이크 미니 714g',
#  '몽쉘 크림 384g',
#  '오리온 초코파이 18개입',
#  '롯데 ABC 초코 187g',
#  '롯데 빅가나 마일드 110g',
#  '들기름 재래 도시락김 12팩',
#  '양반 들기름이 그윽한 김 16팩',
#  '대림 게맛살 큰잔치 300g',
#  '동원 싱싱맛살 실속 500g',
#  '삼호 안심 김밥맛살 264g',
#  '삼호 안심 부산어묵 400g',
#  '동원참치 라이트스탠다드 150g',
#  '동원참치 라이트스탠다드 4캔',
#  '마일드참치 150g',
#  '마일드참치 3개',
#  '사조참치 살코기 안심따개 4캔',
#  '양조간장 501 500ml',
#  '진간장 금F3 930ml',
#  '순창 오리지널 우리쌀 찰고추장 1kg',
#  '해찬들 우리쌀태양초골드 1kg',
#  '해표 순창궁 태양초 100% 우리햅쌀 고추장 1.8kg',
#  '동서 아카시아꿀 600g',
#  '동서벌꿀 600g',
#  '샘표 시골집 토장 900g',
#  '순창 재래식안심생된장 1kg',
#  '해찬들 재래식 된장 1kg',
#  '청정원 발사믹 드레싱',
#  '청정원 오리엔탈 드레싱',
#  '오뚜기 고소한 골드 마요네즈 500g',
#  '청정원 고소한 마요네즈 500g',
#  '백설 자일로스 설탕 1kg',
#  '백설 하얀설탕 1kg',
#  '큐원 하얀설탕 1kg',
#  '백설 구운소금 500g',
#  '청정원 미원 맛소금 500g',
#  '해표 꽃소금 1kg',
#  '백설 식용유 1.5L',
#  '오뚜기 콩기름 100% 900ml',
#  '해표 맑고 신선한 식용유 900ml',
#  '백설 건강발효 사과식초 800ml',
#  '백설 건강발효 현미식초 800ml',
#  '오뚜기 사과식초 900ml',
#  '청정원 순창 양념듬뿍 쌈장 500g',
#  '해찬들 사계절 쌈장 500g',
#  '해표 순창궁 양념쌈장 500g',
#  '딸기잼 500g',
#  '복음자리 딸기잼 370g',
#  '백설 진한참기름',
#  '오뚜기 참기름 320ml',
#  '오뚜기카레 순한맛 100g',
#  '청정원 카레여왕 구운마늘&amp;양파 108g',
#  '오뚜기 토마토 케찹 500g',
#  '청정원 진한 토마토 케찹 500g',
#  '산들애 국내산 해물 250g',
#  '청정원 맛선생 국내산해물 250g',
#  '달콤한 베지밀 비 16팩',
#  '달콤한 삼육두유 B',
#  '매일두유 담백한 맛 16팩',
#  '국순당 생막걸리 750ml',
#  '국순당 우국생 750ml',
#  '서울장수생막걸리 750ml',
#  '제주 위트 에일 500ml',
#  '카스 프레쉬 500ml',
#  '카스 프레쉬 6캔',
#  '테라 500ml',
#  '하이트 엑스트라 콜드 500ml',
#  '하이트 엑스트라 콜드 6캔',
#  '비타500 10개입',
#  '오로나민C 10개입',
#  '스프라이트 1.5L',
#  '칠성사이다 제로 1.5L',
#  '삼다수 2L',
#  '삼다수 500ml',
#  '아이시스 2L',
#  '아이시스 500ml',
#  '삼다수 2L*6개',
#  '삼다수 500ml*20개',
#  '참이슬 클래식 360ml',
#  '참이슬 후레쉬 360ml',
#  '처음처럼 360ml',
#  '레드불 에너지 드링크 250ml',
#  '롯데 핫식스 250ml',
#  '몬스터 에너지 355ml',
#  '게토레이 레몬 600ml',
#  '파워에이드 마운틴블라스트 520ml',
#  '포카리스웨트 620ml',
#  '델몬트 오렌지 100 1.5L',
#  '미넷메이드 오렌지 1.5L',
#  '남양 17차 티백 80개입',
#  '동서현미녹차 100개입',
#  '맥심 티오피 마스터 라떼 275ml',
#  '바리스타룰스 콜드브루 블랙 325ml',
#  '아카페라 아메리카노 240ml',
#  '맥스웰 하우스 오리지날 180개입',
#  '맥심 모카골드 마일드 200개입',
#  '카누 마일드 로스트 아메리카노 30개입',
#  '프렌치카페 카페믹스 220개입',
#  '코카콜라 1.8L',
#  '펩시콜라 1.8L',
#  '마주앙 레드 750ml',
#  '진로 와인 500ml',
#  '오뚜기 콘마가린 180g',
#  '떠먹는 불가리스 딸기 4개',
#  '바이오 플레인 요거트 4개',
#  '불가리스 4개',
#  '요플레 오리지널 4개',
#  '이오 5개',
#  '앱솔루트 명작 3단계 800g',
#  '임페리얼 드림 XO 3단계 800g',
#  '프리미엄 산양분유 1단계 800g',
#  '그릴후랑크 600g',
#  '백설 그릴 비엔나 720g',
#  '의성마늘 빅그릴 비엔나 600g',
#  '주부9단 프랑크소시지 900g',
#  '남양유업 맛있는우유GT 1L',
#  '매일우유 오리지널 900ml',
#  '서울우유 흰우유 1L',
#  '파스퇴르우유 후레쉬 930ml',
#  '드빈치 고칼슘치즈 15매',
#  '매일유업 뼈로가는 칼슘치즈 270g',
#  '서울우유 체다슬라이스치즈 400g',
#  '체다치즈 15매',
#  '스팸 클래식 200g',
#  '의성마늘 한입슬라이스햄 60g',
#  '주부9단 슬라이스햄 300g',
#  '마미손 고무장갑 중 2세트',
#  '크린랩 고무장갑 중 2세트',
#  '크린랩 22cm x 50m',
#  '크린랩 30cm x 50m',
#  '맥스 부탄가스 4개',
#  '썬 부탄가스 4개',
#  '무균무때 세정제 욕실용 900ml',
#  '유한락스 레귤러 1.8L',
#  '유한락스 욕실청소용 1800ml',
#  '유한락스 후레쉬 1.5L',
#  '홈스타 락스와세제 후로랄파인 750ml',
#  '홈스타 욕실용 세정제 900ml',
#  '에프킬라 에어로졸 무향 500ml',
#  '컴배트 스피드 에어졸 500ml',
#  '홈키파 수성 에어졸 500ml',
#  '다우니 고농축 섬유유연제 엑스퍼트 2L',
#  '샤프란 아우라 초고농축 섬유유연제 홀리데이판타지 2.3L',
#  '피죤 섬유유연제 핑크로즈 2.1L',
#  '샤프란 네이처 섬유탈취제 프레쉬 민트 300ml',
#  '페브리즈 상쾌한향 370ml',
#  '페브리즈 상쾌한향 900ml',
#  '때가 쏙 비트 분말세제 6kg',
#  '비트 트리플 액션 2.8L',
#  '스파크 분말세제 6kg',
#  '테크 UP 분말세제 4kg',
#  '테크 베이킹소다 액체세제 3L',
#  '퍼실 파워젤 액체 드럼용 2.7L',
#  '퍼실 파워젤 액체 일반용 2.7L',
#  '물먹는하마 3개입',
#  '피죤 습기제로 8개입',
#  '3M 후레쉬 슬라이드 지퍼백 중형 21cm x 16cm x 6cm',
#  '손잡이 크린백 35cm x 45cm',
#  '지퍼락 지퍼백 냉장 중형 20매',
#  '크린롤백 25cm x 35cm',
#  '크린지퍼백 18cm x 20cm',
#  '메소드 주방세제 핑크 532ml',
#  '자연퐁 솔잎 490ml',
#  '프릴 시크릿 오브 베이킹소다 퓨어레몬향 750ml',
#  '항균 트리오 973ml',
#  '코디 키친타월 6롤',
#  '크리넥스 안심 키친타월 6롤',
#  '밥이보약 CAT 걱정없는 헤어볼',
#  '밥이보약 튼튼한관절',
#  'JB 뉴 베드타임 로션 500ml',
#  '정말 순한 바디밀크 450ml',
#  '크리넥스 KF94 4단 마스크',
#  'PACE6 스타일 면도날 4개',
#  '플로쉴드 옐로우 면도날 4개',
#  '하이드로8 면도날 8개',
#  '도브 뷰티 너리싱 바디워시 1kg',
#  '도브 센스티브 스킨 바디워시 1kg',
#  '세이 온더바디 고보습 아이리스 900ml',
#  '오가니스트 히말라야 핑크솔트 바디워시 리프레싱 민트향 865ml',
#  '해피바스 라벤더 에센스 바디워시 900g',
#  '도브 뷰티바 4개',
#  '드봉 스위트로즈 4개',
#  '해피바스 허브 라벤더 아로마 바 4개',
#  '쏘피 바디피트 볼록맞춤 날개 중형 32개입',
#  '좋은느낌 울트라슬림 에어핏쿠션 날개 중형 36개입',
#  '좋은느낌 좋은순면 울트라 날개 중형 36개입',
#  '화이트 시크릿홀 날개 중형 36개입',
#  '려 함빛 극손상엔영양케어 샴푸 550ml',
#  '미쟝센 퍼펙트세럼 샴푸 680ml',
#  '엘라스틴 모로칸 아르간 오일 집중영양 샴푸 680ml',
#  '케라리스 데미지 클리닉 오리지널 샴푸 750ml',
#  '랩신 핸드워시 센서티브 250ml',
#  '아이!깨끗해 항균폼 상큼레몬향 250ml',
#  '려 두피보호 한방염색 짙은 밤색 4.5 60g',
#  '리엔 흑모비책크림염색 자연갈색 60g',
#  '미쟝센 쉽고빠른거품염색 3N 흑갈색 40g',
#  '하기스 매직컴포트 대형 공용 팬티형 4단계 40매',
#  '하기스 매직컴포트 중형 공용 밴드형 3단계 66매',
#  '하기스 매직컴포트 특대형 공용 팬티형 5단계 33매',
#  '메디안 치석 치약 오리지널 3개',
#  '어드밴스 캐비티 블루 120g',
#  '어드밴스 캐비티 블루 3개',
#  '페리오 캐비티케어 3개',
#  '오랄비 크로스액션 3개입',
#  '죽염 칫술 잇몸 4개',
#  '페리오 토탈7 칫솔 힘있는 미세모 4개',
#  '크리넥스 데코엔소프트 3겹 24롤',
#  '가그린 오리지널 750ml',
#  '리스테린 쿨민트 750ml',
#  '갈치 냉동, 100g',
#  '갈치 생물, 100g',
#  '고등어 생물, 300~500g',
#  '오징어 냉동, 200~300g',
#  '오징어 생물, 200~300g',
#  '부세 200~400g',
#  '참조기 200~400g',
#  '당근 흙당근, 100g',
#  '대파 흙대파, 500~800g',
#  '무 줄기 없는 무, 1.5kg',
#  '배추 1.5~2kg',
#  'CJ 행복한콩 국산콩 콩나물 280g',
#  '국산아작아작콩나물 350g',
#  'CJ 더안심 건강란 대란 15개',
#  'CJ 알짜란 대란 15개',
#  '목초를 먹고 자란 건강한 닭이 낳은 달걀 대란 15개',
#  '풀무원 동물복지 목초란 대란 10개',
#  '참프레 동물복지 닭백숙 1.1kg',
#  '하림 자연실록백숙 830g',
#  '하림 토종닭백숙 1.05kg',
#  '돼지고기 목살 100g',
#  '돼지고기 삼겹살 100g',
#  '쇠고기 등심 1+등급, 100g',
#  '쇠고기 등심 1등급, 100g',
#  '쇠고기 불고기 1+등급, 100g',
#  '쇠고기 불고기 1등급, 100g',
#  'CJ 비비고 왕교자 910g',
#  '해태 오예스 12개입',
#  '대림선어묵 부산어묵 300g',
#  '오뚜기 소프트마가린 180g',
#  '덴마크 오리지널 치즈 14매',
#  '깨끗한나라 순수 시그니쳐 3겹 30롤']

# %%
products
# Out:
# ['머거본 꿀땅콩(135g)',
#  '허니버터아몬드(210g)',
#  '백설 소면(900g)',
#  '옛날국수 소면(900g)',
#  '고향만두(1.08kg)',
#  '비비고 왕교자(1.05kg)',
#  '생야채돼지고기물만두(800g)',
#  '백설 자른 햇당면(300g)',
#  '옛날 자른당면(300g)',
#  '국산콩두부 부침용(380g)',
#  '국산콩두부 찌개용(380g)',
#  '행복한콩 부침두부(300g)',
#  '행복한콩 찌개두부(300g)',
#  '삼양라면(5개입)',
#  '신라면(5개입)',
#  '진라면 순한맛(5개입)',
#  '곰표 밀가루 중력다목적용(1kg)',
#  '백설 찰밀가루(1kg)',
#  '백설 5가지 재료 부침가루(1kg)',
#  '오뚜기 부침가루(1kg)',
#  '삼립호떡 미니꿀호떡(16개입)',
#  '정통크림빵(3개입)',
#  '보노 콘스프(3개입)',
#  '보노 포르치니버섯스프(3개입)',
#  '오뚜기 크림스프(80g)',
#  '스페셜K 오리지널(480g)',
#  '켈로그 콘푸로스트(600g)',
#  '포스트 콘푸라이트(600g)',
#  '오뚜기 간편 미역국(5개입)',
#  '오뚜기 간편 북엇국(5개입)',
#  '3분 쇠고기짜장(200g)',
#  '3분 쇠고기카레(200g)',
#  '오뚜기 3분 백세카레 약간 매운맛(200g)',
#  '청정원 카레여왕 비프카레(160g)',
#  '오뚜기밥(210g)',
#  '오뚜기밥(3개입)',
#  '오뚜기밥(6개입) ',
#  '햇반(210g)',
#  '햇반(3개입)',
#  '햇반(6개입)',
#  '동원 양반 쇠고기죽(287.5g)',
#  '동원 양반 전복죽(287.5g)',
#  '비비고 소고기죽(280g)',
#  '비비고 전복죽(280g)',
#  '농심 신라면 큰사발면(114g)',
#  '오뚜기 참깨라면 컵(110g)',
#  '팔도 왕뚜껑(110g)',
#  '오뚜기 맛있는 쇠고기미역국밥(162g)',
#  '오뚜기 컵밥 제육덮밥(310g)',
#  '햇반 컵반 고추장 제육덮밥(250g)',
#  '햇반 컵반 미역국밥(167g)',
#  '비비고 사골곰탕(500g)',
#  '비비고 육개장(500g)',
#  '오뚜기 옛날 사골곰탕(350g)',
#  '오뚜기 옛날 육개장(300g)',
#  '오리온 포카칩 오리지널(66g)',
#  '포테토칩 오리지날(125g)',
#  '롯데 자일리톨 오리지날(97g)',
#  '빙그레 참붕어 싸만코(150ml)',
#  '아이비(270g)',
#  '참크래커(280g)',
#  '돼지바(70ml)',
#  '메로나(75ml)',
#  '해태 바밤바(63ml)',
#  '롯데 목캔디 허브민트(217g)',
#  '오리온 통아몬드 캔디(90g)',
#  '농심 새우깡(90g)',
#  '롯데 월드콘 바닐라(160ml)',
#  '투게더 오리지널 바닐라(900ml)',
#  '해태 부라보콘 화이트바닐라(140ml)',
#  '닥터유 에너지바(40g)',
#  '닥터유 에너지바(4개입)',
#  '켈로그 레드베리 에너지바(4개입)',
#  '자유시간(36g)',
#  '자유시간(5개입)',
#  '핫브레이크 미니(714g)',
#  '몽쉘 크림(384g)',
#  '오리온 초코파이(18개입)',
#  '롯데 ABC 초코(187g)',
#  '롯데 빅가나 마일드(110g)',
#  '들기름 재래 도시락김(12팩)',
#  '양반 들기름이 그윽한 김(16팩)',
#  '대림 게맛살 큰잔치(300g)',
#  '동원 싱싱맛살 실속(500g)',
#  '삼호 안심 김밥맛살(264g)',
#  '삼호 안심 부산어묵(400g)',
#  '동원참치 라이트스탠다드(150g)',
#  '동원참치 라이트스탠다드(4캔)',
#  '마일드참치(150g)',
#  '마일드참치(3개)',
#  '사조참치 살코기 안심따개(4캔)',
#  '양조간장 501(500ml)',
#  '진간장 금F3(930ml)',
#  '순창 오리지널 우리쌀 찰고추장(1kg)',
#  '해찬들 우리쌀태양초골드(1kg)',
#  '해표 순창궁 태양초 100% 우리햅쌀 고추장(1.8kg)',
#  '동서 아카시아꿀(600g)',
#  '동서벌꿀(600g)',
#  '샘표 시골집 토장(900g)',
#  '순창 재래식안심생된장(1kg)',
#  '해찬들 재래식 된장(1kg)',
#  '청정원 발사믹 드레싱',
#  '청정원 오리엔탈 드레싱',
#  '오뚜기 고소한 골드 마요네즈(500g)',
#  '청정원 고소한 마요네즈(500g)',
#  '백설 자일로스 설탕(1kg)',
#  '백설 하얀설탕(1kg)',
#  '큐원 하얀설탕(1kg)',
#  '백설 구운소금(500g)',
#  '청정원 미원 맛소금(500g)',
#  '해표 꽃소금(1kg)',
#  '백설 식용유(1.5L)',
#  '오뚜기 콩기름 100%(900ml)',
#  '해표 맑고 신선한 식용유(900ml)',
#  '백설 건강발효 사과식초(800ml)',
#  '백설 건강발효 현미식초(800ml)',
#  '오뚜기 사과식초(900ml)',
#  '청정원 순창 양념듬뿍 쌈장(500g)',
#  '해찬들 사계절 쌈장(500g)',
#  '해표 순창궁 양념쌈장(500g)',
#  '딸기잼(500g)',
#  '복음자리 딸기잼(370g)',
#  '백설 진한참기름',
#  '오뚜기 참기름(320ml)',
#  '오뚜기카레 순한맛(100g)',
#  '청정원 카레여왕 구운마늘&amp;양파(108g)',
#  '오뚜기 토마토 케찹(500g)',
#  '청정원 진한 토마토 케찹(500g)',
#  '산들애 국내산 해물(250g)',
#  '청정원 맛선생 국내산해물(250g)',
#  '달콤한 베지밀 비(16팩)',
#  '달콤한 삼육두유 B',
#  '매일두유 담백한 맛(16팩)',
#  '국순당 생막걸리(750ml)',
#  '국순당 우국생(750ml)',
#  '서울장수생막걸리(750ml)',
#  '제주 위트 에일(500ml)',
#  '카스 프레쉬(500ml)',
#  '카스 프레쉬(6캔)',
#  '테라(500ml)',
#  '하이트 엑스트라 콜드(500ml)',
#  '하이트 엑스트라 콜드(6캔)',
#  '비타500(10개입)',
#  '오로나민C(10개입)',
#  '스프라이트(1.5L)',
#  '칠성사이다 제로(1.5L)',
#  '삼다수(2L)',
#  '삼다수(500ml)',
#  '아이시스(2L)',
#  '아이시스(500ml)',
#  '삼다수(2L*6개)',
#  '삼다수(500ml*20개)',
#  '참이슬 클래식(360ml)',
#  '참이슬 후레쉬(360ml)',
#  '처음처럼(360ml)',
#  '레드불 에너지 드링크(250ml)',
#  '롯데 핫식스(250ml)',
#  '몬스터 에너지(355ml)',
#  '게토레이 레몬(600ml)',
#  '파워에이드 마운틴블라스트(520ml)',
#  '포카리스웨트(620ml)',
#  '델몬트 오렌지 100(1.5L)',
#  '미넷메이드 오렌지(1.5L)',
#  '남양 17차 티백(80개입)',
#  '동서현미녹차(100개입)',
#  '맥심 티오피 마스터 라떼(275ml)',
#  '바리스타룰스 콜드브루 블랙(325ml)',
#  '아카페라 아메리카노(240ml)',
#  '맥스웰 하우스 오리지날(180개입)',
#  '맥심 모카골드 마일드(200개입)',
#  '카누 마일드 로스트 아메리카노(30개입)',
#  '프렌치카페 카페믹스(220개입)',
#  '코카콜라(1.8L)',
#  '펩시콜라(1.8L)',
#  '마주앙 레드(750ml)',
#  '진로 와인(500ml)',
#  '오뚜기 콘마가린(180g)',
#  '떠먹는 불가리스 딸기(4개)',
#  '바이오 플레인 요거트(4개)',
#  '불가리스(4개)',
#  '요플레 오리지널(4개)',
#  '이오(5개)',
#  '앱솔루트 명작 3단계(800g)',
#  '임페리얼 드림 XO 3단계(800g)',
#  '프리미엄 산양분유 1단계(800g)',
#  '그릴후랑크(600g)',
#  '백설 그릴 비엔나(720g)',
#  '의성마늘 빅그릴 비엔나(600g)',
#  '주부9단 프랑크소시지(900g)',
#  '남양유업 맛있는우유GT(1L)',
#  '매일우유 오리지널(900ml)',
#  '서울우유 흰우유(1L)',
#  '파스퇴르우유 후레쉬(930ml)',
#  '드빈치 고칼슘치즈(15매)',
#  '매일유업 뼈로가는 칼슘치즈(270g)',
#  '서울우유 체다슬라이스치즈(400g)',
#  '체다치즈(15매)',
#  '스팸 클래식(200g)',
#  '의성마늘 한입슬라이스햄(60g)',
#  '주부9단 슬라이스햄(300g)',
#  '마미손 고무장갑 중(2세트)',
#  '크린랩 고무장갑 중(2세트)',
#  '크린랩(22cm x 50m)',
#  '크린랩(30cm x 50m)',
#  '맥스 부탄가스(4개)',
#  '썬 부탄가스(4개)',
#  '무균무때 세정제 욕실용(900ml)',
#  '유한락스 레귤러(1.8L)',
#  '유한락스 욕실청소용(1800ml)',
#  '유한락스 후레쉬(1.5L)',
#  '홈스타 락스와세제 후로랄파인(750ml)',
#  '홈스타 욕실용 세정제(900ml)',
#  '에프킬라 에어로졸 무향(500ml)',
#  '컴배트 스피드 에어졸(500ml)',
#  '홈키파 수성 에어졸(500ml)',
#  '다우니 고농축 섬유유연제 엑스퍼트(2L)',
#  '샤프란 아우라 초고농축 섬유유연제 홀리데이판타지(2.3L)',
#  '피죤 섬유유연제 핑크로즈(2.1L)',
#  '샤프란 네이처 섬유탈취제 프레쉬 민트(300ml)',
#  '페브리즈 상쾌한향(370ml)',
#  '페브리즈 상쾌한향(900ml)',
#  '때가 쏙 비트 분말세제(6kg)',
#  '비트 트리플 액션(2.8L)',
#  '스파크 분말세제(6kg)',
#  '테크 UP 분말세제(4kg)',
#  '테크 베이킹소다 액체세제(3L)',
#  '퍼실 파워젤 액체 드럼용(2.7L)',
#  '퍼실 파워젤 액체 일반용(2.7L)',
#  '물먹는하마(3개입)',
#  '피죤 습기제로(8개입)',
#  '3M 후레쉬 슬라이드 지퍼백 중형(21cm x 16cm x 6cm)',
#  '손잡이 크린백(35cm x 45cm)',
#  '지퍼락 지퍼백 냉장 중형(20매)',
#  '크린롤백(25cm x 35cm)',
#  '크린지퍼백(18cm x 20cm)',
#  '메소드 주방세제 핑크(532ml)',
#  '자연퐁 솔잎(490ml)',
#  '프릴 시크릿 오브 베이킹소다 퓨어레몬향(750ml)',
#  '항균 트리오(973ml)',
#  '코디 키친타월(6롤)',
#  '크리넥스 안심 키친타월(6롤)',
#  '밥이보약 CAT 걱정없는 헤어볼',
#  '밥이보약 튼튼한관절',
#  'JB 뉴 베드타임 로션(500ml)',
#  '정말 순한 바디밀크(450ml)',
#  '크리넥스 KF94 4단 마스크',
#  'PACE6 스타일 면도날(4개)',
#  '플로쉴드 옐로우 면도날(4개)',
#  '하이드로8 면도날(8개)',
#  '도브 뷰티 너리싱 바디워시(1kg)',
#  '도브 센스티브 스킨 바디워시(1kg)',
#  '세이 온더바디 고보습 아이리스(900ml)',
#  '오가니스트 히말라야 핑크솔트 바디워시 리프레싱 민트향(865ml)',
#  '해피바스 라벤더 에센스 바디워시(900g)',
#  '도브 뷰티바(4개)',
#  '드봉 스위트로즈(4개)',
#  '해피바스 허브 라벤더 아로마 바(4개)',
#  '쏘피 바디피트 볼록맞춤 날개 중형(32개입)',
#  '좋은느낌 울트라슬림 에어핏쿠션 날개 중형(36개입)',
#  '좋은느낌 좋은순면 울트라 날개 중형(36개입)',
#  '화이트 시크릿홀 날개 중형(36개입)',
#  '려 함빛 극손상엔영양케어 샴푸(550ml)',
#  '미쟝센 퍼펙트세럼 샴푸(680ml)',
#  '엘라스틴 모로칸 아르간 오일 집중영양 샴푸(680ml)',
#  '케라리스 데미지 클리닉 오리지널 샴푸(750ml)',
#  '랩신 핸드워시 센서티브(250ml)',
#  '아이!깨끗해 항균폼 상큼레몬향(250ml)',
#  '려 두피보호 한방염색 짙은 밤색 4.5(60g)',
#  '리엔 흑모비책크림염색 자연갈색(60g)',
#  '미쟝센 쉽고빠른거품염색 3N 흑갈색(40g)',
#  '하기스 매직컴포트 대형 공용 팬티형 4단계(40매)',
#  '하기스 매직컴포트 중형 공용 밴드형 3단계(66매)',
#  '하기스 매직컴포트 특대형 공용 팬티형 5단계(33매)',
#  '메디안 치석 치약 오리지널(3개)',
#  '어드밴스 캐비티 블루(120g)',
#  '어드밴스 캐비티 블루(3개)',
#  '페리오 캐비티케어(3개)',
#  '오랄비 크로스액션(3개입)',
#  '죽염 칫술 잇몸(4개)',
#  '페리오 토탈7 칫솔 힘있는 미세모(4개)',
#  '크리넥스 데코엔소프트 3겹(24롤)',
#  '가그린 오리지널(750ml)',
#  '리스테린 쿨민트(750ml)',
#  '갈치(냉동, 100g)',
#  '갈치(생물, 100g)',
#  '고등어(생물, 300~500g)',
#  '오징어(냉동, 200~300g)',
#  '오징어(생물, 200~300g)',
#  '부세(200~400g)',
#  '참조기(200~400g)',
#  '당근(흙당근, 100g)',
#  '대파(흙대파, 500~800g)',
#  '무(줄기 없는 무, 1.5kg)',
#  '배추(1.5~2kg)',
#  'CJ 행복한콩 국산콩 콩나물(280g)',
#  '국산아작아작콩나물(350g)',
#  'CJ 더안심 건강란(대란 15개)',
#  'CJ 알짜란(대란 15개)',
#  '목초를 먹고 자란 건강한 닭이 낳은 달걀(대란 15개)',
#  '풀무원 동물복지 목초란(대란 10개)',
#  '참프레 동물복지 닭백숙(1.1kg)',
#  '하림 자연실록백숙(830g)',
#  '하림 토종닭백숙(1.05kg)',
#  '돼지고기 목살(100g)',
#  '돼지고기 삼겹살(100g)',
#  '쇠고기 등심(1+등급, 100g)',
#  '쇠고기 등심(1등급, 100g)',
#  '쇠고기 불고기(1+등급, 100g)',
#  '쇠고기 불고기(1등급, 100g)',
#  'CJ 비비고 왕교자(910g)',
#  '해태 오예스(12개입)',
#  '대림선어묵 부산어묵(300g)',
#  '오뚜기 소프트마가린(180g)',
#  '덴마크 오리지널 치즈(14매)',
#  '깨끗한나라 순수 시그니쳐 3겹(30롤)']

# %%
# sorted(li_list)
# Out:
# ['3M 후레쉬 슬라이드 지퍼백 중형 21cm x 16cm x 6cm',
#  '3분 쇠고기짜장 200g',
#  '3분 쇠고기카레 200g',
#  'CJ 더안심 건강란 대란 15개',
#  'CJ 비비고 왕교자 910g',
#  'CJ 알짜란 대란 15개',
#  'CJ 행복한콩 국산콩 콩나물 280g',
#  'JB 뉴 베드타임 로션 500ml',
#  'PACE6 스타일 면도날 4개',
#  '가그린 오리지널 750ml',
#  '갈치 냉동, 100g',
#  '갈치 생물, 100g',
#  '게토레이 레몬 600ml',
#  '고등어 생물, 300~500g',
#  '고향만두 1.08kg',
#  '곰표 밀가루 중력다목적용 1kg',
#  '국산아작아작콩나물 350g',
#  '국산콩두부 부침용 380g',
#  '국산콩두부 찌개용 380g',
#  '국순당 생막걸리 750ml',
#  '국순당 우국생 750ml',
#  '그릴후랑크 600g',
#  '깨끗한나라 순수 시그니쳐 3겹 30롤',
#  '남양 17차 티백 80개입',
#  '남양유업 맛있는우유GT 1L',
#  '농심 새우깡 90g',
#  '농심 신라면 큰사발면 114g',
#  '다우니 고농축 섬유유연제 엑스퍼트 2L',
#  '닥터유 에너지바 40g',
#  '닥터유 에너지바 4개입',
#  '달콤한 베지밀 비 16팩',
#  '달콤한 삼육두유 B',
#  '당근 흙당근, 100g',
#  '대림 게맛살 큰잔치 300g',
#  '대림선어묵 부산어묵 300g',
#  '대파 흙대파, 500~800g',
#  '덴마크 오리지널 치즈 14매',
#  '델몬트 오렌지 100 1.5L',
#  '도브 뷰티 너리싱 바디워시 1kg',
#  '도브 뷰티바 4개',
#  '도브 센스티브 스킨 바디워시 1kg',
#  '동서 아카시아꿀 600g',
#  '동서벌꿀 600g',
#  '동서현미녹차 100개입',
#  '동원 싱싱맛살 실속 500g',
#  '동원 양반 쇠고기죽 287.5g',
#  '동원 양반 전복죽 287.5g',
#  '동원참치 라이트스탠다드 150g',
#  '동원참치 라이트스탠다드 4캔',
#  '돼지고기 목살 100g',
#  '돼지고기 삼겹살 100g',
#  '돼지바 70ml',
#  '드봉 스위트로즈 4개',
#  '드빈치 고칼슘치즈 15매',
#  '들기름 재래 도시락김 12팩',
#  '딸기잼 500g',
#  '때가 쏙 비트 분말세제 6kg',
#  '떠먹는 불가리스 딸기 4개',
#  '랩신 핸드워시 센서티브 250ml',
#  '레드불 에너지 드링크 250ml',
#  '려 두피보호 한방염색 짙은 밤색 4.5 60g',
#  '려 함빛 극손상엔영양케어 샴푸 550ml',
#  '롯데 ABC 초코 187g',
#  '롯데 목캔디 허브민트 217g',
#  '롯데 빅가나 마일드 110g',
#  '롯데 월드콘 바닐라 160ml',
#  '롯데 자일리톨 오리지날 97g',
#  '롯데 핫식스 250ml',
#  '리스테린 쿨민트 750ml',
#  '리엔 흑모비책크림염색 자연갈색 60g',
#  '마미손 고무장갑 중 2세트',
#  '마일드참치 150g',
#  '마일드참치 3개',
#  '마주앙 레드 750ml',
#  '매일두유 담백한 맛 16팩',
#  '매일우유 오리지널 900ml',
#  '매일유업 뼈로가는 칼슘치즈 270g',
#  '맥스 부탄가스 4개',
#  '맥스웰 하우스 오리지날 180개입',
#  '맥심 모카골드 마일드 200개입',
#  '맥심 티오피 마스터 라떼 275ml',
#  '머거본 꿀땅콩 135g',
#  '메디안 치석 치약 오리지널 3개',
#  '메로나 75ml',
#  '메소드 주방세제 핑크 532ml',
#  '목초를 먹고 자란 건강한 닭이 낳은 달걀 대란 15개',
#  '몬스터 에너지 355ml',
#  '몽쉘 크림 384g',
#  '무 줄기 없는 무, 1.5kg',
#  '무균무때 세정제 욕실용 900ml',
#  '물먹는하마 3개입',
#  '미넷메이드 오렌지 1.5L',
#  '미쟝센 쉽고빠른거품염색 3N 흑갈색 40g',
#  '미쟝센 퍼펙트세럼 샴푸 680ml',
#  '바리스타룰스 콜드브루 블랙 325ml',
#  '바이오 플레인 요거트 4개',
#  '밥이보약 CAT 걱정없는 헤어볼',
#  '밥이보약 튼튼한관절',
#  '배추 1.5~2kg',
#  '백설 5가지 재료 부침가루 1kg',
#  '백설 건강발효 사과식초 800ml',
#  '백설 건강발효 현미식초 800ml',
#  '백설 구운소금 500g',
#  '백설 그릴 비엔나 720g',
#  '백설 소면 900g',
#  '백설 식용유 1.5L',
#  '백설 자른 햇당면 300g',
#  '백설 자일로스 설탕 1kg',
#  '백설 진한참기름',
#  '백설 찰밀가루 1kg',
#  '백설 하얀설탕 1kg',
#  '보노 콘스프 3개입',
#  '보노 포르치니버섯스프 3개입',
#  '복음자리 딸기잼 370g',
#  '부세 200~400g',
#  '불가리스 4개',
#  '비비고 사골곰탕 500g',
#  '비비고 소고기죽 280g',
#  '비비고 왕교자 1.05kg',
#  '비비고 육개장 500g',
#  '비비고 전복죽 280g',
#  '비타500 10개입',
#  '비트 트리플 액션 2.8L',
#  '빙그레 참붕어 싸만코 150ml',
#  '사조참치 살코기 안심따개 4캔',
#  '산들애 국내산 해물 250g',
#  '삼다수 2L',
#  '삼다수 2L*6개',
#  '삼다수 500ml',
#  '삼다수 500ml*20개',
#  '삼립호떡 미니꿀호떡 16개입',
#  '삼양라면 5개입',
#  '삼호 안심 김밥맛살 264g',
#  '삼호 안심 부산어묵 400g',
#  '샘표 시골집 토장 900g',
#  '생야채돼지고기물만두 800g',
#  '샤프란 네이처 섬유탈취제 프레쉬 민트 300ml',
#  '샤프란 아우라 초고농축 섬유유연제 홀리데이판타지 2.3L',
#  '서울우유 체다슬라이스치즈 400g',
#  '서울우유 흰우유 1L',
#  '서울장수생막걸리 750ml',
#  '세이 온더바디 고보습 아이리스 900ml',
#  '손잡이 크린백 35cm x 45cm',
#  '쇠고기 등심 1+등급, 100g',
#  '쇠고기 등심 1등급, 100g',
#  '쇠고기 불고기 1+등급, 100g',
#  '쇠고기 불고기 1등급, 100g',
#  '순창 오리지널 우리쌀 찰고추장 1kg',
#  '순창 재래식안심생된장 1kg',
#  '스파크 분말세제 6kg',
#  '스팸 클래식 200g',
#  '스페셜K 오리지널 480g',
#  '스프라이트 1.5L',
#  '신라면 5개입',
#  '썬 부탄가스 4개',
#  '쏘피 바디피트 볼록맞춤 날개 중형 32개입',
#  '아이!깨끗해 항균폼 상큼레몬향 250ml',
#  '아이비 270g',
#  '아이시스 2L',
#  '아이시스 500ml',
#  '아카페라 아메리카노 240ml',
#  '앱솔루트 명작 3단계 800g',
#  '양반 들기름이 그윽한 김 16팩',
#  '양조간장 501 500ml',
#  '어드밴스 캐비티 블루 120g',
#  '어드밴스 캐비티 블루 3개',
#  '에프킬라 에어로졸 무향 500ml',
#  '엘라스틴 모로칸 아르간 오일 집중영양 샴푸 680ml',
#  '옛날 자른당면 300g',
#  '옛날국수 소면 900g',
#  '오가니스트 히말라야 핑크솔트 바디워시 리프레싱 민트향 865ml',
#  '오뚜기 3분 백세카레 약간 매운맛 200g',
#  '오뚜기 간편 미역국 5개입',
#  '오뚜기 간편 북엇국 5개입',
#  '오뚜기 고소한 골드 마요네즈 500g',
#  '오뚜기 맛있는 쇠고기미역국밥 162g',
#  '오뚜기 부침가루 1kg',
#  '오뚜기 사과식초 900ml',
#  '오뚜기 소프트마가린 180g',
#  '오뚜기 옛날 사골곰탕 350g',
#  '오뚜기 옛날 육개장 300g',
#  '오뚜기 참기름 320ml',
#  '오뚜기 참깨라면 컵 110g',
#  '오뚜기 컵밥 제육덮밥 310g',
#  '오뚜기 콘마가린 180g',
#  '오뚜기 콩기름 100% 900ml',
#  '오뚜기 크림스프 80g',
#  '오뚜기 토마토 케찹 500g',
#  '오뚜기밥 210g',
#  '오뚜기밥 3개입',
#  '오뚜기밥 6개입 ',
#  '오뚜기카레 순한맛 100g',
#  '오랄비 크로스액션 3개입',
#  '오로나민C 10개입',
#  '오리온 초코파이 18개입',
#  '오리온 통아몬드 캔디 90g',
#  '오리온 포카칩 오리지널 66g',
#  '오징어 냉동, 200~300g',
#  '오징어 생물, 200~300g',
#  '요플레 오리지널 4개',
#  '유한락스 레귤러 1.8L',
#  '유한락스 욕실청소용 1800ml',
#  '유한락스 후레쉬 1.5L',
#  '의성마늘 빅그릴 비엔나 600g',
#  '의성마늘 한입슬라이스햄 60g',
#  '이오 5개',
#  '임페리얼 드림 XO 3단계 800g',
#  '자연퐁 솔잎 490ml',
#  '자유시간 36g',
#  '자유시간 5개입',
#  '정말 순한 바디밀크 450ml',
#  '정통크림빵 3개입',
#  '제주 위트 에일 500ml',
#  '좋은느낌 울트라슬림 에어핏쿠션 날개 중형 36개입',
#  '좋은느낌 좋은순면 울트라 날개 중형 36개입',
#  '주부9단 슬라이스햄 300g',
#  '주부9단 프랑크소시지 900g',
#  '죽염 칫술 잇몸 4개',
#  '지퍼락 지퍼백 냉장 중형 20매',
#  '진간장 금F3 930ml',
#  '진라면 순한맛 5개입',
#  '진로 와인 500ml',
#  '참이슬 클래식 360ml',
#  '참이슬 후레쉬 360ml',
#  '참조기 200~400g',
#  '참크래커 280g',
#  '참프레 동물복지 닭백숙 1.1kg',
#  '처음처럼 360ml',
#  '청정원 고소한 마요네즈 500g',
#  '청정원 맛선생 국내산해물 250g',
#  '청정원 미원 맛소금 500g',
#  '청정원 발사믹 드레싱',
#  '청정원 순창 양념듬뿍 쌈장 500g',
#  '청정원 오리엔탈 드레싱',
#  '청정원 진한 토마토 케찹 500g',
#  '청정원 카레여왕 구운마늘&amp;양파 108g',
#  '청정원 카레여왕 비프카레 160g',
#  '체다치즈 15매',
#  '칠성사이다 제로 1.5L',
#  '카누 마일드 로스트 아메리카노 30개입',
#  '카스 프레쉬 500ml',
#  '카스 프레쉬 6캔',
#  '컴배트 스피드 에어졸 500ml',
#  '케라리스 데미지 클리닉 오리지널 샴푸 750ml',
#  '켈로그 레드베리 에너지바 4개입',
#  '켈로그 콘푸로스트 600g',
#  '코디 키친타월 6롤',
#  '코카콜라 1.8L',
#  '큐원 하얀설탕 1kg',
#  '크리넥스 KF94 4단 마스크',
#  '크리넥스 데코엔소프트 3겹 24롤',
#  '크리넥스 안심 키친타월 6롤',
#  '크린랩 22cm x 50m',
#  '크린랩 30cm x 50m',
#  '크린랩 고무장갑 중 2세트',
#  '크린롤백 25cm x 35cm',
#  '크린지퍼백 18cm x 20cm',
#  '테라 500ml',
#  '테크 UP 분말세제 4kg',
#  '테크 베이킹소다 액체세제 3L',
#  '투게더 오리지널 바닐라 900ml',
#  '파스퇴르우유 후레쉬 930ml',
#  '파워에이드 마운틴블라스트 520ml',
#  '팔도 왕뚜껑 110g',
#  '퍼실 파워젤 액체 드럼용 2.7L',
#  '퍼실 파워젤 액체 일반용 2.7L',
#  '페리오 캐비티케어 3개',
#  '페리오 토탈7 칫솔 힘있는 미세모 4개',
#  '페브리즈 상쾌한향 370ml',
#  '페브리즈 상쾌한향 900ml',
#  '펩시콜라 1.8L',
#  '포스트 콘푸라이트 600g',
#  '포카리스웨트 620ml',
#  '포테토칩 오리지날 125g',
#  '풀무원 동물복지 목초란 대란 10개',
#  '프렌치카페 카페믹스 220개입',
#  '프리미엄 산양분유 1단계 800g',
#  '프릴 시크릿 오브 베이킹소다 퓨어레몬향 750ml',
#  '플로쉴드 옐로우 면도날 4개',
#  '피죤 섬유유연제 핑크로즈 2.1L',
#  '피죤 습기제로 8개입',
#  '하기스 매직컴포트 대형 공용 팬티형 4단계 40매',
#  '하기스 매직컴포트 중형 공용 밴드형 3단계 66매',
#  '하기스 매직컴포트 특대형 공용 팬티형 5단계 33매',
#  '하림 자연실록백숙 830g',
#  '하림 토종닭백숙 1.05kg',
#  '하이드로8 면도날 8개',
#  '하이트 엑스트라 콜드 500ml',
#  '하이트 엑스트라 콜드 6캔',
#  '핫브레이크 미니 714g',
#  '항균 트리오 973ml',
#  '해찬들 사계절 쌈장 500g',
#  '해찬들 우리쌀태양초골드 1kg',
#  '해찬들 재래식 된장 1kg',
#  '해태 바밤바 63ml',
#  '해태 부라보콘 화이트바닐라 140ml',
#  '해태 오예스 12개입',
#  '해표 꽃소금 1kg',
#  '해표 맑고 신선한 식용유 900ml',
#  '해표 순창궁 양념쌈장 500g',
#  '해표 순창궁 태양초 100% 우리햅쌀 고추장 1.8kg',
#  '해피바스 라벤더 에센스 바디워시 900g',
#  '해피바스 허브 라벤더 아로마 바 4개',
#  '햇반 210g',
#  '햇반 3개입',
#  '햇반 6개입',
#  '햇반 컵반 고추장 제육덮밥 250g',
#  '햇반 컵반 미역국밥 167g',
#  '행복한콩 부침두부 300g',
#  '행복한콩 찌개두부 300g',
#  '허니버터아몬드 210g',
#  '홈스타 락스와세제 후로랄파인 750ml',
#  '홈스타 욕실용 세정제 900ml',
#  '홈키파 수성 에어졸 500ml',
#  '화이트 시크릿홀 날개 중형 36개입']

# %%
## 괄호를 제거한 유니크 품목들을 문자열로 전환


pr = '|'.join(products)
pr
# Out:
# '머거본 꿀땅콩(135g)|허니버터아몬드(210g)|백설 소면(900g)|옛날국수 소면(900g)|고향만두(1.08kg)|비비고 왕교자(1.05kg)|생야채돼지고기물만두(800g)|백설 자른 햇당면(300g)|옛날 자른당면(300g)|국산콩두부 부침용(380g)|국산콩두부 찌개용(380g)|행복한콩 부침두부(300g)|행복한콩 찌개두부(300g)|삼양라면(5개입)|신라면(5개입)|진라면 순한맛(5개입)|곰표 밀가루 중력다목적용(1kg)|백설 찰밀가루(1kg)|백설 5가지 재료 부침가루(1kg)|오뚜기 부침가루(1kg)|삼립호떡 미니꿀호떡(16개입)|정통크림빵(3개입)|보노 콘스프(3개입)|보노 포르치니버섯스프(3개입)|오뚜기 크림스프(80g)|스페셜K 오리지널(480g)|켈로그 콘푸로스트(600g)|포스트 콘푸라이트(600g)|오뚜기 간편 미역국(5개입)|오뚜기 간편 북엇국(5개입)|3분 쇠고기짜장(200g)|3분 쇠고기카레(200g)|오뚜기 3분 백세카레 약간 매운맛(200g)|청정원 카레여왕 비프카레(160g)|오뚜기밥(210g)|오뚜기밥(3개입)|오뚜기밥(6개입) |햇반(210g)|햇반(3개입)|햇반(6개입)|동원 양반 쇠고기죽(287.5g)|동원 양반 전복죽(287.5g)|비비고 소고기죽(280g)|비비고 전복죽(280g)|농심 신라면 큰사발면(114g)|오뚜기 참깨라면 컵(110g)|팔도 왕뚜껑(110g)|오뚜기 맛있는 쇠고기미역국밥(162g)|오뚜기 컵밥 제육덮밥(310g)|햇반 컵반 고추장 제육덮밥(250g)|햇반 컵반 미역국밥(167g)|비비고 사골곰탕(500g)|비비고 육개장(500g)|오뚜기 옛날 사골곰탕(350g)|오뚜기 옛날 육개장(300g)|오리온 포카칩 오리지널(66g)|포테토칩 오리지날(125g)|롯데 자일리톨 오리지날(97g)|빙그레 참붕어 싸만코(150ml)|아이비(270g)|참크래커(280g)|돼지바(70ml)|메로나(75ml)|해태 바밤바(63ml)|롯데 목캔디 허브민트(217g)|오리온 통아몬드 캔디(90g)|농심 새우깡(90g)|롯데 월드콘 바닐라(160ml)|투게더 오리지널 바닐라(900ml)|해태 부라보콘 화이트바닐라(140ml)|닥터유 에너지바(40g)|닥터유 에너지바(4개입)|켈로그 레드베리 에너지바(4개입)|자유시간(36g)|자유시간(5개입)|핫브레이크 미니(714g)|몽쉘 크림(384g)|오리온 초코파이(18개입)|롯데 ABC 초코(187g)|롯데 빅가나 마일드(110g)|들기름 재래 도시락김(12팩)|양반 들기름이 그윽한 김(16팩)|대림 게맛살 큰잔치(300g)|동원 싱싱맛살 실속(500g)|삼호 안심 김밥맛살(264g)|삼호 안심 부산어묵(400g)|동원참치 라이트스탠다드(150g)|동원참치 라이트스탠다드(4캔)|마일드참치(150g)|마일드참치(3개)|사조참치 살코기 안심따개(4캔)|양조간장 501(500ml)|진간장 금F3(930ml)|순창 오리지널 우리쌀 찰고추장(1kg)|해찬들 우리쌀태양초골드(1kg)|해표 순창궁 태양초 100% 우리햅쌀 고추장(1.8kg)|동서 아카시아꿀(600g)|동서벌꿀(600g)|샘표 시골집 토장(900g)|순창 재래식안심생된장(1kg)|해찬들 재래식 된장(1kg)|청정원 발사믹 드레싱|청정원 오리엔탈 드레싱|오뚜기 고소한 골드 마요네즈(500g)|청정원 고소한 마요네즈(500g)|백설 자일로스 설탕(1kg)|백설 하얀설탕(1kg)|큐원 하얀설탕(1kg)|백설 구운소금(500g)|청정원 미원 맛소금(500g)|해표 꽃소금(1kg)|백설 식용유(1.5L)|오뚜기 콩기름 100%(900ml)|해표 맑고 신선한 식용유(900ml)|백설 건강발효 사과식초(800ml)|백설 건강발효 현미식초(800ml)|오뚜기 사과식초(900ml)|청정원 순창 양념듬뿍 쌈장(500g)|해찬들 사계절 쌈장(500g)|해표 순창궁 양념쌈장(500g)|딸기잼(500g)|복음자리 딸기잼(370g)|백설 진한참기름|오뚜기 참기름(320ml)|오뚜기카레 순한맛(100g)|청정원 카레여왕 구운마늘&amp;양파(108g)|오뚜기 토마토 케찹(500g)|청정원 진한 토마토 케찹(500g)|산들애 국내산 해물(250g)|청정원 맛선생 국내산해물(250g)|달콤한 베지밀 비(16팩)|달콤한 삼육두유 B|매일두유 담백한 맛(16팩)|국순당 생막걸리(750ml)|국순당 우국생(750ml)|서울장수생막걸리(750ml)|제주 위트 에일(500ml)|카스 프레쉬(500ml)|카스 프레쉬(6캔)|테라(500ml)|하이트 엑스트라 콜드(500ml)|하이트 엑스트라 콜드(6캔)|비타500(10개입)|오로나민C(10개입)|스프라이트(1.5L)|칠성사이다 제로(1.5L)|삼다수(2L)|삼다수(500ml)|아이시스(2L)|아이시스(500ml)|삼다수(2L*6개)|삼다수(500ml*20개)|참이슬 클래식(360ml)|참이슬 후레쉬(360ml)|처음처럼(360ml)|레드불 에너지 드링크(250ml)|롯데 핫식스(250ml)|몬스터 에너지(355ml)|게토레이 레몬(600ml)|파워에이드 마운틴블라스트(520ml)|포카리스웨트(620ml)|델몬트 오렌지 100(1.5L)|미넷메이드 오렌지(1.5L)|남양 17차 티백(80개입)|동서현미녹차(100개입)|맥심 티오피 마스터 라떼(275ml)|바리스타룰스 콜드브루 블랙(325ml)|아카페라 아메리카노(240ml)|맥스웰 하우스 오리지날(180개입)|맥심 모카골드 마일드(200개입)|카누 마일드 로스트 아메리카노(30개입)|프렌치카페 카페믹스(220개입)|코카콜라(1.8L)|펩시콜라(1.8L)|마주앙 레드(750ml)|진로 와인(500ml)|오뚜기 콘마가린(180g)|떠먹는 불가리스 딸기(4개)|바이오 플레인 요거트(4개)|불가리스(4개)|요플레 오리지널(4개)|이오(5개)|앱솔루트 명작 3단계(800g)|임페리얼 드림 XO 3단계(800g)|프리미엄 산양분유 1단계(800g)|그릴후랑크(600g)|백설 그릴 비엔나(720g)|의성마늘 빅그릴 비엔나(600g)|주부9단 프랑크소시지(900g)|남양유업 맛있는우유GT(1L)|매일우유 오리지널(900ml)|서울우유 흰우유(1L)|파스퇴르우유 후레쉬(930ml)|드빈치 고칼슘치즈(15매)|매일유업 뼈로가는 칼슘치즈(270g)|서울우유 체다슬라이스치즈(400g)|체다치즈(15매)|스팸 클래식(200g)|의성마늘 한입슬라이스햄(60g)|주부9단 슬라이스햄(300g)|마미손 고무장갑 중(2세트)|크린랩 고무장갑 중(2세트)|크린랩(22cm x 50m)|크린랩(30cm x 50m)|맥스 부탄가스(4개)|썬 부탄가스(4개)|무균무때 세정제 욕실용(900ml)|유한락스 레귤러(1.8L)|유한락스 욕실청소용(1800ml)|유한락스 후레쉬(1.5L)|홈스타 락스와세제 후로랄파인(750ml)|홈스타 욕실용 세정제(900ml)|에프킬라 에어로졸 무향(500ml)|컴배트 스피드 에어졸(500ml)|홈키파 수성 에어졸(500ml)|다우니 고농축 섬유유연제 엑스퍼트(2L)|샤프란 아우라 초고농축 섬유유연제 홀리데이판타지(2.3L)|피죤 섬유유연제 핑크로즈(2.1L)|샤프란 네이처 섬유탈취제 프레쉬 민트(300ml)|페브리즈 상쾌한향(370ml)|페브리즈 상쾌한향(900ml)|때가 쏙 비트 분말세제(6kg)|비트 트리플 액션(2.8L)|스파크 분말세제(6kg)|테크 UP 분말세제(4kg)|테크 베이킹소다 액체세제(3L)|퍼실 파워젤 액체 드럼용(2.7L)|퍼실 파워젤 액체 일반용(2.7L)|물먹는하마(3개입)|피죤 습기제로(8개입)|3M 후레쉬 슬라이드 지퍼백 중형(21cm x 16cm x 6cm)|손잡이 크린백(35cm x 45cm)|지퍼락 지퍼백 냉장 중형(20매)|크린롤백(25cm x 35cm)|크린지퍼백(18cm x 20cm)|메소드 주방세제 핑크(532ml)|자연퐁 솔잎(490ml)|프릴 시크릿 오브 베이킹소다 퓨어레몬향(750ml)|항균 트리오(973ml)|코디 키친타월(6롤)|크리넥스 안심 키친타월(6롤)|밥이보약 CAT 걱정없는 헤어볼|밥이보약 튼튼한관절|JB 뉴 베드타임 로션(500ml)|정말 순한 바디밀크(450ml)|크리넥스 KF94 4단 마스크|PACE6 스타일 면도날(4개)|플로쉴드 옐로우 면도날(4개)|하이드로8 면도날( ...

# %%
'|'.join(products)
# Out:
# '머거본 꿀땅콩(135g)|허니버터아몬드(210g)|백설 소면(900g)|옛날국수 소면(900g)|고향만두(1.08kg)|비비고 왕교자(1.05kg)|생야채돼지고기물만두(800g)|백설 자른 햇당면(300g)|옛날 자른당면(300g)|국산콩두부 부침용(380g)|국산콩두부 찌개용(380g)|행복한콩 부침두부(300g)|행복한콩 찌개두부(300g)|삼양라면(5개입)|신라면(5개입)|진라면 순한맛(5개입)|곰표 밀가루 중력다목적용(1kg)|백설 찰밀가루(1kg)|백설 5가지 재료 부침가루(1kg)|오뚜기 부침가루(1kg)|삼립호떡 미니꿀호떡(16개입)|정통크림빵(3개입)|보노 콘스프(3개입)|보노 포르치니버섯스프(3개입)|오뚜기 크림스프(80g)|스페셜K 오리지널(480g)|켈로그 콘푸로스트(600g)|포스트 콘푸라이트(600g)|오뚜기 간편 미역국(5개입)|오뚜기 간편 북엇국(5개입)|3분 쇠고기짜장(200g)|3분 쇠고기카레(200g)|오뚜기 3분 백세카레 약간 매운맛(200g)|청정원 카레여왕 비프카레(160g)|오뚜기밥(210g)|오뚜기밥(3개입)|오뚜기밥(6개입) |햇반(210g)|햇반(3개입)|햇반(6개입)|동원 양반 쇠고기죽(287.5g)|동원 양반 전복죽(287.5g)|비비고 소고기죽(280g)|비비고 전복죽(280g)|농심 신라면 큰사발면(114g)|오뚜기 참깨라면 컵(110g)|팔도 왕뚜껑(110g)|오뚜기 맛있는 쇠고기미역국밥(162g)|오뚜기 컵밥 제육덮밥(310g)|햇반 컵반 고추장 제육덮밥(250g)|햇반 컵반 미역국밥(167g)|비비고 사골곰탕(500g)|비비고 육개장(500g)|오뚜기 옛날 사골곰탕(350g)|오뚜기 옛날 육개장(300g)|오리온 포카칩 오리지널(66g)|포테토칩 오리지날(125g)|롯데 자일리톨 오리지날(97g)|빙그레 참붕어 싸만코(150ml)|아이비(270g)|참크래커(280g)|돼지바(70ml)|메로나(75ml)|해태 바밤바(63ml)|롯데 목캔디 허브민트(217g)|오리온 통아몬드 캔디(90g)|농심 새우깡(90g)|롯데 월드콘 바닐라(160ml)|투게더 오리지널 바닐라(900ml)|해태 부라보콘 화이트바닐라(140ml)|닥터유 에너지바(40g)|닥터유 에너지바(4개입)|켈로그 레드베리 에너지바(4개입)|자유시간(36g)|자유시간(5개입)|핫브레이크 미니(714g)|몽쉘 크림(384g)|오리온 초코파이(18개입)|롯데 ABC 초코(187g)|롯데 빅가나 마일드(110g)|들기름 재래 도시락김(12팩)|양반 들기름이 그윽한 김(16팩)|대림 게맛살 큰잔치(300g)|동원 싱싱맛살 실속(500g)|삼호 안심 김밥맛살(264g)|삼호 안심 부산어묵(400g)|동원참치 라이트스탠다드(150g)|동원참치 라이트스탠다드(4캔)|마일드참치(150g)|마일드참치(3개)|사조참치 살코기 안심따개(4캔)|양조간장 501(500ml)|진간장 금F3(930ml)|순창 오리지널 우리쌀 찰고추장(1kg)|해찬들 우리쌀태양초골드(1kg)|해표 순창궁 태양초 100% 우리햅쌀 고추장(1.8kg)|동서 아카시아꿀(600g)|동서벌꿀(600g)|샘표 시골집 토장(900g)|순창 재래식안심생된장(1kg)|해찬들 재래식 된장(1kg)|청정원 발사믹 드레싱|청정원 오리엔탈 드레싱|오뚜기 고소한 골드 마요네즈(500g)|청정원 고소한 마요네즈(500g)|백설 자일로스 설탕(1kg)|백설 하얀설탕(1kg)|큐원 하얀설탕(1kg)|백설 구운소금(500g)|청정원 미원 맛소금(500g)|해표 꽃소금(1kg)|백설 식용유(1.5L)|오뚜기 콩기름 100%(900ml)|해표 맑고 신선한 식용유(900ml)|백설 건강발효 사과식초(800ml)|백설 건강발효 현미식초(800ml)|오뚜기 사과식초(900ml)|청정원 순창 양념듬뿍 쌈장(500g)|해찬들 사계절 쌈장(500g)|해표 순창궁 양념쌈장(500g)|딸기잼(500g)|복음자리 딸기잼(370g)|백설 진한참기름|오뚜기 참기름(320ml)|오뚜기카레 순한맛(100g)|청정원 카레여왕 구운마늘&amp;양파(108g)|오뚜기 토마토 케찹(500g)|청정원 진한 토마토 케찹(500g)|산들애 국내산 해물(250g)|청정원 맛선생 국내산해물(250g)|달콤한 베지밀 비(16팩)|달콤한 삼육두유 B|매일두유 담백한 맛(16팩)|국순당 생막걸리(750ml)|국순당 우국생(750ml)|서울장수생막걸리(750ml)|제주 위트 에일(500ml)|카스 프레쉬(500ml)|카스 프레쉬(6캔)|테라(500ml)|하이트 엑스트라 콜드(500ml)|하이트 엑스트라 콜드(6캔)|비타500(10개입)|오로나민C(10개입)|스프라이트(1.5L)|칠성사이다 제로(1.5L)|삼다수(2L)|삼다수(500ml)|아이시스(2L)|아이시스(500ml)|삼다수(2L*6개)|삼다수(500ml*20개)|참이슬 클래식(360ml)|참이슬 후레쉬(360ml)|처음처럼(360ml)|레드불 에너지 드링크(250ml)|롯데 핫식스(250ml)|몬스터 에너지(355ml)|게토레이 레몬(600ml)|파워에이드 마운틴블라스트(520ml)|포카리스웨트(620ml)|델몬트 오렌지 100(1.5L)|미넷메이드 오렌지(1.5L)|남양 17차 티백(80개입)|동서현미녹차(100개입)|맥심 티오피 마스터 라떼(275ml)|바리스타룰스 콜드브루 블랙(325ml)|아카페라 아메리카노(240ml)|맥스웰 하우스 오리지날(180개입)|맥심 모카골드 마일드(200개입)|카누 마일드 로스트 아메리카노(30개입)|프렌치카페 카페믹스(220개입)|코카콜라(1.8L)|펩시콜라(1.8L)|마주앙 레드(750ml)|진로 와인(500ml)|오뚜기 콘마가린(180g)|떠먹는 불가리스 딸기(4개)|바이오 플레인 요거트(4개)|불가리스(4개)|요플레 오리지널(4개)|이오(5개)|앱솔루트 명작 3단계(800g)|임페리얼 드림 XO 3단계(800g)|프리미엄 산양분유 1단계(800g)|그릴후랑크(600g)|백설 그릴 비엔나(720g)|의성마늘 빅그릴 비엔나(600g)|주부9단 프랑크소시지(900g)|남양유업 맛있는우유GT(1L)|매일우유 오리지널(900ml)|서울우유 흰우유(1L)|파스퇴르우유 후레쉬(930ml)|드빈치 고칼슘치즈(15매)|매일유업 뼈로가는 칼슘치즈(270g)|서울우유 체다슬라이스치즈(400g)|체다치즈(15매)|스팸 클래식(200g)|의성마늘 한입슬라이스햄(60g)|주부9단 슬라이스햄(300g)|마미손 고무장갑 중(2세트)|크린랩 고무장갑 중(2세트)|크린랩(22cm x 50m)|크린랩(30cm x 50m)|맥스 부탄가스(4개)|썬 부탄가스(4개)|무균무때 세정제 욕실용(900ml)|유한락스 레귤러(1.8L)|유한락스 욕실청소용(1800ml)|유한락스 후레쉬(1.5L)|홈스타 락스와세제 후로랄파인(750ml)|홈스타 욕실용 세정제(900ml)|에프킬라 에어로졸 무향(500ml)|컴배트 스피드 에어졸(500ml)|홈키파 수성 에어졸(500ml)|다우니 고농축 섬유유연제 엑스퍼트(2L)|샤프란 아우라 초고농축 섬유유연제 홀리데이판타지(2.3L)|피죤 섬유유연제 핑크로즈(2.1L)|샤프란 네이처 섬유탈취제 프레쉬 민트(300ml)|페브리즈 상쾌한향(370ml)|페브리즈 상쾌한향(900ml)|때가 쏙 비트 분말세제(6kg)|비트 트리플 액션(2.8L)|스파크 분말세제(6kg)|테크 UP 분말세제(4kg)|테크 베이킹소다 액체세제(3L)|퍼실 파워젤 액체 드럼용(2.7L)|퍼실 파워젤 액체 일반용(2.7L)|물먹는하마(3개입)|피죤 습기제로(8개입)|3M 후레쉬 슬라이드 지퍼백 중형(21cm x 16cm x 6cm)|손잡이 크린백(35cm x 45cm)|지퍼락 지퍼백 냉장 중형(20매)|크린롤백(25cm x 35cm)|크린지퍼백(18cm x 20cm)|메소드 주방세제 핑크(532ml)|자연퐁 솔잎(490ml)|프릴 시크릿 오브 베이킹소다 퓨어레몬향(750ml)|항균 트리오(973ml)|코디 키친타월(6롤)|크리넥스 안심 키친타월(6롤)|밥이보약 CAT 걱정없는 헤어볼|밥이보약 튼튼한관절|JB 뉴 베드타임 로션(500ml)|정말 순한 바디밀크(450ml)|크리넥스 KF94 4단 마스크|PACE6 스타일 면도날(4개)|플로쉴드 옐로우 면도날(4개)|하이드로8 면도날( ...

# %%
present_prod['상품명']
# Out:
# 0          깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 1                      깨끗한나라 순수 시그니처 3겹 28m 30롤, 1개
# 2          깨끗한나라 순수 시그니처 3겹 28m30롤 X 1팩 화장지, 단품, 단품
# 3           깨끗한나라 순수 시그니처 3겹데코 28m 30롤 X 1팩, 단품, 단품
# 4                   깨끗한나라 순수 시그니처 3겹 화장지 28m 30롤 휴지
#                            ...
# 8923                          상세설명참고 머거본 꿀땅콩 캔 135g
# 8924                             [머거본] 꿀땅콩 135g, 단품
# 8925    머거본 꿀땅콩 135g 식품 > 신선식품 건과/견과류 견과류 일반땅콩, 1개입
# 8926                   [BIGHAND] 머거본 알땅콩 캔 135g, 1개
# 8927                            머거본 알땅콩(캔) 135g, 1개
# Name: 상품명, Length: 8928, dtype: object

# %%
sum(present_prod['상품명'].str.contains('|'.join(products)))
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_580/700602633.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   sum(present_prod['상품명'].str.contains('|'.join(products)))
# 155

# %%
present_prod['상품명'].str.contains('|'.join(products))[present_prod['상품명'].str.contains('|'.join(products))]
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_580/2692802357.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   present_prod['상품명'].str.contains('|'.join(products))[present_prod['상품명'].str.contains('|'.join(products))]
# 798     True
# 814     True
# 834     True
# 846     True
# 1741    True
#         ...
# 8471    True
# 8475    True
# 8476    True
# 8477    True
# 8868    True
# Name: 상품명, Length: 155, dtype: bool

# %%
## 유니크 품목이 포함돼있는 상품명(크롤링 해서 뽑아온 유니크 품목당 모든 제품들)을 추출

bool_idx = present_prod['상품명'].str.contains('|'.join(products))
present_prod[bool_idx]
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_580/1274840262.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   bool_idx = present_prod['상품명'].str.contains('|'.join(products))
#                                                     상품명      가격
# 798               리스테린 쿨민트750ml-2개 (1+1)무료배송 구강청결제, 1세트  12,250
# 814     리스테린 쿨민트750ml+100ml+100ml 대용량 구강청결제 구취제거 가글 가그린   9,980
# 834   Dentalcare 가그린 오리지널750ml/ 충치예방/ 대용량, 가그린오리지널 7...  12,840
# 846    Dentalcare 가그린 오리지널750ml 충치예방 대용량, 가그린오리지널 750ml  11,310
# 1741                     크리넥스 KF94 4단 마스크 대형 1매, 단품, 단품   1,330
# ...                                                 ...     ...
# 8471              (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비, 1   2,910
# 8475                             (면)CJ백설 찰밀가루1kg, 본제품구매   2,480
# 8476         (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비, 하이니몰 1   2,430
# 8477              (면)CJ백설 찰밀가루1kg 밀가루 박력 중력 찰 부침 수제비, 1   2,370
# 8868  길림양행HBAF 대용량 29종 허니버터아몬드 군옥수수 와사비 마늘빵 당근케이크 흑임...   5,390
#
# [155 rows x 2 columns]

# %%
for p in products:
#     print(i)
    if p.strip() in present_prod[bool_idx]['상품명'].loc[814].strip():
        print(p)

# %%
present_prod[bool_idx]['상품명'].apply(lambda x : x if prod in x else np.nan)
# Out:
# 2      NaN
# 6      NaN
# 9      NaN
# 15     NaN
# 18     NaN
#         ..
# 8233   NaN
# 8515   NaN
# 8517   NaN
# 8530   NaN
# 8533   NaN
# Name: 상품명, Length: 703, dtype: float64

# %%
present_prod[bool_idx]
# Out:
#                                                     상품명      가격
# 2           머거본 꿀땅콩 135g 식품 > 신선식품 건과/견과류 견과류 일반땅콩, 1개입   1,980
# 6                                머거본 꿀땅콩 135g, 상세페이지 참조   2,330
# 9     머거본 꿀땅콩 135g 너트 피넛 캔 안주 허니 맛땅콩, 1N5R_머거본 꿀땅콩 135g   3,000
# 15                               머거본 꿀땅콩 135g, 상세페이지 참조   4,800
# 18                                    머거본 꿀땅콩 135g, 3개입   5,310
# ...                                                 ...     ...
# 8233                                삼양 원조 삼양라면 5개입, 15개   7,540
# 8515  CJ 비비고 왕교자 1.05kg x 2봉+수제고기만두 400g x 2봉, 없음, 상...  27,320
# 8517                                과자 해태 오예스 12개입 336g   4,410
# 8530           해태 오예스 12개입 (360g), 옵션2 - 신선포장 (아이스박스포장)   9,170
# 8533  해태 오예스 12개입 360g +오리온 초코파이 468g 초콜릿 케이크 파이 묶음,...   9,500
#
# [703 rows x 2 columns]

# %%
def prod_split(x):
    try:
        for pro in prods:
            return x.split(pro)[0]
    except:
        return x

# %%
prod_ar = present_prod[bool_idx]
prod_ar.상품명.apply(prod_split)
# Out:
# 2             머거본 꿀땅콩 135g 식품 > 신선식품 건과/견과류 견과류 일반땅콩, 1개입
# 6                                  머거본 꿀땅콩 135g, 상세페이지 참조
# 9       머거본 꿀땅콩 135g 너트 피넛 캔 안주 허니 맛땅콩, 1N5R_머거본 꿀땅콩 135g
# 15                                 머거본 꿀땅콩 135g, 상세페이지 참조
# 18                                      머거본 꿀땅콩 135g, 3개입
#                               ...
# 8233                                  삼양 원조 삼양라면 5개입, 15개
# 8515    CJ 비비고 왕교자 1.05kg x 2봉+수제고기만두 400g x 2봉, 없음, 상...
# 8517                                  과자 해태 오예스 12개입 336g
# 8530             해태 오예스 12개입 (360g), 옵션2 - 신선포장 (아이스박스포장)
# 8533    해태 오예스 12개입 360g +오리온 초코파이 468g 초콜릿 케이크 파이 묶음,...
# Name: 상품명, Length: 703, dtype: object

# %%
prod_ar.iloc[3]
# Out:
# 상품명    CJ 비비고 왕교자 1.05kg x 2봉+수제고기만두 400g x 2봉, 없음, 상...
# 가격                                                27,320
# Name: 107, dtype: object

# %%
# for prod in prods:
#     url = 'https://www.coupang.com/np/search?rocketAll=false&q={}&brand=&offerCondition=&filter=&availableDeliveryFilter=&filterType=&isPriceRange=false&priceRange=&minPrice=&maxPrice=&page=1&trcid=&traid=&filterSetByUser=true&channel=user&backgroundColor=&searchProductCount=326&component=&rating=0&sorter=salePriceAsc&listSize=36'
#     url = url.format(prod)
    
#     headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36'}
    
#     res = requests.get(url, headers = headers)
#     soup = BeautifulSoup(res.text, 'html.parser')
    
#     lis = soup.select(' a > dl > dd > div')
    
#     for li in lis:
#         if prod in li.select('div.name')[0].text:
#             print(li.select('div.name')[0].text)
#             print(li.select('strong.price-value')[0].text, '원')
#             print('===========')
#             break
# Out:
# vono 보노스프(3개입) x 1개 /보노스프 콘스프/간편식/간편한아침/간편스프/즉석스프, 01 보노 콘스프(3개입)
# 2,550 원
# ===========
# 농심 새우깡(90g)
# 1,510 원
# ===========
# 주전부리몰 오리온 닥터유 에너지바(4개입) x 5통(+밀크츄 2봉포함), 1세트
# 19,900 원
# ===========
# 청정원 오리엔탈 드레싱 325G, 옵션2 - 안전포장 플러스
# 5,000 원
# ===========
# 백설 진한참기름450ml, 1개
# 5,130 원
# ===========
# 삼육두유 삼육식품 달콤한 삼육두유 B 190ML 24개입, 1
# 19,500 원
# ===========
# [샘플사료] 밥이보약 CAT 걱정없는 헤어볼 40g 400g, [41-6] 40g
# 1,100 원
# ===========
# 밥이보약 튼튼한관절2Kg(강아지용)
# 22,500 원
# ===========
# 크리넥스 KF94 4단 마스크 대형 1매, 상세페이지 참조
# 1,040 원
# ===========
# 해태 오예스(12개입) 360g + 오뜨 쇼콜라(6개입) 150g 초콜릿 파이 초코 케익 묶음 세트, 1세트
# 7,980 원
# ===========

# %%
# url = 'https://www.coupang.com/np/search?rocketAll=false&q=%EC%82%BC%EC%96%91%EB%9D%BC%EB%A9%B4%285%EA%B0%9C%EC%9E%85%29&brand=&offerCondition=&filter=&availableDeliveryFilter=&filterType=&isPriceRange=false&priceRange=&minPrice=&maxPrice=&page=1&trcid=&traid=&filterSetByUser=true&channel=user&backgroundColor=&searchProductCount=94&component=&rating=0&sorter=salePriceAsc&listSize=36'

# %%
# headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36'}

# %%
# res = requests.get(url, headers = headers)

# %%
# soup = BeautifulSoup(res.text, 'html.parser')

# %%
# lis = soup.select(' a > dl > dd > div')
# lis
# Out:
# [<div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양라면 오리지널 멀티팩(5개입) x 1봉/봉지라면</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">43%</span> <del class="base-price"> 5,000  </del> </span> <em class="sale"> <strong class="price-value">2,800</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(1)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 140원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양라면 오리지널 120g x 5개입/멀티 1팩</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">2,900</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 145원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">농심 오뚜기 삼양 인기라면 5개 1팩 신라면 진라면 삼양라면 불닭볶음면 냄비라면 봉지라면 한강라면, 원조삼양라면 5입 1팩</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">4,200</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 210원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 원조 삼양라면 120g 5개입 멀티팩/라면/봉지면/멀티면/즉석식품 식품 &gt; 스낵/간식 스낵/시리얼 과자쿠키/비스킷/크래커 과자쿠키, 5</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">4,280</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">금요일 2/18  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 214원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 삼양라면 600g(120gX5개입) 멀티팩, 상세페이지 참조</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">4,400</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 220원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 원조 삼양라면 5개입, 2개</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">4,430</strong>원     </em> <span class="unit-price">(<em>1</em>개당 <em>2,215</em>원) </span> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:90%">4.5</em></span> <span class="rating-total-count">(504)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 221원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 삼양라면 120gX5개입 멀티 봉지라면, 5개입</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">4,800</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 240원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양라면 5개입, 옵션1 - 기본포장 (박스or비닐포장) (+0원)</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">5,250</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">금요일 2/18  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(1)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 263원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 오리지널 멀티팩(5개입) x 1봉/무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">33%</span> <del class="base-price"> 8,000  </del> </span> <em class="sale"> <strong class="price-value">5,300</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 265원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 매운맛 멀티팩(5개입) x 1봉/무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">33%</span> <del class="base-price"> 8,000  </del> </span> <em class="sale"> <strong class="price-value">5,300</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 265원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 라이트 불닭볶음면 110g 5개입, 5개</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">5,440</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 272원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양 원조 삼양라면 5개입, 5개</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">5,560</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:90%">4.5</em></span> <span class="rating-total-count">(112)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 278원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양라면 매운맛 멀티팩(5개입) x 2봉/봉지라면</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">43%</span> <del class="base-price"> 10,000  </del> </span> <em class="sale"> <strong class="price-value">5,600</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 280원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양라면 오리지널 멀티팩(5개입) x 2봉/봉지라면</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">43%</span> <del class="base-price"> 10,000  </del> </span> <em class="sale"> <strong class="price-value">5,600</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 280원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양 삼양라면 120g 5개 (멀티팩)_三養라면 since 1963 라면이 생각날때, 5개입</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">5,650</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:80%">4.0</em></span> <span class="rating-total-count">(11)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 283원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 간짬뽕 140g 5개입, 5개</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">5,670</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:20%">1.0</em></span> <span class="rating-total-count">(1)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 284원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양식품 삼양라면매운맛5개, 5개입</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">5,790</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(14)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 290원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양 삼양라면 120g 5개 (멀티팩)_三養라면 since 1963 라면이 생각날때, 5개입</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">5,900</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 295원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">[소공원]농심 삼양 오뚜기 팔도 진라면 매운맛 순한맛 삼양라면 불닭볶음면 멀티 5개입</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">7,000</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">금요일 2/18  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 350원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양라면 5개입, 옵션2 - 신선포장 (아이스박스포장)</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">7,250</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">금요일 2/18  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 363원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">농심 신라면 삼양 라면 짜파게티 불닭볶음면 얼큰한 너구리 오징어짬뽕 골라담기 (5입 멀티팩 11종), 농심 얼큰 장칼국수 103g 4입 멀티팩</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">13%</span> <del class="base-price"> 8,520  </del> </span> <em class="sale"> <strong class="price-value">7,410</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 370원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">[아맛]삼양)삼양라면(멀티) 120g_5개입, 본상품선택</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">7,990</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 400원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 원조 삼양라면 5개입, 15개</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">7,540</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:90%">4.5</em></span> <span class="rating-total-count">(112)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 377원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 오리지널 멀티팩(5개입) x 2봉/무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">37%</span> <del class="base-price"> 13,000  </del> </span> <em class="sale"> <strong class="price-value">8,100</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 405원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 매운맛 멀티팩(5개입) x 2봉/무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">37%</span> <del class="base-price"> 13,000  </del> </span> <em class="sale"> <strong class="price-value">8,100</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 405원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 멀티팩(5개입)x2봉(오리지널1＋매운맛1) 무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">37%</span> <del class="base-price"> 13,000  </del> </span> <em class="sale"> <strong class="price-value">8,100</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 405원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양 쇠고기면 5개입 x 2개, 1</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">14%</span> <del class="base-price"> 9,900  </del> </span> <em class="sale"> <strong class="price-value">8,500</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(2)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 425원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양 불닭볶음면 화끈한 매운맛 140g + 삼양라면 120g 5개입 세트, 10개입</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">8,800</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">금요일 2/18  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 440원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양 원조 삼양라면 5개입, 20개</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">10,540</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:90%">4.5</em></span> <span class="rating-total-count">(112)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 527원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">농심) 신라면 5개입 + 신라면건면 5개입 총10개입, 10개</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">28%</span> <del class="base-price"> 15,300  </del> </span> <em class="sale"> <strong class="price-value">10,900</strong>원     </em> <span class="unit-price">(<em>1</em>개당 <em>1,090</em>원) </span> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:90%">4.5</em></span> <span class="rating-total-count">(52)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 545원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 멀티팩(5개입)x3봉(오리지널2＋매운맛1) 무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">39%</span> <del class="base-price"> 18,000  </del> </span> <em class="sale"> <strong class="price-value">10,900</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 545원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 오리지널 멀티팩(5개입) x 3봉/무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">39%</span> <del class="base-price"> 18,000  </del> </span> <em class="sale"> <strong class="price-value">10,900</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(2)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 545원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 멀티팩(5개입)x3봉(매운맛2＋오리지널1) 무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">39%</span> <del class="base-price"> 18,000  </del> </span> <em class="sale"> <strong class="price-value">10,900</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 545원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">삼양라면 매운맛 멀티팩(5개입) x 3봉/무배</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">39%</span> <del class="base-price"> 18,000  </del> </span> <em class="sale"> <strong class="price-value">10,900</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 545원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> </div><div class="name">삼양라면 매운맛 멀티팩(5개입) x 4봉/봉지라면</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <span class="price-info"> <span class="instant-discount-rate">43%</span> <del class="base-price"> 20,000  </del> </span> <em class="sale"> <strong class="price-value">11,200</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 2/19  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 560원 적립</span></div></div></div> </div>,
#  <div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery">무료배송</span> </div><div class="name">[아맛]삼양)불닭볶음면(멀티) 140g_5개입, 본상품선택</div> <div class="price-area"> <div class="price-wrap"><div class="price"> <em class="sale"> <strong class="price-value">11,510</strong>원     </em> </div><!-- Free Shipping Badge -->
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">모레(목) 2/17  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div> </div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 575원 적립</span></div></div></div> </div>]

# %%
# for li in lis:
#     print(li.select('strong.price-value')[0].text)
# Out:
# 3,290
# 3,660
# 6,300
# 7,500
# 7,510
# 8,700
# 8,700
# 9,040
# 10,450
# 11,100
# 12,000
# 12,330
# 12,790
# 14,900
# 15,670
# 19,900
# 30,800
# 50,900
# 11,090
